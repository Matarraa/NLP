# %%
import pandas as pd
import gzip
import json
import re
from collections import Counter
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
import stanza
from tqdm import tqdm
from nltk.collocations import *

# %% [markdown]
# ### Выкачиваем данные

# %%
reviews = []
for line in open ('Office_Products_5.json', 'r', encoding='utf-8'):
    reviews.append(json.loads(line))

# %%
metadata = []
for line in open ('meta_Office_Products.json', 'r', encoding='utf-8'):
    metadata.append(json.loads(line))

# %%
metadata = {elem['asin'] : {'category' : elem['category'], 
                            'title' : elem['title'], 
                            'brand': elem['brand'] if 'title' in elem.keys() else ''} for elem in metadata}

# %%
data = []
for review in reviews:
    try:
        d = {}
        d['review'] = review['reviewText']
        d['asin'] = review['asin']
        d['category'] = metadata[review['asin']]['category']
        d['title'] = metadata[review['asin']]['title']
        d['brand'] = metadata[review['asin']]['brand']
        data.append(d)
    except:
        continue

# %%
df = pd.DataFrame(data)
df
df.to_csv('data_office_products.csv')

# %% [markdown]
# # 3 способа найти упоминания товаров в отзывах

# %% [markdown]
# #### 1. Использовать модели для извлечения именованных сущностей (например, stanza)
#
# Минусы:
# - обработка занимает много времени
# - вероятно, получится не совсем идеально
# - названия офисной техники специфические, не факт, что пользователи будут в отзывах писать именно названия, а не тип продукта (например, в отзывах часто встречается чисто название без упоминания типа продукта)
#
# Плюсы:
# - скорее всего получится вытащить упоминание названий продукта из отзывов
# - извлеченные названия можно использовать для дальнейшего объединения с типами продукта, что позволит посмотреть извлечь из отзыва больше полезной информации о товаре
#
# #### 2. Извлечь типы товаров из названий или категорий и затем посмотреть на n-граммы с ними в отзывах
#
# Минусы:
# - вероятно, не получится отследить названия товаров, поскольку они часто встречаются без упоминания типа продукта (например: "I bought my first HP12C in about 1984 or so")
# - пользователи могут называть товар иначе (синонимом)
#
# Плюсы:
# - типы продуктов достаточно легко извлечь из их названий
#
# #### 3. Векторизовать корпус c помощью word2vec
#
# Минусы:
# - упоминания товаров могут состоять из >1 слова, следовательно надо думать над n-граммами
# - этот способ не кажется сильно хорошим для выбранного корпуса, поскольку названия типов товаров зачастую не имеют синонимов => вряд ли получится сгруппировать упоминания одного товара и его синонимичных названий
#
# Плюсы:
# - Можно сгруппировать упоминания одного товара и его синонимичных названий
# - Достаточно быстро

# %% [markdown]
# ### Что выбираем?
# Попробуем объединить два способа:
# 1) достанем названия продуктов с помощью stanza
# 2) достанем типы продуктов из названий и/или категорий
#
# Затем посмотрим в отзывах на биграммы с вытащенными сущностями. Плюс использование этих двух способов в совокупности может помочь объединить название товара с его типом, которые в какой-то мере можно считать синонимичными.

# %% [markdown]
# Выделим категории товаров

# %%
categories = []
for item in df['category']:
    categories = categories + [category for category in item]
categories = set(categories)

# %% [markdown]
# Достанем типы товаров из названий категорий

# %%
goods = []
for category in categories:
    doc = nlp(category)
    for sent in doc.sentences:
        for word in sent.words:
            if word.upos == 'NOUN':
                goods.append(word.lemma.lower())

# %% [markdown]
# #### Попробуем также выделить названия типов товаров из их названий.
# Названия товаров в этой категории достаточно длинные и имеют большое количество доп. информации о товаре. Тип товара обычно стоит:
# - либо перед первой запятой, после которой идут уточнения
# - либо перед "for" или "with"
# - либо в конце названия (если нет запятых)
# - либо в конце перед артикулом, который в скобках

# %%
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# #### Извлечем типы товаров из названий

# %%
goods_titles = []
for title in df['title']:
    title = title.split(',')[0] #делим по запятой и берем первую часть, так как в ней содержится название
    title = re.sub(r' .+&quot', r' ', title)
    title = re.sub(r'[ \(]+[0-9A-Z\-\# ]+[ \)]+', r' ', title) #убираем все цифры и коды
    title = re.sub(r' [a-zA-Z0-9]+-[a-z]+ ', ' ', title)
    title = re.sub(r'\(.+\)', '', title)
    title = re.sub(r' +', ' ', title)
    title = title[:-1] if title[-1] == ' ' else title
    try:
        match = re.search(r' ([A-Z][a-z]+)( [for|with|pro])', title)
        if match:
            product = lemmatizer.lemmatize(match[1].lower())
            goods_titles.append(product)
        elif re.search(r'[0-9]', title.split(' ')[-1]) or title.split(' ')[-1].startswith('-'):
            if re.fullmatch('[a-z]+', lemmatizer.lemmatize(title.split(' ')[-2].lower())):
                product = lemmatizer.lemmatize(title.split(' ')[-2].lower())
                goods_titles.append(product)
            else:
                product = lemmatizer.lemmatize(title.split(' ')[-3].lower())
                goods_titles.append(product)
        elif re.fullmatch('[a-z]+', lemmatizer.lemmatize(title.split(' ')[-1].lower())):
            product = lemmatizer.lemmatize(title.split(' ')[-1].lower())
            goods_titles.append(product)
        else:
            goods_titles.append('')
    except:
        goods_titles.append('')
        continue
df['product'] = goods_titles

# %% [markdown]
# Получилось, если честно, не ососбо чисто

# %%
set(goods_titles)
# Out:
# {'',
#  'accessory',
#  'adapter',
#  'adf',
#  'adhesive',
#  'aerosol',
#  'all',
#  'arm',
#  'badge',
#  'bag',
#  'ball',
#  'ballpoint',
#  'base',
#  'bell',
#  'binder',
#  'black',
#  'blade',
#  'block',
#  'board',
#  'body',
#  'book',
#  'bookend',
#  'box',
#  'bridge',
#  'builder',
#  'bundle',
#  'calculator',
#  'calendar',
#  'callisto',
#  'canister',
#  'card',
#  'cardstock',
#  'cart',
#  'cartridge',
#  'case',
#  'cement',
#  'center',
#  'chair',
#  'chairmat',
#  'chalk',
#  'charger',
#  'clear',
#  'clip',
#  'cm',
#  'color',
#  'companion',
#  'compatible',
#  'construction',
#  'converter',
#  'copier',
#  'copyholder',
#  'cosmic',
#  'count',
#  'cover',
#  'cube',
#  'cup',
#  'cushion',
#  'cutter',
#  'cyan',
#  'darkness',
#  'design',
#  'desk',
#  'dictionary',
#  'disappear',
#  'dispenser',
#  'divider',
#  'document',
#  'doorstop',
#  'dpi',
#  'drawer',
#  'easel',
#  'edge',
#  'electric',
#  'envelope',
#  'eprinter',
#  'epson',
#  'eraser',
#  'fastener',
#  'fax',
#  'featuring',
#  'fellowes',
#  'file',
#  'filer',
#  'film',
#  'fine',
#  'finger',
#  'finish',
#  'flag',
#  'fluid',
#  'folder',
#  'footrest',
#  'frame',
#  'glossy',
#  'glue',
#  'gold',
#  'grey',
#  'guide',
#  'handle',
#  'handset',
#  'highlighter',
#  'holder',
#  'imagescanner',
#  'inch',
#  'included',
#  'individually',
#  'ink',
#  'jack',
#  'jacket',
#  'keeper',
#  'keyboard',
#  'keyrack',
#  'kit',
#  'label',
#  'labeler',
#  'laminator',
#  'laser',
#  'laserjet',
#  'lb',
#  'lead',
#  'letter',
#  'liner',
#  'liquid',
#  'list',
#  'loft',
#  'logitech',
#  'machine',
#  'made',
#  'magenta',
#  'magnet',
#  'mailer',
#  'maker',
#  'mar',
#  'marker',
#  'mat',
#  'medium',
#  'metal',
#  'model',
#  'moistener',
#  'monochrome',
#  'multifunction',
#  'neptune',
#  'networking',
#  'note',
#  'notebinder',
#  'notebook',
#  'notepad',
#  'notetabs',
#  'oil',
#  'opener',
#  'optional',
#  'organizer',
#  'organizher',
#  'outdoor',
#  'pack',
#  'packaging',
#  'pad',
#  'page',
#  'pair',
#  'paper',
#  'park',
#  'peanut',
#  'peel',
#  'pen',
#  'pencil',
#  'phone',
#  'photo',
#  'pin',
#  'pixma',
#  'planner',
#  'plastic',
#  'platform',
#  'platinum',
#  'plus',
#  'pocket',
#  'pockettabs',
#  'portfolio',
#  'pouch',
#  'powershred',
#  'presenter',
#  'print',
#  'printer',
#  'printing',
#  'pro',
#  'projector',
#  'protector',
#  'qty',
#  'rack',
#  'record',
#  'reel',
#  'refill',
#  'reinforcement',
#  'reliability',
#  'remote',
#  'remover',
#  'replacement',
#  'rest',
#  'riser',
#  'rocker',
#  'roll',
#  'scale',
#  'scanner',
#  'scansnap',
#  'scheduler',
#  'sealer',
#  'set',
#  'sharpener',
#  'sheet',
#  'shelf',
#  'shredder',
#  'sided',
#  'sign',
#  'signage',
#  'silver',
#  'silvertech',
#  'solution',
#  'sorter',
#  'speakerphone',
#  'stamp',
#  'stand',
#  'staple',
#  'stapler',
#  'station',
#  'stick',
#  'stock',
#  'stool',
#  'stop',
#  'storage',
#  'surface',
#  'swivel',
#  'system',
#  'tab',
#  'tag',
#  'tank',
#  'tape',
#  'telephone',
#  'telezapper',
#  'tft',
#  'thing',
#  'ticket',
#  'tile',
#  'tip',
#  'toner',
#  'topper',
#  'transfer',
#  'transparent',
#  'tray',
#  'trimmer',
#  'unit',
#  'up',
#  'vary',
#  'venus',
#  'version',
#  'warranty',
#  'weighmax',
#  'weight',
#  'white',
#  'whiteboard',
#  'whiteboards',
#  'wide',
#  'wireless',
#  'woodgrain',
#  'wrap',
#  'wrapper',
#  'x'}

# %% [markdown]
# Но если посмотреть на самые частотные, становится лучше

# %%
dict_titles = Counter(goods_titles)
dict_titles.most_common(50)
# Out:
# [('printer', 2944),
#  ('label', 1429),
#  ('binder', 901),
#  ('dispenser', 889),
#  ('folder', 887),
#  ('pad', 828),
#  ('marker', 823),
#  ('tape', 822),
#  ('note', 807),
#  ('pen', 777),
#  ('stapler', 750),
#  ('paper', 673),
#  ('cartridge', 654),
#  ('box', 619),
#  ('sharpener', 556),
#  ('envelope', 511),
#  ('board', 475),
#  ('scanner', 450),
#  ('rest', 425),
#  ('pencil', 351),
#  ('phone', 342),
#  ('laminator', 293),
#  ('kit', 291),
#  ('set', 251),
#  ('shredder', 246),
#  ('pocket', 244),
#  ('card', 238),
#  ('calculator', 237),
#  ('eraser', 235),
#  ('system', 234),
#  ('sheet', 230),
#  ('divider', 222),
#  ('pack', 208),
#  ('tab', 207),
#  ('pouch', 204),
#  ('notebook', 193),
#  ('organizer', 192),
#  ('protector', 189),
#  ('holder', 188),
#  ('tank', 175),
#  ('notetabs', 175),
#  ('maker', 173),
#  ('pockettabs', 145),
#  ('ticket', 144),
#  ('scale', 137),
#  ('flag', 129),
#  ('machine', 128),
#  ('edge', 123),
#  ('liquid', 121),
#  ('black', 117)]

# %% [markdown]
# #### Сравним с товарами, извлеченными из категорий

# %%
dict_categories = Counter(goods)
dict_categories.most_common(50)
# Out:
# [('&amp', 41),
#  ('printer', 17),
#  ('card', 16),
#  ('tape', 15),
#  ('supply', 14),
#  ('label', 13),
#  ('envelope', 11),
#  ('holder', 11),
#  ('accessory', 11),
#  ('paper', 10),
#  ('stand', 10),
#  ('desk', 10),
#  ('pad', 10),
#  ('office', 10),
#  ('index', 10),
#  ('folder', 10),
#  ('pencil', 9),
#  ('file', 9),
#  ('binder', 8),
#  ('adhesive', 8),
#  ('scanner', 8),
#  ('product', 8),
#  ('eraser', 7),
#  ('correction', 7),
#  ('box', 7),
#  ('laser', 6),
#  ('pen', 6),
#  ('stamp', 6),
#  ('organizer', 6),
#  ('stapler', 6),
#  ('dispenser', 6),
#  ('business', 6),
#  ('planner', 6),
#  ('refill', 5),
#  ('cart', 5),
#  ('inkjet', 5),
#  ('storage', 5),
#  ('notebook', 5),
#  ('mailer', 5),
#  ('glue', 5),
#  ('binding', 4),
#  ('book', 4),
#  ('stick', 4),
#  ('pocket', 4),
#  ('calendar', 4),
#  ('board', 4),
#  ('badge', 4),
#  ('form', 4),
#  ('chair', 4),
#  ('photo', 4)]

# %%
print('Тип товара не удалось извлечь у ', len(set(df[df['product']=='']['title'])), 'товаров. \nКоличество отзывов на данные товары в базе: ', len(df[df['product']=='']))
# Out:
# Тип товара не удалось извлечь у  47 товаров.
# Количество отзывов на данные товары в базе:  993

# %% [markdown]
# ### Теперь воспользуемся Stanza для извлечения названий товаров из отзывов.

# %%
nlp = stanza.Pipeline(lang='en', processors='tokenize,lemma,pos,ner')
# Out:
# 2022-12-15 01:00:18 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/tokenize/combined.pt:   0%|    …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/pos/combined.pt:   0%|         …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/lemma/combined.pt:   0%|       …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/ner/ontonotes.pt:   0%|        …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/backward_charlm/1billion.pt:   …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/pretrain/fasttextcrawl.pt:   0%…
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/forward_charlm/1billion.pt:   0…
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/pretrain/combined.pt:   0%|    …
# 2022-12-15 01:01:12 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | pos       | combined  |
# | lemma     | combined  |
# | ner       | ontonotes |
# =========================
#
# 2022-12-15 01:01:12 INFO: Use device: cpu
# 2022-12-15 01:01:12 INFO: Loading: tokenize
# 2022-12-15 01:01:12 INFO: Loading: pos
# 2022-12-15 01:01:12 INFO: Loading: lemma
# 2022-12-15 01:01:12 INFO: Loading: ner
# 2022-12-15 01:01:13 INFO: Done loading processors!

# %% [markdown]
# Так как Stanza работает достаточно долго, не будем обрабатывать всю базу, а возьмем из нее 5 разных (согласно извлеченным типам из названий): printer, calculator, stapler, marker, binder, dispenser

# %%
new_df = df[df['product'].isin(['printer', 'binder', 'dispenser', 'folder', 'stapler', 'calculator'])]

# %%
product_name = []
for text in tqdm(new_df['review']): 
    products = []
    doc = nlp(text)
    for sent in doc.sentences:
        for ent in sent.ents:
            if ent.type == 'PRODUCT':
                products.append(ent.text)
    product_name.append(products)
# Out:
# 100%|██████████| 7379/7379 [8:22:28<00:00,  4.09s/it]

# %%
new_df['NE'] = [list(set(names)) for names in product_name]
# Out:
# <ipython-input-295-29185988adeb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['NE'] = [list(set(names)) for names in product_name]

# %%
new_df.to_csv('new_data_office.csv')

# %% [markdown]
# ### Собираем n-граммы

# %% [markdown]
# Сойдемся на том, что в отзыве автор пишет об одном товаре, то есть, если в названии пользователь упоминает название продукта и оно есть в официальном названии продукта, то мы имеем право заменить упомянутое название на тип продукта.

# %%
def review_preprocessing (review, product, title, NE): 
    for el in set(NE):
        if el in title:
            review = review.replace(el, ' '+product+' ')
        else:
            continue
            
    new_review = ''
    tokens = word_tokenize(review.lower())
    for i in tokens:
        if i.isalpha():
            new_review = new_review + lemmatizer.lemmatize(i) + ' '
    return new_review

# %%
changed_reviews = []
for review, product, title, NE in zip(new_df['review'],  new_df['product'], new_df['title'], new_df['NE']):
    new_review = review_preprocessing (review, product, title, NE)
    changed_reviews.append(new_review)

# %%
new_df['new_review'] = changed_reviews
# Out:
# <ipython-input-313-bcb0ecf26fc8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['new_review'] = changed_reviews

# %% [markdown]
# #### Биграммы

# %%
product_names = ['printer', 'binder', 'dispenser', 'folder', 'stapler', 'calculator']

# %%
bigrams = ngrams(' '.join(new_df['new_review']).split(), 2)

# %%
bi_dict = Counter(bigrams)

# %%
product_bigrams = {'printer':[], 'binder':[], 'dispenser':[], 'folder':[], 'stapler':[], 'calculator':[]}
    
for bigram in bi_dict.most_common():
    for product in product_bigrams.keys():
        if product in bigram[0]:
            product_bigrams[product].append(bigram)

# %%
product_bigrams
# Out:
# {'printer': [(('the', 'printer'), 6406),
#   (('this', 'printer'), 3885),
#   (('printer', 'is'), 1898),
#   (('printer', 'and'), 1337),
#   (('printer', 'i'), 1335),
#   (('printer', 'for'), 937),
#   (('a', 'printer'), 871),
#   (('laser', 'printer'), 707),
#   (('printer', 'to'), 692),
#   (('printer', 'that'), 684),
#   (('epson', 'printer'), 582),
#   (('printer', 'the'), 567),
#   (('printer', 'it'), 557),
#   (('photo', 'printer'), 460),
#   (('printer', 'ha'), 440),
#   (('printer', 'but'), 437),
#   (('printer', 'wa'), 427),
#   (('printer', 'in'), 419),
#   (('printer', 'with'), 406),
#   (('inkjet', 'printer'), 370),
#   (('printer', 'a'), 345),
#   (('other', 'printer'), 339),
#   (('hp', 'printer'), 296),
#   (('canon', 'printer'), 294),
#   (('printer', 'doe'), 283),
#   (('my', 'printer'), 276),
#   (('wireless', 'printer'), 273),
#   (('printer', 'this'), 271),
#   (('printer', 'on'), 267),
#   (('printer', 'printer'), 239),
#   (('printer', 'will'), 235),
#   (('of', 'printer'), 217),
#   (('new', 'printer'), 215),
#   (('great', 'printer'), 213),
#   (('printer', 'are'), 210),
#   (('printer', 'you'), 203),
#   (('printer', 'so'), 201),
#   (('printer', 'which'), 191),
#   (('your', 'printer'), 190),
#   (('printer', 'if'), 182),
#   (('printer', 'at'), 171),
#   (('printer', 'from'), 167),
#   (('printer', 'can'), 151),
#   (('workforce', 'printer'), 147),
#   (('printer', 'itself'), 140),
#   (('color', 'printer'), 135),
#   (('good', 'printer'), 128),
#   (('and', 'printer'), 127),
#   (('old', 'printer'), 122),
#   (('printer', 'have'), 117),
#   (('printer', 'also'), 112),
#   (('brother', 'printer'), 110),
#   (('home', 'printer'), 110),
#   (('printer', 'come'), 109),
#   (('printer', 'or'), 107),
#   (('printer', 'because'), 106),
#   (('printer', 'driver'), 106),
#   (('printer', 'print'), 103),
#   (('printer', 'up'), 103),
#   (('one', 'printer'), 103),
#   (('office', 'printer'), 102),
#   (('printer', 'when'), 96),
#   (('printer', 'work'), 96),
#   (('printer', 'would'), 92),
#   (('printer', 'over'), 90),
#   (('printer', 'we'), 90),
#   (('printer', 'scanner'), 87),
#   (('printer', 'like'), 83),
#   (('printer', 'ink'), 82),
#   (('little', 'printer'), 80),
#   (('pixma', 'printer'), 79),
#   (('any', 'printer'), 78),
#   (('printer', 'us'), 77),
#   (('printer', 'cartridge'), 76),
#   (('printer', 'copier'), 74),
#   (('printer', 'there'), 72),
#   (('printer', 'cable'), 71),
#   (('format', 'printer'), 71),
#   (('printer', 'software'), 71),
#   (('multifunction', 'printer'), 71),
#   (('jet', 'printer'), 70),
#   (('most', 'printer'), 70),
#   (('that', 'printer'), 66),
#   (('printer', 'wireless'), 66),
#   (('printer', 'of'), 66),
#   (('printer', 'my'), 65),
#   (('printer', 'not'), 63),
#   (('these', 'printer'), 63),
#   (('quality', 'printer'), 63),
#   (('previous', 'printer'), 63),
#   (('printer', 'after'), 62),
#   (('printer', 'paper'), 62),
#   (('with', 'printer'), 62),
#   (('nice', 'printer'), 62),
#   (('an', 'printer'), 61),
#   (('printer', 'did'), 61),
#   (('printer', 'before'), 60),
#   (('another', 'printer'), 60),
#   (('to', 'printer'), 60),
#   (('printer', 'just'), 59),
#   (('printer', 'however'), 59),
#   (('usb', 'printer'), 58),
#   (('printer', 'take'), 58),
#   (('both', 'printer'), 57),
#   (('many', 'printer'), 57),
#   (('printer', 'out'), 55),
#   (('monochrome', 'printer'), 55),
#   (('best', 'printer'), 53),
#   (('printer', 'do'), 53),
#   (('first', 'printer'), 53),
#   (('their', 'printer'), 52),
#   (('printer', 'since'), 51),
#   (('excellent', 'printer'), 51),
#   (('printer', 'setup'), 51),
#   (('printer', 'had'), 49),
#   (('printer', 'using'), 49),
#   (('last', 'printer'), 49),
#   (('printer', 'without'), 48),
#   (('samsung', 'printer'), 48),
#   (('printer', 'via'), 48),
#   (('printer', 'they'), 46),
#   (('all', 'printer'), 45),
#   (('printer', 'even'), 45),
#   (('network', 'printer'), 44),
#   (('printer', 'by'), 42),
#   (('printer', 'should'), 41),
#   (('for', 'printer'), 41),
#   (('printer', 'set'), 41),
#   (('kodak', 'printer'), 41),
#   (('on', 'printer'), 40),
#   (('printer', 'could'), 40),
#   (('printer', 'seems'), 39),
#   (('printer', 'head'), 38),
#   (('small', 'printer'), 38),
#   (('printer', 'were'), 37),
#   (('printer', 'while'), 37),
#   (('printer', 'all'), 37),
#   (('printer', 'then'), 37),
#   (('pro', 'printer'), 37),
#   (('printer', 'offer'), 37),
#   (('printer', 'go'), 36),
#   (('in', 'printer'), 36),
#   (('printer', 'look'), 36),
#   (('printer', 'setting'), 35),
#   (('printer', 'epson'), 35),
#   (('printer', 'make'), 35),
#   (('printer', 'control'), 35),
#   (('printer', 'one'), 34),
#   (('older', 'printer'), 34),
#   (('printer', 'an'), 34),
#   (('two', 'printer'), 34),
#   (('solid', 'printer'), 33),
#   (('printer', 'no'), 33),
#   (('printer', 'now'), 33),
#   (('printer', 'where'), 33),
#   (('basic', 'printer'), 33),
#   (('decent', 'printer'), 32),
#   (('printer', 'than'), 32),
#   (('large', 'printer'), 32),
#   (('big', 'printer'), 32),
#   (('fantastic', 'printer'), 32),
#   (('printer', 'feature'), 32),
#   (('expensive', 'printer'), 31),
#   (('printer', 'really'), 31),
#   (('printer', 'although'), 31),
#   (('printer', 'manufacturer'), 31),
#   (('some', 'printer'), 31),
#   (('printer', 'cost'), 30),
#   (('printer', 'worked'), 30),
#   (('printer', 'off'), 29),
#   (('printer', 'through'), 29),
#   (('printer', 'may'), 29),
#   (('reliable', 'printer'), 29),
#   (('printer', 'only'), 29),
#   (('printer', 'into'), 29),
#   (('fast', 'printer'), 28),
#   (('printer', 'star'), 28),
#   (('same', 'printer'), 28),
#   (('printer', 'first'), 28),
#   (('printer', 'connected'), 28),
#   (('regular', 'printer'), 28),
#   (('printer', 'need'), 28),
#   (('printer', 'came'), 28),
#   (('printer', 'very'), 27),
#   (('printer', 'until'), 27),
#   (('from', 'printer'), 27),
#   (('printer', 'canon'), 27),
#   (('printer', 'both'), 27),
#   (('printer', 'get'), 27),
#   (('printer', 'these'), 27),
#   (('printer', 'produce'), 26),
#   (('printer', 'model'), 26),
#   (('better', 'printer'), 26),
#   (('printer', 'use'), 25),
#   (('printer', 'photo'), 25),
#   (('printer', 'once'), 24),
#   (('perfect', 'printer'), 24),
#   (('printer', 'including'), 24),
#   (('business', 'printer'), 24),
#   (('only', 'printer'), 23),
#   (('white', 'printer'), 23),
#   (('document', 'printer'), 23),
#   (('printer', 'function'), 23),
#   (('cheap', 'printer'), 23),
#   (('compact', 'printer'), 23),
#   (('printer', 'overall'), 22),
#   (('printer', 'color'), 22),
#   (('or', 'printer'), 22),
#   (('inexpensive', 'printer'), 22),
#   (('wifi', 'printer'), 22),
#   (('different', 'printer'), 21),
#   (('printer', 'though'), 21),
#   (('printer', 'instead'), 21),
#   (('ink', 'printer'), 21),
#   (('printer', 'easy'), 21),
#   (('printer', 'scan'), 21),
#   (('printer', 'company'), 21),
#   (('printer', 'such'), 21),
#   (('printer', 'wirelessly'), 21),
#   (('printer', 'stand'), 21),
#   (('use', 'printer'), 21),
#   (('particular', 'printer'), 20),
#   (('printer', 'usb'), 20),
#   (('our', 'printer'), 20),
#   (('printer', 'still'), 20),
#   (('label', 'printer'), 20),
#   (('heavy', 'printer'), 20),
#   (('printer', 'right'), 20),
#   (('printer', 'directly'), 20),
#   (('printer', 'took'), 20),
#   (('printer', 'inkjet'), 20),
#   (('standard', 'printer'), 19),
#   (('printer', 'back'), 19),
#   (('printer', 'support'), 19),
#   (('printer', 'used'), 19),
#   (('default', 'printer'), 19),
#   (('printer', 'workforce'), 19),
#   (('printer', 'printing'), 19),
#   (('printer', 'durabrite'), 19),
#   (('printer', 'being'), 18),
#   (('printer', 'requires'), 18),
#   (('printer', 'again'), 18),
#   (('end', 'printer'), 18),
#   (('printer', 'more'), 18),
#   (('few', 'printer'), 18),
#   (('printer', 'well'), 17),
#   (('fastest', 'printer'), 17),
#   (('have', 'printer'), 17),
#   (('printer', 'quality'), 17),
#   (('printer', 'arrived'), 17),
#   (('printer', 'firmware'), 17),
#   (('printer', 'especially'), 17),
#   (('three', 'printer'), 16),
#   (('printer', 'too'), 16),
#   (('wonderful', 'printer'), 16),
#   (('newer', 'printer'), 16),
#   (('model', 'printer'), 16),
#   (('printer', 'easily'), 16),
#   (('printer', 'allows'), 16),
#   (('printer', 'went'), 16),
#   (('printer', 'fax'), 16),
#   (('artisan', 'printer'), 16),
#   (('printer', 'today'), 16),
#   (('premium', 'printer'), 16),
#   (('series', 'printer'), 15),
#   (('each', 'printer'), 15),
#   (('is', 'printer'), 15),
#   (('aio', 'printer'), 15),
#   (('several', 'printer'), 15),
#   (('printer', 'some'), 15),
#   (('fine', 'printer'), 15),
#   (('size', 'printer'), 15),
#   (('printer', 'give'), 15),
#   (('printer', 'within'), 15),
#   (('printer', 'installation'), 15),
#   (('expression', 'printer'), 15),
#   (('personal', 'printer'), 14),
#   (('printer', 'available'), 14),
#   (('printer', 'hp'), 14),
#   (('printer', 'died'), 14),
#   (('printer', 'automatically'), 14),
#   (('entire', 'printer'), 14),
#   (('printer', 's'), 14),
#   (('based', 'printer'), 14),
#   (('level', 'printer'), 14),
#   (('printer', 'unless'), 14),
#   (('up', 'printer'), 14),
#   (('printer', 'what'), 13),
#   (('laserjet', 'printer'), 13),
#   (('printer', 'last'), 13),
#   (('cheaper', 'printer'), 13),
#   (('professional', 'printer'), 13),
#   (('it', 'printer'), 13),
#   (('printer', 'lcd'), 13),
#   (('larger', 'printer'), 13),
#   (('printer', 'provides'), 13),
#   (('second', 'printer'), 13),
#   (('printer', 'menu'), 13),
#   (('smaller', 'printer'), 13),
#   (('printer', 'turn'), 12),
#   (('printer', 'under'), 12),
#   (('printer', 'printed'), 12),
#   (('printer', 'website'), 12),
#   (('cannon', 'printer'), 12),
#   (('printer', 'plus'), 12),
#   (('than', 'printer'), 12),
#   (('simple', 'printer'), 12),
#   (('printer', 'wo'), 12),
#   (('printer', 'product'), 12),
#   (('printer', 'installed'), 12),
#   (('worst', 'printer'), 12),
#   (('are', 'printer'), 12),
#   (('printer', 'about'), 12),
#   (('brand', 'printer'), 12),
#   (('printer', 'hold'), 12),
#   (('printer', 'option'), 12),
#   (('those', 'printer'), 12),
#   (('printer', 'rather'), 12),
#   (('capable', 'printer'), 12),
#   (('no', 'printer'), 12),
#   (('printer', 'status'), 12),
#   (('using', 'printer'), 12),
#   (('printer', 'most'), 12),
#   (('fax', 'printer'), 12),
#   (('printer', 'anywhere'), 12),
#   (('printer', 'fit'), 12),
#   (('printer', 'screen'), 12),
#   (('similar', 'printer'), 12),
#   (('priced', 'printer'), 12),
#   (('printer', 'cord'), 12),
#   (('easy', 'printer'), 12),
#   (('printer', 'app'), 12),
#   (('cartridge', 'printer'), 11),
#   (('actual', 'printer'), 11),
#   (('scanner', 'printer'), 11),
#   (('earlier', 'printer'), 11),
#   (('more', 'printer'), 11),
#   (('printer', 'made'), 11),
#   (('printer', 'other'), 11),
#   (('replacement', 'printer'), 11),
#   (('print', 'printer'), 11),
#   (('printer', 'seem'), 11),
#   (('main', 'printer'), 11),
#   (('printer', 'during'), 11),
#   (('printer', 'pro'), 11),
#   (('wired', 'printer'), 11),
#   (('printer', 'let'), 11),
#   (('printer', 'yet'), 11),
#   (('printer', 'display'), 11),
#   (('budget', 'printer'), 11),
#   (('workhorse', 'printer'), 11),
#   (('awesome', 'printer'), 11),
#   (('primary', 'printer'), 11),
#   (('printer', 'pixma'), 11),
#   (('printer', 'replaced'), 11),
#   (('printer', 'tray'), 10),
#   (('black', 'printer'), 10),
#   (('printer', 'great'), 10),
#   (('own', 'printer'), 10),
#   (('photosmart', 'printer'), 10),
#   (('printer', 'around'), 10),
#   (('lexmark', 'printer'), 10),
#   (('next', 'printer'), 10),
#   (('very', 'printer'), 10),
#   (('printer', 'keep'), 10),
#   (('like', 'printer'), 10),
#   (('printer', 'wired'), 10),
#   (('printer', 'box'), 10),
#   (('printer', 'output'), 10),
#   (('matrix', 'printer'), 10),
#   (('function', 'printer'), 10),
#   (('printer', 'profile'), 10),
#   (('printer', 'touch'), 10),
#   (('esp', 'printer'), 10),
#   (('every', 'printer'), 10),
#   (('looking', 'printer'), 10),
#   (('printer', 'property'), 10),
#   (('but', 'printer'), 10),
#   (('printer', 'meet'), 10),
#   (('amazing', 'printer'), 10),
#   (('printer', 'port'), 9),
#   (('printer', 'ca'), 9),
#   (('printer', 'compared'), 9),
#   (('which', 'printer'), 9),
#   (('printer', 'be'), 9),
#   (('printer', 'put'), 9),
#   (('printer', 'user'), 9),
#   (('quiet', 'printer'), 9),
#   (('overall', 'printer'), 9),
#   (('at', 'printer'), 9),
#   (('printer', 'ip'), 9),
#   (('printer', 'say'), 9),
#   (('printer', 'every'), 9),
#   (('printer', 'size'), 9),
#   (('printer', 'unit'), 9),
#   (('printer', 'here'), 9),
#   (('work', 'printer'), 9),
#   (('huge', 'printer'), 9),
#   (('printer', 'might'), 9),
#   (('printer', 'fan'), 9),
#   (('loading', 'printer'), 9),
#   (('printer', 'capability'), 9),
#   (('about', 'printer'), 9),
#   (('printer', 'mostly'), 9),
#   (('printer', 'actually'), 9),
#   (('printer', 'sometimes'), 9),
#   (('printer', 'manual'), 9),
#   (('printer', 'highly'), 9),
#   (('printer', 'email'), 9),
#   (('apple', 'printer'), 9),
#   (('printer', 'found'), 9),
#   (('printer', 'immediately'), 9),
#   (('multiple', 'printer'), 9),
#   (('printer', 'delivers'), 9),
#   (('what', 'printer'), 8),
#   (('by', 'printer'), 8),
#   (('printer', 'include'), 8),
#   (('w', 'printer'), 8),
#   (('printer', 'simply'), 8),
#   (('printer', 'two'), 8),
#   (('printer', 'several'), 8),
#   (('printer', 'much'), 8),
#   (('printer', 'stopped'), 8),
#   (('existing', 'printer'), 8),
#   (('printer', 'black'), 8),
#   (('printer', 'started'), 8),
#   (('printer', 'often'), 8),
#   (('printer', 'many'), 8),
#   (('printer', 'ever'), 8),
#   (('printer', 'start'), 8),
#   (('printer', 'seemed'), 8),
#   (('printing', 'printer'), 8),
#   (('box', 'printer'), 8),
#   (('current', 'printer'), 8),
#   (('printer', 'large'), 8),
#   (('desktop', 'printer'), 8),
#   (('printer', 'hardware'), 8),
#   (('printer', 'laser'), 8),
#   (('printer', 'design'), 8),
#   (('printer', 'update'), 8),
#   (('pigment', 'printer'), 8),
#   (('ok', 'printer'), 8),
#   (('printer', 'scanning'), 8),
#   (('printer', 'includes'), 8),
#   (('printer', 'toner'), 8),
#   (('printer', 'series'), 8),
#   (('enabled', 'printer'), 8),
#   (('printer', 'performs'), 8),
#   (('printer', 'next'), 8),
#   (('printer', 'hooked'), 8),
#   (('four', 'printer'), 8),
#   (('printer', 'finally'), 8),
#   (('printer', 'must'), 8),
#   (('printer', 'sitting'), 8),
#   (('duty', 'printer'), 8),
#   (('printer', 'line'), 8),
#   (('printer', 'nor'), 8),
#   (('networked', 'printer'), 8),
#   (('printer', 'connect'), 8),
#   (('printer', 'initially'), 7),
#   (('printer', 'having'), 7),
#   (('comparable', 'printer'), 7),
#   (('around', 'printer'), 7),
#   (('printer', 'utility'), 7),
#   (('printer', 'away'), 7),
#   (('x', 'printer'), 7),
#   (('printer', 'power'), 7),
#   (('dell', 'printer'), 7),
#   (('printer', 'far'), 7),
#   (('printer', 'yes'), 7),
#   (('separate', 'printer'), 7),
#   (('printer', 'lack'), 7),
#   (('printer', 'maker'), 7),
#   (('had', 'printer'), 7),
#   (('printer', 'online'), 7),
#   (('add', 'printer'), 7),
#   (('printer', 'handle'), 7),
#   (('printer', 'recently'), 7),
#   (('cost', 'printer'), 7),
#   (('printer', 'high'), 7),
#   (('printer', 'good'), 7),
#   (('printer', 'test'), 7),
#   (('whole', 'printer'), 7),
#   (('everyday', 'printer'), 7),
#   (('printer', 'panel'), 7),
#   (('printer', 'due'), 7),
#   (('type', 'printer'), 7),
#   (('printer', 'web'), 7),
#   (('affordable', 'printer'), 7),
#   (('printer', 'unlike'), 7),
#   (('printer', 'quickly'), 7),
#   (('third', 'printer'), 7),
#   (('page', 'printer'), 7),
#   (('printer', 'designed'), 7),
#   (('printer', 'definitely'), 7),
#   (('printer', 'pretty'), 7),
#   (('printer', 'network'), 7),
#   (('printer', 'already'), 7),
#   (('average', 'printer'), 7),
#   (('printer', 'got'), 7),
#   (('not', 'printer'), 7),
#   (('original', 'printer'), 7),
#   (('airprint', 'printer'), 7),
#   (('printer', 'run'), 7),
#   (('printer', 'sits'), 7),
#   (('printer', 'near'), 7),
#   (('printer', 'despite'), 7),
#   (('printer', 'connection'), 7),
#   (('printer', 'required'), 7),
#   (('printer', 'better'), 7),
#   (('printer', 'particularly'), 7),
#   (('printer', 'speed'), 7),
#   (('purpose', 'printer'), 6),
#   (('printer', 'mainly'), 6),
#   (('printer', 'customer'), 6),
#   (('printer', 'buy'), 6),
#   (('printer', 'working'), 6),
#   (('specific', 'printer'), 6),
#   (('either', 'printer'), 6),
#   (('printer', 'year'), 6),
#   (('printer', 'plug'), 6),
#   (('local', 'printer'), 6),
#   (('printer', 'new'), 6),
#   (('disposable', 'printer'), 6),
#   (('printer', 'specifically'), 6),
#   (('printer', 'down'), 6),
#   (('buy', 'printer'), 6),
#   (('printer', 'machine'), 6),
#   (('general', 'printer'), 6),
#   (('duplex', 'printer'), 6),
#   (('set', 'printer'), 6),
#   (('out', 'printer'), 6),
#   (('attractive', 'printer'), 6),
#   (('versatile', 'printer'), 6),
#   (('printer', 'except'), 6),
#   (('economical', 'printer'), 6),
#   (('printer', 'install'), 6),
#   (('photographic', 'printer'), 6),
#   (('printer', 'appears'), 6),
#   (('printer', 'ran'), 6),
#   (('printer', 'everything'), 6),
#   (('you', 'printer'), 6),
#   (('free', 'printer'), 6),
#   (('printer', 'included'), 6),
#   (('printer', 'copy'), 6),
#   (('printer', 'own'), 6),
#   (('star', 'printer'), 6),
#   (('be', 'printer'), 6),
#   (('secondary', 'printer'), 6),
#   (('into', 'printer'), 6),
#   (('printer', 'claim'), 6),
#   (('printer', 'ship'), 6),
#   (('printer', 'etc'), 6),
#   (('panasonic', 'printer'), 6),
#   (('broken', 'printer'), 6),
#   (('printer', 'wifi'), 6),
#   (('much', 'printer'), 6),
#   (('printer', 'note'), 6),
#   (('printer', 'almost'), 6),
#   (('printer', 'small'), 6),
#   (('printer', 'technology'), 6),
#   (('printer', 'apparently'), 6),
#   (('printer', 'interface'), 6),
#   (('printer', 'list'), 6),
#   (('printer', 'front'), 6),
#   (('easiest', 'printer'), 6),
#   (('printer', 'table'), 6),
#   (('printer', 'five'), 6),
#   (('printer', 'grab'), 6),
#   (('outstanding', 'printer'), 6),
#   (('force', 'printer'), 6),
#   (('printer', 'page'), 6),
#   (('printer', 'needed'), 6),
#   (('bigger', 'printer'), 6),
#   (('printer', 'each'), 6),
#   (('printer', 'see'), 6),
#   (('impressive', 'printer'), 6),
#   (('printer', 'x'), 6),
#   (('lazer', 'printer'), 6),
#   (('dozen', 'printer'), 6),
#   (('printer', 'making'), 5),
#   (('printer', 'gave'), 5),
#   (('printer', 'together'), 5),
#   (('prior', 'printer'), 5),
#   (('printer', 'based'), 5),
#   (('side', 'printer'), 5),
#   (('deskjet', 'printer'), 5),
#   (('printer', 'aba'), 5),
#   (('printer', 'management'), 5),
#   (('printer', 'probably'), 5),
#   (('latest', 'printer'), 5),
#   (('slowest', 'printer'), 5),
#   (('printer', 'brand'), 5),
#   (('included', 'printer'), 5),
#   (('printer', 'life'), 5),
#   (('printer', 'drink'), 5),
#   (('printer', 'footprint'), 5),
#   (('printer', 'produced'), 5),
#   (('printer', 'camera'), 5),
#   (('printer', 'physically'), 5),
#   (('printer', 'sell'), 5),
#   (('printer', 'brings'), 5),
#   (('printer', 'four'), 5),
#   (('his', 'printer'), 5),
#   (('printer', 'meant'), 5),
#   (('printer', 'part'), 5),
#   (('day', 'printer'), 5),
#   (('printer', 'useless'), 5),
#   (('printer', 'long'), 5),
#   (('printer', 'review'), 5),
#   (('working', 'printer'), 5),
#   (('recent', 'printer'), 5),
#   (('recommended', 'printer'), 5),
#   (('called', 'printer'), 5),
#   (('printer', 'home'), 5),
#   (('between', 'printer'), 5),
#   (('grade', 'printer'), 5),
#   (('printer', 'preference'), 5),
#   (('favorite', 'printer'), 5),
#   (('printer', 'showed'), 5),
#   (('printer', 'performed'), 5),
#   (('printer', 'address'), 5),
#   (('built', 'printer'), 5),
#   (('dollar', 'printer'), 5),
#   (('printer', 'duplex'), 5),
#   (('printer', 'brother'), 5),
#   (('printer', 'currently'), 5),
#   (('printer', 'price'), 5),
#   (('former', 'printer'), 5),
#   (('printer', 'beat'), 5),
#   (('printer', 'recognized'), 5),
#   (('cd', 'printer'), 5),
#   (('alone', 'printer'), 5),
#   (('printer', 'onto'), 5),
#   (('printer', 'along'), 5),
#   (('efficient', 'printer'), 5),
#   (('sturdy', 'printer'), 5),
#   (('printer', 'your'), 5),
#   (('though', 'printer'), 5),
#   (('injet', 'printer'), 5),
#   (('printer', 'manager'), 5),
#   (('sized', 'printer'), 5),
#   (('sided', 'printer'), 5),
#   (('printer', 'samsung'), 5),
#   (('printer', 'feel'), 5),
#   (('printer', 'measure'), 5),
#   (('multifunctional', 'printer'), 5),
#   (('cloud', 'printer'), 5),
#   (('how', 'printer'), 5),
#   (('printer', 'touchscreen'), 5),
#   (('past', 'printer'), 5),
#   (('ricoh', 'printer'), 5),
#   (('volume', 'printer'), 4),
#   (('such', 'printer'), 4),
#   (('printer', 'accepts'), 4),
#   (('printer', 'everyone'), 4),
#   (('officejet', 'printer'), 4),
#   (('just', 'printer'), 4),
#   (('used', 'printer'), 4),
#   (('printer', 'never'), 4),
#   (('printer', 'yesterday'), 4),
#   (('printer', 'warms'), 4),
#   (('printer', 'eats'), 4),
#   (('newest', 'printer'), 4),
#   (('printer', 'application'), 4),
#   (('make', 'printer'), 4),
#   (('printer', 'lasted'), 4),
#   (('cheapest', 'printer'), 4),
#   (('printer', 'refused'), 4),
#   (('paper', 'printer'), 4),
#   (('powerful', 'printer'), 4),
#   (('dependable', 'printer'), 4),
#   (('printer', 'free'), 4),
#   (('ideal', 'printer'), 4),
#   (('printer', 'straight'), 4),
#   (('genuine', 'printer'), 4),
#   (('printer', 'repaired'), 4),
#   (('printer', 'fault'), 4),
#   (('printer', 'above'), 4),
#   (('printer', 'frequently'), 4),
#   (('shared', 'printer'), 4),
#   (('will', 'printer'), 4),
#   (('printer', 'decides'), 4),
#   (('printer', 'show'), 4),
#   (('printer', 'refuse'), 4),
#   (('printer', 'recognizes'), 4),
#   (('printer', 'love'), 4),
#   (('printer', 'located'), 4),
#   (('year', 'printer'), 4),
#   (('ethernet', 'printer'), 4),
#   (('defective', 'printer'), 4),
#   (('giant', 'printer'), 4),
#   (('printer', 'either'), 4),
#   (('printer', 'utilizes'), 4),
#   (('printer', 'issue'), 4),
#   (('printer', 'open'), 4),
#   (('printer', 'save'), 4),
#   (('printer', 'owner'), 4),
#   (('printer', 'configuration'), 4),
#   (('printer', 'usually'), 4),
#   (('printer', 'console'), 4),
#   (('printer', 'costing'), 4),
#   (('wa', 'printer'), 4),
#   (('printer', 'quite'), 4),
#   (('packard', 'printer'), 4),
#   (('printer', 'failed'), 4),
#   (('printer', 'require'), 4),
#   (('stylus', 'printer'), 4),
#   (('price', 'printer'), 4),
#   (('printer', 'loaded'), 4),
#   (('printer', 'delivered'), 4),
#   (('printer', 'maybe'), 4),
#   (('printer', 'called'), 4),
#   (('printer', 'generally'), 4),
#   (('printer', 'per'), 4),
#   (('printer', 'worth'), 4),
#   (('printer', 'nice'), 4),
#   (('printer', 'mean'), 4),
#   (('printer', 'top'), 4),
#   (('printer', 'excellent'), 4),
#   (('printer', 'enough'), 4),
#   (('printer', 'text'), 4),
#   (('printer', 'error'), 4),
#   (('typical', 'printer'), 4),
#   (('install', 'printer'), 4),
#   (('printer', 'unfortunately'), 4),
#   (('envy', 'printer'), 4),
#   (('printer', 'sound'), 4),
#   (('printer', 'getting'), 4),
#   (('printer', 'why'), 4),
#   (('printer', 'kept'), 4),
#   (('printer', 'family'), 4),
#   (('when', 'printer'), 4),
#   (('mfc', 'printer'), 4),
#   (('test', 'printer'), 4),
#   (('printer', 'basically'), 4),
#   (('printer', 'wherever'), 4),
#   (('printer', 'replaces'), 4),
#   (('printer', 'folk'), 4),
#   (('printer', 'leaf'), 4),
#   (('why', 'printer'), 4),
#   (('printer', 'offered'), 4),
#   (('right', 'printer'), 4),
#   (('printer', 'showing'), 4),
#   (('printer', 'sat'), 4),
#   (('printer', 'built'), 4),
#   (('via', 'printer'), 4),
#   (('bulky', 'printer'), 4),
#   (('because', 'printer'), 4),
#   (('printer', 'attached'), 4),
#   (('faster', 'printer'), 4),
#   (('dedicated', 'printer'), 4),
#   (('modern', 'printer'), 4),
#   (('manufacturer', 'printer'), 4),
#   (('printer', 'suitable'), 4),
#   (('class', 'printer'), 4),
#   (('terrific', 'printer'), 4),
#   (('competitive', 'printer'), 4),
#   (('mac', 'printer'), 4),
#   (('printer', 'apart'), 4),
#   (('custom', 'printer'), 4),
#   (('printer', 'he'), 4),
#   (('printer', 'between'), 4),
#   (('printer', 'tend'), 4),
#   (('capacity', 'printer'), 4),
#   (('printer', 'mx'), 4),
#   (('printer', 'cloud'), 4),
#   (('ready', 'printer'), 4),
#   (('advanced', 'printer'), 4),
#   (('printer', 'airprint'), 4),
#   (('printer', 'automatic'), 4),
#   (('making', 'printer'), 4),
#   (('printer', 'follows'), 4),
#   (('also', 'printer'), 4),
#   (('printer', 'compare'), 4),
#   (('printer', 'arrives'), 4),
#   (('installing', 'printer'), 4),
#   (('printer', 'icon'), 3),
#   (('printer', 'operation'), 3),
#   (('beloved', 'printer'), 3),
#   (('printer', 'problem'), 3),
#   (('printer', 'broke'), 3),
#   (('text', 'printer'), 3),
#   (('printer', 'quits'), 3),
#   (('dye', 'printer'), 3),
#   (('printer', 'blow'), 3),
#   (('printer', 'read'), 3),
#   (('printer', 'clearly'), 3),
#   (('networkable', 'printer'), 3),
#   (('do', 'printer'), 3),
#   (('printer', 'know'), 3),
#   (('printer', 'cart'), 3),
#   (('printer', 'edited'), 3),
#   (('printer', 'themselves'), 3),
#   (('printer', 'label'), 3),
#   (('printer', 'literally'), 3),
#   (('he', 'printer'), 3),
#   (('printer', 'fast'), 3),
#   (('printer', 'bought'), 3),
#   (('printer', 'cover'), 3),
#   (('printer', 'dy'), 3),
#   (('printer', 'always'), 3),
#   (('printer', 'side'), 3),
#   (('printer', 'business'), 3),
#   (('printer', 'tends'), 3),
#   (('printer', 'dialog'), 3),
#   (('printer', 'retail'), 3),
#   (('printer', 'any'), 3),
#   (('printer', 'device'), 3),
#   (('printer', 'mp'), 3),
#   (('printer', 'earlier'), 3),
#   (('can', 'printer'), 3),
#   (('printer', 'changing'), 3),
#   (('printer', 'spit'), 3),
#   (('printer', 'remember'), 3),
#   (('backup', 'printer'), 3),
#   (('found', 'printer'), 3),
#   (('printer', 'space'), 3),
#   (('printer', 'standard'), 3),
#   (('printer', 'how'), 3),
#   (('printer', 'fairly'), 3),
#   (('printer', 'shake'), 3),
#   (('monitor', 'printer'), 3),
#   (('printer', 'operates'), 3),
#   (('printer', 'feed'), 3),
#   (('printer', 'cd'), 3),
#   (('school', 'printer'), 3),
#   (('wide', 'printer'), 3),
#   (('consumer', 'printer'), 3),
#   (('printer', 'shuts'), 3),
#   (('printer', 'decided'), 3),
#   (('printer', 'adapter'), 3),
#   (('vista', 'printer'), 3),
#   (('printer', 'perhaps'), 3),
#   (('okay', 'printer'), 3),
#   (('wrong', 'printer'), 3),
#   (('bad', 'printer'), 3),
#   (('printer', 'noise'), 3),
#   (('remarkable', 'printer'), 3),
#   (('printer', 'cause'), 3),
#   (('printer', 'taking'), 3),
#   (('printer', 'cannon'), 3),
#   (('printer', 'market'), 3),
#   (('extra', 'printer'), 3),
#   (('initial', 'printer'), 3),
#   (('printer', 'choice'), 3),
#   (('head', 'printer'), 3),
#   (('ha', 'printer'), 3),
#   (('pc', 'printer'), 3),
#   (('iphone', 'printer'), 3),
#   (('printer', 'moreover'), 3),
#   (('printer', 'job'), 3),
#   (('feature', 'printer'), 3),
#   (('printer', 'typically'), 3),
#   (('printer', 'program'), 3),
#   (('envelope', 'printer'), 3),
#   (('led', 'printer'), 3),
#   (('printer', 'check'), 3),
#   (('printer', 'continues'), 3),
#   (('printer', 'add'), 3),
#   (('printer', 'tethered'), 3),
#   (('printer', 'personally'), 3),
#   (('printer', 'gray'), 3),
#   (('printer', 'compatible'), 3),
#   (('printer', 'hummed'), 3),
#   (('printer', 'whose'), 3),
#   (('printer', 'name'), 3),
#   (('medium', 'printer'), 3),
#   (('printer', 'underneath'), 3),
#   (('duplexing', 'printer'), 3),
#   (('printer', 'language'), 3),
#   (('single', 'printer'), 3),
#   (('printer', 'follow'), 3),
#   (('image', 'printer'), 3),
#   (('countless', 'printer'), 3),
#   (('turning', 'printer'), 3),
#   (('made', 'printer'), 3),
#   (('printer', 'besides'), 3),
#   (('imageclass', 'printer'), 3),
#   (('dpi', 'printer'), 3),
#   (('printer', 'intended'), 3),
#   (('printer', 'sd'), 3),
#   (('copier', 'printer'), 3),
#   (('printer', 'ning'), 3),
#   (('printer', 'ability'), 3),
#   (('compatible', 'printer'), 3),
#   (('cyan', 'printer'), 3),
#   (('printer', 'document'), 3),
#   (('quite', 'printer'), 3),
#   (('line', 'printer'), 3),
#   (('mono', 'printer'), 3),
#   (('io', 'printer'), 3),
#   (('functionality', 'printer'), 3),
#   (('window', 'printer'), 3),
#   (('printer', 'separate'), 3),
#   (('printer', 'fail'), 3),
#   (('printer', 'ok'), 3),
#   (('printer', 'draw'), 3),
#   (('tray', 'printer'), 3),
#   (('printer', 'primarily'), 3),
#   (('printer', 'basic'), 3),
#   (('printer', 'alone'), 3),
#   (('notch', 'printer'), 3),
#   (('printer', 'solely'), 3),
#   (('printer', 'fill'), 3),
#   (('printer', 'mobile'), 3),
#   (('printer', 'galaxy'), 3),
#   (('preference', 'printer'), 3),
#   (('value', 'printer'), 3),
#   (('printer', 'call'), 3),
#   (('printer', 'thing'), 3),
#   (('picture', 'printer'), 3),
#   (('cable', 'printer'), 3),
#   (('additional', 'printer'), 3),
#   (('doa', 'printer'), 3),
#   (('wf', 'printer'), 3),
#   (('printer', 'dedicated'), 3),
#   (('printer', 'suffer'), 3),
#   (('massive', 'printer'), 3),
#   (('printer', 'replacement'), 3),
#   (('printer', 'system'), 3),
#   (('printer', 'installing'), 3),
#   (('say', 'printer'), 3),
#   (('printer', 'whether'), 3),
#   (('printer', 'recommended'), 3),
#   (('printer', 'those'), 3),
#   (('printer', 'quit'), 3),
#   (('lightweight', 'printer'), 3),
#   (('printer', 'gui'), 3),
#   (('wise', 'printer'), 3),
#   (('printer', 'remote'), 3),
#   (('printer', 'introduced'), 3),
#   (('printer', 'perfection'), 3),
#   (('wish', 'printer'), 3),
#   (('prefer', 'printer'), 3),
#   (('drive', 'printer'), 3),
#   (('printer', 'full'), 3),
#   (('printer', 'find'), 3),
#   (('printer', 'nothing'), 3),
#   (('printer', 'prior'), 3),
#   (('then', 'printer'), 3),
#   (('printer', 'satisfies'), 3),
#   (('printer', 'le'), 3),
#   (('speedy', 'printer'), 3),
#   (('combo', 'printer'), 3),
#   (('printer', 'monochrome'), 3),
#   (('printer', 'slightly'), 3),
#   (('printer', 'boast'), 3),
#   (('printer', 'operational'), 3),
#   (('copy', 'printer'), 3),
#   (('smallest', 'printer'), 3),
#   (('printer', 'weighing'), 3),
#   (('printer', 'someone'), 3),
#   (('review', 'printer'), 3),
#   (('common', 'printer'), 3),
#   (('printer', 'quick'), 3),
#   (('portable', 'printer'), 3),
#   (('printer', 'thus'), 3),
#   (('printer', 'ranging'), 3),
#   (('printer', 'imo'), 3),
#   (('workgroup', 'printer'), 2),
#   (('printer', 'rep'), 2),
#   (('printer', 'resolution'), 2),
#   (('printer', 'expects'), 2),
#   (('printer', 'myself'), 2),
#   (('largest', 'printer'), 2),
#   (('sub', 'printer'), 2),
#   (('printer', 'break'), 2),
#   (('printer', 'provided'), 2),
#   (('sole', 'printer'), 2),
#   (('printer', 'crank'), 2),
#   (('problem', 'printer'), 2),
#   (('printer', 'becomes'), 2),
#   (('true', 'printer'), 2),
#   (('horse', 'printer'), 2),
#   (('printer', 'costco'), 2),
#   (('printer', 'debbie'), 2),
#   (('printer', 'file'), 2),
#   (('printer', 'anyway'), 2),
#   (('printer', 'construction'), 2),
#   (('printer', 'period'), 2),
#   (('printer', 'sounded'), 2),
#   (('lesser', 'printer'), 2),
#   (('get', 'printer'), 2),
#   (('printer', 'nicely'), 2),
#   (('ordinary', 'printer'), 2),
#   (('printer', 'forward'), 2),
#   (('printer', 'close'), 2),
#   (('printer', 'completely'), 2),
#   (('stupid', 'printer'), 2),
#   (('disc', 'printer'), 2),
#   (('printer', 'spend'), 2),
#   (('printer', 'who'), 2),
#   (('bluetooth', 'printer'), 2),
#   (('printer', 'daily'), 2),
#   (('until', 'printer'), 2),
#   (('printer', 'fails'), 2),
#   (('printer', 'rest'), 2),
#   (('printer', 'low'), 2),
#   (('printer', 'wait'), 2),
#   ...],
#  'binder': [(('the', 'binder'), 571),
#   (('this', 'binder'), 473),
#   (('binder', 'is'), 307),
#   (('a', 'binder'), 223),
#   (('binder', 'i'), 183),
#   (('binder', 'for'), 140),
#   (('binder', 'and'), 128),
#   (('binder', 'that'), 116),
#   (('binder', 'it'), 112),
#   (('binder', 'with'), 110),
#   (('binder', 'ha'), 92),
#   (('binder', 'the'), 88),
#   (('binder', 'are'), 77),
#   (('view', 'binder'), 74),
#   (('binder', 'this'), 73),
#   (('ring', 'binder'), 71),
#   (('other', 'binder'), 71),
#   (('binder', 'to'), 67),
#   (('these', 'binder'), 67),
#   (('binder', 'in'), 64),
#   (('binder', 'but'), 62),
#   (('of', 'binder'), 60),
#   (('duty', 'binder'), 54),
#   (('jones', 'binder'), 50),
#   (('binder', 'a'), 38),
#   (('quality', 'binder'), 38),
#   (('inch', 'binder'), 31),
#   (('binder', 'of'), 30),
#   (('avery', 'binder'), 29),
#   (('my', 'binder'), 29),
#   (('binder', 'so'), 29),
#   (('basic', 'binder'), 27),
#   (('binder', 'will'), 27),
#   (('great', 'binder'), 27),
#   (('nice', 'binder'), 25),
#   (('binder', 'ring'), 25),
#   (('binder', 'wa'), 25),
#   (('binder', 'at'), 25),
#   (('binder', 'if'), 24),
#   (('white', 'binder'), 24),
#   (('good', 'binder'), 24),
#   (('binder', 'on'), 24),
#   (('sturdy', 'binder'), 23),
#   (('durable', 'binder'), 23),
#   (('binder', 'you'), 22),
#   (('binder', 'have'), 22),
#   (('binder', 'from'), 21),
#   (('standard', 'binder'), 19),
#   (('binder', 'cover'), 19),
#   (('binder', 'there'), 19),
#   (('use', 'binder'), 19),
#   (('zipper', 'binder'), 19),
#   (('binder', 'which'), 18),
#   (('binder', 'doe'), 18),
#   (('particular', 'binder'), 17),
#   (('binder', 'would'), 17),
#   (('binder', 'itself'), 16),
#   (('your', 'binder'), 15),
#   (('binder', 'hold'), 15),
#   (('binder', 'not'), 15),
#   (('binder', 'clip'), 14),
#   (('binder', 'seems'), 14),
#   (('average', 'binder'), 14),
#   (('binder', 'should'), 13),
#   (('binder', 'can'), 13),
#   (('binder', 'because'), 13),
#   (('binder', 'one'), 13),
#   (('little', 'binder'), 13),
#   (('small', 'binder'), 12),
#   (('binder', 'or'), 12),
#   (('with', 'binder'), 12),
#   (('binder', 'feel'), 12),
#   (('most', 'binder'), 12),
#   (('regular', 'binder'), 12),
#   (('some', 'binder'), 12),
#   (('binder', 'they'), 12),
#   (('binder', 'like'), 12),
#   (('binder', 'go'), 12),
#   (('binder', 'just'), 11),
#   (('for', 'binder'), 11),
#   (('binder', 'these'), 11),
#   (('binder', 'by'), 11),
#   (('binder', 'when'), 11),
#   (('binder', 'out'), 11),
#   (('in', 'binder'), 10),
#   (('binder', 'also'), 10),
#   (('hard', 'binder'), 10),
#   (('binder', 'instead'), 10),
#   (('cheaper', 'binder'), 10),
#   (('size', 'binder'), 10),
#   (('binder', 'work'), 10),
#   (('many', 'binder'), 9),
#   (('plastic', 'binder'), 9),
#   (('binder', 'do'), 9),
#   (('large', 'binder'), 9),
#   (('and', 'binder'), 9),
#   (('decent', 'binder'), 8),
#   (('sized', 'binder'), 8),
#   (('binder', 'come'), 8),
#   (('binder', 'arrived'), 8),
#   (('another', 'binder'), 8),
#   (('vinyl', 'binder'), 8),
#   (('binder', 'we'), 8),
#   (('ordinary', 'binder'), 8),
#   (('school', 'binder'), 8),
#   (('binder', 'full'), 7),
#   (('binder', 'open'), 7),
#   (('binder', 'no'), 7),
#   (('new', 'binder'), 7),
#   (('their', 'binder'), 7),
#   (('binder', 'however'), 7),
#   (('typical', 'binder'), 7),
#   (('flexible', 'binder'), 7),
#   (('binder', 'unusable'), 7),
#   (('better', 'binder'), 7),
#   (('binder', 'my'), 7),
#   (('one', 'binder'), 7),
#   (('comb', 'binder'), 7),
#   (('black', 'binder'), 7),
#   (('binder', 'especially'), 7),
#   (('binder', 'look'), 7),
#   (('binder', 'last'), 7),
#   (('larger', 'binder'), 6),
#   (('binder', 'than'), 6),
#   (('big', 'binder'), 6),
#   (('on', 'binder'), 6),
#   (('binder', 'while'), 6),
#   (('generic', 'binder'), 6),
#   (('binder', 'without'), 6),
#   (('or', 'binder'), 6),
#   (('binder', 'what'), 6),
#   (('all', 'binder'), 6),
#   (('binder', 'binder'), 6),
#   (('binder', 'over'), 6),
#   (('old', 'binder'), 6),
#   (('premium', 'binder'), 6),
#   (('best', 'binder'), 6),
#   (('binder', 'seem'), 6),
#   (('solid', 'binder'), 6),
#   (('main', 'binder'), 5),
#   (('love', 'binder'), 5),
#   (('binder', 'inch'), 5),
#   (('simplify', 'binder'), 5),
#   (('strongest', 'binder'), 5),
#   (('binder', 'round'), 5),
#   (('end', 'binder'), 5),
#   (('binder', 'may'), 5),
#   (('binder', 'where'), 5),
#   (('binder', 'every'), 5),
#   (('binder', 'make'), 5),
#   (('like', 'binder'), 5),
#   (('binder', 'fit'), 5),
#   (('perfect', 'binder'), 5),
#   (('coupon', 'binder'), 5),
#   (('buy', 'binder'), 5),
#   (('pretty', 'binder'), 5),
#   (('binder', 'all'), 5),
#   (('polypro', 'binder'), 5),
#   (('binder', 'feature'), 4),
#   (('his', 'binder'), 4),
#   (('binder', 'very'), 4),
#   (('had', 'binder'), 4),
#   (('store', 'binder'), 4),
#   (('very', 'binder'), 4),
#   (('binder', 'labeling'), 4),
#   (('sewn', 'binder'), 4),
#   (('ledger', 'binder'), 4),
#   (('both', 'binder'), 4),
#   (('binder', 'close'), 4),
#   (('any', 'binder'), 4),
#   (('different', 'binder'), 4),
#   (('inside', 'binder'), 4),
#   (('binder', 'avery'), 4),
#   (('binder', 'only'), 4),
#   (('economy', 'binder'), 4),
#   (('thick', 'binder'), 4),
#   (('binder', 'rather'), 4),
#   (('huge', 'binder'), 4),
#   (('type', 'binder'), 4),
#   (('get', 'binder'), 4),
#   (('mini', 'binder'), 4),
#   (('x', 'binder'), 4),
#   (('binder', 'get'), 4),
#   (('bliss', 'binder'), 4),
#   (('office', 'binder'), 4),
#   (('binder', 'made'), 4),
#   (('binder', 'around'), 4),
#   (('kid', 'binder'), 4),
#   (('binder', 'looked'), 4),
#   (('binder', 'came'), 4),
#   (('purchasing', 'binder'), 4),
#   (('binder', 'view'), 4),
#   (('binder', 'since'), 3),
#   (('binder', 'he'), 3),
#   (('presentation', 'binder'), 3),
#   (('binder', 'mechanism'), 3),
#   (('entire', 'binder'), 3),
#   (('normal', 'binder'), 3),
#   (('sturdiest', 'binder'), 3),
#   (('binder', 'larger'), 3),
#   (('cheap', 'binder'), 3),
#   (('binder', 'available'), 3),
#   (('binder', 'well'), 3),
#   (('binder', 'had'), 3),
#   (('excellent', 'binder'), 3),
#   (('that', 'binder'), 3),
#   (('back', 'binder'), 3),
#   (('binder', 'good'), 3),
#   (('binder', 'particularly'), 3),
#   (('expensive', 'binder'), 3),
#   (('more', 'binder'), 3),
#   (('binder', 'part'), 3),
#   (('binder', 'through'), 3),
#   (('binder', 'definitely'), 3),
#   (('project', 'binder'), 3),
#   (('binder', 'into'), 3),
#   (('binder', 'could'), 3),
#   (('binder', 'other'), 3),
#   (('wj', 'binder'), 3),
#   (('into', 'binder'), 3),
#   (('binder', 'worth'), 3),
#   (('need', 'binder'), 3),
#   (('binder', 'really'), 3),
#   (('binder', 'even'), 3),
#   (('similar', 'binder'), 3),
#   (('binder', 'although'), 3),
#   (('attractive', 'binder'), 3),
#   (('about', 'binder'), 3),
#   (('single', 'binder'), 3),
#   (('first', 'binder'), 3),
#   (('zippered', 'binder'), 3),
#   (('simple', 'binder'), 3),
#   (('binder', 'each'), 3),
#   (('binder', 'except'), 3),
#   (('thin', 'binder'), 3),
#   (('serviceable', 'binder'), 3),
#   (('strong', 'binder'), 3),
#   (('binder', 'lie'), 3),
#   (('mitt', 'binder'), 2),
#   (('binder', 'too'), 2),
#   (('giant', 'binder'), 2),
#   (('binder', 'exactly'), 2),
#   (('such', 'binder'), 2),
#   (('binder', 'both'), 2),
#   (('binder', 'though'), 2),
#   (('binder', 'contain'), 2),
#   (('home', 'binder'), 2),
#   (('binder', 'yet'), 2),
#   (('binder', 'wilson'), 2),
#   (('binder', 'keep'), 2),
#   (('full', 'binder'), 2),
#   (('priced', 'binder'), 2),
#   (('binder', 'overall'), 2),
#   (('functional', 'binder'), 2),
#   (('binder', 'excellent'), 2),
#   (('binder', 'either'), 2),
#   (('binder', 'nothing'), 2),
#   (('binder', 'size'), 2),
#   (('leaf', 'binder'), 2),
#   (('binder', 'portion'), 2),
#   (('binder', 'chipboard'), 2),
#   (('binder', 'heavy'), 2),
#   (('horse', 'binder'), 2),
#   (('binder', 'much'), 2),
#   (('make', 'binder'), 2),
#   (('binder', 'divider'), 2),
#   (('binder', 'still'), 2),
#   (('binder', 'easy'), 2),
#   (('binder', 'some'), 2),
#   (('find', 'binder'), 2),
#   (('versatile', 'binder'), 2),
#   (('binder', 'buy'), 2),
#   (('binder', 'then'), 2),
#   (('binder', 'now'), 2),
#   (('binder', 'before'), 2),
#   (('binder', 'first'), 2),
#   (('binder', 'unlike'), 2),
#   (('used', 'binder'), 2),
#   (('binder', 'plastic'), 2),
#   (('lightweight', 'binder'), 2),
#   (('binder', 'take'), 2),
#   (('binder', 'any'), 2),
#   (('binder', 'upright'), 2),
#   (('previous', 'binder'), 2),
#   (('last', 'binder'), 2),
#   (('cheapie', 'binder'), 2),
#   (('flimsy', 'binder'), 2),
#   (('binder', 'again'), 2),
#   (('binder', 'fault'), 2),
#   (('binder', 'section'), 2),
#   (('narrow', 'binder'), 2),
#   (('touch', 'binder'), 2),
#   (('binder', 'spine'), 2),
#   (('binder', 'connoisseur'), 2),
#   (('binder', 'our'), 2),
#   (('conventional', 'binder'), 2),
#   (('recycled', 'binder'), 2),
#   (('three', 'binder'), 2),
#   (('real', 'binder'), 2),
#   (('cardboard', 'binder'), 2),
#   (('binder', 'along'), 2),
#   (('binder', 'wo'), 2),
#   (('binder', 'pocket'), 2),
#   (('binder', 'contains'), 2),
#   (('binder', 'material'), 2),
#   (('binder', 'appears'), 2),
#   (('binder', 'fold'), 2),
#   (('binder', 'need'), 2),
#   (('useful', 'binder'), 2),
#   (('binder', 'anyway'), 2),
#   (('binder', 'simple'), 2),
#   (('binder', 'attractive'), 2),
#   (('color', 'binder'), 2),
#   (('binder', 'why'), 2),
#   (('same', 'binder'), 2),
#   (('made', 'binder'), 2),
#   (('colorful', 'binder'), 2),
#   (('star', 'binder'), 2),
#   (('based', 'binder'), 2),
#   (('binder', 'perfect'), 2),
#   (('second', 'binder'), 2),
#   (('brand', 'binder'), 2),
#   (('binder', 'after'), 2),
#   (('have', 'binder'), 2),
#   (('binder', 'break'), 2),
#   (('storage', 'binder'), 2),
#   (('zipped', 'binder'), 2),
#   (('binder', 'plus'), 2),
#   (('binder', 'due'), 2),
#   (('binder', 'includes'), 2),
#   (('binder', 'were'), 2),
#   (('than', 'binder'), 2),
#   (('few', 'binder'), 2),
#   (('classroom', 'binder'), 2),
#   (('binder', 'notebook'), 2),
#   (('binder', 'three'), 2),
#   (('binder', 's'), 2),
#   (('comparable', 'binder'), 2),
#   (('binder', 'stand'), 2),
#   (('which', 'binder'), 2),
#   (('wilson', 'binder'), 2),
#   (('duratech', 'binder'), 2),
#   (('binder', 'violet'), 2),
#   (('just', 'binder'), 2),
#   (('budget', 'binder'), 2),
#   (('looking', 'binder'), 2),
#   (('binder', 'quite'), 2),
#   (('bottom', 'binder'), 2),
#   (('to', 'binder'), 2),
#   (('aged', 'binder'), 2),
#   (('look', 'binder'), 2),
#   (('binder', 'themselves'), 2),
#   (('binder', 'nut'), 2),
#   (('using', 'binder'), 2),
#   (('built', 'binder'), 2),
#   (('binder', 'cost'), 2),
#   (('older', 'binder'), 2),
#   (('binder', 'tout'), 1),
#   (('it', 'binder'), 1),
#   (('binder', 'requires'), 1),
#   (('each', 'binder'), 1),
#   (('whole', 'binder'), 1),
#   (('binder', 'fail'), 1),
#   (('metallic', 'binder'), 1),
#   (('binder', 'six'), 1),
#   (('biggest', 'binder'), 1),
#   (('binder', 'their'), 1),
#   (('level', 'binder'), 1),
#   (('binder', 'thanks'), 1),
#   (('amazing', 'binder'), 1),
#   (('binder', 'apart'), 1),
#   (('discovered', 'binder'), 1),
#   (('want', 'binder'), 1),
#   (('binder', 'nonetheless'), 1),
#   (('nicer', 'binder'), 1),
#   (('binder', 'such'), 1),
#   (('binder', 'carried'), 1),
#   (('binder', 'prettier'), 1),
#   (('binder', 'mine'), 1),
#   (('hole', 'binder'), 1),
#   (('organized', 'binder'), 1),
#   (('pleated', 'binder'), 1),
#   (('binder', 'smead'), 1),
#   (('binder', 'cheap'), 1),
#   (('close', 'binder'), 1),
#   (('binder', 'five'), 1),
#   (('friendly', 'binder'), 1),
#   (('junky', 'binder'), 1),
#   (('binder', 'page'), 1),
#   (('come', 'binder'), 1),
#   (('sweet', 'binder'), 1),
#   (('wearing', 'binder'), 1),
#   (('right', 'binder'), 1),
#   (('binder', 'let'), 1),
#   (('binder', 'solves'), 1),
#   (('binder', 'panel'), 1),
#   (('binder', 'indeed'), 1),
#   (('replacement', 'binder'), 1),
#   (('binder', 'better'), 1),
#   (('household', 'binder'), 1),
#   (('notebook', 'binder'), 1),
#   (('binder', 'strong'), 1),
#   (('art', 'binder'), 1),
#   (('style', 'binder'), 1),
#   (('binder', 'extra'), 1),
#   (('binder', 'eventually'), 1),
#   (('long', 'binder'), 1),
#   (('manual', 'binder'), 1),
#   (('binder', 'rated'), 1),
#   (('binder', 'obviously'), 1),
#   (('binder', 'enough'), 1),
#   (('binder', 'extensively'), 1),
#   (('heavily', 'binder'), 1),
#   (('binder', 'escape'), 1),
#   (('binder', 'considering'), 1),
#   (('together', 'binder'), 1),
#   (('binder', 'area'), 1),
#   (('binder', 'proved'), 1),
#   (('dented', 'binder'), 1),
#   (('binder', 'us'), 1),
#   (('free', 'binder'), 1),
#   (('binder', 'store'), 1),
#   (('up', 'binder'), 1),
#   (('binder', 'incase'), 1),
#   (('binder', 'expecting'), 1),
#   (('binder', 'she'), 1),
#   (('you', 'binder'), 1),
#   (('handy', 'binder'), 1),
#   (('binder', 'appeal'), 1),
#   (('binder', 'yard'), 1),
#   (('protruding', 'binder'), 1),
#   (('fellowes', 'binder'), 1),
#   (('binder', 'video'), 1),
#   (('binder', 'perhaps'), 1),
#   (('binder', 'transparent'), 1),
#   (('binder', 'comb'), 1),
#   (('binder', 'sitting'), 1),
#   (('binder', 'starlet'), 1),
#   (('binder', 'together'), 1),
#   (('binder', 'face'), 1),
#   (('professional', 'binder'), 1),
#   (('binder', 'velo'), 1),
#   (('binder', 'queen'), 1),
#   (('binder', 'ala'), 1),
#   (('knew', 'binder'), 1),
#   (('binder', 'down'), 1),
#   (('us', 'binder'), 1),
#   (('binder', 'trim'), 1),
#   (('binder', 'claim'), 1),
#   (('go', 'binder'), 1),
#   (('binder', 'combine'), 1),
#   (('binder', 'help'), 1),
#   (('capability', 'binder'), 1),
#   (('advanced', 'binder'), 1),
#   (('capacity', 'binder'), 1),
#   (('binder', 'life'), 1),
#   (('binder', 'book'), 1),
#   (('cheapest', 'binder'), 1),
#   (('binder', 'premium'), 1),
#   (('binder', 'tear'), 1),
#   (('binder', 'sometimes'), 1),
#   (('binder', 'lack'), 1),
#   (('binder', 'until'), 1),
#   (('binder', 'warrant'), 1),
#   (('binder', 'edge'), 1),
#   (('binder', 'rivet'), 1),
#   (('getavery', 'binder'), 1),
#   (('blue', 'binder'), 1),
#   (('binder', 'content'), 1),
#   (('binder', 'added'), 1),
#   (('recyclable', 'binder'), 1),
#   (('binder', 'always'), 1),
#   (('binder', 'closeing'), 1),
#   (('metal', 'binder'), 1),
#   (('convenient', 'binder'), 1),
#   (('binder', 'looking'), 1),
#   (('binder', 'market'), 1),
#   (('binder', 'shape'), 1),
#   (('binder', 'appearance'), 1),
#   (('binder', 'inside'), 1),
#   (('covered', 'binder'), 1),
#   (('binder', 'certainly'), 1),
#   (('binder', 'roughly'), 1),
#   (('side', 'binder'), 1),
#   (('getting', 'binder'), 1),
#   (('binder', 'wow'), 1),
#   (('shopping', 'binder'), 1),
#   (('binder', 'punch'), 1),
#   (('ubiquitous', 'binder'), 1),
#   (('binder', 'similar'), 1),
#   (('me', 'binder'), 1),
#   (('smaller', 'binder'), 1),
#   (('binder', 'x'), 1),
#   (('binder', 'offer'), 1),
#   (('binder', 'love'), 1),
#   (('maybe', 'binder'), 1),
#   (('stick', 'binder'), 1),
#   (('binder', 'anytime'), 1),
#   (('binder', 'holder'), 1),
#   (('no', 'binder'), 1),
#   (('self', 'binder'), 1),
#   (('binder', 'turn'), 1),
#   (('closed', 'binder'), 1),
#   (('binder', 'clear'), 1),
#   (('empty', 'binder'), 1),
#   (('tiny', 'binder'), 1),
#   (('binder', 'pack'), 1),
#   (('looseleaf', 'binder'), 1),
#   (('are', 'binder'), 1),
#   (('binder', 'suit'), 1),
#   (('binder', 'accessory'), 1),
#   (('binder', 'free'), 1),
#   (('binder', 'shrunk'), 1),
#   (('binder', 'standard'), 1),
#   (('paper', 'binder'), 1),
#   (('binder', 'rear'), 1),
#   (('binder', 'seemed'), 1),
#   (('seven', 'binder'), 1),
#   (('binder', 'stay'), 1),
#   (('girlie', 'binder'), 1),
#   (('fun', 'binder'), 1),
#   (('wonderful', 'binder'), 1),
#   (('binder', 'allows'), 1),
#   (('sturdier', 'binder'), 1),
#   (('usual', 'binder'), 1),
#   (('adult', 'binder'), 1),
#   (('binder', 'standout'), 1),
#   (('alternative', 'binder'), 1),
#   (('enough', 'binder'), 1),
#   (('binder', 'turned'), 1),
#   (('binder', 'most'), 1),
#   (('boring', 'binder'), 1),
#   (('binder', 'apparatus'), 1),
#   (('printed', 'binder'), 1),
#   (('plain', 'binder'), 1),
#   (('greenroom', 'binder'), 1),
#   (('recipe', 'binder'), 1),
#   (('adorable', 'binder'), 1),
#   (('binder', 'tab'), 1),
#   (('actual', 'binder'), 1),
#   (('binder', 'super'), 1),
#   (('interesting', 'binder'), 1),
#   (('binder', 'hardware'), 1),
#   (('binder', 'almost'), 1),
#   (('binder', 'olympics'), 1),
#   (('cover', 'binder'), 1),
#   (('binder', 'manufacturer'), 1),
#   (('binder', 'notable'), 1),
#   (('binder', 'filled'), 1),
#   (('equivalent', 'binder'), 1),
#   (('fanatastic', 'binder'), 1),
#   (('binder', 'wish'), 1),
#   (('picture', 'binder'), 1),
#   (('binder', 'unless'), 1),
#   (('binder', 'folder'), 1),
#   (('pocket', 'binder'), 1),
#   (('maintenance', 'binder'), 1),
#   (('spiral', 'binder'), 1),
#   (('binder', 'fine'), 1),
#   (('binder', 'zipper'), 1),
#   (('binder', 'two'), 1),
#   (('binder', 'back'), 1),
#   (('binder', 'seriously'), 1),
#   (('fivestar', 'binder'), 1),
#   (('binder', 'throughout'), 1),
#   (('mead', 'binder'), 1),
#   (('timeflexible', 'binder'), 1),
#   (('student', 'binder'), 1),
#   (('smooth', 'binder'), 1),
#   (('here', 'binder'), 1),
#   (('grade', 'binder'), 1),
#   (('binder', 'complaint'), 1),
#   (('locking', 'binder'), 1),
#   (('binder', 'who'), 1),
#   (('binder', 'mentioned'), 1),
#   (('acceptable', 'binder'), 1),
#   (('favorite', 'binder'), 1),
#   (('binder', 'felt'), 1),
#   (('binder', 'read'), 1),
#   (('binder', 'gave'), 1),
#   (('binder', 'straightened'), 1),
#   (('binder', 'appropriate'), 1),
#   (('binder', 'department'), 1),
#   (('binder', 'basically'), 1),
#   (('dollar', 'binder'), 1),
#   (('binder', 'white'), 1),
#   (('binder', 'boast'), 1),
#   (('stock', 'binder'), 1),
#   (('le', 'binder'), 1),
#   (('binder', 'bend'), 1),
#   (('within', 'binder'), 1),
#   (('tough', 'binder'), 1),
#   (('binder', 'popped'), 1),
#   (('superior', 'binder'), 1),
#   (('qualify', 'binder'), 1),
#   (('binder', 'endure'), 1),
#   (('binder', 'model'), 1),
#   (('binder', 'okay'), 1),
#   (('binder', 'got'), 1),
#   (('binder', 'line'), 1),
#   (('binder', 'nevertheless'), 1),
#   (('those', 'binder'), 1),
#   (('binder', 'wherein'), 1),
#   (('binder', 'right'), 1),
#   (('binder', 'upside'), 1),
#   (('binder', 'meet'), 1),
#   (('binder', 'fall'), 1),
#   (('binder', 'address'), 1),
#   (('bought', 'binder'), 1),
#   (('countless', 'binder'), 1),
#   (('binder', 'fails'), 1),
#   (('binder', 'eliminates'), 1),
#   (('inexpensive', 'binder'), 1),
#   (('binder', 'snap'), 1),
#   (('binder', 'lay'), 1),
#   (('binder', 'seemingly'), 1),
#   (('seuss', 'binder'), 1),
#   (('binder', 'classroom'), 1),
#   (('binder', 'etc'), 1),
#   (('binder', 'pas'), 1),
#   (('binder', 'style'), 1),
#   (('current', 'binder'), 1),
#   (('separate', 'binder'), 1),
#   (('okay', 'binder'), 1),
#   (('remember', 'binder'), 1),
#   (('binder', 'prof'), 1),
# ...
#   (('stapler', 'gave'), 1),
#   (('stapler', 'packaging'), 1),
#   (('vanity', 'stapler'), 1),
#   (('item', 'stapler'), 1),
#   (('stapler', 'state'), 1),
#   (('model', 'stapler'), 1),
#   (('whose', 'stapler'), 1),
#   (('stapler', 'start'), 1),
#   (('stapler', 'everything'), 1),
#   (('stapler', 'under'), 1),
#   (('plain', 'stapler'), 1),
#   (('unicolored', 'stapler'), 1),
#   (('stapler', 'herself'), 1),
#   (('stapler', 'called'), 1)],
#  'calculator': [(('the', 'calculator'), 169),
#   (('this', 'calculator'), 145),
#   (('calculator', 'is'), 88),
#   (('a', 'calculator'), 75),
#   (('calculator', 'for'), 63),
#   (('graphing', 'calculator'), 61),
#   (('calculator', 'i'), 56),
#   (('scientific', 'calculator'), 51),
#   (('calculator', 'and'), 49),
#   (('hp', 'calculator'), 43),
#   (('calculator', 'that'), 39),
#   (('calculator', 'the'), 32),
#   (('calculator', 'in'), 29),
#   (('calculator', 'to'), 28),
#   (('calculator', 'it'), 27),
#   (('calculator', 'ha'), 25),
#   (('financial', 'calculator'), 21),
#   (('calculator', 'but'), 21),
#   (('calculator', 'a'), 18),
#   (('calculator', 'with'), 18),
#   (('basic', 'calculator'), 18),
#   (('ti', 'calculator'), 16),
#   (('casio', 'calculator'), 16),
#   (('good', 'calculator'), 13),
#   (('calculator', 'which'), 13),
#   (('these', 'calculator'), 12),
#   (('calculator', 'can'), 12),
#   (('calculator', 'you'), 11),
#   (('calculator', 'doe'), 11),
#   (('calculator', 'are'), 11),
#   (('calculator', 'on'), 10),
#   (('of', 'calculator'), 10),
#   (('calculator', 'this'), 10),
#   (('calculator', 'at'), 10),
#   (('calculator', 'so'), 10),
#   (('great', 'calculator'), 10),
#   (('other', 'calculator'), 10),
#   (('little', 'calculator'), 9),
#   (('calculator', 'gold'), 8),
#   (('calculator', 'would'), 8),
#   (('calculator', 'if'), 8),
#   (('calculator', 'wa'), 8),
#   (('calculator', 'will'), 8),
#   (('calculator', 'because'), 8),
#   (('pocket', 'calculator'), 8),
#   (('printing', 'calculator'), 8),
#   (('desktop', 'calculator'), 7),
#   (('new', 'calculator'), 7),
#   (('calculator', 'or'), 6),
#   (('simple', 'calculator'), 6),
#   (('solar', 'calculator'), 6),
#   (('my', 'calculator'), 6),
#   (('your', 'calculator'), 6),
#   (('old', 'calculator'), 6),
#   (('calculator', 'when'), 6),
#   (('canon', 'calculator'), 6),
#   (('calculator', 'also'), 6),
#   (('use', 'calculator'), 6),
#   (('calculator', 'just'), 5),
#   (('calculator', 'like'), 5),
#   (('calculator', 'from'), 5),
#   (('calculator', 'of'), 5),
#   (('any', 'calculator'), 5),
#   (('calculator', 'not'), 5),
#   (('larger', 'calculator'), 5),
#   (('calculator', 'calculator'), 5),
#   (('and', 'calculator'), 5),
#   (('calculator', 'there'), 5),
#   (('calculator', 'should'), 4),
#   (('calculator', 'without'), 4),
#   (('more', 'calculator'), 4),
#   (('another', 'calculator'), 4),
#   (('most', 'calculator'), 4),
#   (('nice', 'calculator'), 4),
#   (('instrument', 'calculator'), 4),
#   (('calculator', 'after'), 4),
#   (('same', 'calculator'), 4),
#   (('calculator', 'do'), 4),
#   (('calculator', 'really'), 4),
#   (('desk', 'calculator'), 4),
#   (('calculator', 'h'), 4),
#   (('calculator', 'come'), 4),
#   (('both', 'calculator'), 4),
#   (('calculator', 'user'), 4),
#   (('calculator', 'back'), 4),
#   (('calculator', 'multiview'), 4),
#   (('calculator', 'mv'), 4),
#   (('pen', 'calculator'), 4),
#   (('reliable', 'calculator'), 3),
#   (('calculator', 'before'), 3),
#   (('calculator', 'product'), 3),
#   (('calculator', 'line'), 3),
#   (('classic', 'calculator'), 3),
#   (('calculator', 'work'), 3),
#   (('standard', 'calculator'), 3),
#   (('those', 'calculator'), 3),
#   (('all', 'calculator'), 3),
#   (('calculator', 'today'), 3),
#   (('powered', 'calculator'), 3),
#   (('calculator', 'need'), 3),
#   (('calculator', 'all'), 3),
#   (('cheap', 'calculator'), 3),
#   (('graphic', 'calculator'), 3),
#   (('calculator', 'feature'), 3),
#   (('calculator', 'instead'), 3),
#   (('advanced', 'calculator'), 3),
#   (('calculator', 'stay'), 3),
#   (('calculator', 'first'), 3),
#   (('calculator', 'manufacturer'), 3),
#   (('inexpensive', 'calculator'), 3),
#   (('calculator', 'arrived'), 3),
#   (('calculator', 'seems'), 3),
#   (('only', 'calculator'), 3),
#   (('own', 'calculator'), 3),
#   (('calculator', 'have'), 3),
#   (('calculator', 'had'), 3),
#   (('older', 'calculator'), 3),
#   (('calculator', 'look'), 3),
#   (('their', 'calculator'), 3),
#   (('small', 'calculator'), 3),
#   (('calculator', 'screen'), 3),
#   (('or', 'calculator'), 3),
#   (('calculator', 'owner'), 2),
#   (('calculator', 'hp'), 2),
#   (('it', 'calculator'), 2),
#   (('calculator', 'business'), 2),
#   (('calculator', 'now'), 2),
#   (('calculator', 'fan'), 2),
#   (('calculator', 'series'), 2),
#   (('calculator', 'function'), 2),
#   (('calculator', 'maybe'), 2),
#   (('calculator', 'time'), 2),
#   (('calculator', 'us'), 2),
#   (('calculator', 'take'), 2),
#   (('calculator', 'big'), 2),
#   (('built', 'calculator'), 2),
#   (('calculator', 'very'), 2),
#   (('calculator', 'affordable'), 2),
#   (('calculator', 'since'), 2),
#   (('durable', 'calculator'), 2),
#   (('calculator', 'get'), 2),
#   (('calculator', 'out'), 2),
#   (('function', 'calculator'), 2),
#   (('powerful', 'calculator'), 2),
#   (('calculator', 'these'), 2),
#   (('last', 'calculator'), 2),
#   (('model', 'calculator'), 2),
#   (('using', 'calculator'), 2),
#   (('useful', 'calculator'), 2),
#   (('l', 'calculator'), 2),
#   (('smaller', 'calculator'), 2),
#   (('calculator', 'being'), 2),
#   (('h', 'calculator'), 2),
#   (('calculator', 'still'), 2),
#   (('calculator', 'sharp'), 2),
#   (('calculator', 'only'), 2),
#   (('battery', 'calculator'), 2),
#   (('business', 'calculator'), 2),
#   (('calculator', 'run'), 2),
#   (('fancy', 'calculator'), 2),
#   (('similar', 'calculator'), 2),
#   (('calculator', 'came'), 2),
#   (('calculator', 'output'), 2),
#   (('calculator', 'until'), 2),
#   (('calculator', 'use'), 2),
#   (('handheld', 'calculator'), 2),
#   (('calculator', 'production'), 2),
#   (('calculator', 'we'), 2),
#   (('calculator', 'however'), 2),
#   (('calculator', 'than'), 2),
#   (('calculator', 'gave'), 2),
#   (('calculator', 'they'), 2),
#   (('lined', 'calculator'), 2),
#   (('particular', 'calculator'), 2),
#   (('with', 'calculator'), 2),
#   (('calculator', 'could'), 2),
#   (('to', 'calculator'), 2),
#   (('calculator', 'student'), 2),
#   (('expensive', 'calculator'), 2),
#   (('calculator', 'were'), 2),
#   (('calculator', 'though'), 2),
#   (('phone', 'calculator'), 2),
#   (('calculator', 'etc'), 2),
#   (('large', 'calculator'), 2),
#   (('calculator', 'such'), 2),
#   (('calculator', 'display'), 2),
#   (('an', 'calculator'), 2),
#   (('priced', 'calculator'), 2),
#   (('affordable', 'calculator'), 2),
#   (('calculator', 'by'), 2),
#   (('calculator', 'item'), 2),
#   (('lcd', 'calculator'), 2),
#   (('calculator', 'style'), 2),
#   (('calculator', 'may'), 1),
#   (('surviving', 'calculator'), 1),
#   (('electronic', 'calculator'), 1),
#   (('calculator', 'ever'), 1),
#   (('calculator', 's'), 1),
#   (('rpn', 'calculator'), 1),
#   (('calculator', 'remains'), 1),
#   (('heldheld', 'calculator'), 1),
#   (('calculator', 'built'), 1),
#   (('calculator', 'why'), 1),
#   (('calculator', 'engraved'), 1),
#   (('calculator', 'anniversary'), 1),
#   (('calculator', 'legacy'), 1),
#   (('calculator', 'rpn'), 1),
#   (('straightforward', 'calculator'), 1),
#   (('walmart', 'calculator'), 1),
#   (('calculator', 'straightforward'), 1),
#   (('calculator', 'amortization'), 1),
#   (('calculator', 'require'), 1),
#   (('calculator', 'anyway'), 1),
#   (('whole', 'calculator'), 1),
#   (('calculator', 'premise'), 1),
#   (('calculator', 'worthwhile'), 1),
#   (('few', 'calculator'), 1),
#   (('different', 'calculator'), 1),
#   (('calculator', 'sadly'), 1),
#   (('newer', 'calculator'), 1),
#   (('now', 'calculator'), 1),
#   (('calculator', 'talk'), 1),
#   (('keyed', 'calculator'), 1),
#   (('calculator', 'under'), 1),
#   (('neat', 'calculator'), 1),
#   (('price', 'calculator'), 1),
#   (('required', 'calculator'), 1),
#   (('wonderful', 'calculator'), 1),
#   (('individual', 'calculator'), 1),
#   (('calculator', 'throughout'), 1),
#   (('available', 'calculator'), 1),
#   (('calculator', 'packaging'), 1),
#   (('calculator', 'scientific'), 1),
#   (('he', 'calculator'), 1),
#   (('calculator', 'apparently'), 1),
#   (('calculator', 'mandatory'), 1),
#   (('versatile', 'calculator'), 1),
#   (('calculator', 'yes'), 1),
#   (('calculator', 'unlike'), 1),
#   (('calculator', 'go'), 1),
#   (('one', 'calculator'), 1),
#   (('calculator', 'my'), 1),
#   (('solid', 'calculator'), 1),
#   (('calculator', 'sure'), 1),
#   (('calculator', 'cable'), 1),
#   (('calculator', 'powered'), 1),
#   (('plus', 'calculator'), 1),
#   (('calculator', 'combine'), 1),
#   (('calculator', 'contains'), 1),
#   (('in', 'calculator'), 1),
#   (('manual', 'calculator'), 1),
#   (('calculator', 'david'), 1),
#   (('calculator', 'worked'), 1),
#   (('calculator', 'site'), 1),
#   (('calculator', 'app'), 1),
#   (('star', 'calculator'), 1),
#   (('analyst', 'calculator'), 1),
#   (('have', 'calculator'), 1),
#   (('very', 'calculator'), 1),
#   (('normal', 'calculator'), 1),
#   (('competent', 'calculator'), 1),
#   (('calculator', 'either'), 1),
#   (('r', 'calculator'), 1),
#   (('when', 'calculator'), 1),
#   (('number', 'calculator'), 1),
#   (('portable', 'calculator'), 1),
#   (('main', 'calculator'), 1),
#   (('calculator', 'managing'), 1),
#   (('calculator', 'sits'), 1),
#   (('easy', 'calculator'), 1),
#   (('calculator', 'compact'), 1),
#   (('calculator', 'popular'), 1),
#   (('calculator', 'therefore'), 1),
#   (('calculator', 'say'), 1),
#   (('therethe', 'calculator'), 1),
#   (('calculator', 'upside'), 1),
#   (('calculator', 'trick'), 1),
#   (('calculator', 'down'), 1),
#   (('regular', 'calculator'), 1),
#   (('calculator', 'pretty'), 1),
#   (('calculator', 'especially'), 1),
#   (('supply', 'calculator'), 1),
#   (('fun', 'calculator'), 1),
#   (('calculator', 'stopped'), 1),
#   (('calculator', 'basically'), 1),
#   (('calculator', 'who'), 1),
#   (('sturdy', 'calculator'), 1),
#   (('fantastic', 'calculator'), 1),
#   (('calculator', 'solid'), 1),
#   (('calculator', 'thus'), 1),
#   (('calculator', 'most'), 1),
#   (('calculator', 'default'), 1),
#   (('calculator', 'aos'), 1),
#   (('calculator', 'wish'), 1),
#   (('nose', 'calculator'), 1),
#   (('calculator', 'daily'), 1),
#   (('cost', 'calculator'), 1),
#   (('calculator', 'froze'), 1),
#   (('calculator', 'canon'), 1),
#   (('calculator', 'died'), 1),
#   (('calculator', 'offer'), 1),
#   (('calculator', 'mentioned'), 1),
#   (('calculator', 'helped'), 1),
#   (('overpriced', 'calculator'), 1),
#   (('calculator', 'instruction'), 1),
#   (('calculator', 'scientifics'), 1),
#   (('calculator', 'cover'), 1),
#   (('calculator', 'often'), 1),
#   (('calculator', 'register'), 1),
#   (('calculator', 'solves'), 1),
#   (('excellent', 'calculator'), 1),
#   (('calculator', 'used'), 1),
#   (('calculator', 'fraction'), 1),
#   (('notice', 'calculator'), 1),
#   (('calculator', 'worthless'), 1),
#   (('calculator', 'cousin'), 1),
#   (('series', 'calculator'), 1),
#   (('calculator', 'previously'), 1),
#   (('calculator', 'face'), 1),
#   (('moved', 'calculator'), 1),
#   (('produced', 'calculator'), 1),
#   (('calculator', 'market'), 1),
#   (('dollar', 'calculator'), 1),
#   (('calculator', 'ti'), 1),
#   (('better', 'calculator'), 1),
#   (('calculator', 'same'), 1),
#   (('researching', 'calculator'), 1),
#   (('superior', 'calculator'), 1),
#   (('calculator', 'every'), 1),
#   (('calculator', 'useless'), 1),
#   (('child', 'calculator'), 1),
#   (('calculator', 'supply'), 1),
#   (('calculator', 'lack'), 1),
#   (('bad', 'calculator'), 1),
#   (('calculator', 'using'), 1),
#   (('calculator', 'exists'), 1),
#   (('potent', 'calculator'), 1),
#   (('so', 'calculator'), 1),
#   (('calculator', 'support'), 1),
#   (('best', 'calculator'), 1),
#   (('work', 'calculator'), 1),
#   (('many', 'calculator'), 1),
#   (('if', 'calculator'), 1),
#   (('x', 'calculator'), 1),
#   (('calculator', 'button'), 1),
#   (('calculator', 'mostly'), 1),
#   (('stylish', 'calculator'), 1),
#   (('calculator', 'bought'), 1),
#   (('calculator', 'allowed'), 1),
#   (('original', 'calculator'), 1),
#   (('calculator', 'did'), 1),
#   (('updated', 'calculator'), 1),
#   (('carry', 'calculator'), 1),
#   (('rich', 'calculator'), 1),
#   (('calculator', 'thank'), 1),
#   (('traditional', 'calculator'), 1),
#   (('calculator', 'during'), 1),
#   (('scienfic', 'calculator'), 1),
#   (('scienfitic', 'calculator'), 1),
#   (('terrible', 'calculator'), 1),
#   (('regarding', 'calculator'), 1),
#   (('calculator', 'design'), 1),
#   (('calculator', 'world'), 1),
#   (('earlier', 'calculator'), 1),
#   (('calculator', 'feel'), 1),
#   (('calculator', 'innovation'), 1),
#   (('calculator', 'salesperson'), 1),
#   (('calculator', 'software'), 1),
#   (('calculator', 'quality'), 1),
#   (('enough', 'calculator'), 1),
#   (('calculator', 'apps'), 1),
#   (('calculator', 'nice'), 1),
#   (('you', 'calculator'), 1),
#   (('calculator', 'wallet'), 1),
#   (('digit', 'calculator'), 1),
#   (('calculator', 'happily'), 1),
#   (('calculator', 'too'), 1),
#   (('newest', 'calculator'), 1),
#   (('calculator', 'thanks'), 1),
#   (('calculator', 'ran'), 1),
#   (('calculator', 'where'), 1),
#   (('every', 'calculator'), 1),
#   (('calculator', 'even'), 1),
#   (('mini', 'calculator'), 1),
#   (('calculator', 'worth'), 1),
#   (('calculator', 'great'), 1),
#   (('calculator', 'another'), 1),
#   (('having', 'calculator'), 1),
#   (('by', 'calculator'), 1),
#   (('calculator', 'itself'), 1),
#   (('calculator', 'he'), 1),
#   (('calculator', 'about'), 1),
#   (('calculator', 'highly'), 1),
#   (('calculator', 'well'), 1),
#   (('calculator', 'here'), 1),
#   (('calculator', 'specifically'), 1),
#   (('calculator', 'similar'), 1),
#   (('calculator', 'something'), 1),
#   (('calculator', 'star'), 1),
#   (('calculator', 'manual'), 1),
#   (('thing', 'calculator'), 1),
#   (('calculator', 'man'), 1),
#   (('cool', 'calculator'), 1),
#   (('calculator', 'per'), 1),
#   (('calculator', 'no'), 1),
#   (('perfect', 'calculator'), 1),
#   (('efficient', 'calculator'), 1),
#   (('minor', 'calculator'), 1),
#   (('handsome', 'calculator'), 1),
#   (('used', 'calculator'), 1),
#   (('forany', 'calculator'), 1),
#   (('calculator', 'differs'), 1),
#   (('calculator', 'once'), 1),
#   (('calculator', 'over'), 1),
#   (('casiothis', 'calculator'), 1),
#   (('calculator', 'directly'), 1),
#   (('calculator', 'performs'), 1),
#   (('are', 'calculator'), 1),
#   (('should', 'calculator'), 1),
#   (('calculator', 'receipt'), 1),
#   (('protractor', 'calculator'), 1),
#   (('calculator', 'swatch'), 1),
#   (('calculator', 'best'), 1),
#   (('calculator', 'pencil'), 1),
#   (('calculator', 'measuring'), 1),
#   (('calculator', 'coupon'), 1),
#   (('tool', 'calculator'), 1),
#   (('calculator', 'tape'), 1),
#   (('calculator', 'ruler'), 1),
#   (('prizm', 'calculator'), 1),
#   (('calculator', 'color'), 1),
#   (('thought', 'calculator'), 1),
#   (('coolest', 'calculator'), 1),
#   (('calculator', 'more'), 1),
#   (('calculator', 'received'), 1),
#   (('calculator', 'how'), 1),
#   (('average', 'calculator'), 1),
#   (('calculator', 'keyset'), 1),
#   (('our', 'calculator'), 1),
#   (('calculator', 'collection'), 1),
#   (('issue', 'calculator'), 1),
#   (('higher', 'calculator'), 1),
#   (('calculator', 'compared'), 1),
#   (('amazing', 'calculator'), 1),
#   (('amazonbasics', 'calculator'), 1),
#   (('cheapy', 'calculator'), 1),
#   (('plain', 'calculator'), 1),
#   (('calculator', 'made'), 1),
#   (('is', 'calculator'), 1),
#   (('window', 'calculator'), 1),
#   (('looking', 'calculator'), 1),
#   (('calculator', 'put'), 1),
#   (('calculator', 'control'), 1),
#   (('abasic', 'calculator'), 1),
#   (('brand', 'calculator'), 1),
#   (('some', 'calculator'), 1),
#   (('several', 'calculator'), 1),
#   (('calculator', 'include'), 1),
#   (('calculator', 'huge'), 1),
#   (('amazonasics', 'calculator'), 1),
#   (('son', 'calculator'), 1),
#   (('top', 'calculator'), 1),
#   (('calculator', 'our'), 1),
#   (('calculator', 'collector'), 1),
#   (('household', 'calculator'), 1),
#   (('calculator', 'measure'), 1),
#   (('display', 'calculator'), 1),
#   (('walgreens', 'calculator'), 1),
#   (('amazon', 'calculator'), 1),
#   (('calculator', 'meant'), 1),
#   (('general', 'calculator'), 1),
#   (('calculator', 'many'), 1),
#   (('calculator', 'outside'), 1),
#   (('calculator', 'gum'), 1),
#   (('item', 'calculator'), 1),
#   (('smallish', 'calculator'), 1),
#   (('pencil', 'calculator'), 1),
#   (('calculator', 'cell'), 1)]}

# %% [markdown]
# Многие частотные биграммы не особо информативны, поскольку содержат в себе предлоги, артикли и тд.
# Создадим список стоп-слов, чтобы отсеить по нему неинформативные биграммы

# %%
stopwords = ['the', 'this', 'is', 'and', 'i', 'for', 'a', 'to',
                'that', 'it', 'on', 'of', 'at', 'from', 'with',
                'can', 'are', 'in', 'will', 'would','these', 'if', 
                'but', 'so', 'or', 'because', 'up', 'ha']

# %% [markdown]
# Отфильтруем биграммы

# %%
product_bigrams_2 = {'printer':[], 'binder':[], 'dispenser':[], 'folder':[], 'stapler':[], 'calculator':[]}
    
for bigram in bi_dict.most_common():
    for product in product_bigrams_2.keys():
        if (product in bigram[0] and bigram[0][0] not in stopwords 
            and bigram[0][1] not in stopwords and bigram[0][0] != bigram[0][1]):
            product_bigrams_2[product].append(bigram)

# %% [markdown]
# Уже гораздо лучше

# %%
product_bigrams_2
# Out:
# {'printer': [(('laser', 'printer'), 707),
#   (('epson', 'printer'), 582),
#   (('photo', 'printer'), 460),
#   (('printer', 'wa'), 427),
#   (('inkjet', 'printer'), 370),
#   (('other', 'printer'), 339),
#   (('hp', 'printer'), 296),
#   (('canon', 'printer'), 294),
#   (('printer', 'doe'), 283),
#   (('my', 'printer'), 276),
#   (('wireless', 'printer'), 273),
#   (('new', 'printer'), 215),
#   (('great', 'printer'), 213),
#   (('printer', 'you'), 203),
#   (('printer', 'which'), 191),
#   (('your', 'printer'), 190),
#   (('workforce', 'printer'), 147),
#   (('printer', 'itself'), 140),
#   (('color', 'printer'), 135),
#   (('good', 'printer'), 128),
#   (('old', 'printer'), 122),
#   (('printer', 'have'), 117),
#   (('printer', 'also'), 112),
#   (('brother', 'printer'), 110),
#   (('home', 'printer'), 110),
#   (('printer', 'come'), 109),
#   (('printer', 'driver'), 106),
#   (('printer', 'print'), 103),
#   (('one', 'printer'), 103),
#   (('office', 'printer'), 102),
#   (('printer', 'when'), 96),
#   (('printer', 'work'), 96),
#   (('printer', 'over'), 90),
#   (('printer', 'we'), 90),
#   (('printer', 'scanner'), 87),
#   (('printer', 'like'), 83),
#   (('printer', 'ink'), 82),
#   (('little', 'printer'), 80),
#   (('pixma', 'printer'), 79),
#   (('any', 'printer'), 78),
#   (('printer', 'us'), 77),
#   (('printer', 'cartridge'), 76),
#   (('printer', 'copier'), 74),
#   (('printer', 'there'), 72),
#   (('printer', 'cable'), 71),
#   (('format', 'printer'), 71),
#   (('printer', 'software'), 71),
#   (('multifunction', 'printer'), 71),
#   (('jet', 'printer'), 70),
#   (('most', 'printer'), 70),
#   (('printer', 'wireless'), 66),
#   (('printer', 'my'), 65),
#   (('printer', 'not'), 63),
#   (('quality', 'printer'), 63),
#   (('previous', 'printer'), 63),
#   (('printer', 'after'), 62),
#   (('printer', 'paper'), 62),
#   (('nice', 'printer'), 62),
#   (('an', 'printer'), 61),
#   (('printer', 'did'), 61),
#   (('printer', 'before'), 60),
#   (('another', 'printer'), 60),
#   (('printer', 'just'), 59),
#   (('printer', 'however'), 59),
#   (('usb', 'printer'), 58),
#   (('printer', 'take'), 58),
#   (('both', 'printer'), 57),
#   (('many', 'printer'), 57),
#   (('printer', 'out'), 55),
#   (('monochrome', 'printer'), 55),
#   (('best', 'printer'), 53),
#   (('printer', 'do'), 53),
#   (('first', 'printer'), 53),
#   (('their', 'printer'), 52),
#   (('printer', 'since'), 51),
#   (('excellent', 'printer'), 51),
#   (('printer', 'setup'), 51),
#   (('printer', 'had'), 49),
#   (('printer', 'using'), 49),
#   (('last', 'printer'), 49),
#   (('printer', 'without'), 48),
#   (('samsung', 'printer'), 48),
#   (('printer', 'via'), 48),
#   (('printer', 'they'), 46),
#   (('all', 'printer'), 45),
#   (('printer', 'even'), 45),
#   (('network', 'printer'), 44),
#   (('printer', 'by'), 42),
#   (('printer', 'should'), 41),
#   (('printer', 'set'), 41),
#   (('kodak', 'printer'), 41),
#   (('printer', 'could'), 40),
#   (('printer', 'seems'), 39),
#   (('printer', 'head'), 38),
#   (('small', 'printer'), 38),
#   (('printer', 'were'), 37),
#   (('printer', 'while'), 37),
#   (('printer', 'all'), 37),
#   (('printer', 'then'), 37),
#   (('pro', 'printer'), 37),
#   (('printer', 'offer'), 37),
#   (('printer', 'go'), 36),
#   (('printer', 'look'), 36),
#   (('printer', 'setting'), 35),
#   (('printer', 'epson'), 35),
#   (('printer', 'make'), 35),
#   (('printer', 'control'), 35),
#   (('printer', 'one'), 34),
#   (('older', 'printer'), 34),
#   (('printer', 'an'), 34),
#   (('two', 'printer'), 34),
#   (('solid', 'printer'), 33),
#   (('printer', 'no'), 33),
#   (('printer', 'now'), 33),
#   (('printer', 'where'), 33),
#   (('basic', 'printer'), 33),
#   (('decent', 'printer'), 32),
#   (('printer', 'than'), 32),
#   (('large', 'printer'), 32),
#   (('big', 'printer'), 32),
#   (('fantastic', 'printer'), 32),
#   (('printer', 'feature'), 32),
#   (('expensive', 'printer'), 31),
#   (('printer', 'really'), 31),
#   (('printer', 'although'), 31),
#   (('printer', 'manufacturer'), 31),
#   (('some', 'printer'), 31),
#   (('printer', 'cost'), 30),
#   (('printer', 'worked'), 30),
#   (('printer', 'off'), 29),
#   (('printer', 'through'), 29),
#   (('printer', 'may'), 29),
#   (('reliable', 'printer'), 29),
#   (('printer', 'only'), 29),
#   (('printer', 'into'), 29),
#   (('fast', 'printer'), 28),
#   (('printer', 'star'), 28),
#   (('same', 'printer'), 28),
#   (('printer', 'first'), 28),
#   (('printer', 'connected'), 28),
#   (('regular', 'printer'), 28),
#   (('printer', 'need'), 28),
#   (('printer', 'came'), 28),
#   (('printer', 'very'), 27),
#   (('printer', 'until'), 27),
#   (('printer', 'canon'), 27),
#   (('printer', 'both'), 27),
#   (('printer', 'get'), 27),
#   (('printer', 'produce'), 26),
#   (('printer', 'model'), 26),
#   (('better', 'printer'), 26),
#   (('printer', 'use'), 25),
#   (('printer', 'photo'), 25),
#   (('printer', 'once'), 24),
#   (('perfect', 'printer'), 24),
#   (('printer', 'including'), 24),
#   (('business', 'printer'), 24),
#   (('only', 'printer'), 23),
#   (('white', 'printer'), 23),
#   (('document', 'printer'), 23),
#   (('printer', 'function'), 23),
#   (('cheap', 'printer'), 23),
#   (('compact', 'printer'), 23),
#   (('printer', 'overall'), 22),
#   (('printer', 'color'), 22),
#   (('inexpensive', 'printer'), 22),
#   (('wifi', 'printer'), 22),
#   (('different', 'printer'), 21),
#   (('printer', 'though'), 21),
#   (('printer', 'instead'), 21),
#   (('ink', 'printer'), 21),
#   (('printer', 'easy'), 21),
#   (('printer', 'scan'), 21),
#   (('printer', 'company'), 21),
#   (('printer', 'such'), 21),
#   (('printer', 'wirelessly'), 21),
#   (('printer', 'stand'), 21),
#   (('use', 'printer'), 21),
#   (('particular', 'printer'), 20),
#   (('printer', 'usb'), 20),
#   (('our', 'printer'), 20),
#   (('printer', 'still'), 20),
#   (('label', 'printer'), 20),
#   (('heavy', 'printer'), 20),
#   (('printer', 'right'), 20),
#   (('printer', 'directly'), 20),
#   (('printer', 'took'), 20),
#   (('printer', 'inkjet'), 20),
#   (('standard', 'printer'), 19),
#   (('printer', 'back'), 19),
#   (('printer', 'support'), 19),
#   (('printer', 'used'), 19),
#   (('default', 'printer'), 19),
#   (('printer', 'workforce'), 19),
#   (('printer', 'printing'), 19),
#   (('printer', 'durabrite'), 19),
#   (('printer', 'being'), 18),
#   (('printer', 'requires'), 18),
#   (('printer', 'again'), 18),
#   (('end', 'printer'), 18),
#   (('printer', 'more'), 18),
#   (('few', 'printer'), 18),
#   (('printer', 'well'), 17),
#   (('fastest', 'printer'), 17),
#   (('have', 'printer'), 17),
#   (('printer', 'quality'), 17),
#   (('printer', 'arrived'), 17),
#   (('printer', 'firmware'), 17),
#   (('printer', 'especially'), 17),
#   (('three', 'printer'), 16),
#   (('printer', 'too'), 16),
#   (('wonderful', 'printer'), 16),
#   (('newer', 'printer'), 16),
#   (('model', 'printer'), 16),
#   (('printer', 'easily'), 16),
#   (('printer', 'allows'), 16),
#   (('printer', 'went'), 16),
#   (('printer', 'fax'), 16),
#   (('artisan', 'printer'), 16),
#   (('printer', 'today'), 16),
#   (('premium', 'printer'), 16),
#   (('series', 'printer'), 15),
#   (('each', 'printer'), 15),
#   (('aio', 'printer'), 15),
#   (('several', 'printer'), 15),
#   (('printer', 'some'), 15),
#   (('fine', 'printer'), 15),
#   (('size', 'printer'), 15),
#   (('printer', 'give'), 15),
#   (('printer', 'within'), 15),
#   (('printer', 'installation'), 15),
#   (('expression', 'printer'), 15),
#   (('personal', 'printer'), 14),
#   (('printer', 'available'), 14),
#   (('printer', 'hp'), 14),
#   (('printer', 'died'), 14),
#   (('printer', 'automatically'), 14),
#   (('entire', 'printer'), 14),
#   (('printer', 's'), 14),
#   (('based', 'printer'), 14),
#   (('level', 'printer'), 14),
#   (('printer', 'unless'), 14),
#   (('printer', 'what'), 13),
#   (('laserjet', 'printer'), 13),
#   (('printer', 'last'), 13),
#   (('cheaper', 'printer'), 13),
#   (('professional', 'printer'), 13),
#   (('printer', 'lcd'), 13),
#   (('larger', 'printer'), 13),
#   (('printer', 'provides'), 13),
#   (('second', 'printer'), 13),
#   (('printer', 'menu'), 13),
#   (('smaller', 'printer'), 13),
#   (('printer', 'turn'), 12),
#   (('printer', 'under'), 12),
#   (('printer', 'printed'), 12),
#   (('printer', 'website'), 12),
#   (('cannon', 'printer'), 12),
#   (('printer', 'plus'), 12),
#   (('than', 'printer'), 12),
#   (('simple', 'printer'), 12),
#   (('printer', 'wo'), 12),
#   (('printer', 'product'), 12),
#   (('printer', 'installed'), 12),
#   (('worst', 'printer'), 12),
#   (('printer', 'about'), 12),
#   (('brand', 'printer'), 12),
#   (('printer', 'hold'), 12),
#   (('printer', 'option'), 12),
#   (('those', 'printer'), 12),
#   (('printer', 'rather'), 12),
#   (('capable', 'printer'), 12),
#   (('no', 'printer'), 12),
#   (('printer', 'status'), 12),
#   (('using', 'printer'), 12),
#   (('printer', 'most'), 12),
#   (('fax', 'printer'), 12),
#   (('printer', 'anywhere'), 12),
#   (('printer', 'fit'), 12),
#   (('printer', 'screen'), 12),
#   (('similar', 'printer'), 12),
#   (('priced', 'printer'), 12),
#   (('printer', 'cord'), 12),
#   (('easy', 'printer'), 12),
#   (('printer', 'app'), 12),
#   (('cartridge', 'printer'), 11),
#   (('actual', 'printer'), 11),
#   (('scanner', 'printer'), 11),
#   (('earlier', 'printer'), 11),
#   (('more', 'printer'), 11),
#   (('printer', 'made'), 11),
#   (('printer', 'other'), 11),
#   (('replacement', 'printer'), 11),
#   (('print', 'printer'), 11),
#   (('printer', 'seem'), 11),
#   (('main', 'printer'), 11),
#   (('printer', 'during'), 11),
#   (('printer', 'pro'), 11),
#   (('wired', 'printer'), 11),
#   (('printer', 'let'), 11),
#   (('printer', 'yet'), 11),
#   (('printer', 'display'), 11),
#   (('budget', 'printer'), 11),
#   (('workhorse', 'printer'), 11),
#   (('awesome', 'printer'), 11),
#   (('primary', 'printer'), 11),
#   (('printer', 'pixma'), 11),
#   (('printer', 'replaced'), 11),
#   (('printer', 'tray'), 10),
#   (('black', 'printer'), 10),
#   (('printer', 'great'), 10),
#   (('own', 'printer'), 10),
#   (('photosmart', 'printer'), 10),
#   (('printer', 'around'), 10),
#   (('lexmark', 'printer'), 10),
#   (('next', 'printer'), 10),
#   (('very', 'printer'), 10),
#   (('printer', 'keep'), 10),
#   (('like', 'printer'), 10),
#   (('printer', 'wired'), 10),
#   (('printer', 'box'), 10),
#   (('printer', 'output'), 10),
#   (('matrix', 'printer'), 10),
#   (('function', 'printer'), 10),
#   (('printer', 'profile'), 10),
#   (('printer', 'touch'), 10),
#   (('esp', 'printer'), 10),
#   (('every', 'printer'), 10),
#   (('looking', 'printer'), 10),
#   (('printer', 'property'), 10),
#   (('printer', 'meet'), 10),
#   (('amazing', 'printer'), 10),
#   (('printer', 'port'), 9),
#   (('printer', 'ca'), 9),
#   (('printer', 'compared'), 9),
#   (('which', 'printer'), 9),
#   (('printer', 'be'), 9),
#   (('printer', 'put'), 9),
#   (('printer', 'user'), 9),
#   (('quiet', 'printer'), 9),
#   (('overall', 'printer'), 9),
#   (('printer', 'ip'), 9),
#   (('printer', 'say'), 9),
#   (('printer', 'every'), 9),
#   (('printer', 'size'), 9),
#   (('printer', 'unit'), 9),
#   (('printer', 'here'), 9),
#   (('work', 'printer'), 9),
#   (('huge', 'printer'), 9),
#   (('printer', 'might'), 9),
#   (('printer', 'fan'), 9),
#   (('loading', 'printer'), 9),
#   (('printer', 'capability'), 9),
#   (('about', 'printer'), 9),
#   (('printer', 'mostly'), 9),
#   (('printer', 'actually'), 9),
#   (('printer', 'sometimes'), 9),
#   (('printer', 'manual'), 9),
#   (('printer', 'highly'), 9),
#   (('printer', 'email'), 9),
#   (('apple', 'printer'), 9),
#   (('printer', 'found'), 9),
#   (('printer', 'immediately'), 9),
#   (('multiple', 'printer'), 9),
#   (('printer', 'delivers'), 9),
#   (('what', 'printer'), 8),
#   (('by', 'printer'), 8),
#   (('printer', 'include'), 8),
#   (('w', 'printer'), 8),
#   (('printer', 'simply'), 8),
#   (('printer', 'two'), 8),
#   (('printer', 'several'), 8),
#   (('printer', 'much'), 8),
#   (('printer', 'stopped'), 8),
#   (('existing', 'printer'), 8),
#   (('printer', 'black'), 8),
#   (('printer', 'started'), 8),
#   (('printer', 'often'), 8),
#   (('printer', 'many'), 8),
#   (('printer', 'ever'), 8),
#   (('printer', 'start'), 8),
#   (('printer', 'seemed'), 8),
#   (('printing', 'printer'), 8),
#   (('box', 'printer'), 8),
#   (('current', 'printer'), 8),
#   (('printer', 'large'), 8),
#   (('desktop', 'printer'), 8),
#   (('printer', 'hardware'), 8),
#   (('printer', 'laser'), 8),
#   (('printer', 'design'), 8),
#   (('printer', 'update'), 8),
#   (('pigment', 'printer'), 8),
#   (('ok', 'printer'), 8),
#   (('printer', 'scanning'), 8),
#   (('printer', 'includes'), 8),
#   (('printer', 'toner'), 8),
#   (('printer', 'series'), 8),
#   (('enabled', 'printer'), 8),
#   (('printer', 'performs'), 8),
#   (('printer', 'next'), 8),
#   (('printer', 'hooked'), 8),
#   (('four', 'printer'), 8),
#   (('printer', 'finally'), 8),
#   (('printer', 'must'), 8),
#   (('printer', 'sitting'), 8),
#   (('duty', 'printer'), 8),
#   (('printer', 'line'), 8),
#   (('printer', 'nor'), 8),
#   (('networked', 'printer'), 8),
#   (('printer', 'connect'), 8),
#   (('printer', 'initially'), 7),
#   (('printer', 'having'), 7),
#   (('comparable', 'printer'), 7),
#   (('around', 'printer'), 7),
#   (('printer', 'utility'), 7),
#   (('printer', 'away'), 7),
#   (('x', 'printer'), 7),
#   (('printer', 'power'), 7),
#   (('dell', 'printer'), 7),
#   (('printer', 'far'), 7),
#   (('printer', 'yes'), 7),
#   (('separate', 'printer'), 7),
#   (('printer', 'lack'), 7),
#   (('printer', 'maker'), 7),
#   (('had', 'printer'), 7),
#   (('printer', 'online'), 7),
#   (('add', 'printer'), 7),
#   (('printer', 'handle'), 7),
#   (('printer', 'recently'), 7),
#   (('cost', 'printer'), 7),
#   (('printer', 'high'), 7),
#   (('printer', 'good'), 7),
#   (('printer', 'test'), 7),
#   (('whole', 'printer'), 7),
#   (('everyday', 'printer'), 7),
#   (('printer', 'panel'), 7),
#   (('printer', 'due'), 7),
#   (('type', 'printer'), 7),
#   (('printer', 'web'), 7),
#   (('affordable', 'printer'), 7),
#   (('printer', 'unlike'), 7),
#   (('printer', 'quickly'), 7),
#   (('third', 'printer'), 7),
#   (('page', 'printer'), 7),
#   (('printer', 'designed'), 7),
#   (('printer', 'definitely'), 7),
#   (('printer', 'pretty'), 7),
#   (('printer', 'network'), 7),
#   (('printer', 'already'), 7),
#   (('average', 'printer'), 7),
#   (('printer', 'got'), 7),
#   (('not', 'printer'), 7),
#   (('original', 'printer'), 7),
#   (('airprint', 'printer'), 7),
#   (('printer', 'run'), 7),
#   (('printer', 'sits'), 7),
#   (('printer', 'near'), 7),
#   (('printer', 'despite'), 7),
#   (('printer', 'connection'), 7),
#   (('printer', 'required'), 7),
#   (('printer', 'better'), 7),
#   (('printer', 'particularly'), 7),
#   (('printer', 'speed'), 7),
#   (('purpose', 'printer'), 6),
#   (('printer', 'mainly'), 6),
#   (('printer', 'customer'), 6),
#   (('printer', 'buy'), 6),
#   (('printer', 'working'), 6),
#   (('specific', 'printer'), 6),
#   (('either', 'printer'), 6),
#   (('printer', 'year'), 6),
#   (('printer', 'plug'), 6),
#   (('local', 'printer'), 6),
#   (('printer', 'new'), 6),
#   (('disposable', 'printer'), 6),
#   (('printer', 'specifically'), 6),
#   (('printer', 'down'), 6),
#   (('buy', 'printer'), 6),
#   (('printer', 'machine'), 6),
#   (('general', 'printer'), 6),
#   (('duplex', 'printer'), 6),
#   (('set', 'printer'), 6),
#   (('out', 'printer'), 6),
#   (('attractive', 'printer'), 6),
#   (('versatile', 'printer'), 6),
#   (('printer', 'except'), 6),
#   (('economical', 'printer'), 6),
#   (('printer', 'install'), 6),
#   (('photographic', 'printer'), 6),
#   (('printer', 'appears'), 6),
#   (('printer', 'ran'), 6),
#   (('printer', 'everything'), 6),
#   (('you', 'printer'), 6),
#   (('free', 'printer'), 6),
#   (('printer', 'included'), 6),
#   (('printer', 'copy'), 6),
#   (('printer', 'own'), 6),
#   (('star', 'printer'), 6),
#   (('be', 'printer'), 6),
#   (('secondary', 'printer'), 6),
#   (('into', 'printer'), 6),
#   (('printer', 'claim'), 6),
#   (('printer', 'ship'), 6),
#   (('printer', 'etc'), 6),
#   (('panasonic', 'printer'), 6),
#   (('broken', 'printer'), 6),
#   (('printer', 'wifi'), 6),
#   (('much', 'printer'), 6),
#   (('printer', 'note'), 6),
#   (('printer', 'almost'), 6),
#   (('printer', 'small'), 6),
#   (('printer', 'technology'), 6),
#   (('printer', 'apparently'), 6),
#   (('printer', 'interface'), 6),
#   (('printer', 'list'), 6),
#   (('printer', 'front'), 6),
#   (('easiest', 'printer'), 6),
#   (('printer', 'table'), 6),
#   (('printer', 'five'), 6),
#   (('printer', 'grab'), 6),
#   (('outstanding', 'printer'), 6),
#   (('force', 'printer'), 6),
#   (('printer', 'page'), 6),
#   (('printer', 'needed'), 6),
#   (('bigger', 'printer'), 6),
#   (('printer', 'each'), 6),
#   (('printer', 'see'), 6),
#   (('impressive', 'printer'), 6),
#   (('printer', 'x'), 6),
#   (('lazer', 'printer'), 6),
#   (('dozen', 'printer'), 6),
#   (('printer', 'making'), 5),
#   (('printer', 'gave'), 5),
#   (('printer', 'together'), 5),
#   (('prior', 'printer'), 5),
#   (('printer', 'based'), 5),
#   (('side', 'printer'), 5),
#   (('deskjet', 'printer'), 5),
#   (('printer', 'aba'), 5),
#   (('printer', 'management'), 5),
#   (('printer', 'probably'), 5),
#   (('latest', 'printer'), 5),
#   (('slowest', 'printer'), 5),
#   (('printer', 'brand'), 5),
#   (('included', 'printer'), 5),
#   (('printer', 'life'), 5),
#   (('printer', 'drink'), 5),
#   (('printer', 'footprint'), 5),
#   (('printer', 'produced'), 5),
#   (('printer', 'camera'), 5),
#   (('printer', 'physically'), 5),
#   (('printer', 'sell'), 5),
#   (('printer', 'brings'), 5),
#   (('printer', 'four'), 5),
#   (('his', 'printer'), 5),
#   (('printer', 'meant'), 5),
#   (('printer', 'part'), 5),
#   (('day', 'printer'), 5),
#   (('printer', 'useless'), 5),
#   (('printer', 'long'), 5),
#   (('printer', 'review'), 5),
#   (('working', 'printer'), 5),
#   (('recent', 'printer'), 5),
#   (('recommended', 'printer'), 5),
#   (('called', 'printer'), 5),
#   (('printer', 'home'), 5),
#   (('between', 'printer'), 5),
#   (('grade', 'printer'), 5),
#   (('printer', 'preference'), 5),
#   (('favorite', 'printer'), 5),
#   (('printer', 'showed'), 5),
#   (('printer', 'performed'), 5),
#   (('printer', 'address'), 5),
#   (('built', 'printer'), 5),
#   (('dollar', 'printer'), 5),
#   (('printer', 'duplex'), 5),
#   (('printer', 'brother'), 5),
#   (('printer', 'currently'), 5),
#   (('printer', 'price'), 5),
#   (('former', 'printer'), 5),
#   (('printer', 'beat'), 5),
#   (('printer', 'recognized'), 5),
#   (('cd', 'printer'), 5),
#   (('alone', 'printer'), 5),
#   (('printer', 'onto'), 5),
#   (('printer', 'along'), 5),
#   (('efficient', 'printer'), 5),
#   (('sturdy', 'printer'), 5),
#   (('printer', 'your'), 5),
#   (('though', 'printer'), 5),
#   (('injet', 'printer'), 5),
#   (('printer', 'manager'), 5),
#   (('sized', 'printer'), 5),
#   (('sided', 'printer'), 5),
#   (('printer', 'samsung'), 5),
#   (('printer', 'feel'), 5),
#   (('printer', 'measure'), 5),
#   (('multifunctional', 'printer'), 5),
#   (('cloud', 'printer'), 5),
#   (('how', 'printer'), 5),
#   (('printer', 'touchscreen'), 5),
#   (('past', 'printer'), 5),
#   (('ricoh', 'printer'), 5),
#   (('volume', 'printer'), 4),
#   (('such', 'printer'), 4),
#   (('printer', 'accepts'), 4),
#   (('printer', 'everyone'), 4),
#   (('officejet', 'printer'), 4),
#   (('just', 'printer'), 4),
#   (('used', 'printer'), 4),
#   (('printer', 'never'), 4),
#   (('printer', 'yesterday'), 4),
#   (('printer', 'warms'), 4),
#   (('printer', 'eats'), 4),
#   (('newest', 'printer'), 4),
#   (('printer', 'application'), 4),
#   (('make', 'printer'), 4),
#   (('printer', 'lasted'), 4),
#   (('cheapest', 'printer'), 4),
#   (('printer', 'refused'), 4),
#   (('paper', 'printer'), 4),
#   (('powerful', 'printer'), 4),
#   (('dependable', 'printer'), 4),
#   (('printer', 'free'), 4),
#   (('ideal', 'printer'), 4),
#   (('printer', 'straight'), 4),
#   (('genuine', 'printer'), 4),
#   (('printer', 'repaired'), 4),
#   (('printer', 'fault'), 4),
#   (('printer', 'above'), 4),
#   (('printer', 'frequently'), 4),
#   (('shared', 'printer'), 4),
#   (('printer', 'decides'), 4),
#   (('printer', 'show'), 4),
#   (('printer', 'refuse'), 4),
#   (('printer', 'recognizes'), 4),
#   (('printer', 'love'), 4),
#   (('printer', 'located'), 4),
#   (('year', 'printer'), 4),
#   (('ethernet', 'printer'), 4),
#   (('defective', 'printer'), 4),
#   (('giant', 'printer'), 4),
#   (('printer', 'either'), 4),
#   (('printer', 'utilizes'), 4),
#   (('printer', 'issue'), 4),
#   (('printer', 'open'), 4),
#   (('printer', 'save'), 4),
#   (('printer', 'owner'), 4),
#   (('printer', 'configuration'), 4),
#   (('printer', 'usually'), 4),
#   (('printer', 'console'), 4),
#   (('printer', 'costing'), 4),
#   (('wa', 'printer'), 4),
#   (('printer', 'quite'), 4),
#   (('packard', 'printer'), 4),
#   (('printer', 'failed'), 4),
#   (('printer', 'require'), 4),
#   (('stylus', 'printer'), 4),
#   (('price', 'printer'), 4),
#   (('printer', 'loaded'), 4),
#   (('printer', 'delivered'), 4),
#   (('printer', 'maybe'), 4),
#   (('printer', 'called'), 4),
#   (('printer', 'generally'), 4),
#   (('printer', 'per'), 4),
#   (('printer', 'worth'), 4),
#   (('printer', 'nice'), 4),
#   (('printer', 'mean'), 4),
#   (('printer', 'top'), 4),
#   (('printer', 'excellent'), 4),
#   (('printer', 'enough'), 4),
#   (('printer', 'text'), 4),
#   (('printer', 'error'), 4),
#   (('typical', 'printer'), 4),
#   (('install', 'printer'), 4),
#   (('printer', 'unfortunately'), 4),
#   (('envy', 'printer'), 4),
#   (('printer', 'sound'), 4),
#   (('printer', 'getting'), 4),
#   (('printer', 'why'), 4),
#   (('printer', 'kept'), 4),
#   (('printer', 'family'), 4),
#   (('when', 'printer'), 4),
#   (('mfc', 'printer'), 4),
#   (('test', 'printer'), 4),
#   (('printer', 'basically'), 4),
#   (('printer', 'wherever'), 4),
#   (('printer', 'replaces'), 4),
#   (('printer', 'folk'), 4),
#   (('printer', 'leaf'), 4),
#   (('why', 'printer'), 4),
#   (('printer', 'offered'), 4),
#   (('right', 'printer'), 4),
#   (('printer', 'showing'), 4),
#   (('printer', 'sat'), 4),
#   (('printer', 'built'), 4),
#   (('via', 'printer'), 4),
#   (('bulky', 'printer'), 4),
#   (('printer', 'attached'), 4),
#   (('faster', 'printer'), 4),
#   (('dedicated', 'printer'), 4),
#   (('modern', 'printer'), 4),
#   (('manufacturer', 'printer'), 4),
#   (('printer', 'suitable'), 4),
#   (('class', 'printer'), 4),
#   (('terrific', 'printer'), 4),
#   (('competitive', 'printer'), 4),
#   (('mac', 'printer'), 4),
#   (('printer', 'apart'), 4),
#   (('custom', 'printer'), 4),
#   (('printer', 'he'), 4),
#   (('printer', 'between'), 4),
#   (('printer', 'tend'), 4),
#   (('capacity', 'printer'), 4),
#   (('printer', 'mx'), 4),
#   (('printer', 'cloud'), 4),
#   (('ready', 'printer'), 4),
#   (('advanced', 'printer'), 4),
#   (('printer', 'airprint'), 4),
#   (('printer', 'automatic'), 4),
#   (('making', 'printer'), 4),
#   (('printer', 'follows'), 4),
#   (('also', 'printer'), 4),
#   (('printer', 'compare'), 4),
#   (('printer', 'arrives'), 4),
#   (('installing', 'printer'), 4),
#   (('printer', 'icon'), 3),
#   (('printer', 'operation'), 3),
#   (('beloved', 'printer'), 3),
#   (('printer', 'problem'), 3),
#   (('printer', 'broke'), 3),
#   (('text', 'printer'), 3),
#   (('printer', 'quits'), 3),
#   (('dye', 'printer'), 3),
#   (('printer', 'blow'), 3),
#   (('printer', 'read'), 3),
#   (('printer', 'clearly'), 3),
#   (('networkable', 'printer'), 3),
#   (('do', 'printer'), 3),
#   (('printer', 'know'), 3),
#   (('printer', 'cart'), 3),
#   (('printer', 'edited'), 3),
#   (('printer', 'themselves'), 3),
#   (('printer', 'label'), 3),
#   (('printer', 'literally'), 3),
#   (('he', 'printer'), 3),
#   (('printer', 'fast'), 3),
#   (('printer', 'bought'), 3),
#   (('printer', 'cover'), 3),
#   (('printer', 'dy'), 3),
#   (('printer', 'always'), 3),
#   (('printer', 'side'), 3),
#   (('printer', 'business'), 3),
#   (('printer', 'tends'), 3),
#   (('printer', 'dialog'), 3),
#   (('printer', 'retail'), 3),
#   (('printer', 'any'), 3),
#   (('printer', 'device'), 3),
#   (('printer', 'mp'), 3),
#   (('printer', 'earlier'), 3),
#   (('printer', 'changing'), 3),
#   (('printer', 'spit'), 3),
#   (('printer', 'remember'), 3),
#   (('backup', 'printer'), 3),
#   (('found', 'printer'), 3),
#   (('printer', 'space'), 3),
#   (('printer', 'standard'), 3),
#   (('printer', 'how'), 3),
#   (('printer', 'fairly'), 3),
#   (('printer', 'shake'), 3),
#   (('monitor', 'printer'), 3),
#   (('printer', 'operates'), 3),
#   (('printer', 'feed'), 3),
#   (('printer', 'cd'), 3),
#   (('school', 'printer'), 3),
#   (('wide', 'printer'), 3),
#   (('consumer', 'printer'), 3),
#   (('printer', 'shuts'), 3),
#   (('printer', 'decided'), 3),
#   (('printer', 'adapter'), 3),
#   (('vista', 'printer'), 3),
#   (('printer', 'perhaps'), 3),
#   (('okay', 'printer'), 3),
#   (('wrong', 'printer'), 3),
#   (('bad', 'printer'), 3),
#   (('printer', 'noise'), 3),
#   (('remarkable', 'printer'), 3),
#   (('printer', 'cause'), 3),
#   (('printer', 'taking'), 3),
#   (('printer', 'cannon'), 3),
#   (('printer', 'market'), 3),
#   (('extra', 'printer'), 3),
#   (('initial', 'printer'), 3),
#   (('printer', 'choice'), 3),
#   (('head', 'printer'), 3),
#   (('pc', 'printer'), 3),
#   (('iphone', 'printer'), 3),
#   (('printer', 'moreover'), 3),
#   (('printer', 'job'), 3),
#   (('feature', 'printer'), 3),
#   (('printer', 'typically'), 3),
#   (('printer', 'program'), 3),
#   (('envelope', 'printer'), 3),
#   (('led', 'printer'), 3),
#   (('printer', 'check'), 3),
#   (('printer', 'continues'), 3),
#   (('printer', 'add'), 3),
#   (('printer', 'tethered'), 3),
#   (('printer', 'personally'), 3),
#   (('printer', 'gray'), 3),
#   (('printer', 'compatible'), 3),
#   (('printer', 'hummed'), 3),
#   (('printer', 'whose'), 3),
#   (('printer', 'name'), 3),
#   (('medium', 'printer'), 3),
#   (('printer', 'underneath'), 3),
#   (('duplexing', 'printer'), 3),
#   (('printer', 'language'), 3),
#   (('single', 'printer'), 3),
#   (('printer', 'follow'), 3),
#   (('image', 'printer'), 3),
#   (('countless', 'printer'), 3),
#   (('turning', 'printer'), 3),
#   (('made', 'printer'), 3),
#   (('printer', 'besides'), 3),
#   (('imageclass', 'printer'), 3),
#   (('dpi', 'printer'), 3),
#   (('printer', 'intended'), 3),
#   (('printer', 'sd'), 3),
#   (('copier', 'printer'), 3),
#   (('printer', 'ning'), 3),
#   (('printer', 'ability'), 3),
#   (('compatible', 'printer'), 3),
#   (('cyan', 'printer'), 3),
#   (('printer', 'document'), 3),
#   (('quite', 'printer'), 3),
#   (('line', 'printer'), 3),
#   (('mono', 'printer'), 3),
#   (('io', 'printer'), 3),
#   (('functionality', 'printer'), 3),
#   (('window', 'printer'), 3),
#   (('printer', 'separate'), 3),
#   (('printer', 'fail'), 3),
#   (('printer', 'ok'), 3),
#   (('printer', 'draw'), 3),
#   (('tray', 'printer'), 3),
#   (('printer', 'primarily'), 3),
#   (('printer', 'basic'), 3),
#   (('printer', 'alone'), 3),
#   (('notch', 'printer'), 3),
#   (('printer', 'solely'), 3),
#   (('printer', 'fill'), 3),
#   (('printer', 'mobile'), 3),
#   (('printer', 'galaxy'), 3),
#   (('preference', 'printer'), 3),
#   (('value', 'printer'), 3),
#   (('printer', 'call'), 3),
#   (('printer', 'thing'), 3),
#   (('picture', 'printer'), 3),
#   (('cable', 'printer'), 3),
#   (('additional', 'printer'), 3),
#   (('doa', 'printer'), 3),
#   (('wf', 'printer'), 3),
#   (('printer', 'dedicated'), 3),
#   (('printer', 'suffer'), 3),
#   (('massive', 'printer'), 3),
#   (('printer', 'replacement'), 3),
#   (('printer', 'system'), 3),
#   (('printer', 'installing'), 3),
#   (('say', 'printer'), 3),
#   (('printer', 'whether'), 3),
#   (('printer', 'recommended'), 3),
#   (('printer', 'those'), 3),
#   (('printer', 'quit'), 3),
#   (('lightweight', 'printer'), 3),
#   (('printer', 'gui'), 3),
#   (('wise', 'printer'), 3),
#   (('printer', 'remote'), 3),
#   (('printer', 'introduced'), 3),
#   (('printer', 'perfection'), 3),
#   (('wish', 'printer'), 3),
#   (('prefer', 'printer'), 3),
#   (('drive', 'printer'), 3),
#   (('printer', 'full'), 3),
#   (('printer', 'find'), 3),
#   (('printer', 'nothing'), 3),
#   (('printer', 'prior'), 3),
#   (('then', 'printer'), 3),
#   (('printer', 'satisfies'), 3),
#   (('printer', 'le'), 3),
#   (('speedy', 'printer'), 3),
#   (('combo', 'printer'), 3),
#   (('printer', 'monochrome'), 3),
#   (('printer', 'slightly'), 3),
#   (('printer', 'boast'), 3),
#   (('printer', 'operational'), 3),
#   (('copy', 'printer'), 3),
#   (('smallest', 'printer'), 3),
#   (('printer', 'weighing'), 3),
#   (('printer', 'someone'), 3),
#   (('review', 'printer'), 3),
#   (('common', 'printer'), 3),
#   (('printer', 'quick'), 3),
#   (('portable', 'printer'), 3),
#   (('printer', 'thus'), 3),
#   (('printer', 'ranging'), 3),
#   (('printer', 'imo'), 3),
#   (('workgroup', 'printer'), 2),
#   (('printer', 'rep'), 2),
#   (('printer', 'resolution'), 2),
#   (('printer', 'expects'), 2),
#   (('printer', 'myself'), 2),
#   (('largest', 'printer'), 2),
#   (('sub', 'printer'), 2),
#   (('printer', 'break'), 2),
#   (('printer', 'provided'), 2),
#   (('sole', 'printer'), 2),
#   (('printer', 'crank'), 2),
#   (('problem', 'printer'), 2),
#   (('printer', 'becomes'), 2),
#   (('true', 'printer'), 2),
#   (('horse', 'printer'), 2),
#   (('printer', 'costco'), 2),
#   (('printer', 'debbie'), 2),
#   (('printer', 'file'), 2),
#   (('printer', 'anyway'), 2),
#   (('printer', 'construction'), 2),
#   (('printer', 'period'), 2),
#   (('printer', 'sounded'), 2),
#   (('lesser', 'printer'), 2),
#   (('get', 'printer'), 2),
#   (('printer', 'nicely'), 2),
#   (('ordinary', 'printer'), 2),
#   (('printer', 'forward'), 2),
#   (('printer', 'close'), 2),
#   (('printer', 'completely'), 2),
#   (('stupid', 'printer'), 2),
#   (('disc', 'printer'), 2),
#   (('printer', 'spend'), 2),
#   (('printer', 'who'), 2),
#   (('bluetooth', 'printer'), 2),
#   (('printer', 'daily'), 2),
#   (('until', 'printer'), 2),
#   (('printer', 'fails'), 2),
#   (('printer', 'rest'), 2),
#   (('printer', 'low'), 2),
#   (('printer', 'wait'), 2),
#   (('printer', 'inkjets'), 2),
#   (('finest', 'printer'), 2),
#   (('printer', 'suck'), 2),
#   (('printer', 'otherwise'), 2),
#   (('purchase', 'printer'), 2),
#   (('printer', 'duh'), 2),
#   (('anything', 'printer'), 2),
#   (('dead', 'printer'), 2),
#   (('printer', 'developed'), 2),
#   (('printer', 'store'), 2),
#   (('printer', 'bottom'), 2),
#   (('printer', 'body'), 2),
#   (('printer', 'fell'), 2),
#   (('printer', 'posse'), 2),
#   (('printer', 'held'), 2),
#   (('printer', 'dimension'), 2),
#   (('printer', 'please'), 2),
#   (('printer', 'join'), 2),
#   (('printer', 'wanted'), 2),
#   (('quick', 'printer'), 2),
#   (('printer', 'command'), 2),
#   (('printer', 'happy'), 2),
#   (('printer', 'linked'), 2),
#   (('printer', 'throughout'), 2),
#   (('printer', 'cabinet'), 2),
#   (('combination', 'printer'), 2),
#   (('printer', 'cycle'), 2),
#   (('printer', 'surpasses'), 2),
#   (('printer', 'aio'), 2),
#   (('printer', 'utilize'), 2),
#   (('printer', 'integrates'), 2),
#   (('printer', 'identity'), 2),
#   (('substantial', 'printer'), 2),
#   (('central', 'printer'), 2),
#   (('printer', 'six'), 2),
#   (('printer', 'sent'), 2),
#   (('support', 'printer'), 2),
#   (('printer', 'solid'), 2),
#   (('printer', 'pause'), 2),
#   (('printer', 'plugged'), 2),
#   (('feb', 'printer'), 2),
#   (('printer', 'stop'), 2),
#   (('special', 'printer'), 2),
#   (('printer', 'way'), 2),
#   (('printer', 'fine'), 2),
#   (('labelwriter', 'printer'), 2),
#   (('printer', 'geared'), 2),
#   (('owned', 'printer'), 2),
#   (('printer', 'month'), 2),
#   (('touchscreen', 'printer'), 2),
#   (('interesting', 'printer'), 2),
#   (('sharing', 'printer'), 2),
#   (('printer', 'luckily'), 2),
#   ...],
#  'binder': [(('view', 'binder'), 74),
#   (('ring', 'binder'), 71),
#   (('other', 'binder'), 71),
#   (('duty', 'binder'), 54),
#   (('jones', 'binder'), 50),
#   (('quality', 'binder'), 38),
#   (('inch', 'binder'), 31),
#   (('avery', 'binder'), 29),
#   (('my', 'binder'), 29),
#   (('basic', 'binder'), 27),
#   (('great', 'binder'), 27),
#   (('nice', 'binder'), 25),
#   (('binder', 'ring'), 25),
#   (('binder', 'wa'), 25),
#   (('white', 'binder'), 24),
#   (('good', 'binder'), 24),
#   (('sturdy', 'binder'), 23),
#   (('durable', 'binder'), 23),
#   (('binder', 'you'), 22),
#   (('binder', 'have'), 22),
#   (('standard', 'binder'), 19),
#   (('binder', 'cover'), 19),
#   (('binder', 'there'), 19),
#   (('use', 'binder'), 19),
#   (('zipper', 'binder'), 19),
#   (('binder', 'which'), 18),
#   (('binder', 'doe'), 18),
#   (('particular', 'binder'), 17),
#   (('binder', 'itself'), 16),
#   (('your', 'binder'), 15),
#   (('binder', 'hold'), 15),
#   (('binder', 'not'), 15),
#   (('binder', 'clip'), 14),
#   (('binder', 'seems'), 14),
#   (('average', 'binder'), 14),
#   (('binder', 'should'), 13),
#   (('binder', 'one'), 13),
#   (('little', 'binder'), 13),
#   (('small', 'binder'), 12),
#   (('binder', 'feel'), 12),
#   (('most', 'binder'), 12),
#   (('regular', 'binder'), 12),
#   (('some', 'binder'), 12),
#   (('binder', 'they'), 12),
#   (('binder', 'like'), 12),
#   (('binder', 'go'), 12),
#   (('binder', 'just'), 11),
#   (('binder', 'by'), 11),
#   (('binder', 'when'), 11),
#   (('binder', 'out'), 11),
#   (('binder', 'also'), 10),
#   (('hard', 'binder'), 10),
#   (('binder', 'instead'), 10),
#   (('cheaper', 'binder'), 10),
#   (('size', 'binder'), 10),
#   (('binder', 'work'), 10),
#   (('many', 'binder'), 9),
#   (('plastic', 'binder'), 9),
#   (('binder', 'do'), 9),
#   (('large', 'binder'), 9),
#   (('decent', 'binder'), 8),
#   (('sized', 'binder'), 8),
#   (('binder', 'come'), 8),
#   (('binder', 'arrived'), 8),
#   (('another', 'binder'), 8),
#   (('vinyl', 'binder'), 8),
#   (('binder', 'we'), 8),
#   (('ordinary', 'binder'), 8),
#   (('school', 'binder'), 8),
#   (('binder', 'full'), 7),
#   (('binder', 'open'), 7),
#   (('binder', 'no'), 7),
#   (('new', 'binder'), 7),
#   (('their', 'binder'), 7),
#   (('binder', 'however'), 7),
#   (('typical', 'binder'), 7),
#   (('flexible', 'binder'), 7),
#   (('binder', 'unusable'), 7),
#   (('better', 'binder'), 7),
#   (('binder', 'my'), 7),
#   (('one', 'binder'), 7),
#   (('comb', 'binder'), 7),
#   (('black', 'binder'), 7),
#   (('binder', 'especially'), 7),
#   (('binder', 'look'), 7),
#   (('binder', 'last'), 7),
#   (('larger', 'binder'), 6),
#   (('binder', 'than'), 6),
#   (('big', 'binder'), 6),
#   (('binder', 'while'), 6),
#   (('generic', 'binder'), 6),
#   (('binder', 'without'), 6),
#   (('binder', 'what'), 6),
#   (('all', 'binder'), 6),
#   (('binder', 'over'), 6),
#   (('old', 'binder'), 6),
#   (('premium', 'binder'), 6),
#   (('best', 'binder'), 6),
#   (('binder', 'seem'), 6),
#   (('solid', 'binder'), 6),
#   (('main', 'binder'), 5),
#   (('love', 'binder'), 5),
#   (('binder', 'inch'), 5),
#   (('simplify', 'binder'), 5),
#   (('strongest', 'binder'), 5),
#   (('binder', 'round'), 5),
#   (('end', 'binder'), 5),
#   (('binder', 'may'), 5),
#   (('binder', 'where'), 5),
#   (('binder', 'every'), 5),
#   (('binder', 'make'), 5),
#   (('like', 'binder'), 5),
#   (('binder', 'fit'), 5),
#   (('perfect', 'binder'), 5),
#   (('coupon', 'binder'), 5),
#   (('buy', 'binder'), 5),
#   (('pretty', 'binder'), 5),
#   (('binder', 'all'), 5),
#   (('polypro', 'binder'), 5),
#   (('binder', 'feature'), 4),
#   (('his', 'binder'), 4),
#   (('binder', 'very'), 4),
#   (('had', 'binder'), 4),
#   (('store', 'binder'), 4),
#   (('very', 'binder'), 4),
#   (('binder', 'labeling'), 4),
#   (('sewn', 'binder'), 4),
#   (('ledger', 'binder'), 4),
#   (('both', 'binder'), 4),
#   (('binder', 'close'), 4),
#   (('any', 'binder'), 4),
#   (('different', 'binder'), 4),
#   (('inside', 'binder'), 4),
#   (('binder', 'avery'), 4),
#   (('binder', 'only'), 4),
#   (('economy', 'binder'), 4),
#   (('thick', 'binder'), 4),
#   (('binder', 'rather'), 4),
#   (('huge', 'binder'), 4),
#   (('type', 'binder'), 4),
#   (('get', 'binder'), 4),
#   (('mini', 'binder'), 4),
#   (('x', 'binder'), 4),
#   (('binder', 'get'), 4),
#   (('bliss', 'binder'), 4),
#   (('office', 'binder'), 4),
#   (('binder', 'made'), 4),
#   (('binder', 'around'), 4),
#   (('kid', 'binder'), 4),
#   (('binder', 'looked'), 4),
#   (('binder', 'came'), 4),
#   (('purchasing', 'binder'), 4),
#   (('binder', 'view'), 4),
#   (('binder', 'since'), 3),
#   (('binder', 'he'), 3),
#   (('presentation', 'binder'), 3),
#   (('binder', 'mechanism'), 3),
#   (('entire', 'binder'), 3),
#   (('normal', 'binder'), 3),
#   (('sturdiest', 'binder'), 3),
#   (('binder', 'larger'), 3),
#   (('cheap', 'binder'), 3),
#   (('binder', 'available'), 3),
#   (('binder', 'well'), 3),
#   (('binder', 'had'), 3),
#   (('excellent', 'binder'), 3),
#   (('back', 'binder'), 3),
#   (('binder', 'good'), 3),
#   (('binder', 'particularly'), 3),
#   (('expensive', 'binder'), 3),
#   (('more', 'binder'), 3),
#   (('binder', 'part'), 3),
#   (('binder', 'through'), 3),
#   (('binder', 'definitely'), 3),
#   (('project', 'binder'), 3),
#   (('binder', 'into'), 3),
#   (('binder', 'could'), 3),
#   (('binder', 'other'), 3),
#   (('wj', 'binder'), 3),
#   (('into', 'binder'), 3),
#   (('binder', 'worth'), 3),
#   (('need', 'binder'), 3),
#   (('binder', 'really'), 3),
#   (('binder', 'even'), 3),
#   (('similar', 'binder'), 3),
#   (('binder', 'although'), 3),
#   (('attractive', 'binder'), 3),
#   (('about', 'binder'), 3),
#   (('single', 'binder'), 3),
#   (('first', 'binder'), 3),
#   (('zippered', 'binder'), 3),
#   (('simple', 'binder'), 3),
#   (('binder', 'each'), 3),
#   (('binder', 'except'), 3),
#   (('thin', 'binder'), 3),
#   (('serviceable', 'binder'), 3),
#   (('strong', 'binder'), 3),
#   (('binder', 'lie'), 3),
#   (('mitt', 'binder'), 2),
#   (('binder', 'too'), 2),
#   (('giant', 'binder'), 2),
#   (('binder', 'exactly'), 2),
#   (('such', 'binder'), 2),
#   (('binder', 'both'), 2),
#   (('binder', 'though'), 2),
#   (('binder', 'contain'), 2),
#   (('home', 'binder'), 2),
#   (('binder', 'yet'), 2),
#   (('binder', 'wilson'), 2),
#   (('binder', 'keep'), 2),
#   (('full', 'binder'), 2),
#   (('priced', 'binder'), 2),
#   (('binder', 'overall'), 2),
#   (('functional', 'binder'), 2),
#   (('binder', 'excellent'), 2),
#   (('binder', 'either'), 2),
#   (('binder', 'nothing'), 2),
#   (('binder', 'size'), 2),
#   (('leaf', 'binder'), 2),
#   (('binder', 'portion'), 2),
#   (('binder', 'chipboard'), 2),
#   (('binder', 'heavy'), 2),
#   (('horse', 'binder'), 2),
#   (('binder', 'much'), 2),
#   (('make', 'binder'), 2),
#   (('binder', 'divider'), 2),
#   (('binder', 'still'), 2),
#   (('binder', 'easy'), 2),
#   (('binder', 'some'), 2),
#   (('find', 'binder'), 2),
#   (('versatile', 'binder'), 2),
#   (('binder', 'buy'), 2),
#   (('binder', 'then'), 2),
#   (('binder', 'now'), 2),
#   (('binder', 'before'), 2),
#   (('binder', 'first'), 2),
#   (('binder', 'unlike'), 2),
#   (('used', 'binder'), 2),
#   (('binder', 'plastic'), 2),
#   (('lightweight', 'binder'), 2),
#   (('binder', 'take'), 2),
#   (('binder', 'any'), 2),
#   (('binder', 'upright'), 2),
#   (('previous', 'binder'), 2),
#   (('last', 'binder'), 2),
#   (('cheapie', 'binder'), 2),
#   (('flimsy', 'binder'), 2),
#   (('binder', 'again'), 2),
#   (('binder', 'fault'), 2),
#   (('binder', 'section'), 2),
#   (('narrow', 'binder'), 2),
#   (('touch', 'binder'), 2),
#   (('binder', 'spine'), 2),
#   (('binder', 'connoisseur'), 2),
#   (('binder', 'our'), 2),
#   (('conventional', 'binder'), 2),
#   (('recycled', 'binder'), 2),
#   (('three', 'binder'), 2),
#   (('real', 'binder'), 2),
#   (('cardboard', 'binder'), 2),
#   (('binder', 'along'), 2),
#   (('binder', 'wo'), 2),
#   (('binder', 'pocket'), 2),
#   (('binder', 'contains'), 2),
#   (('binder', 'material'), 2),
#   (('binder', 'appears'), 2),
#   (('binder', 'fold'), 2),
#   (('binder', 'need'), 2),
#   (('useful', 'binder'), 2),
#   (('binder', 'anyway'), 2),
#   (('binder', 'simple'), 2),
#   (('binder', 'attractive'), 2),
#   (('color', 'binder'), 2),
#   (('binder', 'why'), 2),
#   (('same', 'binder'), 2),
#   (('made', 'binder'), 2),
#   (('colorful', 'binder'), 2),
#   (('star', 'binder'), 2),
#   (('based', 'binder'), 2),
#   (('binder', 'perfect'), 2),
#   (('second', 'binder'), 2),
#   (('brand', 'binder'), 2),
#   (('binder', 'after'), 2),
#   (('have', 'binder'), 2),
#   (('binder', 'break'), 2),
#   (('storage', 'binder'), 2),
#   (('zipped', 'binder'), 2),
#   (('binder', 'plus'), 2),
#   (('binder', 'due'), 2),
#   (('binder', 'includes'), 2),
#   (('binder', 'were'), 2),
#   (('than', 'binder'), 2),
#   (('few', 'binder'), 2),
#   (('classroom', 'binder'), 2),
#   (('binder', 'notebook'), 2),
#   (('binder', 'three'), 2),
#   (('binder', 's'), 2),
#   (('comparable', 'binder'), 2),
#   (('binder', 'stand'), 2),
#   (('which', 'binder'), 2),
#   (('wilson', 'binder'), 2),
#   (('duratech', 'binder'), 2),
#   (('binder', 'violet'), 2),
#   (('just', 'binder'), 2),
#   (('budget', 'binder'), 2),
#   (('looking', 'binder'), 2),
#   (('binder', 'quite'), 2),
#   (('bottom', 'binder'), 2),
#   (('aged', 'binder'), 2),
#   (('look', 'binder'), 2),
#   (('binder', 'themselves'), 2),
#   (('binder', 'nut'), 2),
#   (('using', 'binder'), 2),
#   (('built', 'binder'), 2),
#   (('binder', 'cost'), 2),
#   (('older', 'binder'), 2),
#   (('binder', 'tout'), 1),
#   (('binder', 'requires'), 1),
#   (('each', 'binder'), 1),
#   (('whole', 'binder'), 1),
#   (('binder', 'fail'), 1),
#   (('metallic', 'binder'), 1),
#   (('binder', 'six'), 1),
#   (('biggest', 'binder'), 1),
#   (('binder', 'their'), 1),
#   (('level', 'binder'), 1),
#   (('binder', 'thanks'), 1),
#   (('amazing', 'binder'), 1),
#   (('binder', 'apart'), 1),
#   (('discovered', 'binder'), 1),
#   (('want', 'binder'), 1),
#   (('binder', 'nonetheless'), 1),
#   (('nicer', 'binder'), 1),
#   (('binder', 'such'), 1),
#   (('binder', 'carried'), 1),
#   (('binder', 'prettier'), 1),
#   (('binder', 'mine'), 1),
#   (('hole', 'binder'), 1),
#   (('organized', 'binder'), 1),
#   (('pleated', 'binder'), 1),
#   (('binder', 'smead'), 1),
#   (('binder', 'cheap'), 1),
#   (('close', 'binder'), 1),
#   (('binder', 'five'), 1),
#   (('friendly', 'binder'), 1),
#   (('junky', 'binder'), 1),
#   (('binder', 'page'), 1),
#   (('come', 'binder'), 1),
#   (('sweet', 'binder'), 1),
#   (('wearing', 'binder'), 1),
#   (('right', 'binder'), 1),
#   (('binder', 'let'), 1),
#   (('binder', 'solves'), 1),
#   (('binder', 'panel'), 1),
#   (('binder', 'indeed'), 1),
#   (('replacement', 'binder'), 1),
#   (('binder', 'better'), 1),
#   (('household', 'binder'), 1),
#   (('notebook', 'binder'), 1),
#   (('binder', 'strong'), 1),
#   (('art', 'binder'), 1),
#   (('style', 'binder'), 1),
#   (('binder', 'extra'), 1),
#   (('binder', 'eventually'), 1),
#   (('long', 'binder'), 1),
#   (('manual', 'binder'), 1),
#   (('binder', 'rated'), 1),
#   (('binder', 'obviously'), 1),
#   (('binder', 'enough'), 1),
#   (('binder', 'extensively'), 1),
#   (('heavily', 'binder'), 1),
#   (('binder', 'escape'), 1),
#   (('binder', 'considering'), 1),
#   (('together', 'binder'), 1),
#   (('binder', 'area'), 1),
#   (('binder', 'proved'), 1),
#   (('dented', 'binder'), 1),
#   (('binder', 'us'), 1),
#   (('free', 'binder'), 1),
#   (('binder', 'store'), 1),
#   (('binder', 'incase'), 1),
#   (('binder', 'expecting'), 1),
#   (('binder', 'she'), 1),
#   (('you', 'binder'), 1),
#   (('handy', 'binder'), 1),
#   (('binder', 'appeal'), 1),
#   (('binder', 'yard'), 1),
#   (('protruding', 'binder'), 1),
#   (('fellowes', 'binder'), 1),
#   (('binder', 'video'), 1),
#   (('binder', 'perhaps'), 1),
#   (('binder', 'transparent'), 1),
#   (('binder', 'comb'), 1),
#   (('binder', 'sitting'), 1),
#   (('binder', 'starlet'), 1),
#   (('binder', 'together'), 1),
#   (('binder', 'face'), 1),
#   (('professional', 'binder'), 1),
#   (('binder', 'velo'), 1),
#   (('binder', 'queen'), 1),
#   (('binder', 'ala'), 1),
#   (('knew', 'binder'), 1),
#   (('binder', 'down'), 1),
#   (('us', 'binder'), 1),
#   (('binder', 'trim'), 1),
#   (('binder', 'claim'), 1),
#   (('go', 'binder'), 1),
#   (('binder', 'combine'), 1),
#   (('binder', 'help'), 1),
#   (('capability', 'binder'), 1),
#   (('advanced', 'binder'), 1),
#   (('capacity', 'binder'), 1),
#   (('binder', 'life'), 1),
#   (('binder', 'book'), 1),
#   (('cheapest', 'binder'), 1),
#   (('binder', 'premium'), 1),
#   (('binder', 'tear'), 1),
#   (('binder', 'sometimes'), 1),
#   (('binder', 'lack'), 1),
#   (('binder', 'until'), 1),
#   (('binder', 'warrant'), 1),
#   (('binder', 'edge'), 1),
#   (('binder', 'rivet'), 1),
#   (('getavery', 'binder'), 1),
#   (('blue', 'binder'), 1),
#   (('binder', 'content'), 1),
#   (('binder', 'added'), 1),
#   (('recyclable', 'binder'), 1),
#   (('binder', 'always'), 1),
#   (('binder', 'closeing'), 1),
#   (('metal', 'binder'), 1),
#   (('convenient', 'binder'), 1),
#   (('binder', 'looking'), 1),
#   (('binder', 'market'), 1),
#   (('binder', 'shape'), 1),
#   (('binder', 'appearance'), 1),
#   (('binder', 'inside'), 1),
#   (('covered', 'binder'), 1),
#   (('binder', 'certainly'), 1),
#   (('binder', 'roughly'), 1),
#   (('side', 'binder'), 1),
#   (('getting', 'binder'), 1),
#   (('binder', 'wow'), 1),
#   (('shopping', 'binder'), 1),
#   (('binder', 'punch'), 1),
#   (('ubiquitous', 'binder'), 1),
#   (('binder', 'similar'), 1),
#   (('me', 'binder'), 1),
#   (('smaller', 'binder'), 1),
#   (('binder', 'x'), 1),
#   (('binder', 'offer'), 1),
#   (('binder', 'love'), 1),
#   (('maybe', 'binder'), 1),
#   (('stick', 'binder'), 1),
#   (('binder', 'anytime'), 1),
#   (('binder', 'holder'), 1),
#   (('no', 'binder'), 1),
#   (('self', 'binder'), 1),
#   (('binder', 'turn'), 1),
#   (('closed', 'binder'), 1),
#   (('binder', 'clear'), 1),
#   (('empty', 'binder'), 1),
#   (('tiny', 'binder'), 1),
#   (('binder', 'pack'), 1),
#   (('looseleaf', 'binder'), 1),
#   (('binder', 'suit'), 1),
#   (('binder', 'accessory'), 1),
#   (('binder', 'free'), 1),
#   (('binder', 'shrunk'), 1),
#   (('binder', 'standard'), 1),
#   (('paper', 'binder'), 1),
#   (('binder', 'rear'), 1),
#   (('binder', 'seemed'), 1),
#   (('seven', 'binder'), 1),
#   (('binder', 'stay'), 1),
#   (('girlie', 'binder'), 1),
#   (('fun', 'binder'), 1),
#   (('wonderful', 'binder'), 1),
#   (('binder', 'allows'), 1),
#   (('sturdier', 'binder'), 1),
#   (('usual', 'binder'), 1),
#   (('adult', 'binder'), 1),
#   (('binder', 'standout'), 1),
#   (('alternative', 'binder'), 1),
#   (('enough', 'binder'), 1),
#   (('binder', 'turned'), 1),
#   (('binder', 'most'), 1),
#   (('boring', 'binder'), 1),
#   (('binder', 'apparatus'), 1),
#   (('printed', 'binder'), 1),
#   (('plain', 'binder'), 1),
#   (('greenroom', 'binder'), 1),
#   (('recipe', 'binder'), 1),
#   (('adorable', 'binder'), 1),
#   (('binder', 'tab'), 1),
#   (('actual', 'binder'), 1),
#   (('binder', 'super'), 1),
#   (('interesting', 'binder'), 1),
#   (('binder', 'hardware'), 1),
#   (('binder', 'almost'), 1),
#   (('binder', 'olympics'), 1),
#   (('cover', 'binder'), 1),
#   (('binder', 'manufacturer'), 1),
#   (('binder', 'notable'), 1),
#   (('binder', 'filled'), 1),
#   (('equivalent', 'binder'), 1),
#   (('fanatastic', 'binder'), 1),
#   (('binder', 'wish'), 1),
#   (('picture', 'binder'), 1),
#   (('binder', 'unless'), 1),
#   (('binder', 'folder'), 1),
#   (('pocket', 'binder'), 1),
#   (('maintenance', 'binder'), 1),
#   (('spiral', 'binder'), 1),
#   (('binder', 'fine'), 1),
#   (('binder', 'zipper'), 1),
#   (('binder', 'two'), 1),
#   (('binder', 'back'), 1),
#   (('binder', 'seriously'), 1),
#   (('fivestar', 'binder'), 1),
#   (('binder', 'throughout'), 1),
#   (('mead', 'binder'), 1),
#   (('timeflexible', 'binder'), 1),
#   (('student', 'binder'), 1),
#   (('smooth', 'binder'), 1),
#   (('here', 'binder'), 1),
#   (('grade', 'binder'), 1),
#   (('binder', 'complaint'), 1),
#   (('locking', 'binder'), 1),
#   (('binder', 'who'), 1),
#   (('binder', 'mentioned'), 1),
#   (('acceptable', 'binder'), 1),
#   (('favorite', 'binder'), 1),
#   (('binder', 'felt'), 1),
#   (('binder', 'read'), 1),
#   (('binder', 'gave'), 1),
#   (('binder', 'straightened'), 1),
#   (('binder', 'appropriate'), 1),
#   (('binder', 'department'), 1),
#   (('binder', 'basically'), 1),
#   (('dollar', 'binder'), 1),
#   (('binder', 'white'), 1),
#   (('binder', 'boast'), 1),
#   (('stock', 'binder'), 1),
#   (('le', 'binder'), 1),
#   (('binder', 'bend'), 1),
#   (('within', 'binder'), 1),
#   (('tough', 'binder'), 1),
#   (('binder', 'popped'), 1),
#   (('superior', 'binder'), 1),
#   (('qualify', 'binder'), 1),
#   (('binder', 'endure'), 1),
#   (('binder', 'model'), 1),
#   (('binder', 'okay'), 1),
#   (('binder', 'got'), 1),
#   (('binder', 'line'), 1),
#   (('binder', 'nevertheless'), 1),
#   (('those', 'binder'), 1),
#   (('binder', 'wherein'), 1),
#   (('binder', 'right'), 1),
#   (('binder', 'upside'), 1),
#   (('binder', 'meet'), 1),
#   (('binder', 'fall'), 1),
#   (('binder', 'address'), 1),
#   (('bought', 'binder'), 1),
#   (('countless', 'binder'), 1),
#   (('binder', 'fails'), 1),
#   (('binder', 'eliminates'), 1),
#   (('inexpensive', 'binder'), 1),
#   (('binder', 'snap'), 1),
#   (('binder', 'lay'), 1),
#   (('binder', 'seemingly'), 1),
#   (('seuss', 'binder'), 1),
#   (('binder', 'classroom'), 1),
#   (('binder', 'etc'), 1),
#   (('binder', 'pas'), 1),
#   (('binder', 'style'), 1),
#   (('current', 'binder'), 1),
#   (('separate', 'binder'), 1),
#   (('okay', 'binder'), 1),
#   (('remember', 'binder'), 1),
#   (('binder', 'prof'), 1),
#   (('binder', 'long'), 1),
#   (('binder', 'sits'), 1),
#   (('binder', 'including'), 1),
#   (('binder', 'intended'), 1),
#   (('overpriced', 'binder'), 1),
#   (('binder', 'looseleaf'), 1),
#   (('binder', 'twice'), 1),
#   (('expected', 'binder'), 1),
#   (('tab', 'binder'), 1),
#   (('binder', 'state'), 1),
#   (('outside', 'binder'), 1),
#   (('binder', 'top'), 1),
#   (('binder', 'using'), 1),
#   (('window', 'binder'), 1),
#   (('binder', 'surface'), 1),
#   (('avoided', 'binder'), 1),
#   (('binder', 'many'), 1),
#   (('reasonable', 'binder'), 1),
#   (('skinny', 'binder'), 1),
#   (('plasticthe', 'binder'), 1),
#   (('binder', 'start'), 1),
#   (('visible', 'binder'), 1),
#   (('binder', 'host'), 1),
#   (('binder', 'having'), 1),
#   (('binder', 'doing'), 1),
#   (('hinged', 'binder'), 1),
#   (('binder', 'another'), 1),
#   (('binder', 'covered'), 1),
#   (('binder', 'construction'), 1),
#   (('ultra', 'binder'), 1),
#   (('binder', 'those'), 1),
#   (('abuse', 'binder'), 1),
#   (('every', 'binder'), 1),
#   (('binder', 'assembly'), 1),
#   (('binder', 'given'), 1),
#   (('binder', 'already'), 1),
#   (('next', 'binder'), 1),
#   (('nothing', 'binder'), 1),
# ...
#   (('usable', 'stapler'), 1),
#   (('stapler', 'cake'), 1),
#   (('stapler', 'mainly'), 1),
#   (('stapler', 'doing'), 1),
#   (('sparkly', 'stapler'), 1),
#   (('stapler', 'decorated'), 1),
#   (('stapler', 'leaving'), 1),
#   (('stapler', 'alone'), 1),
#   (('sticky', 'stapler'), 1),
#   (('stapler', 'noting'), 1),
#   (('stapler', 'four'), 1),
#   (('strong', 'stapler'), 1),
#   (('beautiful', 'stapler'), 1),
#   (('skin', 'stapler'), 1),
#   (('art', 'stapler'), 1),
#   (('stapler', 'frame'), 1),
#   (('stapler', 'another'), 1),
#   (('weight', 'stapler'), 1),
#   (('athletics', 'stapler'), 1),
#   (('stapler', 'unique'), 1),
#   (('blank', 'stapler'), 1),
#   (('customizeable', 'stapler'), 1),
#   (('making', 'stapler'), 1),
#   (('free', 'stapler'), 1),
#   (('kid', 'stapler'), 1),
#   (('stapler', 'sure'), 1),
#   (('stapler', 'typed'), 1),
#   (('thousand', 'stapler'), 1),
#   (('had', 'stapler'), 1),
#   (('stapler', 'operates'), 1),
#   (('stapler', 'back'), 1),
#   (('stapler', 'looked'), 1),
#   (('stapler', 'consisting'), 1),
#   (('frill', 'stapler'), 1),
#   (('stapler', 'arrives'), 1),
#   (('stapler', 'upright'), 1),
#   (('stapler', 'different'), 1),
#   (('stapler', 'being'), 1),
#   (('stapler', 'functionality'), 1),
#   (('stapler', 'function'), 1),
#   (('stapler', 'nobody'), 1),
#   (('stapler', 'basically'), 1),
#   (('competent', 'stapler'), 1),
#   (('stapler', 'gave'), 1),
#   (('stapler', 'packaging'), 1),
#   (('vanity', 'stapler'), 1),
#   (('item', 'stapler'), 1),
#   (('stapler', 'state'), 1),
#   (('model', 'stapler'), 1),
#   (('whose', 'stapler'), 1),
#   (('stapler', 'start'), 1),
#   (('stapler', 'everything'), 1),
#   (('stapler', 'under'), 1),
#   (('plain', 'stapler'), 1),
#   (('unicolored', 'stapler'), 1),
#   (('stapler', 'herself'), 1),
#   (('stapler', 'called'), 1)],
#  'calculator': [(('graphing', 'calculator'), 61),
#   (('scientific', 'calculator'), 51),
#   (('hp', 'calculator'), 43),
#   (('financial', 'calculator'), 21),
#   (('basic', 'calculator'), 18),
#   (('ti', 'calculator'), 16),
#   (('casio', 'calculator'), 16),
#   (('good', 'calculator'), 13),
#   (('calculator', 'which'), 13),
#   (('calculator', 'you'), 11),
#   (('calculator', 'doe'), 11),
#   (('great', 'calculator'), 10),
#   (('other', 'calculator'), 10),
#   (('little', 'calculator'), 9),
#   (('calculator', 'gold'), 8),
#   (('calculator', 'wa'), 8),
#   (('pocket', 'calculator'), 8),
#   (('printing', 'calculator'), 8),
#   (('desktop', 'calculator'), 7),
#   (('new', 'calculator'), 7),
#   (('simple', 'calculator'), 6),
#   (('solar', 'calculator'), 6),
#   (('my', 'calculator'), 6),
#   (('your', 'calculator'), 6),
#   (('old', 'calculator'), 6),
#   (('calculator', 'when'), 6),
#   (('canon', 'calculator'), 6),
#   (('calculator', 'also'), 6),
#   (('use', 'calculator'), 6),
#   (('calculator', 'just'), 5),
#   (('calculator', 'like'), 5),
#   (('any', 'calculator'), 5),
#   (('calculator', 'not'), 5),
#   (('larger', 'calculator'), 5),
#   (('calculator', 'there'), 5),
#   (('calculator', 'should'), 4),
#   (('calculator', 'without'), 4),
#   (('more', 'calculator'), 4),
#   (('another', 'calculator'), 4),
#   (('most', 'calculator'), 4),
#   (('nice', 'calculator'), 4),
#   (('instrument', 'calculator'), 4),
#   (('calculator', 'after'), 4),
#   (('same', 'calculator'), 4),
#   (('calculator', 'do'), 4),
#   (('calculator', 'really'), 4),
#   (('desk', 'calculator'), 4),
#   (('calculator', 'h'), 4),
#   (('calculator', 'come'), 4),
#   (('both', 'calculator'), 4),
#   (('calculator', 'user'), 4),
#   (('calculator', 'back'), 4),
#   (('calculator', 'multiview'), 4),
#   (('calculator', 'mv'), 4),
#   (('pen', 'calculator'), 4),
#   (('reliable', 'calculator'), 3),
#   (('calculator', 'before'), 3),
#   (('calculator', 'product'), 3),
#   (('calculator', 'line'), 3),
#   (('classic', 'calculator'), 3),
#   (('calculator', 'work'), 3),
#   (('standard', 'calculator'), 3),
#   (('those', 'calculator'), 3),
#   (('all', 'calculator'), 3),
#   (('calculator', 'today'), 3),
#   (('powered', 'calculator'), 3),
#   (('calculator', 'need'), 3),
#   (('calculator', 'all'), 3),
#   (('cheap', 'calculator'), 3),
#   (('graphic', 'calculator'), 3),
#   (('calculator', 'feature'), 3),
#   (('calculator', 'instead'), 3),
#   (('advanced', 'calculator'), 3),
#   (('calculator', 'stay'), 3),
#   (('calculator', 'first'), 3),
#   (('calculator', 'manufacturer'), 3),
#   (('inexpensive', 'calculator'), 3),
#   (('calculator', 'arrived'), 3),
#   (('calculator', 'seems'), 3),
#   (('only', 'calculator'), 3),
#   (('own', 'calculator'), 3),
#   (('calculator', 'have'), 3),
#   (('calculator', 'had'), 3),
#   (('older', 'calculator'), 3),
#   (('calculator', 'look'), 3),
#   (('their', 'calculator'), 3),
#   (('small', 'calculator'), 3),
#   (('calculator', 'screen'), 3),
#   (('calculator', 'owner'), 2),
#   (('calculator', 'hp'), 2),
#   (('calculator', 'business'), 2),
#   (('calculator', 'now'), 2),
#   (('calculator', 'fan'), 2),
#   (('calculator', 'series'), 2),
#   (('calculator', 'function'), 2),
#   (('calculator', 'maybe'), 2),
#   (('calculator', 'time'), 2),
#   (('calculator', 'us'), 2),
#   (('calculator', 'take'), 2),
#   (('calculator', 'big'), 2),
#   (('built', 'calculator'), 2),
#   (('calculator', 'very'), 2),
#   (('calculator', 'affordable'), 2),
#   (('calculator', 'since'), 2),
#   (('durable', 'calculator'), 2),
#   (('calculator', 'get'), 2),
#   (('calculator', 'out'), 2),
#   (('function', 'calculator'), 2),
#   (('powerful', 'calculator'), 2),
#   (('last', 'calculator'), 2),
#   (('model', 'calculator'), 2),
#   (('using', 'calculator'), 2),
#   (('useful', 'calculator'), 2),
#   (('l', 'calculator'), 2),
#   (('smaller', 'calculator'), 2),
#   (('calculator', 'being'), 2),
#   (('h', 'calculator'), 2),
#   (('calculator', 'still'), 2),
#   (('calculator', 'sharp'), 2),
#   (('calculator', 'only'), 2),
#   (('battery', 'calculator'), 2),
#   (('business', 'calculator'), 2),
#   (('calculator', 'run'), 2),
#   (('fancy', 'calculator'), 2),
#   (('similar', 'calculator'), 2),
#   (('calculator', 'came'), 2),
#   (('calculator', 'output'), 2),
#   (('calculator', 'until'), 2),
#   (('calculator', 'use'), 2),
#   (('handheld', 'calculator'), 2),
#   (('calculator', 'production'), 2),
#   (('calculator', 'we'), 2),
#   (('calculator', 'however'), 2),
#   (('calculator', 'than'), 2),
#   (('calculator', 'gave'), 2),
#   (('calculator', 'they'), 2),
#   (('lined', 'calculator'), 2),
#   (('particular', 'calculator'), 2),
#   (('calculator', 'could'), 2),
#   (('calculator', 'student'), 2),
#   (('expensive', 'calculator'), 2),
#   (('calculator', 'were'), 2),
#   (('calculator', 'though'), 2),
#   (('phone', 'calculator'), 2),
#   (('calculator', 'etc'), 2),
#   (('large', 'calculator'), 2),
#   (('calculator', 'such'), 2),
#   (('calculator', 'display'), 2),
#   (('an', 'calculator'), 2),
#   (('priced', 'calculator'), 2),
#   (('affordable', 'calculator'), 2),
#   (('calculator', 'by'), 2),
#   (('calculator', 'item'), 2),
#   (('lcd', 'calculator'), 2),
#   (('calculator', 'style'), 2),
#   (('calculator', 'may'), 1),
#   (('surviving', 'calculator'), 1),
#   (('electronic', 'calculator'), 1),
#   (('calculator', 'ever'), 1),
#   (('calculator', 's'), 1),
#   (('rpn', 'calculator'), 1),
#   (('calculator', 'remains'), 1),
#   (('heldheld', 'calculator'), 1),
#   (('calculator', 'built'), 1),
#   (('calculator', 'why'), 1),
#   (('calculator', 'engraved'), 1),
#   (('calculator', 'anniversary'), 1),
#   (('calculator', 'legacy'), 1),
#   (('calculator', 'rpn'), 1),
#   (('straightforward', 'calculator'), 1),
#   (('walmart', 'calculator'), 1),
#   (('calculator', 'straightforward'), 1),
#   (('calculator', 'amortization'), 1),
#   (('calculator', 'require'), 1),
#   (('calculator', 'anyway'), 1),
#   (('whole', 'calculator'), 1),
#   (('calculator', 'premise'), 1),
#   (('calculator', 'worthwhile'), 1),
#   (('few', 'calculator'), 1),
#   (('different', 'calculator'), 1),
#   (('calculator', 'sadly'), 1),
#   (('newer', 'calculator'), 1),
#   (('now', 'calculator'), 1),
#   (('calculator', 'talk'), 1),
#   (('keyed', 'calculator'), 1),
#   (('calculator', 'under'), 1),
#   (('neat', 'calculator'), 1),
#   (('price', 'calculator'), 1),
#   (('required', 'calculator'), 1),
#   (('wonderful', 'calculator'), 1),
#   (('individual', 'calculator'), 1),
#   (('calculator', 'throughout'), 1),
#   (('available', 'calculator'), 1),
#   (('calculator', 'packaging'), 1),
#   (('calculator', 'scientific'), 1),
#   (('he', 'calculator'), 1),
#   (('calculator', 'apparently'), 1),
#   (('calculator', 'mandatory'), 1),
#   (('versatile', 'calculator'), 1),
#   (('calculator', 'yes'), 1),
#   (('calculator', 'unlike'), 1),
#   (('calculator', 'go'), 1),
#   (('one', 'calculator'), 1),
#   (('calculator', 'my'), 1),
#   (('solid', 'calculator'), 1),
#   (('calculator', 'sure'), 1),
#   (('calculator', 'cable'), 1),
#   (('calculator', 'powered'), 1),
#   (('plus', 'calculator'), 1),
#   (('calculator', 'combine'), 1),
#   (('calculator', 'contains'), 1),
#   (('manual', 'calculator'), 1),
#   (('calculator', 'david'), 1),
#   (('calculator', 'worked'), 1),
#   (('calculator', 'site'), 1),
#   (('calculator', 'app'), 1),
#   (('star', 'calculator'), 1),
#   (('analyst', 'calculator'), 1),
#   (('have', 'calculator'), 1),
#   (('very', 'calculator'), 1),
#   (('normal', 'calculator'), 1),
#   (('competent', 'calculator'), 1),
#   (('calculator', 'either'), 1),
#   (('r', 'calculator'), 1),
#   (('when', 'calculator'), 1),
#   (('number', 'calculator'), 1),
#   (('portable', 'calculator'), 1),
#   (('main', 'calculator'), 1),
#   (('calculator', 'managing'), 1),
#   (('calculator', 'sits'), 1),
#   (('easy', 'calculator'), 1),
#   (('calculator', 'compact'), 1),
#   (('calculator', 'popular'), 1),
#   (('calculator', 'therefore'), 1),
#   (('calculator', 'say'), 1),
#   (('therethe', 'calculator'), 1),
#   (('calculator', 'upside'), 1),
#   (('calculator', 'trick'), 1),
#   (('calculator', 'down'), 1),
#   (('regular', 'calculator'), 1),
#   (('calculator', 'pretty'), 1),
#   (('calculator', 'especially'), 1),
#   (('supply', 'calculator'), 1),
#   (('fun', 'calculator'), 1),
#   (('calculator', 'stopped'), 1),
#   (('calculator', 'basically'), 1),
#   (('calculator', 'who'), 1),
#   (('sturdy', 'calculator'), 1),
#   (('fantastic', 'calculator'), 1),
#   (('calculator', 'solid'), 1),
#   (('calculator', 'thus'), 1),
#   (('calculator', 'most'), 1),
#   (('calculator', 'default'), 1),
#   (('calculator', 'aos'), 1),
#   (('calculator', 'wish'), 1),
#   (('nose', 'calculator'), 1),
#   (('calculator', 'daily'), 1),
#   (('cost', 'calculator'), 1),
#   (('calculator', 'froze'), 1),
#   (('calculator', 'canon'), 1),
#   (('calculator', 'died'), 1),
#   (('calculator', 'offer'), 1),
#   (('calculator', 'mentioned'), 1),
#   (('calculator', 'helped'), 1),
#   (('overpriced', 'calculator'), 1),
#   (('calculator', 'instruction'), 1),
#   (('calculator', 'scientifics'), 1),
#   (('calculator', 'cover'), 1),
#   (('calculator', 'often'), 1),
#   (('calculator', 'register'), 1),
#   (('calculator', 'solves'), 1),
#   (('excellent', 'calculator'), 1),
#   (('calculator', 'used'), 1),
#   (('calculator', 'fraction'), 1),
#   (('notice', 'calculator'), 1),
#   (('calculator', 'worthless'), 1),
#   (('calculator', 'cousin'), 1),
#   (('series', 'calculator'), 1),
#   (('calculator', 'previously'), 1),
#   (('calculator', 'face'), 1),
#   (('moved', 'calculator'), 1),
#   (('produced', 'calculator'), 1),
#   (('calculator', 'market'), 1),
#   (('dollar', 'calculator'), 1),
#   (('calculator', 'ti'), 1),
#   (('better', 'calculator'), 1),
#   (('calculator', 'same'), 1),
#   (('researching', 'calculator'), 1),
#   (('superior', 'calculator'), 1),
#   (('calculator', 'every'), 1),
#   (('calculator', 'useless'), 1),
#   (('child', 'calculator'), 1),
#   (('calculator', 'supply'), 1),
#   (('calculator', 'lack'), 1),
#   (('bad', 'calculator'), 1),
#   (('calculator', 'using'), 1),
#   (('calculator', 'exists'), 1),
#   (('potent', 'calculator'), 1),
#   (('calculator', 'support'), 1),
#   (('best', 'calculator'), 1),
#   (('work', 'calculator'), 1),
#   (('many', 'calculator'), 1),
#   (('x', 'calculator'), 1),
#   (('calculator', 'button'), 1),
#   (('calculator', 'mostly'), 1),
#   (('stylish', 'calculator'), 1),
#   (('calculator', 'bought'), 1),
#   (('calculator', 'allowed'), 1),
#   (('original', 'calculator'), 1),
#   (('calculator', 'did'), 1),
#   (('updated', 'calculator'), 1),
#   (('carry', 'calculator'), 1),
#   (('rich', 'calculator'), 1),
#   (('calculator', 'thank'), 1),
#   (('traditional', 'calculator'), 1),
#   (('calculator', 'during'), 1),
#   (('scienfic', 'calculator'), 1),
#   (('scienfitic', 'calculator'), 1),
#   (('terrible', 'calculator'), 1),
#   (('regarding', 'calculator'), 1),
#   (('calculator', 'design'), 1),
#   (('calculator', 'world'), 1),
#   (('earlier', 'calculator'), 1),
#   (('calculator', 'feel'), 1),
#   (('calculator', 'innovation'), 1),
#   (('calculator', 'salesperson'), 1),
#   (('calculator', 'software'), 1),
#   (('calculator', 'quality'), 1),
#   (('enough', 'calculator'), 1),
#   (('calculator', 'apps'), 1),
#   (('calculator', 'nice'), 1),
#   (('you', 'calculator'), 1),
#   (('calculator', 'wallet'), 1),
#   (('digit', 'calculator'), 1),
#   (('calculator', 'happily'), 1),
#   (('calculator', 'too'), 1),
#   (('newest', 'calculator'), 1),
#   (('calculator', 'thanks'), 1),
#   (('calculator', 'ran'), 1),
#   (('calculator', 'where'), 1),
#   (('every', 'calculator'), 1),
#   (('calculator', 'even'), 1),
#   (('mini', 'calculator'), 1),
#   (('calculator', 'worth'), 1),
#   (('calculator', 'great'), 1),
#   (('calculator', 'another'), 1),
#   (('having', 'calculator'), 1),
#   (('by', 'calculator'), 1),
#   (('calculator', 'itself'), 1),
#   (('calculator', 'he'), 1),
#   (('calculator', 'about'), 1),
#   (('calculator', 'highly'), 1),
#   (('calculator', 'well'), 1),
#   (('calculator', 'here'), 1),
#   (('calculator', 'specifically'), 1),
#   (('calculator', 'similar'), 1),
#   (('calculator', 'something'), 1),
#   (('calculator', 'star'), 1),
#   (('calculator', 'manual'), 1),
#   (('thing', 'calculator'), 1),
#   (('calculator', 'man'), 1),
#   (('cool', 'calculator'), 1),
#   (('calculator', 'per'), 1),
#   (('calculator', 'no'), 1),
#   (('perfect', 'calculator'), 1),
#   (('efficient', 'calculator'), 1),
#   (('minor', 'calculator'), 1),
#   (('handsome', 'calculator'), 1),
#   (('used', 'calculator'), 1),
#   (('forany', 'calculator'), 1),
#   (('calculator', 'differs'), 1),
#   (('calculator', 'once'), 1),
#   (('calculator', 'over'), 1),
#   (('casiothis', 'calculator'), 1),
#   (('calculator', 'directly'), 1),
#   (('calculator', 'performs'), 1),
#   (('should', 'calculator'), 1),
#   (('calculator', 'receipt'), 1),
#   (('protractor', 'calculator'), 1),
#   (('calculator', 'swatch'), 1),
#   (('calculator', 'best'), 1),
#   (('calculator', 'pencil'), 1),
#   (('calculator', 'measuring'), 1),
#   (('calculator', 'coupon'), 1),
#   (('tool', 'calculator'), 1),
#   (('calculator', 'tape'), 1),
#   (('calculator', 'ruler'), 1),
#   (('prizm', 'calculator'), 1),
#   (('calculator', 'color'), 1),
#   (('thought', 'calculator'), 1),
#   (('coolest', 'calculator'), 1),
#   (('calculator', 'more'), 1),
#   (('calculator', 'received'), 1),
#   (('calculator', 'how'), 1),
#   (('average', 'calculator'), 1),
#   (('calculator', 'keyset'), 1),
#   (('our', 'calculator'), 1),
#   (('calculator', 'collection'), 1),
#   (('issue', 'calculator'), 1),
#   (('higher', 'calculator'), 1),
#   (('calculator', 'compared'), 1),
#   (('amazing', 'calculator'), 1),
#   (('amazonbasics', 'calculator'), 1),
#   (('cheapy', 'calculator'), 1),
#   (('plain', 'calculator'), 1),
#   (('calculator', 'made'), 1),
#   (('window', 'calculator'), 1),
#   (('looking', 'calculator'), 1),
#   (('calculator', 'put'), 1),
#   (('calculator', 'control'), 1),
#   (('abasic', 'calculator'), 1),
#   (('brand', 'calculator'), 1),
#   (('some', 'calculator'), 1),
#   (('several', 'calculator'), 1),
#   (('calculator', 'include'), 1),
#   (('calculator', 'huge'), 1),
#   (('amazonasics', 'calculator'), 1),
#   (('son', 'calculator'), 1),
#   (('top', 'calculator'), 1),
#   (('calculator', 'our'), 1),
#   (('calculator', 'collector'), 1),
#   (('household', 'calculator'), 1),
#   (('calculator', 'measure'), 1),
#   (('display', 'calculator'), 1),
#   (('walgreens', 'calculator'), 1),
#   (('amazon', 'calculator'), 1),
#   (('calculator', 'meant'), 1),
#   (('general', 'calculator'), 1),
#   (('calculator', 'many'), 1),
#   (('calculator', 'outside'), 1),
#   (('calculator', 'gum'), 1),
#   (('item', 'calculator'), 1),
#   (('smallish', 'calculator'), 1),
#   (('pencil', 'calculator'), 1),
#   (('calculator', 'cell'), 1)]}

# %%
df_bigrams = pd.DataFrame({el : [' '.join(i[0]) for i in product_bigrams_2[el][:200]] for el in product_names})

# %%
df_bigrams
# Out:
#                printer              binder             dispenser  \
# 0        laser printer         view binder        tape dispenser
# 1        epson printer         ring binder        note dispenser
# 2        photo printer        other binder    handband dispenser
# 3           printer wa         duty binder        dispenser tape
# 4       inkjet printer        jones binder      little dispenser
# ..                 ...                 ...                   ...
# 195  printer durabrite  serviceable binder  dispenser refillable
# 196      printer being       strong binder       dispenser along
# 197   printer requires          binder lie    dispenser designed
# 198      printer again         mitt binder     dispenser release
# 199        end printer          binder too    dispenser actually
#
#                 folder             stapler             calculator
# 0          file folder          my stapler    graphing calculator
# 1       hanging folder   swingline stapler  scientific calculator
# 2        manila folder         stapler doe          hp calculator
# 3          folder they    standard stapler   financial calculator
# 4          folder have          stapler wa       basic calculator
# ..                 ...                 ...                    ...
# 195       cheap folder     typical stapler          he calculator
# 196   different folder       usual stapler  calculator apparently
# 197    folder together  attractive stapler   calculator mandatory
# 198   partition folder        easy stapler   versatile calculator
# 199  additional folder     stapler capable         calculator yes
#
# [200 rows x 6 columns]

# %% [markdown]
# #### Триграммы

# %%
trigrams = ngrams(' '.join(new_df['new_review']).split(), 3)

# %%
tri_dict = Counter(trigrams)

# %%
product_trigrams = {'printer':[], 'binder':[], 'dispenser':[], 'folder':[], 'stapler':[], 'calculator':[]}

for trigram in tri_dict.most_common():
    for product in product_trigrams.keys():
        if (product in trigram[0] and trigram[0][0] != trigram[0][1] and trigram[0][1] != trigram[0][2]):
            product_trigrams[product].append(trigram)

# %%
product_trigrams
# Out:
# {'printer': [(('this', 'printer', 'is'), 657),
#   (('the', 'printer', 'is'), 630),
#   (('of', 'the', 'printer'), 545),
#   (('the', 'printer', 'and'), 367),
#   (('with', 'this', 'printer'), 366),
#   (('on', 'the', 'printer'), 360),
#   (('the', 'printer', 'to'), 339),
#   (('with', 'the', 'printer'), 334),
#   (('to', 'the', 'printer'), 284),
#   (('printer', 'is', 'a'), 283),
#   (('printer', 'i', 'have'), 267),
#   (('of', 'this', 'printer'), 241),
#   (('this', 'printer', 'for'), 199),
#   (('the', 'printer', 'i'), 195),
#   (('and', 'the', 'printer'), 194),
#   (('the', 'printer', 'wa'), 188),
#   (('this', 'printer', 'i'), 182),
#   (('this', 'printer', 'and'), 171),
#   (('for', 'the', 'printer'), 171),
#   (('a', 'great', 'printer'), 161),
#   (('that', 'the', 'printer'), 158),
#   (('for', 'this', 'printer'), 152),
#   (('from', 'the', 'printer'), 143),
#   (('the', 'printer', 'on'), 142),
#   (('up', 'the', 'printer'), 142),
#   (('the', 'epson', 'printer'), 140),
#   (('that', 'this', 'printer'), 139),
#   (('printer', 'and', 'i'), 139),
#   (('the', 'printer', 'for'), 139),
#   (('this', 'printer', 'ha'), 138),
#   (('a', 'laser', 'printer'), 137),
#   (('the', 'printer', 'ha'), 135),
#   (('a', 'printer', 'that'), 134),
#   (('this', 'printer', 'to'), 133),
#   (('printer', 'and', 'the'), 128),
#   (('recommend', 'this', 'printer'), 127),
#   (('for', 'a', 'printer'), 124),
#   (('printer', 'it', 'is'), 123),
#   (('in', 'the', 'printer'), 123),
#   (('printer', 'in', 'the'), 123),
#   (('printer', 'ha', 'a'), 122),
#   (('this', 'printer', 'it'), 116),
#   (('printer', 'if', 'you'), 115),
#   (('the', 'printer', 'itself'), 114),
#   (('the', 'printer', 'the'), 114),
#   (('a', 'new', 'printer'), 113),
#   (('on', 'this', 'printer'), 112),
#   (('printer', 'that', 'i'), 111),
#   (('printer', 'and', 'it'), 109),
#   (('printer', 'for', 'a'), 109),
#   (('this', 'printer', 'doe'), 108),
#   (('use', 'the', 'printer'), 107),
#   (('about', 'this', 'printer'), 106),
#   (('this', 'printer', 'a'), 104),
#   (('printer', 'for', 'the'), 103),
#   (('the', 'printer', 'will'), 101),
#   (('printer', 'is', 'the'), 97),
#   (('this', 'printer', 'wa'), 94),
#   (('the', 'printer', 'doe'), 94),
#   (('the', 'printer', 'it'), 93),
#   (('using', 'this', 'printer'), 91),
#   (('a', 'wireless', 'printer'), 91),
#   (('printer', 'come', 'with'), 89),
#   (('color', 'inkjet', 'printer'), 89),
#   (('printer', 'this', 'is'), 87),
#   (('printer', 'doe', 'not'), 87),
#   (('the', 'printer', 'a'), 86),
#   (('this', 'printer', 'the'), 86),
#   (('to', 'this', 'printer'), 84),
#   (('the', 'printer', 'in'), 84),
#   (('use', 'this', 'printer'), 83),
#   (('and', 'this', 'printer'), 82),
#   (('printer', 'i', 'had'), 81),
#   (('a', 'photo', 'printer'), 81),
#   (('printer', 'on', 'the'), 77),
#   (('love', 'this', 'printer'), 77),
#   (('printer', 'is', 'very'), 76),
#   (('my', 'old', 'printer'), 75),
#   (('epson', 'workforce', 'printer'), 75),
#   (('into', 'the', 'printer'), 74),
#   (('using', 'the', 'printer'), 74),
#   (('printer', 'but', 'it'), 73),
#   (('printer', 'is', 'that'), 72),
#   (('the', 'printer', 'but'), 71),
#   (('in', 'one', 'printer'), 70),
#   (('a', 'the', 'printer'), 69),
#   (('color', 'laser', 'printer'), 69),
#   (('a', 'good', 'printer'), 67),
#   (('printer', 'is', 'not'), 66),
#   (('other', 'printer', 'i'), 66),
#   (('this', 'printer', 'will'), 64),
#   (('the', 'printer', 'driver'), 63),
#   (('ink', 'jet', 'printer'), 63),
#   (('printer', 'to', 'the'), 62),
#   (('epson', 'printer', 'i'), 62),
#   (('like', 'this', 'printer'), 61),
#   (('my', 'other', 'printer'), 61),
#   (('printer', 'over', 'the'), 60),
#   (('get', 'the', 'printer'), 60),
#   (('the', 'printer', 'with'), 60),
#   (('connect', 'the', 'printer'), 60),
#   (('printer', 'copier', 'scanner'), 59),
#   (('printer', 'but', 'i'), 59),
#   (('a', 'printer', 'i'), 57),
#   (('the', 'printer', 'can'), 57),
#   (('printer', 'i', 'wa'), 57),
#   (('printer', 'with', 'a'), 56),
#   (('printer', 'the', 'printer'), 55),
#   (('the', 'canon', 'printer'), 55),
#   (('the', 'printer', 'up'), 55),
#   (('printer', 'i', 'used'), 55),
#   (('set', 'the', 'printer'), 54),
#   (('the', 'printer', 'are'), 54),
#   (('bought', 'this', 'printer'), 53),
#   (('the', 'hp', 'printer'), 53),
#   (('the', 'printer', 'come'), 53),
#   (('printer', 'that', 'is'), 52),
#   (('laser', 'printer', 'for'), 50),
#   (('laser', 'printer', 'and'), 50),
#   (('printer', 'to', 'my'), 50),
#   (('brother', 'laser', 'printer'), 49),
#   (('printer', 'you', 'can'), 49),
#   (('an', 'inkjet', 'printer'), 49),
#   (('a', 'printer', 'and'), 49),
#   (('printer', 'for', 'my'), 49),
#   (('this', 'printer', 'but'), 49),
#   (('printer', 'i', 'ever'), 49),
#   (('printer', 'with', 'scanner'), 49),
#   (('had', 'this', 'printer'), 48),
#   (('printer', 'wa', 'a'), 48),
#   (('the', 'printer', 'you'), 48),
#   (('the', 'best', 'printer'), 48),
#   (('but', 'the', 'printer'), 48),
#   (('printer', 'in', 'this'), 48),
#   (('epson', 'printer', 'and'), 48),
#   (('printer', 'so', 'i'), 48),
#   (('this', 'epson', 'printer'), 48),
#   (('of', 'a', 'printer'), 47),
#   (('printer', 'in', 'my'), 46),
#   (('the', 'printer', 'so'), 46),
#   (('laser', 'printer', 'i'), 46),
#   (('the', 'printer', 'work'), 46),
#   (('a', 'printer', 'for'), 45),
#   (('great', 'printer', 'for'), 45),
#   (('printer', 'to', 'print'), 45),
#   (('this', 'printer', 'because'), 45),
#   (('photo', 'printer', 'with'), 45),
#   (('this', 'printer', 'in'), 44),
#   (('printer', 'is', 'an'), 44),
#   (('the', 'printer', 'also'), 44),
#   (('the', 'printer', 'from'), 44),
#   (('epson', 'printer', 'is'), 43),
#   (('up', 'this', 'printer'), 43),
#   (('printer', 'can', 'be'), 43),
#   (('have', 'the', 'printer'), 43),
#   (('the', 'printer', 'this'), 43),
#   (('inkjet', 'printer', 'copier'), 43),
#   (('printer', 'i', 'would'), 42),
#   (('got', 'this', 'printer'), 42),
#   (('other', 'epson', 'printer'), 42),
#   (('to', 'your', 'printer'), 42),
#   (('this', 'printer', 'can'), 41),
#   (('the', 'printer', 'software'), 41),
#   (('the', 'printer', 'that'), 40),
#   (('photo', 'printer', 'i'), 40),
#   (('printer', 'and', 'this'), 40),
#   (('printer', 'it', 'wa'), 40),
#   (('a', 'home', 'printer'), 40),
#   (('this', 'printer', 'on'), 40),
#   (('printer', 'in', 'a'), 39),
#   (('printer', 'this', 'printer'), 39),
#   (('is', 'a', 'printer'), 39),
#   (('found', 'the', 'printer'), 39),
#   (('if', 'the', 'printer'), 38),
#   (('a', 'printer', 'with'), 38),
#   (('the', 'printer', 'would'), 38),
#   (('printer', 'and', 'a'), 37),
#   (('had', 'the', 'printer'), 37),
#   (('is', 'the', 'printer'), 37),
#   (('all', 'the', 'printer'), 37),
#   (('printer', 'ha', 'been'), 37),
#   (('the', 'printer', 'via'), 37),
#   (('usb', 'printer', 'cable'), 37),
#   (('canon', 'pixma', 'printer'), 37),
#   (('the', 'other', 'printer'), 36),
#   (('printer', 'itself', 'is'), 36),
#   (('an', 'excellent', 'printer'), 36),
#   (('this', 'printer', 'so'), 36),
#   (('printer', 'scanner', 'copier'), 36),
#   (('the', 'printer', 'or'), 36),
#   (('canon', 'printer', 'and'), 36),
#   (('printer', 'on', 'a'), 36),
#   (('printer', 'to', 'be'), 36),
#   (('color', 'photo', 'printer'), 36),
#   (('wide', 'format', 'printer'), 35),
#   (('this', 'printer', 'you'), 35),
#   (('printer', 'for', 'home'), 35),
#   (('printer', 'it', 'doe'), 35),
#   (('laser', 'printer', 'that'), 35),
#   (('printer', 'doe', 'a'), 35),
#   (('the', 'printer', 'if'), 35),
#   (('printer', 'with', 'the'), 35),
#   (('printer', 'but', 'the'), 35),
#   (('find', 'the', 'printer'), 35),
#   (('need', 'a', 'printer'), 35),
#   (('the', 'printer', 'print'), 34),
#   (('printer', 'is', 'great'), 34),
#   (('photo', 'printer', 'and'), 34),
#   (('this', 'printer', 'with'), 34),
#   (('because', 'the', 'printer'), 34),
#   (('my', 'last', 'printer'), 34),
#   (('printer', 'that', 'can'), 34),
#   (('printer', 'i', 'do'), 33),
#   (('the', 'printer', 'when'), 33),
#   (('printer', 'is', 'fast'), 33),
#   (('from', 'this', 'printer'), 33),
#   (('put', 'the', 'printer'), 33),
#   (('make', 'this', 'printer'), 33),
#   (('wireless', 'printer', 'i'), 33),
#   (('printer', 'set', 'up'), 33),
#   (('when', 'the', 'printer'), 32),
#   (('this', 'printer', 'if'), 32),
#   (('the', 'printer', 'cartridge'), 32),
#   (('this', 'printer', 'up'), 32),
#   (('dedicated', 'photo', 'printer'), 32),
#   (('than', 'the', 'printer'), 32),
#   (('used', 'the', 'printer'), 31),
#   (('the', 'printer', 'us'), 31),
#   (('in', 'this', 'printer'), 31),
#   (('about', 'the', 'printer'), 31),
#   (('printer', 'i', 'owned'), 31),
#   (('printer', 'i', 'am'), 31),
#   (('monochrome', 'laser', 'printer'), 31),
#   (('inkjet', 'printer', 'i'), 31),
#   (('printer', 'at', 'a'), 31),
#   (('installed', 'the', 'printer'), 31),
#   (('the', 'brother', 'printer'), 30),
#   (('an', 'epson', 'printer'), 30),
#   (('printer', 'it', 'ha'), 30),
#   (('a', 'color', 'printer'), 30),
#   (('printer', 'to', 'work'), 30),
#   (('printer', 'that', 'doe'), 30),
#   (('while', 'the', 'printer'), 30),
#   (('canon', 'printer', 'i'), 30),
#   (('install', 'the', 'printer'), 30),
#   (('laser', 'printer', 'with'), 30),
#   (('my', 'previous', 'printer'), 30),
#   (('the', 'printer', 'which'), 30),
#   (('of', 'epson', 'printer'), 30),
#   (('printer', 'up', 'and'), 29),
#   (('epson', 'printer', 'for'), 29),
#   (('this', 'printer', 'that'), 29),
#   (('buy', 'this', 'printer'), 29),
#   (('printer', 'there', 'is'), 29),
#   (('hp', 'printer', 'i'), 29),
#   (('printer', 'which', 'is'), 29),
#   (('at', 'the', 'printer'), 29),
#   (('printer', 'on', 'my'), 29),
#   (('in', 'a', 'printer'), 29),
#   (('wireless', 'printer', 'and'), 29),
#   (('printer', 'wa', 'easy'), 29),
#   (('printer', 'for', 'about'), 28),
#   (('printer', 'is', 'also'), 28),
#   (('printer', 'that', 'will'), 28),
#   (('the', 'printer', 'without'), 28),
#   (('installing', 'the', 'printer'), 28),
#   (('the', 'new', 'printer'), 28),
#   (('laser', 'printer', 'the'), 28),
#   (('printer', 'the', 'epson'), 28),
#   (('printer', 'and', 'have'), 28),
#   (('printer', 'out', 'of'), 28),
#   (('printer', 'and', 'scanner'), 28),
#   (('not', 'the', 'printer'), 28),
#   (('the', 'printer', 'control'), 28),
#   (('printer', 'to', 'your'), 28),
#   (('but', 'this', 'printer'), 28),
#   (('printer', 'from', 'the'), 28),
#   (('printer', 'a', 'well'), 27),
#   (('printer', 'because', 'it'), 27),
#   (('turn', 'the', 'printer'), 27),
#   (('printer', 'is', 'so'), 27),
#   (('this', 'little', 'printer'), 27),
#   (('printer', 'to', 'replace'), 27),
#   (('the', 'laser', 'printer'), 27),
#   (('of', 'these', 'printer'), 27),
#   (('used', 'this', 'printer'), 27),
#   (('a', 'printer', 'it'), 27),
#   (('laser', 'printer', 'but'), 27),
#   (('printer', 'this', 'one'), 27),
#   (('a', 'usb', 'printer'), 27),
#   (('printer', 'like', 'this'), 27),
#   (('my', 'hp', 'printer'), 27),
#   (('a', 'printer', 'is'), 27),
#   (('the', 'workforce', 'printer'), 27),
#   (('laser', 'printer', 'is'), 26),
#   (('the', 'printer', 'at'), 26),
#   (('get', 'this', 'printer'), 26),
#   (('this', 'printer', 'us'), 26),
#   (('this', 'printer', 'work'), 26),
#   (('printer', 'we', 'have'), 26),
#   (('with', 'a', 'printer'), 26),
#   (('large', 'format', 'printer'), 26),
#   (('this', 'printer', 'from'), 26),
#   (('good', 'printer', 'for'), 26),
#   (('printer', 'is', 'quite'), 26),
#   (('inkjet', 'photo', 'printer'), 26),
#   (('printer', 'seems', 'to'), 26),
#   (('printer', 'to', 'a'), 26),
#   (('printer', 'that', 'ha'), 26),
#   (('workforce', 'printer', 'is'), 26),
#   (('the', 'printer', 'had'), 25),
#   (('inkjet', 'printer', 'and'), 25),
#   (('printer', 'and', 'they'), 25),
#   (('printer', 'but', 'this'), 25),
#   (('purchased', 'this', 'printer'), 25),
#   (('a', 'decent', 'printer'), 25),
#   (('like', 'the', 'printer'), 25),
#   (('this', 'printer', 'are'), 25),
#   (('great', 'little', 'printer'), 25),
#   (('printer', 'is', 'easy'), 25),
#   (('printer', 'at', 'home'), 25),
#   (('any', 'other', 'printer'), 25),
#   (('printer', 'ink', 'cartridge'), 25),
#   (('by', 'the', 'printer'), 25),
#   (('printer', 'wa', 'very'), 25),
#   (('printer', 'ha', 'the'), 25),
#   (('wireless', 'monochrome', 'printer'), 25),
#   (('best', 'printer', 'i'), 24),
#   (('getting', 'the', 'printer'), 24),
#   (('printer', 'at', 'the'), 24),
#   (('give', 'this', 'printer'), 24),
#   (('printer', 'for', 'year'), 24),
#   (('printer', 'which', 'i'), 24),
#   (('off', 'the', 'printer'), 24),
#   (('printer', 'that', 'print'), 24),
#   (('printer', 'would', 'be'), 24),
#   (('a', 'canon', 'printer'), 24),
#   (('through', 'the', 'printer'), 24),
#   (('the', 'printer', 'using'), 24),
#   (('printer', 'the', 'print'), 24),
#   (('the', 'printer', 'did'), 24),
#   (('a', 'fantastic', 'printer'), 24),
#   (('printer', 'there', 'are'), 24),
#   (('very', 'good', 'printer'), 23),
#   (('my', 'canon', 'printer'), 23),
#   (('the', 'printer', 'take'), 23),
#   (('printer', 'because', 'of'), 23),
#   (('since', 'the', 'printer'), 23),
#   (('printer', 'will', 'be'), 23),
#   (('very', 'nice', 'printer'), 23),
#   (('inkjet', 'printer', 'the'), 23),
#   (('the', 'printer', 'ink'), 23),
#   (('printer', 'is', 'pretty'), 23),
#   (('printer', 'of', 'this'), 23),
#   (('type', 'of', 'printer'), 23),
#   (('a', 'nice', 'printer'), 23),
#   (('printer', 'that', 'wa'), 23),
#   (('printer', 'for', 'printing'), 22),
#   (('printer', 'for', 'you'), 22),
#   (('the', 'printer', 'there'), 22),
#   (('inkjet', 'printer', 'that'), 22),
#   (('this', 'printer', 'at'), 22),
#   (('printer', 'like', 'the'), 22),
#   (('lot', 'of', 'printer'), 22),
#   (('epson', 'printer', 'in'), 22),
#   (('have', 'a', 'printer'), 22),
#   (('have', 'this', 'printer'), 22),
#   (('connecting', 'the', 'printer'), 22),
#   (('a', 'printer', 'in'), 22),
#   (('printer', 'you', 'will'), 22),
#   (('printer', 'control', 'panel'), 22),
#   (('printer', 'also', 'ha'), 22),
#   (('printer', 'and', 'my'), 22),
#   (('to', 'my', 'printer'), 22),
#   (('printer', 'wireless', 'color'), 22),
#   (('this', 'printer', 'print'), 21),
#   (('other', 'printer', 'in'), 21),
#   (('with', 'epson', 'printer'), 21),
#   (('the', 'same', 'printer'), 21),
#   (('printer', 'have', 'been'), 21),
#   (('printer', 'for', 'your'), 21),
#   (('keep', 'the', 'printer'), 21),
#   (('and', 'white', 'printer'), 21),
#   (('this', 'printer', 'would'), 21),
#   (('printer', 'scanner', 'and'), 21),
#   (('printer', 'wa', 'not'), 21),
#   (('this', 'printer', 'this'), 21),
#   (('printer', 'to', 'use'), 21),
#   (('a', 'network', 'printer'), 21),
#   (('setup', 'the', 'printer'), 21),
#   (('on', 'a', 'printer'), 21),
#   (('the', 'first', 'printer'), 21),
#   (('other', 'canon', 'printer'), 21),
#   (('my', 'first', 'printer'), 21),
#   (('with', 'other', 'printer'), 21),
#   (('the', 'samsung', 'printer'), 21),
#   (('the', 'printer', 'after'), 20),
#   (('to', 'other', 'printer'), 20),
#   (('photo', 'printer', 'but'), 20),
#   (('wireless', 'color', 'printer'), 20),
#   (('from', 'a', 'printer'), 20),
#   (('this', 'printer', 'after'), 20),
#   (('the', 'printer', 'out'), 20),
#   (('the', 'printer', 'head'), 20),
#   (('buy', 'a', 'printer'), 20),
#   (('printer', 'is', 'it'), 20),
#   (('it', 'the', 'printer'), 20),
#   (('printer', 'on', 'your'), 20),
#   (('this', 'printer', 'seems'), 20),
#   (('printer', 'and', 'you'), 20),
#   (('printer', 'i', 'like'), 20),
#   (('printer', 'it', 'print'), 20),
#   (('a', 'small', 'printer'), 20),
#   (('a', 'printer', 'to'), 20),
#   (('printer', 'when', 'i'), 20),
#   (('a', 'printer', 'this'), 20),
#   (('a', 'printer', 'but'), 20),
#   (('printer', 'wa', 'the'), 19),
#   (('printer', 'for', 'over'), 19),
#   (('inside', 'the', 'printer'), 19),
#   (('the', 'printer', 'off'), 19),
#   (('my', 'printer', 'is'), 19),
#   (('laser', 'printer', 'it'), 19),
#   (('printer', 'that', 'would'), 19),
#   (('printer', 'easy', 'to'), 19),
#   (('epson', 'photo', 'printer'), 19),
#   (('printer', 'and', 'then'), 19),
#   (('laser', 'printer', 'are'), 19),
#   (('once', 'the', 'printer'), 19),
#   (('received', 'this', 'printer'), 19),
#   (('than', 'this', 'printer'), 19),
#   (('printer', 'i', 'love'), 19),
#   (('hp', 'printer', 'and'), 19),
#   (('any', 'printer', 'i'), 19),
#   (('a', 'this', 'printer'), 19),
#   (('a', 'big', 'printer'), 19),
#   (('photo', 'printer', 'the'), 19),
#   (('add', 'the', 'printer'), 19),
#   (('the', 'printer', 'worked'), 19),
#   (('your', 'printer', 'is'), 19),
#   (('printer', 'such', 'a'), 19),
#   (('printer', 'to', 'anyone'), 19),
#   (('photo', 'printer', 'is'), 19),
#   (('a', 'printer', 'the'), 19),
#   (('my', 'laser', 'printer'), 19),
#   (('printer', 'using', 'the'), 19),
#   (('the', 'printer', 'setting'), 19),
#   (('printer', 'i', 'think'), 19),
#   (('epson', 'printer', 'that'), 19),
#   (('the', 'old', 'printer'), 19),
#   (('think', 'this', 'printer'), 19),
#   (('old', 'hp', 'printer'), 19),
#   (('inkjet', 'printer', 'is'), 19),
#   (('printer', 'durabrite', 'ultra'), 19),
#   (('home', 'office', 'printer'), 19),
#   (('this', 'canon', 'printer'), 18),
#   (('an', 'hp', 'printer'), 18),
#   (('paper', 'the', 'printer'), 18),
#   (('of', 'printer', 'and'), 18),
#   (('by', 'this', 'printer'), 18),
#   (('this', 'printer', 'star'), 18),
#   (('a', 'solid', 'printer'), 18),
#   (('printer', 'out', 'there'), 18),
#   (('printer', 'i', 'will'), 18),
#   (('this', 'printer', 'my'), 18),
#   (('the', 'printer', 'over'), 18),
#   (('printer', 'will', 'print'), 18),
#   (('set', 'this', 'printer'), 18),
#   (('printer', 'is', 'to'), 18),
#   (('printer', 'is', 'just'), 18),
#   (('printer', 'but', 'for'), 18),
#   (('of', 'printer', 'i'), 18),
#   (('this', 'printer', 'also'), 18),
#   (('the', 'printer', 'into'), 18),
#   (('wireless', 'printer', 'is'), 18),
#   (('printer', 'can', 'do'), 18),
#   (('printer', 'the', 'ink'), 18),
#   (('printer', 'when', 'it'), 18),
#   (('line', 'of', 'printer'), 17),
#   (('this', 'laser', 'printer'), 17),
#   (('canon', 'printer', 'is'), 17),
#   (('printer', 'you', 'have'), 17),
#   (('printer', 'should', 'be'), 17),
#   (('canon', 'printer', 'for'), 17),
#   (('my', 'epson', 'printer'), 17),
#   (('the', 'printer', 'by'), 17),
#   (('a', 'printer', 'cable'), 17),
#   (('laser', 'printer', 'which'), 17),
#   (('printer', 'is', 'much'), 17),
#   (('than', 'other', 'printer'), 17),
#   (('see', 'the', 'printer'), 17),
#   (('then', 'this', 'printer'), 17),
#   (('the', 'printer', 'then'), 17),
#   (('white', 'laser', 'printer'), 17),
#   (('the', 'printer', 'setup'), 17),
#   (('laser', 'printer', 'in'), 17),
#   (('photo', 'printer', 'for'), 17),
#   (('printer', 'is', 'huge'), 17),
#   (('printer', 'it', 'will'), 17),
#   (('printer', 'i', 'did'), 17),
#   (('printer', 'and', 'not'), 17),
#   (('the', 'kodak', 'printer'), 17),
#   (('printer', 'at', 'this'), 17),
#   (('printer', 'is', 'small'), 17),
#   (('printer', 'these', 'day'), 17),
#   (('printer', 'i', 'can'), 17),
#   (('the', 'printer', 'connected'), 17),
#   (('workforce', 'pro', 'printer'), 17),
#   (('my', 'printer', 'for'), 16),
#   (('good', 'printer', 'and'), 16),
#   (('not', 'a', 'printer'), 16),
#   (('more', 'expensive', 'printer'), 16),
#   (('the', 'printer', 'go'), 16),
#   (('hp', 'printer', 'that'), 16),
#   (('printer', 'and', 'ha'), 16),
#   (('ink', 'this', 'printer'), 16),
#   (('printer', 'i', 'bought'), 16),
#   (('printer', 'for', 'photo'), 16),
#   (('then', 'the', 'printer'), 16),
#   (('hp', 'printer', 'is'), 16),
#   (('the', 'printer', 'just'), 16),
#   (('printer', 'take', 'up'), 16),
#   (('printer', 'for', 'it'), 16),
#   (('printer', 'even', 'though'), 16),
#   (('printer', 'need', 'to'), 16),
#   (('a', 'large', 'printer'), 16),
#   (('the', 'printer', 'while'), 16),
#   (('other', 'printer', 'that'), 16),
#   (('connected', 'the', 'printer'), 16),
#   (('great', 'printer', 'i'), 16),
#   (('needed', 'a', 'printer'), 16),
#   (('printer', 'will', 'not'), 16),
#   (('with', 'most', 'printer'), 16),
#   (('new', 'printer', 'i'), 16),
#   (('printer', 'doe', 'have'), 16),
#   (('want', 'a', 'printer'), 16),
#   (('so', 'the', 'printer'), 16),
#   (('printer', 'that', 'are'), 16),
#   (('the', 'printer', 'not'), 16),
#   (('printer', 'connected', 'to'), 16),
#   (('quality', 'photo', 'printer'), 16),
#   (('the', 'printer', 'however'), 16),
#   (('printer', 'is', 'on'), 16),
#   (('this', 'printer', 'which'), 16),
#   (('some', 'other', 'printer'), 16),
#   (('printer', 'so', 'far'), 16),
#   (('me', 'this', 'printer'), 15),
#   (('this', 'printer', 'we'), 15),
#   (('the', 'printer', 'through'), 15),
#   (('make', 'the', 'printer'), 15),
#   (('printer', 'and', 'is'), 15),
#   (('this', 'brother', 'printer'), 15),
#   (('printer', 'i', 'use'), 15),
#   (('printer', 'that', 'you'), 15),
#   (('printer', 'it', 'a'), 15),
#   (('this', 'printer', 'take'), 15),
#   (('of', 'my', 'printer'), 15),
#   (('to', 'a', 'printer'), 15),
#   (('the', 'fastest', 'printer'), 15),
#   (('printer', 'up', 'to'), 15),
#   (('printer', 'driver', 'and'), 15),
#   (('it', 'this', 'printer'), 15),
#   (('the', 'printer', 'only'), 15),
#   (('price', 'this', 'printer'), 15),
#   (('color', 'printer', 'i'), 15),
#   (('printer', 'and', 'would'), 15),
#   (('this', 'printer', 'really'), 15),
#   (('printer', 'for', 'all'), 15),
#   (('printer', 'a', 'it'), 15),
#   (('on', 'my', 'printer'), 15),
#   (('printer', 'is', 'wireless'), 15),
#   (('printer', 'a', 'i'), 15),
#   (('the', 'printer', 'directly'), 15),
#   (('printer', 'is', 'still'), 15),
#   (('printer', 'via', 'usb'), 15),
#   (('printer', 'so', 'it'), 15),
#   (('printer', 'work', 'great'), 15),
#   (('this', 'printer', 'when'), 15),
#   (('printer', 'from', 'epson'), 15),
#   (('printer', 'is', 'in'), 15),
#   (('other', 'printer', 'and'), 15),
#   (('first', 'wireless', 'printer'), 15),
#   (('new', 'printer', 'and'), 15),
#   (('a', 'few', 'printer'), 15),
#   (('this', 'particular', 'printer'), 14),
#   (('printer', 'because', 'i'), 14),
#   (('printer', 'i', 'just'), 14),
#   (('printer', 'is', 'one'), 14),
#   (('though', 'the', 'printer'), 14),
#   (('printer', 'when', 'you'), 14),
#   (('printing', 'this', 'printer'), 14),
#   (('samsung', 'laser', 'printer'), 14),
#   (('printer', 'would', 'not'), 14),
#   (('printer', 'in', 'our'), 14),
#   (('the', 'perfect', 'printer'), 14),
#   (('printer', 'is', 'no'), 14),
#   (('printing', 'the', 'printer'), 14),
#   (('printer', 'may', 'be'), 14),
#   (('printer', 'which', 'wa'), 14),
#   (('printer', 'but', 'if'), 14),
#   (('printer', 'is', 'big'), 14),
#   (('use', 'my', 'printer'), 14),
#   (('where', 'the', 'printer'), 14),
#   (('a', 'printer', 'you'), 14),
#   (('hp', 'printer', 'it'), 14),
#   (('found', 'this', 'printer'), 14),
#   (('an', 'office', 'printer'), 14),
#   (('printer', 'and', 'print'), 14),
#   (('a', 'better', 'printer'), 14),
#   (('printer', 'can', 'print'), 14),
#   (('got', 'the', 'printer'), 14),
#   (('a', 'printer', 'of'), 14),
#   (('print', 'the', 'printer'), 14),
#   (('printer', 'instead', 'of'), 14),
#   (('this', 'printer', 'there'), 14),
#   (('this', 'printer', 'could'), 14),
#   (('a', 'printer', 'like'), 14),
#   (('buying', 'this', 'printer'), 14),
#   (('of', 'printer', 'over'), 14),
#   (('small', 'office', 'printer'), 14),
#   (('printer', 'i', 'also'), 14),
#   (('printer', 'are', 'the'), 14),
#   (('office', 'printer', 'and'), 14),
#   (('this', 'new', 'printer'), 14),
#   (('printer', 'came', 'with'), 14),
#   (('had', 'a', 'printer'), 14),
#   (('just', 'a', 'printer'), 14),
#   (('printer', 'while', 'it'), 13),
#   (('printer', 'us', 'a'), 13),
#   (('brand', 'of', 'printer'), 13),
#   (('cartridge', 'the', 'printer'), 13),
#   (('laser', 'printer', 'this'), 13),
#   (('printer', 'with', 'my'), 13),
#   (('setting', 'the', 'printer'), 13),
#   (('great', 'printer', 'and'), 13),
#   (('excellent', 'printer', 'for'), 13),
#   (('the', 'printer', 'need'), 13),
#   (('this', 'printer', 'should'), 13),
#   (('with', 'any', 'printer'), 13),
#   (('printer', 'to', 'do'), 13),
#   (('format', 'photo', 'printer'), 13),
#   (('photo', 'printer', 'this'), 13),
#   (('printer', 'are', 'not'), 13),
#   (('place', 'the', 'printer'), 13),
#   (('the', 'printer', 'could'), 13),
#   (('printer', 'for', 'me'), 13),
#   (('laser', 'printer', 'so'), 13),
#   (('wireless', 'printer', 'that'), 13),
#   (('printer', 'is', 'connected'), 13),
#   (('printer', 'that', 'work'), 13),
#   (('good', 'quality', 'printer'), 13),
#   (('first', 'printer', 'i'), 13),
#   (('my', 'older', 'printer'), 13),
#   (('printer', 'is', 'really'), 13),
#   (('photo', 'printer', 'that'), 13),
#   (('this', 'printer', 'set'), 13),
#   (('printer', 'doe', 'it'), 13),
#   (('the', 'printer', 'workforce'), 13),
#   (('printer', 'ha', 'an'), 13),
#   (('printer', 'unless', 'you'), 13),
#   (('printer', 'and', 'that'), 13),
#   (('printer', 'with', 'wireless'), 13),
#   (('printer', 'a', 'lot'), 13),
#   (('number', 'of', 'printer'), 13),
#   (('printer', 'did', 'not'), 13),
#   (('a', 'basic', 'printer'), 13),
#   (('the', 'pixma', 'printer'), 13),
#   (('canon', 'printer', 'in'), 13),
#   (('this', 'printer', 'not'), 12),
#   (('epson', 'printer', 'are'), 12),
#   (('over', 'the', 'printer'), 12),
#   (('for', 'an', 'printer'), 12),
#   (('printer', 'have', 'a'), 12),
#   (('printer', 'a', 'the'), 12),
#   (('epson', 'inkjet', 'printer'), 12),
#   (('printer', 'i', 'got'), 12),
#   (('tested', 'the', 'printer'), 12),
#   (('out', 'the', 'printer'), 12),
#   (('printer', 'which', 'are'), 12),
#   (('so', 'this', 'printer'), 12),
#   (('great', 'printer', 'that'), 12),
#   (('both', 'the', 'printer'), 12),
#   (('one', 'printer', 'i'), 12),
#   (('printer', 'for', 'that'), 12),
#   (('it', 'a', 'printer'), 12),
#   (('printer', 'used', 'to'), 12),
#   (('if', 'this', 'printer'), 12),
#   (('printer', 'is', 'perfect'), 12),
#   (('easy', 'the', 'printer'), 12),
#   (('several', 'epson', 'printer'), 12),
#   (('the', 'this', 'printer'), 12),
#   (('on', 'both', 'printer'), 12),
#   (('printer', 'before', 'and'), 12),
#   (('printer', 'with', 'all'), 12),
#   (('the', 'printer', 'wirelessly'), 12),
#   (('getting', 'this', 'printer'), 12),
#   (('printer', 'had', 'a'), 12),
#   (('network', 'the', 'printer'), 12),
#   (('the', 'printer', 'automatically'), 12),
#   (('printer', 'i', 'ca'), 12),
#   (('printer', 'ha', 'all'), 12),
#   (('my', 'printer', 'and'), 12),
#   (('the', 'printer', 'seems'), 12),
#   (('home', 'printer', 'i'), 12),
#   (('printer', 'is', 'more'), 12),
#   (('plug', 'the', 'printer'), 12),
#   (('scanner', 'and', 'printer'), 12),
#   (('printer', 'i', 'could'), 12),
#   (('access', 'the', 'printer'), 12),
#   (('old', 'printer', 'and'), 12),
#   (('setup', 'this', 'printer'), 12),
#   (('the', 'printer', 'function'), 12),
#   (('the', 'printer', 'came'), 12),
#   (('kind', 'of', 'printer'), 12),
#   (('printer', 'can', 'also'), 12),
#   (('be', 'the', 'printer'), 12),
#   (('review', 'this', 'printer'), 12),
#   (('recognized', 'the', 'printer'), 12),
#   (('the', 'printer', 'printing'), 12),
#   (('my', 'new', 'printer'), 12),
#   (('my', 'printer', 'wa'), 12),
#   (('photo', 'printer', 'which'), 12),
#   (('expression', 'premium', 'printer'), 12),
#   (('on', 'your', 'printer'), 11),
#   (('photo', 'inkjet', 'printer'), 11),
#   (('printer', 'since', 'the'), 11),
#   (('a', 'wonderful', 'printer'), 11),
#   (('a', 'different', 'printer'), 11),
#   (('canon', 'printer', 'but'), 11),
#   (('other', 'printer', 'the'), 11),
#   (('in', 'my', 'printer'), 11),
#   (('hp', 'printer', 'in'), 11),
#   (('other', 'photo', 'printer'), 11),
#   (('the', 'printer', 'wireless'), 11),
#   (('printer', 'that', 'cost'), 11),
#   (('printer', 'will', 'do'), 11),
#   (('other', 'laser', 'printer'), 11),
#   (('laser', 'printer', 'to'), 11),
#   (('time', 'the', 'printer'), 11),
#   (('most', 'other', 'printer'), 11),
#   (('the', 'worst', 'printer'), 11),
#   (('now', 'the', 'printer'), 11),
#   (('printer', 'the', 'quality'), 11),
#   (('canon', 'printer', 'the'), 11),
#   (('printer', 'i', 'recommend'), 11),
#   (('this', 'printer', 'may'), 11),
#   (('photo', 'printer', 'like'), 11),
#   (('printer', 'is', 'quiet'), 11),
#   (('the', 'printer', 'look'), 11),
#   (('find', 'a', 'printer'), 11),
#   (('a', 'multifunction', 'printer'), 11),
#   (('the', 'entire', 'printer'), 11),
#   (('this', 'printer', 'make'), 11),
#   (('box', 'the', 'printer'), 11),
#   (('and', 'hp', 'printer'), 11),
#   (('printer', 'and', 'wa'), 11),
#   (('printer', 'to', 'get'), 11),
#   (('the', 'printer', 'scan'), 11),
#   (('buying', 'a', 'printer'), 11),
#   (('this', 'printer', 'even'), 11),
#   (('open', 'the', 'printer'), 11),
#   (('printer', 'rather', 'than'), 11),
#   (('the', 'printer', 'now'), 11),
#   (('printer', 'and', 'do'), 11),
#   (('a', 'fine', 'printer'), 11),
#   (('printer', 'with', 'it'), 11),
#   (('printer', 'but', 'you'), 11),
#   (('recommend', 'the', 'printer'), 11),
#   (('printer', 'they', 'are'), 11),
#   (('printer', 'it', 'really'), 11),
#   (('printer', 'with', 'good'), 11),
#   (('color', 'printer', 'that'), 11),
#   (('the', 'printer', 'do'), 11),
#   (('printer', 'wa', 'connected'), 11),
#   (('which', 'the', 'printer'), 11),
#   (('the', 'wireless', 'printer'), 11),
#   (('after', 'the', 'printer'), 11),
#   (('printer', 'with', 'this'), 11),
#   (('a', 'business', 'printer'), 11),
#   (('wireless', 'printer', 'the'), 11),
#   (('wireless', 'printer', 'it'), 11),
#   (('printer', 'i', 'own'), 11),
#   (('printer', 'on', 'and'), 11),
#   (('printer', 'i', 'really'), 11),
#   (('printer', 'and', 'all'), 11),
#   (('setting', 'this', 'printer'), 11),
#   (('this', 'printer', 'offer'), 11),
#   (('printer', 'setup', 'wa'), 11),
#   (('other', 'inkjet', 'printer'), 11),
#   (('the', 'printer', 'lcd'), 11),
#   (('printer', 'in', 'term'), 11),
#   (('printer', 'is', 'definitely'), 11),
#   (('workforce', 'wireless', 'printer'), 11),
#   (('the', 'default', 'printer'), 11),
#   (('high', 'quality', 'printer'), 11),
#   (('old', 'printer', 'i'), 11),
#   (('your', 'printer', 'from'), 11),
#   (('the', 'printer', 'instead'), 11),
#   (('workforce', 'printer', 'i'), 11),
#   (('than', 'most', 'printer'), 11),
#   (('computer', 'and', 'printer'), 10),
#   (('at', 'this', 'printer'), 10),
#   (('a', 'fast', 'printer'), 10),
#   (('good', 'printer', 'i'), 10),
#   (('printer', 'back', 'in'), 10),
#   (('printer', 'is', 'better'), 10),
#   (('the', 'printer', 'since'), 10),
#   (('purchase', 'this', 'printer'), 10),
#   (('printer', 'is', 'fairly'), 10),
#   (('printer', 'it', 'would'), 10),
#   (('the', 'printer', 'all'), 10),
#   (('the', 'printer', 'one'), 10),
#   (('printer', 'is', 'large'), 10),
#   (('printer', 'is', 'excellent'), 10),
#   (('this', 'printer', 'produce'), 10),
#   (('printer', 'for', 'some'), 10),
#   (('printer', 'so', 'you'), 10),
#   (('printer', 'and', 'will'), 10),
#   (('printer', 'i', 'wanted'), 10),
#   (('have', 'my', 'printer'), 10),
#   (('inkjet', 'printer', 'for'), 10),
#   (('with', 'my', 'printer'), 10),
#   (('printer', 'it', 'took'), 10),
#   (('most', 'laser', 'printer'), 10),
#   (('printer', 'so', 'that'), 10),
#   (('printer', 'doe', 'the'), 10),
#   (('my', 'brother', 'printer'), 10),
#   (('printer', 'will', 'last'), 10),
#   (('new', 'printer', 'a'), 10),
#   (('printer', 'however', 'i'), 10),
#   (('out', 'this', 'printer'), 10),
#   (('printer', 'where', 'you'), 10),
#   (('this', 'printer', 'through'), 10),
#   (('the', 'printer', 'before'), 10),
#   (('nice', 'printer', 'for'), 10),
#   (('configure', 'the', 'printer'), 10),
#   (('printer', 'to', 'make'), 10),
#   (('between', 'the', 'printer'), 10),
#   (('printer', 'through', 'the'), 10),
#   (('wanted', 'a', 'printer'), 10),
#   (('the', 'printer', 'set'), 10),
#   (('the', 'printer', 'have'), 10),
#   (('printer', 'is', 'for'), 10),
#   (('ink', 'the', 'printer'), 10),
#   (('epson', 'artisan', 'printer'), 10),
#   (('dot', 'matrix', 'printer'), 10),
#   (('printer', 'could', 'be'), 10),
#   (('printer', 'but', 'not'), 10),
#   (('this', 'printer', 'first'), 10),
#   (('mode', 'the', 'printer'), 10),
#   (('the', 'printer', 'anywhere'), 10),
#   (('printer', 'into', 'the'), 10),
#   (('wireless', 'printer', 'for'), 10),
#   (('this', 'printer', 'cost'), 10),
#   (('the', 'printer', 'make'), 10),
#   (('all', 'this', 'printer'), 10),
#   (('thing', 'this', 'printer'), 10),
#   (('a', 'printer', 'a'), 10),
#   (('get', 'a', 'printer'), 10),
#   (('printer', 'an', 'hp'), 10),
#   (('printer', 'i', 'been'), 10),
#   (('previous', 'epson', 'printer'), 10),
#   (('printer', 'touch', 'screen'), 10),
#   (('printer', 'to', 'set'), 10),
#   (('wireless', 'printer', 'to'), 10),
#   (('the', 'printer', 'menu'), 10),
#   (('for', 'your', 'printer'), 10),
#   (('printer', 'it', 'not'), 10),
#   (('the', 'printer', 'screen'), 10),
#   (('printer', 'ha', 'two'), 10),
#   (('printer', 'but', 'there'), 10),
#   (('printer', 'the', 'only'), 10),
#   (('brother', 'printer', 'is'), 10),
#   (('find', 'this', 'printer'), 10),
#   (('printer', 'to', 'connect'), 10),
#   (('printer', 'i', 'found'), 10),
#   (('this', 'printer', 'just'), 10),
#   (('printer', 'is', 'about'), 10),
#   (('a', 'compact', 'printer'), 10),
#   (('pixma', 'printer', 'wireless'), 10),
#   (('epson', 'printer', 'wa'), 10),
#   (('printer', 'for', 'many'), 10),
#   (('great', 'printer', 'it'), 10),
#   (('tray', 'the', 'printer'), 10),
#   (('printer', 'it', 'easy'), 10),
#   (('this', 'printer', 'look'), 10),
#   (('printer', 'it', 'also'), 10),
#   (('quality', 'printer', 'for'), 10),
#   (('workforce', 'printer', 'wireless'), 10),
#   (('printer', 'is', 'amazing'), 9),
#   (('hp', 'printer', 'the'), 9),
#   (('printer', 'compared', 'to'), 9),
#   (('this', 'printer', 'although'), 9),
#   (('printer', 'for', 'several'), 9),
#   (('color', 'printer', 'for'), 9),
#   (('printer', 'take', 'a'), 9),
#   (('photo', 'printer', 'in'), 9),
#   (('printer', 'doe', 'everything'), 9),
#   (('the', 'printer', 'were'), 9),
#   (('laser', 'printer', 'at'), 9),
#   (('with', 'hp', 'printer'), 9),
#   (('purchasing', 'this', 'printer'), 9),
#   (('compact', 'laser', 'printer'), 9),
#   (('a', 'reliable', 'printer'), 9),
#   (('printer', 'work', 'well'), 9),
#   (('the', 'printer', 'still'), 9),
#   (('printer', 'for', 'our'), 9),
#   (('the', 'printer', 'installed'), 9),
#   (('printer', 'other', 'than'), 9),
#   (('printer', 'for', 'use'), 9),
#   (('buy', 'another', 'printer'), 9),
#   (('perfect', 'printer', 'for'), 9),
#   (('since', 'this', 'printer'), 9),
#   (('the', 'printer', 'we'), 9),
#   (('regular', 'printer', 'paper'), 9),
#   (('printer', 'paper', 'and'), 9),
#   (('move', 'the', 'printer'), 9),
#   (('great', 'printer', 'at'), 9),
#   (('canon', 'photo', 'printer'), 9),
#   (('this', 'printer', 'or'), 9),
#   (('well', 'this', 'printer'), 9),
#   (('the', 'printer', 'requires'), 9),
#   (('hp', 'printer', 'for'), 9),
#   (('cable', 'the', 'printer'), 9),
#   (('printer', 'that', 'were'), 9),
#   (('of', 'canon', 'printer'), 9),
#   (('great', 'printer', 'but'), 9),
#   (('great', 'printer', 'if'), 9),
#   (('printer', 'the', 'canon'), 9),
#   (('have', 'another', 'printer'), 9),
#   (('printer', 'usb', 'cable'), 9),
#   (('is', 'this', 'printer'), 9),
#   (('think', 'the', 'printer'), 9),
#   (('printer', 'doe', 'work'), 9),
#   (('printer', 'since', 'i'), 9),
#   (('w', 'laser', 'printer'), 9),
#   (('feature', 'this', 'printer'), 9),
#   (('printer', 'seem', 'to'), 9),
#   (('the', 'printer', 'even'), 9),
#   (('this', 'printer', 'come'), 9),
#   (('need', 'this', 'printer'), 9),
#   (('install', 'this', 'printer'), 9),
#   (('printer', 'wa', 'on'), 9),
#   (('printer', 'photo', 'printer'), 9),
#   (('pixma', 'printer', 'is'), 9),
#   (('say', 'this', 'printer'), 9),
#   (('printer', 'although', 'i'), 9),
#   (('and', 'canon', 'printer'), 9),
#   (('epson', 'printer', 'ha'), 9),
#   (('connect', 'this', 'printer'), 9),
#   (('an', 'inexpensive', 'printer'), 9),
#   (('printer', 'is', 'fantastic'), 9),
#   (('unpacking', 'the', 'printer'), 9),
#   (('the', 'printer', 'display'), 9),
#   (('the', 'printer', 'took'), 9),
#   (('hp', 'laser', 'printer'), 9),
#   (('printer', 'for', 'wireless'), 9),
#   (('the', 'printer', 'allows'), 9),
#   (('inkjet', 'printer', 'with'), 9),
#   (('printer', 'of', 'course'), 9),
#   (('printer', 'it', 'just'), 9),
#   (('printer', 'from', 'my'), 9),
#   (('print', 'this', 'printer'), 9),
#   (('love', 'the', 'printer'), 9),
#   (('quality', 'this', 'printer'), 9),
#   (('purchase', 'a', 'printer'), 9),
#   (('having', 'the', 'printer'), 9),
#   (('used', 'epson', 'printer'), 9),
#   (('because', 'this', 'printer'), 9),
#   (('note', 'this', 'printer'), 9),
#   (('the', 'printer', 'touch'), 9),
#   (('however', 'the', 'printer'), 9),
#   (('great', 'printer', 'with'), 9),
#   (('printer', 'that', 'do'), 9),
#   (('printer', 'would', 'have'), 9),
#   (('up', 'my', 'printer'), 9),
#   (('previous', 'printer', 'wa'), 9),
#   (('kodak', 'esp', 'printer'), 9),
#   (('update', 'the', 'printer'), 9),
#   (('great', 'printer', 'the'), 9),
#   (('printer', 'and', 'doe'), 9),
#   (('this', 'printer', 'came'), 9),
#   (('the', 'printer', 'went'), 9),
#   (('to', 'use', 'printer'), 9),
#   (('new', 'printer', 'for'), 9),
#   (('printer', 'however', 'the'), 9),
#   (('of', 'printer', 'you'), 9),
#   (('put', 'this', 'printer'), 9),
#   (('new', 'printer', 'is'), 9),
#   (('printer', 'inkjet', 'printer'), 9),
#   (('via', 'the', 'printer'), 9),
#   (('printer', 'the', 'is'), 9),
#   (('of', 'inkjet', 'printer'), 9),
#   (('the', 'printer', 'property'), 9),
#   (('printer', 'ink', 'is'), 9),
#   (('a', 'perfect', 'printer'), 9),
#   (('printer', 'give', 'you'), 9),
#   (('the', 'printer', 'right'), 9),
#   (('printer', 'and', 'can'), 9),
#   (('pro', 'printer', 'is'), 9),
#   ...],
#  'binder': [(('of', 'the', 'binder'), 137),
#   (('this', 'binder', 'is'), 104),
#   (('the', 'binder', 'is'), 77),
#   (('wilson', 'jones', 'binder'), 48),
#   (('heavy', 'duty', 'binder'), 43),
#   (('of', 'this', 'binder'), 43),
#   (('binder', 'is', 'a'), 36),
#   (('this', 'binder', 'ha'), 32),
#   (('binder', 'this', 'is'), 31),
#   (('binder', 'ha', 'a'), 30),
#   (('binder', 'i', 'have'), 29),
#   (('the', 'binder', 'ha'), 29),
#   (('for', 'a', 'binder'), 26),
#   (('in', 'the', 'binder'), 25),
#   (('binder', 'it', 'is'), 24),
#   (('binder', 'that', 'i'), 23),
#   (('the', 'binder', 'i'), 22),
#   (('these', 'binder', 'are'), 21),
#   (('the', 'binder', 'and'), 21),
#   (('ring', 'view', 'binder'), 21),
#   (('view', 'binder', 'with'), 21),
#   (('about', 'this', 'binder'), 21),
#   (('this', 'binder', 'for'), 20),
#   (('three', 'ring', 'binder'), 20),
#   (('a', 'great', 'binder'), 19),
#   (('in', 'a', 'binder'), 19),
#   (('binder', 'that', 'is'), 18),
#   (('with', 'this', 'binder'), 18),
#   (('this', 'binder', 'it'), 18),
#   (('a', 'binder', 'that'), 18),
#   (('binder', 'and', 'the'), 18),
#   (('this', 'binder', 'i'), 18),
#   (('use', 'this', 'binder'), 18),
#   (('inside', 'the', 'binder'), 18),
#   (('binder', 'i', 'use'), 17),
#   (('binder', 'for', 'my'), 17),
#   (('on', 'this', 'binder'), 17),
#   (('binder', 'with', 'a'), 17),
#   (('a', 'binder', 'it'), 16),
#   (('a', 'good', 'binder'), 16),
#   (('lot', 'of', 'binder'), 16),
#   (('the', 'binder', 'the'), 16),
#   (('other', 'binder', 'i'), 16),
#   (('binder', 'is', 'the'), 16),
#   (('this', 'binder', 'to'), 16),
#   (('binder', 'it', 'ha'), 15),
#   (('the', 'binder', 'ring'), 15),
#   (('the', 'binder', 'are'), 15),
#   (('binder', 'in', 'the'), 15),
#   (('binder', 'with', 'the'), 15),
#   (('the', 'binder', 'itself'), 15),
#   (('that', 'this', 'binder'), 15),
#   (('binder', 'and', 'i'), 15),
#   (('it', 'a', 'binder'), 14),
#   (('the', 'binder', 'to'), 14),
#   (('binder', 'with', 'extra'), 14),
#   (('recommend', 'this', 'binder'), 14),
#   (('binder', 'is', 'that'), 14),
#   (('the', 'binder', 'for'), 14),
#   (('a', 'nice', 'binder'), 14),
#   (('that', 'the', 'binder'), 13),
#   (('and', 'the', 'binder'), 13),
#   (('binder', 'is', 'very'), 13),
#   (('with', 'the', 'binder'), 13),
#   (('view', 'binder', 'is'), 13),
#   (('make', 'the', 'binder'), 13),
#   (('to', 'the', 'binder'), 13),
#   (('the', 'binder', 'on'), 13),
#   (('a', 'binder', 'with'), 13),
#   (('the', 'binder', 'it'), 13),
#   (('binder', 'this', 'one'), 12),
#   (('duty', 'view', 'binder'), 12),
#   (('binder', 'and', 'it'), 12),
#   (('is', 'a', 'binder'), 12),
#   (('a', 'binder', 'this'), 12),
#   (('a', 'binder', 'is'), 11),
#   (('type', 'of', 'binder'), 11),
#   (('when', 'the', 'binder'), 11),
#   (('this', 'binder', 'in'), 11),
#   (('binder', 'would', 'be'), 11),
#   (('like', 'the', 'binder'), 11),
#   (('need', 'a', 'binder'), 11),
#   (('for', 'this', 'binder'), 11),
#   (('this', 'binder', 'and'), 11),
#   (('a', 'binder', 'and'), 11),
#   (('this', 'particular', 'binder'), 11),
#   (('binder', 'are', 'the'), 10),
#   (('a', 'binder', 'but'), 10),
#   (('binder', 'but', 'i'), 10),
#   (('and', 'this', 'binder'), 10),
#   (('binder', 'but', 'it'), 10),
#   (('any', 'other', 'binder'), 10),
#   (('round', 'ring', 'binder'), 10),
#   (('binder', 'in', 'my'), 10),
#   (('the', 'other', 'binder'), 10),
#   (('this', 'binder', 'will'), 10),
#   (('a', 'binder', 'for'), 10),
#   (('this', 'binder', 'would'), 10),
#   (('binder', 'you', 'can'), 10),
#   (('binder', 'the', 'ring'), 10),
#   (('open', 'the', 'binder'), 10),
#   (('binder', 'is', 'made'), 10),
#   (('this', 'binder', 'doe'), 10),
#   (('mead', 'zipper', 'binder'), 10),
#   (('binder', 'is', 'just'), 9),
#   (('ring', 'binder', 'is'), 9),
#   (('ultra', 'duty', 'binder'), 9),
#   (('binder', 'for', 'school'), 9),
#   (('binder', 'on', 'a'), 9),
#   (('binder', 'for', 'a'), 9),
#   (('in', 'this', 'binder'), 9),
#   (('binder', 'instead', 'of'), 9),
#   (('binder', 'i', 'would'), 9),
#   (('a', 'binder', 'i'), 9),
#   (('a', 'binder', 'go'), 9),
#   (('the', 'binder', 'there'), 9),
#   (('on', 'the', 'binder'), 9),
#   (('love', 'this', 'binder'), 9),
#   (('the', 'binder', 'so'), 9),
#   (('binder', 'to', 'hold'), 8),
#   (('binder', 'cover', 'and'), 8),
#   (('of', 'a', 'binder'), 8),
#   (('binder', 'is', 'perfect'), 8),
#   (('binder', 'that', 'you'), 8),
#   (('this', 'binder', 'feel'), 8),
#   (('like', 'this', 'binder'), 8),
#   (('is', 'the', 'binder'), 8),
#   (('high', 'quality', 'binder'), 8),
#   (('a', 'binder', 'the'), 8),
#   (('the', 'average', 'binder'), 8),
#   (('binder', 'out', 'there'), 8),
#   (('but', 'this', 'binder'), 8),
#   (('binder', 'is', 'nice'), 8),
#   (('this', 'binder', 'a'), 8),
#   (('binder', 'full', 'of'), 7),
#   (('the', 'binder', 'wa'), 7),
#   (('on', 'a', 'binder'), 7),
#   (('a', 'decent', 'binder'), 7),
#   (('the', 'binder', 'this'), 7),
#   (('the', 'binder', 'will'), 7),
#   (('into', 'a', 'binder'), 7),
#   (('binder', 'to', 'keep'), 7),
#   (('binder', 'hold', 'sheet'), 7),
#   (('binder', 'from', 'the'), 7),
#   (('jones', 'binder', 'is'), 7),
#   (('binder', 'is', 'great'), 7),
#   (('binder', 'is', 'pretty'), 7),
#   (('a', 'standard', 'binder'), 7),
#   (('of', 'these', 'binder'), 7),
#   (('the', 'binder', 'unusable'), 7),
#   (('a', 'regular', 'binder'), 7),
#   (('about', 'a', 'binder'), 7),
#   (('for', 'the', 'binder'), 7),
#   (('binder', 'if', 'you'), 7),
#   (('binder', 'there', 'are'), 7),
#   (('this', 'binder', 'are'), 7),
#   (('binder', 'ring', 'are'), 7),
#   (('binder', 'i', 'wa'), 7),
#   (('binder', 'like', 'this'), 7),
#   (('binder', 'i', 'will'), 7),
#   (('binder', 'so', 'i'), 7),
#   (('binder', 'that', 'will'), 7),
#   (('the', 'binder', 'a'), 7),
#   (('a', 'binder', 'of'), 7),
#   (('binder', 'of', 'this'), 7),
#   (('using', 'this', 'binder'), 7),
#   (('binder', 'i', 'like'), 7),
#   (('i', 'use', 'binder'), 7),
#   (('a', 'small', 'binder'), 6),
#   (('very', 'nice', 'binder'), 6),
#   (('than', 'a', 'binder'), 6),
#   (('avery', 'binder', 'is'), 6),
#   (('quality', 'binder', 'that'), 6),
#   (('binder', 'it', 'a'), 6),
#   (('binder', 'is', 'sturdy'), 6),
#   (('nice', 'sturdy', 'binder'), 6),
#   (('inch', 'binder', 'is'), 6),
#   (('a', 'the', 'binder'), 6),
#   (('paper', 'this', 'binder'), 6),
#   (('binder', 'i', 'used'), 6),
#   (('other', 'binder', 'this'), 6),
#   (('binder', 'and', 'this'), 6),
#   (('have', 'this', 'binder'), 6),
#   (('if', 'the', 'binder'), 6),
#   (('laying', 'the', 'binder'), 6),
#   (('binder', 'in', 'this'), 6),
#   (('ring', 'binder', 'and'), 6),
#   (('binder', 'that', 'have'), 6),
#   (('one', 'inch', 'binder'), 6),
#   (('the', 'binder', 'that'), 6),
#   (('my', 'other', 'binder'), 6),
#   (('than', 'other', 'binder'), 6),
#   (('a', 'sturdy', 'binder'), 6),
#   (('durable', 'view', 'binder'), 6),
#   (('think', 'this', 'binder'), 6),
#   (('the', 'binder', 'can'), 6),
#   (('binder', 'is', 'not'), 6),
#   (('the', 'binder', 'cover'), 6),
#   (('binder', 'i', 'do'), 6),
#   (('binder', 'ha', 'two'), 6),
#   (('binder', 'doe', 'not'), 6),
#   (('binder', 'is', 'quite'), 6),
#   (('the', 'best', 'binder'), 6),
#   (('the', 'binder', 'with'), 6),
#   (('but', 'the', 'binder'), 6),
#   (('binder', 'doe', 'seem'), 6),
#   (('this', 'binder', 'wa'), 6),
#   (('of', 'my', 'binder'), 6),
#   (('use', 'the', 'binder'), 6),
#   (('the', 'view', 'binder'), 6),
#   (('binder', 'that', 'can'), 6),
#   (('a', 'other', 'binder'), 6),
#   (('duty', 'binder', 'is'), 5),
#   (('binder', 'if', 'it'), 5),
#   (('binder', 'are', 'just'), 5),
#   (('a', 'new', 'binder'), 5),
#   (('binder', 'is', 'of'), 5),
#   (('my', 'particular', 'binder'), 5),
#   (('to', 'other', 'binder'), 5),
#   (('basic', 'binder', 'that'), 5),
#   (('white', 'binder', 'with'), 5),
#   (('the', 'binder', 'clip'), 5),
#   (('basic', 'binder', 'with'), 5),
#   (('binder', 'for', 'the'), 5),
#   (('binder', 'it', 'doe'), 5),
#   (('binder', 'i', 'had'), 5),
#   (('personalize', 'the', 'binder'), 5),
#   (('binder', 'but', 'they'), 5),
#   (('jones', 'binder', 'and'), 5),
#   (('binder', 'for', 'storing'), 5),
#   (('spine', 'simplify', 'binder'), 5),
#   (('our', 'strongest', 'binder'), 5),
#   (('strongest', 'binder', 'cover'), 5),
#   (('these', 'binder', 'for'), 5),
#   (('good', 'basic', 'binder'), 5),
#   (('of', 'binder', 'and'), 5),
#   (('the', 'binder', 'at'), 5),
#   (('cover', 'this', 'binder'), 5),
#   (('the', 'avery', 'binder'), 5),
#   (('a', 'basic', 'binder'), 5),
#   (('binder', 'that', 'ha'), 5),
#   (('binder', 'is', 'well'), 5),
#   (('this', 'binder', 'with'), 5),
#   (('received', 'this', 'binder'), 5),
#   (('this', 'binder', 'from'), 5),
#   (('the', 'hard', 'binder'), 5),
#   (('hard', 'binder', 'i'), 5),
#   (('buying', 'hard', 'binder'), 5),
#   (('hard', 'binder', 'for'), 5),
#   (('a', 'flexible', 'binder'), 5),
#   (('flexible', 'binder', 'in'), 5),
#   (('binder', 'in', 'general'), 5),
#   (('binder', 'unusable', 'and'), 5),
#   (('on', 'your', 'binder'), 5),
#   (('your', 'binder', 'ha'), 5),
#   (('just', 'a', 'binder'), 5),
#   (('of', 'binder', 'that'), 5),
#   (('close', 'the', 'binder'), 5),
#   (('time', 'this', 'binder'), 5),
#   (('it', 'the', 'binder'), 5),
#   (('avery', 'binder', 'i'), 5),
#   (('binder', 'i', 'got'), 5),
#   (('binder', 'in', 'a'), 5),
#   (('durable', 'binder', 'that'), 5),
#   (('duty', 'binder', 'with'), 5),
#   (('this', 'binder', 'should'), 5),
#   (('binder', 'itself', 'is'), 5),
#   (('using', 'the', 'binder'), 5),
#   (('binder', 'from', 'avery'), 5),
#   (('binder', 'at', 'work'), 5),
#   (('of', 'binder', 'in'), 5),
#   (('binder', 'but', 'the'), 5),
#   (('binder', 'can', 'be'), 5),
#   (('give', 'this', 'binder'), 5),
#   (('view', 'binder', 'for'), 5),
#   (('my', 'old', 'binder'), 5),
#   (('binder', 'for', 'you'), 5),
#   (('the', 'binder', 'in'), 5),
#   (('the', 'binder', 'if'), 5),
#   (('this', 'binder', 'the'), 5),
#   (('the', 'ring', 'binder'), 5),
#   (('binder', 'there', 'is'), 5),
#   (('this', 'binder', 'seems'), 5),
#   (('this', 'binder', 'work'), 5),
#   (('kind', 'of', 'binder'), 5),
#   (('the', 'binder', 'instead'), 5),
#   (('store', 'view', 'binder'), 5),
#   (('binder', 'is', 'one'), 5),
#   (('well', 'this', 'binder'), 5),
#   (('binder', 'which', 'is'), 5),
#   (('use', 'binder', 'for'), 5),
#   (('d', 'ring', 'binder'), 5),
#   (('these', 'polypro', 'binder'), 5),
#   (('polypro', 'binder', 'last'), 5),
#   (('binder', 'last', 'up'), 5),
#   (('far', 'a', 'binder'), 5),
#   (('jones', 'binder', 'are'), 5),
#   (('view', 'binder', 'the'), 5),
#   (('the', 'standard', 'binder'), 4),
#   (('the', 'binder', 'open'), 4),
#   (('binder', 'are', 'great'), 4),
#   (('a', 'binder', 'a'), 4),
#   (('binder', 'are', 'perfect'), 4),
#   (('binder', 'to', 'put'), 4),
#   (('ring', 'binder', 'for'), 4),
#   (('this', 'avery', 'binder'), 4),
#   (('this', 'binder', 'also'), 4),
#   (('binder', 'will', 'hold'), 4),
#   (('a', 'binder', 'so'), 4),
#   (('quality', 'binder', 'it'), 4),
#   (('sturdy', 'binder', 'with'), 4),
#   (('these', 'binder', 'to'), 4),
#   (('perfect', 'sized', 'binder'), 4),
#   (('sized', 'binder', 'for'), 4),
#   (('simplify', 'binder', 'labeling'), 4),
#   (('binder', 'labeling', 'and'), 4),
#   (('and', 'sewn', 'binder'), 4),
#   (('sewn', 'binder', 'round'), 4),
#   (('binder', 'round', 'ringswilson'), 4),
#   (('ring', 'ledger', 'binder'), 4),
#   (('ledger', 'binder', 'inch'), 4),
#   (('binder', 'inch', 'capacity'), 4),
#   (('binder', 'at', 'a'), 4),
#   (('ring', 'the', 'binder'), 4),
#   (('binder', 'these', 'are'), 4),
#   (('binder', 'seems', 'sturdy'), 4),
#   (('binder', 'every', 'year'), 4),
#   (('binder', 'for', 'her'), 4),
#   (('a', 'binder', 'in'), 4),
#   (('that', 'these', 'binder'), 4),
#   (('binder', 'i', 'own'), 4),
#   (('ring', 'binder', 'but'), 4),
#   (('binder', 'i', 'received'), 4),
#   (('binder', 'so', 'you'), 4),
#   (('duty', 'binder', 'ha'), 4),
#   (('binder', 'ha', 'the'), 4),
#   (('use', 'a', 'binder'), 4),
#   (('with', 'a', 'binder'), 4),
#   (('binder', 'of', 'woman'), 4),
#   (('the', 'binder', 'they'), 4),
#   (('this', 'binder', 'can'), 4),
#   (('binder', 'i', 'been'), 4),
#   (('good', 'quality', 'binder'), 4),
# ...
#   (('more', 'calculator', 'for'), 1),
#   (('a', 'durable', 'calculator'), 1),
#   (('durable', 'calculator', 'that'), 1),
#   (('calculator', 'that', 'work'), 1),
#   (('instrument', 'calculator', 'that'), 1),
#   (('calculator', 'that', 'everyone'), 1),
#   (('instrument', 'calculator', 'i'), 1),
#   (('calculator', 'i', 'also'), 1),
#   (('have', 'the', 'calculator'), 1),
#   (('the', 'calculator', 'get'), 1),
#   (('calculator', 'get', 'temperamental'), 1),
#   (('this', 'calculator', 'after'), 1),
#   (('calculator', 'after', 'the'), 1),
#   (('blue', 'graphing', 'calculator'), 1),
#   (('graphing', 'calculator', 'packaging'), 1),
#   (('calculator', 'packaging', 'may'), 1),
#   (('remember', 'this', 'calculator'), 1),
#   (('this', 'calculator', 'from'), 1),
#   (('calculator', 'from', 'several'), 1),
#   (('require', 'a', 'calculator'), 1),
#   (('calculator', 'with', 'specific'), 1),
#   (('old', 'calculator', 'scientific'), 1),
#   (('calculator', 'scientific', 'from'), 1),
#   (('of', 'he', 'calculator'), 1),
#   (('he', 'calculator', 'which'), 1),
#   (('advanced', 'scientific', 'calculator'), 1),
#   (('scientific', 'calculator', 'apparently'), 1),
#   (('calculator', 'apparently', 'ti'), 1),
#   (('make', 'these', 'calculator'), 1),
#   (('these', 'calculator', 'mandatory'), 1),
#   (('calculator', 'mandatory', 'in'), 1),
#   (('the', 'calculator', 'feature'), 1),
#   (('calculator', 'feature', 'a'), 1),
#   (('calculator', 'is', 'complicated'), 1),
#   (('button', 'the', 'calculator'), 1),
#   (('calculator', 'will', 'often'), 1),
#   (('these', 'ti', 'calculator'), 1),
#   (('ti', 'calculator', 'you'), 1),
#   (('calculator', 'you', 'would'), 1),
#   (('hp', 'graphing', 'calculator'), 1),
#   (('graphing', 'calculator', 'instead'), 1),
#   (('calculator', 'instead', 'have'), 1),
#   (('but', 'versatile', 'calculator'), 1),
#   (('versatile', 'calculator', 'yes'), 1),
#   (('calculator', 'yes', 'there'), 1),
#   (('advanced', 'calculator', 'out'), 1),
#   (('model', 'of', 'calculator'), 1),
#   (('of', 'calculator', 'to'), 1),
#   (('calculator', 'to', 'purchase'), 1),
#   (('exam', 'this', 'calculator'), 1),
#   (('this', 'calculator', 'unlike'), 1),
#   (('calculator', 'unlike', 'the'), 1),
#   (('limited', 'function', 'calculator'), 1),
#   (('function', 'calculator', 'go'), 1),
#   (('calculator', 'go', 'with'), 1),
#   (('purchasing', 'one', 'calculator'), 1),
#   (('one', 'calculator', 'that'), 1),
#   (('a', 'calculator', 'you'), 1),
#   (('because', 'a', 'calculator'), 1),
#   (('calculator', 'for', 'calculus'), 1),
#   (('advanced', 'calculator', 'for'), 1),
#   (('calculator', 'for', 'calc'), 1),
#   (('work', 'the', 'calculator'), 1),
#   (('the', 'calculator', 'my'), 1),
#   (('calculator', 'my', 'overall'), 1),
#   (('calculator', 'is', 'do'), 1),
#   (('a', 'solid', 'calculator'), 1),
#   (('solid', 'calculator', 'but'), 1),
#   (('calculator', 'but', 'pay'), 1),
#   (('calculus', 'a', 'calculator'), 1),
#   (('a', 'calculator', 'will'), 1),
#   (('calculator', 'will', 'have'), 1),
#   (('these', 'calculator', 'in'), 1),
#   (('calculator', 'in', 'high'), 1),
#   (('powerful', 'calculator', 'that'), 1),
#   (('calculator', 'that', 'have'), 1),
#   (('standard', 'calculator', 'because'), 1),
#   (('graphing', 'calculator', 'these'), 1),
#   (('calculator', 'these', 'calculator'), 1),
#   (('these', 'calculator', 'can'), 1),
#   (('calculator', 'can', 'even'), 1),
#   (('to', 'these', 'calculator'), 1),
#   (('want', 'your', 'calculator'), 1),
#   (('your', 'calculator', 'to'), 1),
#   (('calculator', 'to', 'power'), 1),
#   (('although', 'this', 'calculator'), 1),
#   (('calculator', 'is', 'from'), 1),
#   (('good', 'calculator', 'that'), 1),
#   (('the', 'calculator', 'sure'), 1),
#   (('calculator', 'sure', 'made'), 1),
#   (('expected', 'classic', 'calculator'), 1),
#   (('classic', 'calculator', 'it'), 1),
#   (('calculator', 'it', 'back'), 1),
#   (('a', 'calculator', 'of'), 1),
#   (('calculator', 'of', 'course'), 1),
#   (('just', 'any', 'calculator'), 1),
#   (('any', 'calculator', 'i'), 1),
#   (('a', 'calculator', 'cable'), 1),
#   (('calculator', 'cable', 'of'), 1),
#   (('graphing', 'calculator', 'powered'), 1),
#   (('calculator', 'powered', 'by'), 1),
#   (('calculator', 'is', 'large'), 1),
#   (('confirms', 'plus', 'calculator'), 1),
#   (('plus', 'calculator', 'combine'), 1),
#   (('calculator', 'combine', 'feature'), 1),
#   (('line', 'the', 'calculator'), 1),
#   (('calculator', 'can', 'equation'), 1),
#   (('the', 'calculator', 'contains'), 1),
#   (('calculator', 'contains', 'a'), 1),
#   (('graphing', 'calculator', 'like'), 1),
#   (('calculator', 'like', 'a'), 1),
#   (('whatever', 'model', 'calculator'), 1),
#   (('model', 'calculator', 'will'), 1),
#   (('bought', 'the', 'calculator'), 1),
#   (('calculator', 'for', 'accounting'), 1),
#   (('upgrade', 'your', 'calculator'), 1),
#   (('calculator', 'i', 'got'), 1),
#   (('calculator', 'at', 'request'), 1),
#   (('had', 'in', 'calculator'), 1),
#   (('in', 'calculator', 'a'), 1),
#   (('a', 'manual', 'calculator'), 1),
#   (('manual', 'calculator', 'david'), 1),
#   (('calculator', 'david', 'wilson'), 1),
#   (('this', 'calculator', 'worked'), 1),
#   (('calculator', 'worked', 'perfectly'), 1),
#   (('calculator', 'in', 'number'), 1),
#   (('from', 'ti', 'calculator'), 1),
#   (('ti', 'calculator', 'site'), 1),
#   (('calculator', 'site', 'and'), 1),
#   (('financial', 'calculator', 'app'), 1),
#   (('calculator', 'app', 'that'), 1),
#   (('first', 'ti', 'calculator'), 1),
#   (('ti', 'calculator', 'in'), 1),
#   (('calculator', 'in', 'or'), 1),
#   (('my', 'graphing', 'calculator'), 1),
#   (('calculator', 'the', 'first'), 1),
#   (('this', 'calculator', 'a'), 1),
#   (('calculator', 'a', 'for'), 1),
#   (('good', 'calculator', 'a'), 1),
#   (('calculator', 'a', 'would'), 1),
#   (('the', 'calculator', 'business'), 1),
#   (('calculator', 'business', 'for'), 1),
#   (('decade', 'a', 'calculator'), 1),
#   (('a', 'calculator', 'should'), 1),
#   (('calculator', 'should', 'do'), 1),
#   (('which', 'this', 'calculator'), 1),
#   (('calculator', 'doe', 'however'), 1),
#   (('but', 'most', 'calculator'), 1),
#   (('most', 'calculator', 'do'), 1),
#   (('five', 'star', 'calculator'), 1),
#   (('star', 'calculator', 'a'), 1),
#   (('calculator', 'a', 'the'), 1),
#   (('this', 'calculator', 'when'), 1),
#   (('calculator', 'when', 'taking'), 1),
#   (('calculator', 'really', 'failed'), 1),
#   (('the', 'calculator', 'not'), 1),
#   (('calculator', 'not', 'taking'), 1),
#   (('of', 'using', 'calculator'), 1),
#   (('using', 'calculator', 'i'), 1),
#   (('calculator', 'to', 'my'), 1),
#   (('business', 'analyst', 'calculator'), 1),
#   (('analyst', 'calculator', 'in'), 1),
#   (('the', 'calculator', 'that'), 1),
#   (('not', 'have', 'calculator'), 1),
#   (('have', 'calculator', 'is'), 1),
#   (('calculator', 'is', 'encased'), 1),
#   (('sharp', 'financial', 'calculator'), 1),
#   (('calculator', 'and', 'in'), 1),
#   (('calculator', 'for', 'several'), 1),
#   (('error', 'this', 'calculator'), 1),
#   (('calculator', 'wa', 'required'), 1),
#   (('calculator', 'that', 'could'), 1),
#   (('simple', 'desk', 'calculator'), 1),
#   (('desk', 'calculator', 'for'), 1),
#   (('calculator', 'for', 'quick'), 1),
#   (('basic', 'calculator', 'i'), 1),
#   (('this', 'very', 'calculator'), 1),
#   (('very', 'calculator', 'at'), 1),
#   (('make', 'this', 'calculator'), 1),
#   (('this', 'calculator', 'so'), 1),
#   (('calculator', 'so', 'nice'), 1),
#   (('have', 'another', 'calculator'), 1),
#   (('another', 'calculator', 'for'), 1),
#   (('calculator', 'for', 'that'), 1),
#   (('and', 'useful', 'calculator'), 1),
#   (('useful', 'calculator', 'i'), 1),
#   (('calculator', 'i', 'perform'), 1),
#   (('my', 'normal', 'calculator'), 1),
#   (('normal', 'calculator', 'from'), 1),
#   (('calculator', 'from', 'the'), 1),
#   (('purchased', 'canon', 'calculator'), 1),
#   (('canon', 'calculator', 'in'), 1),
#   (('both', 'competent', 'calculator'), 1),
#   (('competent', 'calculator', 'and'), 1),
#   (('calculator', 'and', 'do'), 1),
#   (('smaller', 'canon', 'calculator'), 1),
#   (('canon', 'calculator', 'the'), 1),
#   (('calculator', 'the', 'want'), 1),
#   (('right', 'this', 'calculator'), 1),
#   (('calculator', 'the', 'canon'), 1),
#   (('canon', 'l', 'calculator'), 1),
#   (('l', 'calculator', 'the'), 1),
#   (('calculator', 'the', 'smaller'), 1),
#   (('smaller', 'calculator', 'also'), 1),
#   (('calculator', 'also', 'reviewed'), 1),
#   (('cannon', 'l', 'calculator'), 1),
#   (('l', 'calculator', 'being'), 1),
#   (('perfect', 'a', 'calculator'), 1),
#   (('calculator', 'a', 'one'), 1),
#   (('other', 'calculator', 'a'), 1),
#   (('calculator', 'a', 'percent'), 1),
#   (('h', 'calculator', 'ha'), 1),
#   (('the', 'calculator', 'of'), 1),
#   (('smaller', 'calculator', 'and'), 1),
#   (('h', 'calculator', 'stay'), 1),
#   (('from', 'this', 'calculator'), 1),
#   (('this', 'calculator', 'are'), 1),
#   (('calculator', 'are', 'an'), 1),
#   (('most', 'other', 'calculator'), 1),
#   (('other', 'calculator', 'either'), 1),
#   (('calculator', 'either', 'a'), 1),
#   (('sharp', 'r', 'calculator'), 1),
#   (('r', 'calculator', 'but'), 1),
#   (('calculator', 'but', 'a'), 1),
#   (('any', 'calculator', 'and'), 1),
#   (('have', 'when', 'calculator'), 1),
#   (('when', 'calculator', 'first'), 1),
#   (('calculator', 'first', 'came'), 1),
#   (('model', 'number', 'calculator'), 1),
#   (('number', 'calculator', 'h'), 1),
#   (('calculator', 'h', 'looking'), 1),
#   (('powered', 'portable', 'calculator'), 1),
#   (('portable', 'calculator', 'a'), 1),
#   (('calculator', 'a', 'will'), 1),
#   (('other', 'calculator', 'manufacturer'), 1),
#   (('calculator', 'manufacturer', 'replacable'), 1),
#   (('aa', 'powered', 'calculator'), 1),
#   (('powered', 'calculator', 'still'), 1),
#   (('calculator', 'still', 'on'), 1),
#   (('a', 'larger', 'calculator'), 1),
#   (('larger', 'calculator', 'which'), 1),
#   (('calculator', 'which', 'us'), 1),
#   (('canon', 'calculator', 'h'), 1),
#   (('calculator', 'h', 'which'), 1),
#   (('the', 'main', 'calculator'), 1),
#   (('main', 'calculator', 'being'), 1),
#   (('average', 'desktop', 'calculator'), 1),
#   (('desktop', 'calculator', 'also'), 1),
#   (('calculator', 'also', 'due'), 1),
#   (('year', 'a', 'calculator'), 1),
#   (('a', 'calculator', 'managing'), 1),
#   (('calculator', 'managing', 'the'), 1),
#   (('where', 'the', 'calculator'), 1),
#   (('calculator', 'come', 'in'), 1),
#   (('canon', 'calculator', 'sits'), 1),
#   (('calculator', 'sits', 'snugly'), 1),
#   (('straightforward', 'easy', 'calculator'), 1),
#   (('easy', 'calculator', 'compact'), 1),
#   (('calculator', 'compact', 'but'), 1),
#   (('a', 'other', 'calculator'), 1),
#   (('other', 'calculator', 'on'), 1),
#   (('size', 'desktop', 'calculator'), 1),
#   (('desktop', 'calculator', 'popular'), 1),
#   (('calculator', 'popular', 'a'), 1),
#   (('find', 'other', 'calculator'), 1),
#   (('other', 'calculator', 'sharp'), 1),
#   (('calculator', 'sharp', 'awkward'), 1),
#   (('have', 'a', 'calculator'), 1),
#   (('calculator', 'on', 'your'), 1),
#   (('small', 'pocket', 'calculator'), 1),
#   (('this', 'calculator', 'therefore'), 1),
#   (('calculator', 'therefore', 'here'), 1),
#   (('calculator', 'it', 'can'), 1),
#   (('memory', 'the', 'calculator'), 1),
#   (('calculator', 'to', 'it'), 1),
#   (('calculator', 'the', 'change'), 1),
#   (('frustrate', 'this', 'calculator'), 1),
#   (('and', 'inexpensive', 'calculator'), 1),
#   (('inexpensive', 'calculator', 'just'), 1),
#   (('calculator', 'for', 'most'), 1),
#   (('canon', 'calculator', 'at'), 1),
#   (('calculator', 'and', 'pet'), 1),
#   (('compact', 'little', 'calculator'), 1),
#   (('little', 'calculator', 'only'), 1),
#   (('calculator', 'only', 'x'), 1),
#   (('the', 'little', 'calculator'), 1),
#   (('little', 'calculator', 'say'), 1),
#   (('calculator', 'say', 'take'), 1),
#   (('good', 'calculator', 'which'), 1),
#   (('calculator', 'which', 'the'), 1),
#   (('enough', 'therethe', 'calculator'), 1),
#   (('therethe', 'calculator', 'i'), 1),
#   (('these', 'little', 'calculator'), 1),
#   (('little', 'calculator', 'would'), 1),
#   (('calculator', 'would', 'finda'), 1),
#   (('calculator', 'arrived', 'i'), 1),
#   (('turned', 'the', 'calculator'), 1),
#   (('the', 'calculator', 'upside'), 1),
#   (('calculator', 'upside', 'down'), 1),
#   (('with', 'any', 'calculator'), 1),
#   (('any', 'calculator', 'the'), 1),
#   (('calculator', 'the', 'word'), 1),
#   (('bookof', 'these', 'calculator'), 1),
#   (('these', 'calculator', 'trick'), 1),
#   (('calculator', 'trick', 'which'), 1),
#   (('the', 'calculator', 'down'), 1),
#   (('calculator', 'down', 'but'), 1),
#   (('solarand', 'battery', 'calculator'), 1),
#   (('battery', 'calculator', 'you'), 1),
#   (('sure', 'the', 'calculator'), 1),
#   (('then', 'the', 'calculator'), 1),
#   (('a', 'calculator', 'only'), 1),
#   (('calculator', 'only', 'if'), 1),
#   (('true', 'this', 'calculator'), 1),
#   (('calculator', 'ha', 'only'), 1),
#   (('solar', 'calculator', 'or'), 1),
#   (('calculator', 'or', 'getting'), 1),
#   (('to', 'both', 'calculator'), 1),
#   (('both', 'calculator', 'and'), 1),
#   (('love', 'regular', 'calculator'), 1),
#   (('regular', 'calculator', 'and'), 1),
#   (('calculator', 'is', 'nice'), 1),
#   (('miss', 'my', 'calculator'), 1),
#   (('my', 'calculator', 'with'), 1),
#   (('good', 'basic', 'calculator'), 1),
#   (('basic', 'calculator', 'pretty'), 1),
#   (('calculator', 'pretty', 'good'), 1),
#   (('standard', 'calculator', 'this'), 1),
#   (('great', 'calculator', 'especially'), 1),
#   (('calculator', 'especially', 'since'), 1),
#   (('to', 'supply', 'calculator'), 1),
#   (('supply', 'calculator', 'so'), 1),
#   (('calculator', 'so', 'the'), 1),
#   (('this', 'simple', 'calculator'), 1),
#   (('simple', 'calculator', 'seems'), 1),
#   (('could', 'use', 'calculator'), 1),
#   (('use', 'calculator', 'in'), 1),
#   (('calculator', 'in', 'class'), 1),
#   (('fancy', 'fun', 'calculator'), 1),
#   (('fun', 'calculator', 'but'), 1),
#   (('calculator', 'but', 'none'), 1),
#   (('and', 'cheap', 'calculator'), 1),
#   (('cheap', 'calculator', 'the'), 1),
#   (('nice', 'useful', 'calculator'), 1),
#   (('useful', 'calculator', 'not'), 1),
#   (('pocket', 'calculator', 'which'), 1),
#   (('protects', 'the', 'calculator'), 1),
#   (('the', 'calculator', 'from'), 1),
#   (('calculator', 'from', 'regular'), 1),
#   (('handy', 'durable', 'calculator'), 1),
#   (('durable', 'calculator', 'i'), 1),
#   (('pocket', 'calculator', 'will'), 1),
#   (('previous', 'solar', 'calculator'), 1),
#   (('solar', 'calculator', 'stopped'), 1),
#   (('calculator', 'stopped', 'working'), 1),
#   (('trusty', 'ti', 'calculator'), 1),
#   (('ti', 'calculator', 'after'), 1),
#   (('calculator', 'after', 'year'), 1),
#   (('solar', 'only', 'calculator'), 1),
#   (('only', 'calculator', 'but'), 1),
#   (('calculator', 'but', 'it'), 1),
#   (('calculator', 'when', 'doing'), 1),
#   (('harder', 'this', 'calculator'), 1),
#   (('this', 'calculator', 'basically'), 1),
#   (('calculator', 'basically', 'meet'), 1),
#   (('loving', 'this', 'calculator'), 1),
#   (('pocket', 'calculator', 'it'), 1),
#   (('calculator', 'it', 'almost'), 1),
#   (('to', 'this', 'calculator'), 1),
#   (('calculator', 'to', 'balance'), 1),
#   (('tried', 'other', 'calculator'), 1),
#   (('power', 'this', 'calculator'), 1),
#   (('longer', 'this', 'calculator'), 1),
#   (('calculator', 'is', 'worth'), 1),
#   (('need', 'another', 'calculator'), 1),
#   (('another', 'calculator', 'i'), 1),
#   (('latest', 'business', 'calculator'), 1),
#   (('business', 'calculator', 'which'), 1),
#   (('calculator', 'which', 'would'), 1),
#   (('and', 'a', 'calculator'), 1),
#   (('a', 'calculator', 'which'), 1),
#   (('calculator', 'which', 'ha'), 1),
#   (('hold', 'the', 'calculator'), 1),
#   (('operating', 'the', 'calculator'), 1),
#   (('solver', 'financial', 'calculator'), 1),
#   (('financial', 'calculator', 'which'), 1),
#   (('calculator', 'which', 'could'), 1),
#   (('deepest', 'financial', 'calculator'), 1),
#   (('financial', 'calculator', 'in'), 1),
#   (('calculator', 'in', 'it'), 1),
#   (('financial', 'calculator', 'who'), 1),
#   (('calculator', 'who', 'ha'), 1),
#   (('one', 'business', 'calculator'), 1),
#   (('business', 'calculator', 'the'), 1),
#   (('calculator', 'the', 'should'), 1),
#   (('a', 'sturdy', 'calculator'), 1),
#   (('sturdy', 'calculator', 'that'), 1),
#   (('financial', 'calculator', 'user'), 1),
#   (('were', 'fantastic', 'calculator'), 1),
#   (('fantastic', 'calculator', 'solid'), 1),
#   ...]}

# %% [markdown]
# Не очень хочется убирать стоп-слова, так как некоторые триграммы с ними достаточно неплохие

# %%
df_trigrams = pd.DataFrame({el : [' '.join(i[0]) for i in product_trigrams[el][:200]] for el in product_names})

# %%
df_trigrams
# Out:
#                 printer               binder                    dispenser  \
# 0       this printer is        of the binder             of the dispenser
# 1        the printer is       this binder is             the dispenser is
# 2        of the printer        the binder is          this tape dispenser
# 3       the printer and  wilson jones binder               dispenser is a
# 4     with this printer    heavy duty binder            this dispenser is
# ..                  ...                  ...                          ...
# 195    this printer you       the binder can            dispenser on your
# 196    printer for home        binder is not            dispenser make it
# 197      printer it doe     the binder cover          tape dispenser will
# 198  laser printer that          binder i do            tape dispenser on
# 199       printer doe a        binder ha two  conventional tape dispenser
#
#                       folder              stapler             calculator
# 0              of the folder      this stapler is     this calculator is
# 1           these folder are       of the stapler      the calculator is
# 2             the folder are       the stapler is  a graphing calculator
# 3        hanging file folder    with this stapler      of the calculator
# 4          these file folder         stapler is a      the hp calculator
# ..                       ...                  ...                    ...
# 195            in one folder    stapler work well    with all calculator
# 196         folder that will  a swingline stapler    this calculator big
# 197  standard hanging folder       stapler with a  calculator big number
# 198       use hanging folder         a stapler go     calculator for you
# 199             a the folder    the stapler would  basic calculator that
#
# [200 rows x 6 columns]

# %% [markdown]
# ### Ранжирование n-грамм с помощью коллокационных метрик

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
trigram_measures = nltk.collocations.TrigramAssocMeasures()

# %%
finder = BigramCollocationFinder.from_words(' '.join(new_df['new_review']).split())

# %% [markdown]
# ### PMI

# %%
pmi_bigrams = {'printer':[], 'binder':[], 'dispenser':[], 'folder':[], 'stapler':[], 'calculator':[]}
for bigram in finder.score_ngrams(bigram_measures.pmi):
    for product in product_names:
        if (product in bigram[0] and bigram[0][0] != bigram[0][1] 
            and bigram[0][0] not in stopwords and bigram[0][1] not in stopwords):
                pmi_bigrams[product].append(bigram)

# %%
for product in product_names:
    print(product) 
    for bigram in pmi_bigrams[product][0:50]:
        print(bigram)
    print('\n')
# Out:
# printer
# (('ahp', 'printer'), 6.043137262229832)
# (('anaemic', 'printer'), 6.043137262229832)
# (('ausb', 'printer'), 6.043137262229832)
# (('beastmode', 'printer'), 6.043137262229832)
# (('boxthe', 'printer'), 6.043137262229832)
# (('btter', 'printer'), 6.043137262229832)
# (('capacityblack', 'printer'), 6.043137262229832)
# (('cartridgethis', 'printer'), 6.043137262229832)
# (('clunkyno', 'printer'), 6.043137262229832)
# (('cmyblack', 'printer'), 6.043137262229832)
# (('comparablebrother', 'printer'), 6.043137262229832)
# (('comparisonthe', 'printer'), 6.043137262229832)
# (('considerationsthis', 'printer'), 6.043137262229832)
# (('crated', 'printer'), 6.043137262229832)
# (('cxi', 'printer'), 6.043137262229832)
# (('daisywheel', 'printer'), 6.043137262229832)
# (('departmental', 'printer'), 6.043137262229832)
# (('devicesthe', 'printer'), 6.043137262229832)
# (('doggiest', 'printer'), 6.043137262229832)
# (('duplexerthe', 'printer'), 6.043137262229832)
# (('exhale', 'printer'), 6.043137262229832)
# (('expson', 'printer'), 6.043137262229832)
# (('firmwarethe', 'printer'), 6.043137262229832)
# (('fontsthis', 'printer'), 6.043137262229832)
# (('footprintthis', 'printer'), 6.043137262229832)
# (('incumbent', 'printer'), 6.043137262229832)
# (('inket', 'printer'), 6.043137262229832)
# (('inkor', 'printer'), 6.043137262229832)
# (('lazor', 'printer'), 6.043137262229832)
# (('microcomputer', 'printer'), 6.043137262229832)
# (('monochromic', 'printer'), 6.043137262229832)
# (('morethe', 'printer'), 6.043137262229832)
# (('multifuction', 'printer'), 6.043137262229832)
# (('multifunc', 'printer'), 6.043137262229832)
# (('multifuntional', 'printer'), 6.043137262229832)
# (('noisethis', 'printer'), 6.043137262229832)
# (('noisiest', 'printer'), 6.043137262229832)
# (('ordinarylaser', 'printer'), 6.043137262229832)
# (('outletinstall', 'printer'), 6.043137262229832)
# (('pinnacle', 'printer'), 6.043137262229832)
# (('portcolor', 'printer'), 6.043137262229832)
# (('printer', 'abrogating'), 6.043137262229832)
# (('printer', 'affordably'), 6.043137262229832)
# (('printer', 'andsamsung'), 6.043137262229832)
# (('printer', 'apporximately'), 6.043137262229832)
# (('printer', 'authenticated'), 6.043137262229832)
# (('printer', 'automate'), 6.043137262229832)
# (('printer', 'babysitting'), 6.043137262229832)
# (('printer', 'bli'), 6.043137262229832)
# (('printer', 'chug'), 6.043137262229832)
#
#
# binder
# (('binder', 'closeing'), 8.984936734494934)
# (('binder', 'connoisseur'), 8.984936734494934)
# (('binder', 'olympics'), 8.984936734494934)
# (('binder', 'velo'), 8.984936734494934)
# (('binder', 'violet'), 8.984936734494934)
# (('duratech', 'binder'), 8.984936734494934)
# (('fanatastic', 'binder'), 8.984936734494934)
# (('getavery', 'binder'), 8.984936734494934)
# (('greenroom', 'binder'), 8.984936734494934)
# (('plasticthe', 'binder'), 8.984936734494934)
# (('pleated', 'binder'), 8.984936734494934)
# (('seuss', 'binder'), 8.984936734494934)
# (('timeflexible', 'binder'), 8.984936734494934)
# (('weakest', 'binder'), 8.984936734494934)
# (('sturdiest', 'binder'), 8.569899235216088)
# (('binder', 'incase'), 7.984936734494934)
# (('binder', 'queen'), 7.984936734494934)
# (('binder', 'standout'), 7.984936734494934)
# (('binder', 'straightened'), 7.984936734494934)
# (('fivestar', 'binder'), 7.984936734494934)
# (('knowthis', 'binder'), 7.984936734494934)
# (('wj', 'binder'), 7.762544313158484)
# (('strongest', 'binder'), 7.721902328661139)
# (('bliss', 'binder'), 7.663008639607572)
# (('ledger', 'binder'), 7.663008639607572)
# (('simplify', 'binder'), 7.606425111241203)
# (('view', 'binder'), 7.587059786374272)
# (('sewn', 'binder'), 7.525505115857635)
# (('binder', 'unusable'), 7.470363561665174)
# (('binder', 'addict'), 7.3999742337737775)
# (('binder', 'apparatus'), 7.3999742337737775)
# (('binder', 'conversely'), 7.3999742337737775)
# (('binder', 'prettier'), 7.3999742337737775)
# (('binder', 'shrunk'), 7.3999742337737775)
# (('binder', 'titling'), 7.3999742337737775)
# (('destroys', 'binder'), 7.3999742337737775)
# (('girlie', 'binder'), 7.3999742337737775)
# (('mitt', 'binder'), 7.3999742337737775)
# (('requesting', 'binder'), 7.3999742337737775)
# (('zipper', 'binder'), 7.278667937551642)
# (('cheapie', 'binder'), 7.17758181243733)
# (('zipped', 'binder'), 7.17758181243733)
# (('aged', 'binder'), 6.984936734494934)
# (('binder', 'looseleaf'), 6.984936734494934)
# (('looseleaf', 'binder'), 6.984936734494934)
# (('jones', 'binder'), 6.880600074680196)
# (('binder', 'rivet'), 6.663008639607572)
# (('junky', 'binder'), 6.663008639607572)
# (('polypro', 'binder'), 6.6064251112412045)
# (('zippered', 'binder'), 6.569899235216088)
#
#
# dispenser
# (('anote', 'dispenser'), 9.529216316813)
# (('basicbandit', 'dispenser'), 9.529216316813)
# (('bescotch', 'dispenser'), 9.529216316813)
# (('dispenser', 'alleviates'), 9.529216316813)
# (('dispenser', 'bottomthe'), 9.529216316813)
# (('dispenser', 'conceptually'), 9.529216316813)
# (('dispenser', 'devidoir'), 9.529216316813)
# (('dispenser', 'inas'), 9.529216316813)
# (('dispenser', 'incategory'), 9.529216316813)
# (('dispenser', 'silvertech'), 9.529216316813)
# (('dispenser', 'whoopee'), 9.529216316813)
# (('dispensingthis', 'dispenser'), 9.529216316813)
# (('mannnny', 'dispenser'), 9.529216316813)
# (('mountable', 'dispenser'), 9.529216316813)
# (('pez', 'dispenser'), 9.529216316813)
# (('refillsthe', 'dispenser'), 9.529216316813)
# (('handband', 'dispenser'), 9.162433986141377)
# (('deskgrip', 'dispenser'), 8.770224416316793)
# (('dispenser', 'enclosure'), 8.529216316813)
# (('dispenser', 'infor'), 8.529216316813)
# (('dispenser', 'slowing'), 8.529216316813)
# (('dispenser', 'tartan'), 8.529216316813)
# (('headband', 'dispenser'), 8.529216316813)
# (('attachable', 'dispenser'), 7.9442538160918446)
# (('contour', 'dispenser'), 7.9442538160918446)
# (('dispenser', 'um'), 7.9442538160918446)
# (('dispenser', 'ymmv'), 7.9442538160918446)
# (('giftwrap', 'dispenser'), 7.9442538160918446)
# (('taper', 'dispenser'), 7.9442538160918446)
# (('heart', 'dispenser'), 7.572285038704887)
# (('dispenser', 'aided'), 7.529216316813001)
# (('petite', 'dispenser'), 7.529216316813001)
# (('dispenser', 'attache'), 7.44175347556266)
# (('dispenser', 'anticipating'), 7.207288221925637)
# (('dispenser', 'flopping'), 7.207288221925637)
# (('dispenser', 'paired'), 7.207288221925637)
# (('dispenser', 'thingy'), 7.207288221925637)
# (('shoe', 'dispenser'), 7.207288221925637)
# (('dispenser', 'loses'), 7.114178817534155)
# (('tape', 'dispenser'), 6.946704462240625)
# (('dandy', 'dispenser'), 6.9442538160918446)
# (('dispenser', 'solves'), 6.866251304090568)
# (('dang', 'dispenser'), 6.721861394755395)
# (('dispenser', 'earns'), 6.721861394755395)
# (('reusable', 'dispenser'), 6.654747198896857)
# (('disposable', 'dispenser'), 6.641691046071411)
# (('dispenser', 'affix'), 6.529216316813001)
# (('dispenser', 'utilizing'), 6.529216316813001)
# (('pebble', 'dispenser'), 6.529216316813001)
# (('weighted', 'dispenser'), 6.2704820484128305)
#
#
# folder
# (('almighty', 'folder'), 8.647860813311619)
# (('coloful', 'folder'), 8.647860813311619)
# (('dcim', 'folder'), 8.647860813311619)
# (('erasablesupertab', 'folder'), 8.647860813311619)
# (('folder', 'appealed'), 8.647860813311619)
# (('folder', 'bowing'), 8.647860813311619)
# (('folder', 'frenzy'), 8.647860813311619)
# (('folder', 'gape'), 8.647860813311619)
# (('folder', 'heavywieght'), 8.647860813311619)
# (('folder', 'organizes'), 8.647860813311619)
# (('folder', 'privide'), 8.647860813311619)
# (('folder', 'webdav'), 8.647860813311619)
# (('heavywieght', 'folder'), 8.647860813311619)
# (('lolthese', 'folder'), 8.647860813311619)
# (('nesting', 'folder'), 8.647860813311619)
# (('paperboard', 'folder'), 8.647860813311619)
# (('reusuable', 'folder'), 8.647860813311619)
# (('sizeeach', 'folder'), 8.647860813311619)
# (('snapper', 'folder'), 8.647860813311619)
# (('subtopic', 'folder'), 8.647860813311619)
# (('superheavyweight', 'folder'), 8.647860813311619)
# (('pocketed', 'folder'), 8.647860813311617)
# (('manilla', 'folder'), 8.19719940430205)
# (('classification', 'folder'), 8.062898312590463)
# (('manila', 'folder'), 8.000876585983079)
# (('hanging', 'folder'), 7.674212140258568)
# (('burberry', 'folder'), 7.647860813311619)
# (('dividing', 'folder'), 7.647860813311619)
# (('folder', 'excepting'), 7.647860813311619)
# (('repocket', 'folder'), 7.647860813311619)
# (('ringed', 'folder'), 7.647860813311619)
# (('semicircular', 'folder'), 7.647860813311619)
# (('weakling', 'folder'), 7.647860813311619)
# (('yugo', 'folder'), 7.647860813311619)
# (('handing', 'folder'), 7.647860813311617)
# (('partition', 'folder'), 7.647860813311617)
# (('folder', 'tuff'), 7.548325139760703)
# (('organizer', 'folder'), 7.510357289561682)
# (('tabbed', 'folder'), 7.325932718424255)
# (('supertab', 'folder'), 7.133287640481857)
# (('file', 'folder'), 7.0961239361241155)
# (('heavyweight', 'folder'), 7.095319790282836)
# (('differentiating', 'folder'), 7.0628983125904625)
# (('folder', 'handwrite'), 7.0628983125904625)
# (('folder', 'identifiable'), 7.0628983125904625)
# (('folder', 'maroon'), 7.0628983125904625)
# (('folder', 'resting'), 7.0628983125904625)
# (('folder', 'spends'), 7.0628983125904625)
# (('mature', 'folder'), 7.0628983125904625)
# (('lockit', 'folder'), 6.9848958005891895)
#
#
# stapler
# (('accentra', 'stapler'), 9.079848381520401)
# (('athletics', 'stapler'), 9.079848381520401)
# (('customizeable', 'stapler'), 9.079848381520401)
# (('ergonomicsthe', 'stapler'), 9.079848381520401)
# (('forswingline', 'stapler'), 9.079848381520401)
# (('friggen', 'stapler'), 9.079848381520401)
# (('gentler', 'stapler'), 9.079848381520401)
# (('impale', 'stapler'), 9.079848381520401)
# (('industral', 'stapler'), 9.079848381520401)
# (('middleweight', 'stapler'), 9.079848381520401)
# (('nam', 'stapler'), 9.079848381520401)
# (('simplee', 'stapler'), 9.079848381520401)
# (('stapler', 'balk'), 9.079848381520401)
# (('stapler', 'boasting'), 9.079848381520401)
# (('stapler', 'poop'), 9.079848381520401)
# (('stapler', 'slapper'), 9.079848381520401)
# (('stapler', 'unsupervised'), 9.079848381520401)
# (('stapleroverview', 'stapler'), 9.079848381520401)
# (('unicolored', 'stapler'), 9.079848381520401)
# (('vanity', 'stapler'), 9.079848381520401)
# (('prodigy', 'stapler'), 8.71727830213569)
# (('boston', 'stapler'), 8.494885880799243)
# (('occupation', 'stapler'), 8.494885880799243)
# (('electric', 'stapler'), 8.358564409586464)
# (('ace', 'stapler'), 8.079848381520401)
# (('bitty', 'stapler'), 8.079848381520401)
# (('forceful', 'stapler'), 8.079848381520401)
# (('junior', 'stapler'), 8.079848381520401)
# (('levered', 'stapler'), 8.079848381520401)
# (('nonelectric', 'stapler'), 8.079848381520401)
# (('stapler', 'fetish'), 8.079848381520401)
# (('stapler', 'reside'), 8.079848381520401)
# (('stapler', 'snob'), 8.079848381520401)
# (('surplus', 'stapler'), 8.079848381520401)
# (('thepaperpro', 'stapler'), 8.079848381520401)
# (('smarttouch', 'stapler'), 7.735893980303036)
# (('auxiliary', 'stapler'), 7.494885880799243)
# (('bid', 'stapler'), 7.494885880799243)
# (('clipper', 'stapler'), 7.494885880799243)
# (('girly', 'stapler'), 7.494885880799243)
# (('regulation', 'stapler'), 7.494885880799243)
# (('stapler', 'crimp'), 7.494885880799243)
# (('stapler', 'imaginable'), 7.494885880799243)
# (('stapler', 'smoothgrip'), 7.494885880799243)
# (('stapler', 'understandably'), 7.494885880799243)
# (('streamline', 'stapler'), 7.494885880799243)
# (('fashion', 'stapler'), 7.494885880799242)
# (('associate', 'stapler'), 7.272493459462796)
# (('mill', 'stapler'), 7.272493459462796)
# (('handheld', 'stapler'), 7.1412489261845415)
#
#
# calculator
# (('abasic', 'calculator'), 10.48825599713323)
# (('amazonasics', 'calculator'), 10.48825599713323)
# (('amazonbasics', 'calculator'), 10.48825599713323)
# (('calculator', 'david'), 10.48825599713323)
# (('calculator', 'keyset'), 10.48825599713323)
# (('calculator', 'mv'), 10.48825599713323)
# (('calculator', 'scientifics'), 10.48825599713323)
# (('casiothis', 'calculator'), 10.48825599713323)
# (('forany', 'calculator'), 10.48825599713323)
# (('potent', 'calculator'), 10.48825599713323)
# (('protractor', 'calculator'), 10.48825599713323)
# (('scienfic', 'calculator'), 10.48825599713323)
# (('scienfitic', 'calculator'), 10.48825599713323)
# (('therethe', 'calculator'), 10.48825599713323)
# (('scientific', 'calculator'), 10.183401415604807)
# (('graphing', 'calculator'), 10.152206794001213)
# (('calculator', 'multiview'), 9.903293496412074)
# (('calculator', 'engraved'), 9.48825599713323)
# (('calculator', 'gum'), 9.48825599713323)
# (('calculator', 'premise'), 9.48825599713323)
# (('calculator', 'swatch'), 9.48825599713323)
# (('heldheld', 'calculator'), 9.48825599713323)
# (('keyed', 'calculator'), 9.48825599713323)
# (('surviving', 'calculator'), 9.48825599713323)
# (('analyst', 'calculator'), 8.903293496412074)
# (('calculator', 'amortization'), 8.903293496412074)
# (('calculator', 'salesperson'), 8.903293496412074)
# (('cheapy', 'calculator'), 8.903293496412074)
# (('financial', 'calculator'), 8.772048963133823)
# (('calculator', 'aos'), 8.48825599713323)
# (('coolest', 'calculator'), 8.48825599713323)
# (('calculator', 'gold'), 8.443861877774777)
# (('calculator', 'differs'), 8.166327902245868)
# (('calculator', 'legacy'), 8.166327902245868)
# (('calculator', 'mandatory'), 8.166327902245868)
# (('casio', 'calculator'), 8.012522566166833)
# (('calculator', 'h'), 7.964694041076218)
# (('calculator', 'froze'), 7.903293496412074)
# (('prizm', 'calculator'), 7.680901075075626)
# (('calculator', 'collector'), 7.48825599713323)
# (('ti', 'calculator'), 7.358972980188263)
# (('calculator', 'exists'), 7.318330995690918)
# (('calculator', 'ruler'), 7.318330995690918)
# (('instrument', 'calculator'), 7.278802631504281)
# (('calculator', 'cousin'), 7.166327902245868)
# (('calculator', 'managing'), 7.166327902245868)
# (('handsome', 'calculator'), 7.0288243784959334)
# (('researching', 'calculator'), 7.0288243784959334)
# (('solar', 'calculator'), 6.985755656604045)
# (('h', 'calculator'), 6.964694041076218)

# %% [markdown]
# ### raw_freq

# %%
rf_bigrams = {'printer':[], 'binder':[], 'dispenser':[], 'folder':[], 'stapler':[], 'calculator':[]}
for bigram in finder.score_ngrams(bigram_measures.raw_freq):
    for product in product_names:
        if (product in bigram[0] and bigram[0][0] != bigram[0][1] 
            and bigram[0][0] not in stopwords and bigram[0][1] not in stopwords):
                rf_bigrams[product].append(bigram)

# %%
for product in product_names:
    print(product) 
    for bigram in rf_bigrams[product][0:50]:
        print(bigram)
    print('\n')
# Out:
# printer
# (('laser', 'printer'), 0.0004750944981100378)
# (('epson', 'printer'), 0.0003910961780764385)
# (('photo', 'printer'), 0.00030911381772364554)
# (('printer', 'wa'), 0.00028693826123477533)
# (('inkjet', 'printer'), 0.000248635027299454)
# (('other', 'printer'), 0.00022780344393112138)
# (('hp', 'printer'), 0.0001989080218395632)
# (('canon', 'printer'), 0.00019756404871902562)
# (('printer', 'doe'), 0.00019017219655606887)
# (('my', 'printer'), 0.0001854682906341873)
# (('wireless', 'printer'), 0.00018345233095338093)
# (('new', 'printer'), 0.00014447711045779084)
# (('great', 'printer'), 0.00014313313733725326)
# (('printer', 'you'), 0.00013641327173456532)
# (('printer', 'which'), 0.00012834943301133977)
# (('your', 'printer'), 0.00012767744645107097)
# (('workforce', 'printer'), 9.878202435951281e-05)
# (('printer', 'itself'), 9.407811843763125e-05)
# (('color', 'printer'), 9.071818563628727e-05)
# (('good', 'printer'), 8.601427971440571e-05)
# (('old', 'printer'), 8.198236035279295e-05)
# (('printer', 'have'), 7.862242755144898e-05)
# (('printer', 'also'), 7.526249475010499e-05)
# (('brother', 'printer'), 7.391852162956741e-05)
# (('home', 'printer'), 7.391852162956741e-05)
# (('printer', 'come'), 7.324653506929861e-05)
# (('printer', 'driver'), 7.123057538849223e-05)
# (('one', 'printer'), 6.921461570768585e-05)
# (('printer', 'print'), 6.921461570768585e-05)
# (('office', 'printer'), 6.854262914741705e-05)
# (('printer', 'when'), 6.451070978580429e-05)
# (('printer', 'work'), 6.451070978580429e-05)
# (('printer', 'over'), 6.047879042419152e-05)
# (('printer', 'we'), 6.047879042419152e-05)
# (('printer', 'scanner'), 5.846283074338513e-05)
# (('printer', 'like'), 5.5774884502309955e-05)
# (('printer', 'ink'), 5.510289794204116e-05)
# (('little', 'printer'), 5.375892482150357e-05)
# (('pixma', 'printer'), 5.308693826123478e-05)
# (('any', 'printer'), 5.241495170096598e-05)
# (('printer', 'us'), 5.174296514069719e-05)
# (('printer', 'cartridge'), 5.107097858042839e-05)
# (('printer', 'copier'), 4.97270054598908e-05)
# (('printer', 'there'), 4.8383032339353215e-05)
# (('format', 'printer'), 4.771104577908442e-05)
# (('multifunction', 'printer'), 4.771104577908442e-05)
# (('printer', 'cable'), 4.771104577908442e-05)
# (('printer', 'software'), 4.771104577908442e-05)
# (('jet', 'printer'), 4.703905921881562e-05)
# (('most', 'printer'), 4.703905921881562e-05)
#
#
# binder
# (('view', 'binder'), 4.97270054598908e-05)
# (('other', 'binder'), 4.771104577908442e-05)
# (('ring', 'binder'), 4.771104577908442e-05)
# (('duty', 'binder'), 3.628727425451491e-05)
# (('jones', 'binder'), 3.359932801343973e-05)
# (('quality', 'binder'), 2.5535489290214196e-05)
# (('inch', 'binder'), 2.0831583368332632e-05)
# (('avery', 'binder'), 1.9487610247795044e-05)
# (('my', 'binder'), 1.9487610247795044e-05)
# (('basic', 'binder'), 1.8143637127257456e-05)
# (('great', 'binder'), 1.8143637127257456e-05)
# (('binder', 'ring'), 1.6799664006719864e-05)
# (('binder', 'wa'), 1.6799664006719864e-05)
# (('nice', 'binder'), 1.6799664006719864e-05)
# (('good', 'binder'), 1.612767744645107e-05)
# (('white', 'binder'), 1.612767744645107e-05)
# (('durable', 'binder'), 1.5455690886182276e-05)
# (('sturdy', 'binder'), 1.5455690886182276e-05)
# (('binder', 'have'), 1.4783704325913482e-05)
# (('binder', 'you'), 1.4783704325913482e-05)
# (('binder', 'cover'), 1.2767744645107098e-05)
# (('binder', 'there'), 1.2767744645107098e-05)
# (('standard', 'binder'), 1.2767744645107098e-05)
# (('use', 'binder'), 1.2767744645107098e-05)
# (('zipper', 'binder'), 1.2767744645107098e-05)
# (('binder', 'doe'), 1.2095758084838304e-05)
# (('binder', 'which'), 1.2095758084838304e-05)
# (('particular', 'binder'), 1.1423771524569508e-05)
# (('binder', 'itself'), 1.0751784964300714e-05)
# (('binder', 'hold'), 1.007979840403192e-05)
# (('binder', 'not'), 1.007979840403192e-05)
# (('your', 'binder'), 1.007979840403192e-05)
# (('average', 'binder'), 9.407811843763124e-06)
# (('binder', 'clip'), 9.407811843763124e-06)
# (('binder', 'seems'), 9.407811843763124e-06)
# (('binder', 'one'), 8.73582528349433e-06)
# (('binder', 'should'), 8.73582528349433e-06)
# (('little', 'binder'), 8.73582528349433e-06)
# (('binder', 'feel'), 8.063838723225536e-06)
# (('binder', 'go'), 8.063838723225536e-06)
# (('binder', 'like'), 8.063838723225536e-06)
# (('binder', 'they'), 8.063838723225536e-06)
# (('most', 'binder'), 8.063838723225536e-06)
# (('regular', 'binder'), 8.063838723225536e-06)
# (('small', 'binder'), 8.063838723225536e-06)
# (('some', 'binder'), 8.063838723225536e-06)
# (('binder', 'by'), 7.391852162956741e-06)
# (('binder', 'just'), 7.391852162956741e-06)
# (('binder', 'out'), 7.391852162956741e-06)
# (('binder', 'when'), 7.391852162956741e-06)
#
#
# dispenser
# (('tape', 'dispenser'), 0.00032994540109197815)
# (('note', 'dispenser'), 4.435111297774045e-05)
# (('handband', 'dispenser'), 2.5535489290214196e-05)
# (('dispenser', 'tape'), 2.351952960940781e-05)
# (('little', 'dispenser'), 1.9487610247795044e-05)
# (('dispenser', 'work'), 1.747165056698866e-05)
# (('dispenser', 'wa'), 1.4783704325913482e-05)
# (('dispenser', 'doe'), 1.4111717765644688e-05)
# (('dispenser', 'which'), 1.2767744645107098e-05)
# (('dispenser', 'you'), 1.2095758084838304e-05)
# (('heart', 'dispenser'), 1.1423771524569508e-05)
# (('new', 'dispenser'), 1.0751784964300714e-05)
# (('dispenser', 'itself'), 9.407811843763124e-06)
# (('old', 'dispenser'), 9.407811843763124e-06)
# (('plastic', 'dispenser'), 9.407811843763124e-06)
# (('deskgrip', 'dispenser'), 8.73582528349433e-06)
# (('dispenser', 'make'), 8.73582528349433e-06)
# (('scotch', 'dispenser'), 8.73582528349433e-06)
# (('dispenser', 'come'), 8.063838723225536e-06)
# (('dispenser', 'also'), 7.391852162956741e-06)
# (('other', 'dispenser'), 7.391852162956741e-06)
# (('desktop', 'dispenser'), 6.719865602687946e-06)
# (('dispenser', 'x'), 6.719865602687946e-06)
# (('dispenser', 'one'), 6.047879042419152e-06)
# (('dispenser', 'when'), 6.047879042419152e-06)
# (('apple', 'dispenser'), 5.375892482150357e-06)
# (('dispenser', 'hold'), 5.375892482150357e-06)
# (('dispenser', 'my'), 5.375892482150357e-06)
# (('most', 'dispenser'), 5.375892482150357e-06)
# (('my', 'dispenser'), 5.375892482150357e-06)
# (('dispenser', 'by'), 4.703905921881562e-06)
# (('dispenser', 'just'), 4.703905921881562e-06)
# (('dispenser', 'like'), 4.703905921881562e-06)
# (('dispenser', 'not'), 4.703905921881562e-06)
# (('dispenser', 'very'), 4.703905921881562e-06)
# (('regular', 'dispenser'), 4.703905921881562e-06)
# (('standard', 'dispenser'), 4.703905921881562e-06)
# (('weighted', 'dispenser'), 4.703905921881562e-06)
# (('desk', 'dispenser'), 4.031919361612768e-06)
# (('dispenser', 'refill'), 4.031919361612768e-06)
# (('dispenser', 'stick'), 4.031919361612768e-06)
# (('dispenser', 'us'), 4.031919361612768e-06)
# (('dispenser', 'we'), 4.031919361612768e-06)
# (('handy', 'dispenser'), 4.031919361612768e-06)
# (('cheap', 'dispenser'), 3.359932801343973e-06)
# (('cute', 'dispenser'), 3.359932801343973e-06)
# (('dispenser', 'brand'), 3.359932801343973e-06)
# (('dispenser', 'came'), 3.359932801343973e-06)
# (('dispenser', 'only'), 3.359932801343973e-06)
# (('dispenser', 'provides'), 3.359932801343973e-06)
#
#
# folder
# (('file', 'folder'), 0.0003837043259134817)
# (('hanging', 'folder'), 0.0001485090298194036)
# (('manila', 'folder'), 8.66862662746745e-05)
# (('folder', 'they'), 5.711885762284754e-05)
# (('folder', 'have'), 4.569508609827803e-05)
# (('folder', 'you'), 4.1663166736665264e-05)
# (('each', 'folder'), 4.031919361612768e-05)
# (('other', 'folder'), 2.8223435531289375e-05)
# (('folder', 'which'), 2.755144897102058e-05)
# (('supertab', 'folder'), 2.351952960940781e-05)
# (('heavyweight', 'folder'), 2.015959680806384e-05)
# (('manilla', 'folder'), 2.015959680806384e-05)
# (('pocket', 'folder'), 2.015959680806384e-05)
# (('regular', 'folder'), 1.8815623687526248e-05)
# (('your', 'folder'), 1.8143637127257456e-05)
# (('colored', 'folder'), 1.747165056698866e-05)
# (('tab', 'folder'), 1.6799664006719864e-05)
# (('folder', 'when'), 1.612767744645107e-05)
# (('smead', 'folder'), 1.612767744645107e-05)
# (('standard', 'folder'), 1.5455690886182276e-05)
# (('folder', 'come'), 1.4783704325913482e-05)
# (('folder', 'tab'), 1.4783704325913482e-05)
# (('folder', 'without'), 1.4783704325913482e-05)
# (('my', 'folder'), 1.4783704325913482e-05)
# (('folder', 'themselves'), 1.4111717765644688e-05)
# (('folder', 'do'), 1.3439731205375892e-05)
# (('folder', 'letter'), 1.3439731205375892e-05)
# (('organizer', 'folder'), 1.3439731205375892e-05)
# (('folder', 'label'), 1.2767744645107098e-05)
# (('great', 'folder'), 1.2767744645107098e-05)
# (('folder', 'itself'), 1.1423771524569508e-05)
# (('folder', 'like'), 1.1423771524569508e-05)
# (('nice', 'folder'), 1.1423771524569508e-05)
# (('folder', 'look'), 1.0751784964300714e-05)
# (('folder', 'make'), 1.007979840403192e-05)
# (('one', 'folder'), 1.007979840403192e-05)
# (('new', 'folder'), 9.407811843763124e-06)
# (('tabbed', 'folder'), 9.407811843763124e-06)
# (('folder', 'also'), 8.73582528349433e-06)
# (('folder', 'just'), 8.73582528349433e-06)
# (('per', 'folder'), 8.73582528349433e-06)
# (('sturdy', 'folder'), 8.73582528349433e-06)
# (('erasable', 'folder'), 8.063838723225536e-06)
# (('folder', 'were'), 8.063838723225536e-06)
# (('red', 'folder'), 8.063838723225536e-06)
# (('fastab', 'folder'), 7.391852162956741e-06)
# (('folder', 'seem'), 7.391852162956741e-06)
# (('folder', 'should'), 7.391852162956741e-06)
# (('paper', 'folder'), 7.391852162956741e-06)
# (('quality', 'folder'), 7.391852162956741e-06)
#
#
# stapler
# (('my', 'stapler'), 3.695926081478371e-05)
# (('swingline', 'stapler'), 3.628727425451491e-05)
# (('stapler', 'doe'), 3.359932801343973e-05)
# (('standard', 'stapler'), 2.5535489290214196e-05)
# (('electric', 'stapler'), 2.48635027299454e-05)
# (('stapler', 'wa'), 2.48635027299454e-05)
# (('other', 'stapler'), 2.351952960940781e-05)
# (('regular', 'stapler'), 2.2847543049139016e-05)
# (('duty', 'stapler'), 2.1503569928601428e-05)
# (('great', 'stapler'), 2.1503569928601428e-05)
# (('stapler', 'work'), 2.1503569928601428e-05)
# (('old', 'stapler'), 2.015959680806384e-05)
# (('new', 'stapler'), 1.9487610247795044e-05)
# (('stapler', 'you'), 1.9487610247795044e-05)
# (('stapler', 'itself'), 1.747165056698866e-05)
# (('desk', 'stapler'), 1.612767744645107e-05)
# (('stapler', 'which'), 1.612767744645107e-05)
# (('your', 'stapler'), 1.612767744645107e-05)
# (('effort', 'stapler'), 1.4111717765644688e-05)
# (('good', 'stapler'), 1.4111717765644688e-05)
# (('red', 'stapler'), 1.2095758084838304e-05)
# (('stapler', 'come'), 1.1423771524569508e-05)
# (('desktop', 'stapler'), 1.0751784964300714e-05)
# (('basic', 'stapler'), 1.007979840403192e-05)
# (('classic', 'stapler'), 1.007979840403192e-05)
# (('quality', 'stapler'), 9.407811843763124e-06)
# (('stapler', 'when'), 9.407811843763124e-06)
# (('traditional', 'stapler'), 9.407811843763124e-06)
# (('best', 'stapler'), 8.73582528349433e-06)
# (('metal', 'stapler'), 8.73582528349433e-06)
# (('smarttouch', 'stapler'), 8.73582528349433e-06)
# (('stapler', 'look'), 8.73582528349433e-06)
# (('stapler', 'staple'), 8.73582528349433e-06)
# (('compact', 'stapler'), 8.063838723225536e-06)
# (('normal', 'stapler'), 8.063838723225536e-06)
# (('stapler', 'make'), 8.063838723225536e-06)
# (('stapler', 'sheet'), 8.063838723225536e-06)
# (('any', 'stapler'), 7.391852162956741e-06)
# (('fashion', 'stapler'), 7.391852162956741e-06)
# (('office', 'stapler'), 7.391852162956741e-06)
# (('stapler', 'also'), 7.391852162956741e-06)
# (('stapler', 'however'), 7.391852162956741e-06)
# (('stapler', 'just'), 7.391852162956741e-06)
# (('stapler', 'not'), 7.391852162956741e-06)
# (('stapler', 'there'), 7.391852162956741e-06)
# (('capacity', 'stapler'), 6.719865602687946e-06)
# (('most', 'stapler'), 6.719865602687946e-06)
# (('small', 'stapler'), 6.719865602687946e-06)
# (('stapler', 'came'), 6.719865602687946e-06)
# (('stapler', 'like'), 6.719865602687946e-06)
#
#
# calculator
# (('graphing', 'calculator'), 4.0991180176396475e-05)
# (('scientific', 'calculator'), 3.4271314573708524e-05)
# (('hp', 'calculator'), 2.8895422091558168e-05)
# (('financial', 'calculator'), 1.4111717765644688e-05)
# (('basic', 'calculator'), 1.2095758084838304e-05)
# (('casio', 'calculator'), 1.0751784964300714e-05)
# (('ti', 'calculator'), 1.0751784964300714e-05)
# (('calculator', 'which'), 8.73582528349433e-06)
# (('good', 'calculator'), 8.73582528349433e-06)
# (('calculator', 'doe'), 7.391852162956741e-06)
# (('calculator', 'you'), 7.391852162956741e-06)
# (('great', 'calculator'), 6.719865602687946e-06)
# (('other', 'calculator'), 6.719865602687946e-06)
# (('little', 'calculator'), 6.047879042419152e-06)
# (('calculator', 'gold'), 5.375892482150357e-06)
# (('calculator', 'wa'), 5.375892482150357e-06)
# (('pocket', 'calculator'), 5.375892482150357e-06)
# (('printing', 'calculator'), 5.375892482150357e-06)
# (('desktop', 'calculator'), 4.703905921881562e-06)
# (('new', 'calculator'), 4.703905921881562e-06)
# (('calculator', 'also'), 4.031919361612768e-06)
# (('calculator', 'when'), 4.031919361612768e-06)
# (('canon', 'calculator'), 4.031919361612768e-06)
# (('my', 'calculator'), 4.031919361612768e-06)
# (('old', 'calculator'), 4.031919361612768e-06)
# (('simple', 'calculator'), 4.031919361612768e-06)
# (('solar', 'calculator'), 4.031919361612768e-06)
# (('use', 'calculator'), 4.031919361612768e-06)
# (('your', 'calculator'), 4.031919361612768e-06)
# (('any', 'calculator'), 3.359932801343973e-06)
# (('calculator', 'just'), 3.359932801343973e-06)
# (('calculator', 'like'), 3.359932801343973e-06)
# (('calculator', 'not'), 3.359932801343973e-06)
# (('calculator', 'there'), 3.359932801343973e-06)
# (('larger', 'calculator'), 3.359932801343973e-06)
# (('another', 'calculator'), 2.6879462410751785e-06)
# (('both', 'calculator'), 2.6879462410751785e-06)
# (('calculator', 'after'), 2.6879462410751785e-06)
# (('calculator', 'back'), 2.6879462410751785e-06)
# (('calculator', 'come'), 2.6879462410751785e-06)
# (('calculator', 'do'), 2.6879462410751785e-06)
# (('calculator', 'h'), 2.6879462410751785e-06)
# (('calculator', 'multiview'), 2.6879462410751785e-06)
# (('calculator', 'mv'), 2.6879462410751785e-06)
# (('calculator', 'really'), 2.6879462410751785e-06)
# (('calculator', 'should'), 2.6879462410751785e-06)
# (('calculator', 'user'), 2.6879462410751785e-06)
# (('calculator', 'without'), 2.6879462410751785e-06)
# (('desk', 'calculator'), 2.6879462410751785e-06)
# (('instrument', 'calculator'), 2.6879462410751785e-06)

# %% [markdown]
# ### likelihood_ratio

# %%
lr_bigrams = {'printer':[], 'binder':[], 'dispenser':[], 'folder':[], 'stapler':[], 'calculator':[]}
for bigram in finder.score_ngrams(bigram_measures.likelihood_ratio):
    for product in product_names:
        if (product in bigram[0] and bigram[0][0] != bigram[0][1] 
            and bigram[0][0] not in stopwords and bigram[0][1] not in stopwords):
                lr_bigrams[product].append(bigram)

# %%
for product in product_names:
    print(product) 
    for bigram in lr_bigrams[product][0:50]:
        print(bigram)
    print('\n')
# Out:
# printer
# (('laser', 'printer'), 4337.908207532014)
# (('inkjet', 'printer'), 1977.5440037485907)
# (('epson', 'printer'), 1720.6376901940112)
# (('photo', 'printer'), 1038.2792985470176)
# (('canon', 'printer'), 868.6867049642465)
# (('hp', 'printer'), 819.4020082643071)
# (('other', 'printer'), 735.275073641096)
# (('new', 'printer'), 635.879060723498)
# (('wireless', 'printer'), 564.2953722599759)
# (('printer', 'itself'), 551.8026973642714)
# (('workforce', 'printer'), 514.713613843623)
# (('printer', 'doe'), 480.52692014655787)
# (('you', 'printer'), 479.86537633420585)
# (('printer', 'wa'), 398.19639179383046)
# (('multifunction', 'printer'), 371.27909255629)
# (('jet', 'printer'), 311.65955884535015)
# (('brother', 'printer'), 300.8277979053021)
# (('great', 'printer'), 300.5128568776336)
# (('format', 'printer'), 277.82529172016837)
# (('old', 'printer'), 274.05840934239177)
# (('have', 'printer'), 263.40303134900654)
# (('pixma', 'printer'), 261.8320926411314)
# (('not', 'printer'), 259.72807114281574)
# (('monochrome', 'printer'), 248.8827825093973)
# (('wa', 'printer'), 243.2219243608139)
# (('printer', 'driver'), 241.3293989029895)
# (('printer', 'copier'), 230.35483355156398)
# (('previous', 'printer'), 226.3696697066175)
# (('print', 'printer'), 213.15969812143476)
# (('paper', 'printer'), 199.72015317382827)
# (('be', 'printer'), 192.86405852575018)
# (('printer', 'which'), 185.25408437401654)
# (('printer', 'us'), 185.00493369616643)
# (('your', 'printer'), 178.17253331689304)
# (('printer', 'be'), 176.10916774119332)
# (('do', 'printer'), 170.68092122608914)
# (('printer', 'come'), 133.89562223314647)
# (('printer', 'scanner'), 132.52520490015755)
# (('home', 'printer'), 126.25431118936103)
# (('samsung', 'printer'), 121.93902183797591)
# (('they', 'printer'), 121.80856585382628)
# (('kodak', 'printer'), 118.48962603749871)
# (('out', 'printer'), 111.71302035444677)
# (('when', 'printer'), 107.30551619329347)
# (('printing', 'printer'), 105.91836924313861)
# (('printer', 'folder'), 103.431474505885)
# (('doe', 'printer'), 102.73925981167768)
# (('just', 'printer'), 102.63300848279987)
# (('printer', 'cable'), 100.55817765638471)
# (('very', 'printer'), 100.52786415966713)
#
#
# binder
# (('view', 'binder'), 665.1826265098974)
# (('jones', 'binder'), 391.07359923527207)
# (('ring', 'binder'), 379.4024668504595)
# (('duty', 'binder'), 345.6701860557622)
# (('avery', 'binder'), 212.17244651539698)
# (('other', 'binder'), 209.9380294513894)
# (('zipper', 'binder'), 160.53854457828422)
# (('inch', 'binder'), 137.41578475460466)
# (('basic', 'binder'), 129.46978187199608)
# (('durable', 'binder'), 110.76227173381696)
# (('particular', 'binder'), 95.04568286833228)
# (('binder', 'clip'), 93.20393543671676)
# (('sturdy', 'binder'), 91.48198002442126)
# (('binder', 'ring'), 82.32089370534736)
# (('white', 'binder'), 79.86560785179341)
# (('binder', 'unusable'), 61.360411246819986)
# (('quality', 'binder'), 60.81463059143724)
# (('you', 'binder'), 60.39730930424662)
# (('average', 'binder'), 60.06124993018203)
# (('binder', 'itself'), 55.72577764005272)
# (('ordinary', 'binder'), 52.472145656282045)
# (('binder', 'cover'), 52.0496501333359)
# (('nice', 'binder'), 50.86048398296778)
# (('vinyl', 'binder'), 50.399252432971934)
# (('standard', 'binder'), 49.91303996627291)
# (('flexible', 'binder'), 46.88018277561014)
# (('strongest', 'binder'), 46.014308459834595)
# (('simplify', 'binder'), 44.99565179069985)
# (('comb', 'binder'), 43.019445637453295)
# (('binder', 'arrived'), 41.060303320974405)
# (('polypro', 'binder'), 36.91347090847628)
# (('bliss', 'binder'), 36.39194932738695)
# (('ledger', 'binder'), 36.39194932738695)
# (('great', 'binder'), 36.075269022735576)
# (('sewn', 'binder'), 35.43552943270041)
# (('have', 'binder'), 35.05447843407785)
# (('cheaper', 'binder'), 34.013034267841206)
# (('sturdiest', 'binder'), 32.875626699674186)
# (('binder', 'seems'), 30.377994455078387)
# (('sized', 'binder'), 30.368951462383432)
# (('regular', 'binder'), 29.947274256933042)
# (('binder', 'instead'), 28.44594798962741)
# (('binder', 'feel'), 28.21935734461604)
# (('wj', 'binder'), 27.825435762882385)
# (('typical', 'binder'), 27.349541901709898)
# (('binder', 'hold'), 26.701922154337534)
# (('decent', 'binder'), 26.360142464780083)
# (('hard', 'binder'), 25.435334174204183)
# (('binder', 'should'), 25.363649488324132)
# (('binder', 'connoisseur'), 24.91289381498429)
#
#
# dispenser
# (('tape', 'dispenser'), 3969.059748825981)
# (('handband', 'dispenser'), 450.553007056001)
# (('note', 'dispenser'), 374.0981355995397)
# (('heart', 'dispenser'), 149.5436079239825)
# (('deskgrip', 'dispenser'), 142.07494309634976)
# (('dispenser', 'tape'), 90.95068629157683)
# (('little', 'dispenser'), 81.56456367007657)
# (('scotch', 'dispenser'), 64.2150431007036)
# (('dispenser', 'itself'), 55.14698086819718)
# (('weighted', 'dispenser'), 47.79364998371463)
# (('dispenser', 'work'), 40.920161185246705)
# (('new', 'dispenser'), 40.141973473516245)
# (('plastic', 'dispenser'), 39.6647295133068)
# (('you', 'dispenser'), 39.294559875448755)
# (('desktop', 'dispenser'), 39.019543704655945)
# (('disposable', 'dispenser'), 36.84391313042033)
# (('old', 'dispenser'), 36.61561942906658)
# (('apple', 'dispenser'), 35.063062789452985)
# (('dispenser', 'attache'), 34.334060775088616)
# (('dispenser', 'doe'), 28.535992250660968)
# (('traditional', 'dispenser'), 24.723322006764427)
# (('cute', 'dispenser'), 24.641977619549454)
# (('dispenser', 'loses'), 24.228038819383016)
# (('dispenser', 'x'), 23.56797364772279)
# (('dispenser', 'solves'), 23.104466308953135)
# (('reusable', 'dispenser'), 22.161235451435793)
# (('dispenser', 'provides'), 21.922663337113544)
# (('dispenser', 'which'), 20.94430823691624)
# (('purse', 'dispenser'), 19.610516719739202)
# (('dispenser', 'come'), 18.254791101741116)
# (('industrial', 'dispenser'), 18.126074973285988)
# (('refillable', 'dispenser'), 17.705252277419692)
# (('handy', 'dispenser'), 16.58182046036428)
# (('shoe', 'dispenser'), 16.436180603977192)
# (('grip', 'dispenser'), 16.30555184184914)
# (('dispenser', 'stick'), 16.118519136978527)
# (('dispenser', 'refill'), 16.07339485163721)
# (('regular', 'dispenser'), 15.455861382385146)
# (('sealing', 'dispenser'), 15.308354604302181)
# (('style', 'dispenser'), 14.961183852882208)
# (('gun', 'dispenser'), 14.638472536545786)
# (('dispenser', 'be'), 14.61441273053148)
# (('dispenser', 'have'), 14.136791100814257)
# (('paper', 'dispenser'), 14.1216472026493)
# (('particular', 'dispenser'), 13.904327220544317)
# (('dispenser', 'make'), 13.835348116241871)
# (('dispenser', 'packaging'), 13.213654406695028)
# (('anote', 'dispenser'), 13.210794780366953)
# (('basicbandit', 'dispenser'), 13.210794780366953)
# (('bescotch', 'dispenser'), 13.210794780366953)
#
#
# folder
# (('file', 'folder'), 4794.019282045608)
# (('hanging', 'folder'), 2062.351472406371)
# (('manila', 'folder'), 1287.0915041387036)
# (('manilla', 'folder'), 312.26416192192636)
# (('supertab', 'folder'), 290.75935802713786)
# (('each', 'folder'), 268.0338061620295)
# (('heavyweight', 'folder'), 247.25623684951222)
# (('folder', 'they'), 196.90009428804672)
# (('organizer', 'folder'), 179.36371545467446)
# (('colored', 'folder'), 175.6835002489566)
# (('folder', 'themselves'), 152.37688381853314)
# (('smead', 'folder'), 124.14017862676442)
# (('tabbed', 'folder'), 120.88512319883344)
# (('pocket', 'folder'), 108.34841052332541)
# (('printer', 'folder'), 103.431474505885)
# (('regular', 'folder'), 101.84876385850654)
# (('folder', 'letter'), 91.24735322810201)
# (('fastab', 'folder'), 88.45123151284625)
# (('classification', 'folder'), 80.66865197387447)
# (('erasable', 'folder'), 72.24225773632249)
# (('other', 'folder'), 68.48243400893512)
# (('pendaflex', 'folder'), 63.96680150088149)
# (('folder', 'tuff'), 63.24471219637433)
# (('vertical', 'folder'), 60.508465571907585)
# (('standard', 'folder'), 58.74376269992395)
# (('folder', 'which'), 54.991114932622516)
# (('tab', 'folder'), 54.81149607378929)
# (('folder', 'itself'), 53.776040623838625)
# (('presentation', 'folder'), 51.788589729328706)
# (('red', 'folder'), 49.07514874613912)
# (('folder', 'label'), 48.47475384115411)
# (('lockit', 'folder'), 48.306480562763184)
# (('folder', 'tab'), 43.4051377465037)
# (('not', 'folder'), 43.35628187375025)
# (('folder', 'without'), 42.23474643344032)
# (('green', 'folder'), 40.6872159699439)
# (('folder', 'print'), 39.39145901897583)
# (('have', 'folder'), 37.61903280836694)
# (('repocket', 'folder'), 36.88781929045129)
# (('pocketed', 'folder'), 35.967862525759614)
# (('cutless', 'folder'), 35.480332538634464)
# (('fastener', 'folder'), 34.99466212599232)
# (('folder', 'have'), 33.66937118700713)
# (('folder', 'come'), 33.3735598823017)
# (('ordinary', 'folder'), 32.99586290407899)
# (('expansion', 'folder'), 32.40513198598048)
# (('sturdy', 'folder'), 32.262658843647046)
# (('folder', 'be'), 31.39735934320081)
# (('per', 'folder'), 30.579139482430577)
# (('folder', 'paper'), 30.4454397878537)
#
#
# stapler
# (('swingline', 'stapler'), 386.948247668649)
# (('electric', 'stapler'), 384.5463121106975)
# (('duty', 'stapler'), 174.27656978715896)
# (('regular', 'stapler'), 156.00873737237433)
# (('standard', 'stapler'), 153.9603008138562)
# (('effort', 'stapler'), 120.43816436005955)
# (('smarttouch', 'stapler'), 119.51900513642074)
# (('classic', 'stapler'), 118.84937917952271)
# (('stapler', 'itself'), 118.25299112679393)
# (('stapler', 'doe'), 114.13300413006651)
# (('old', 'stapler'), 103.56837822323253)
# (('red', 'stapler'), 98.59192297448192)
# (('fashion', 'stapler'), 96.57587204134165)
# (('traditional', 'stapler'), 89.9855534333806)
# (('new', 'stapler'), 87.79818330786509)
# (('prodigy', 'stapler'), 78.60186696668158)
# (('desk', 'stapler'), 77.21228403773193)
# (('desktop', 'stapler'), 67.47616762459137)
# (('other', 'stapler'), 63.72963020014338)
# (('metal', 'stapler'), 59.93872741284051)
# (('basic', 'stapler'), 56.57169962745232)
# (('great', 'stapler'), 54.725366742344534)
# (('handheld', 'stapler'), 49.197517454003)
# (('personalized', 'stapler'), 48.61148844092983)
# (('normal', 'stapler'), 47.09412372234351)
# (('stapler', 'work'), 45.15179581603936)
# (('compact', 'stapler'), 44.73599489834615)
# (('optimum', 'stapler'), 40.34039172809723)
# (('stapler', 'reduced'), 39.24001434713709)
# (('lightweight', 'stapler'), 38.15875565232461)
# (('my', 'stapler'), 35.251635096479404)
# (('conventional', 'stapler'), 33.75750933162938)
# (('not', 'stapler'), 30.520406544344098)
# (('best', 'stapler'), 29.96332806907537)
# (('bostitch', 'stapler'), 28.449260632032875)
# (('stapler', 'arrived'), 28.11824031596911)
# (('stapler', 'come'), 26.883863603145727)
# (('capacity', 'stapler'), 25.89386667871978)
# (('lighttouch', 'stapler'), 25.592892204491818)
# (('stapler', 'slapper'), 25.176137432141005)
# (('stapler', 'came'), 24.719108829616427)
# (('paperpro', 'stapler'), 24.2772302191943)
# (('customizable', 'stapler'), 23.884200730137657)
# (('stapler', 'which'), 23.81059349152379)
# (('ribbon', 'stapler'), 23.75694125898537)
# (('mini', 'stapler'), 23.510275809164796)
# (('your', 'stapler'), 23.224579656705977)
# (('stapler', 'be'), 21.802278874335858)
# (('average', 'stapler'), 21.644333365663698)
# (('manual', 'stapler'), 21.515262015383257)
#
#
# calculator
# (('graphing', 'calculator'), 811.9146518071309)
# (('scientific', 'calculator'), 682.7463200234662)
# (('financial', 'calculator'), 221.02834259781616)
# (('hp', 'calculator'), 208.6982225423774)
# (('casio', 'calculator'), 149.13793036617108)
# (('ti', 'calculator'), 133.54801854681423)
# (('basic', 'calculator'), 108.47486244650112)
# (('calculator', 'gold'), 79.86028323240527)
# (('calculator', 'mv'), 58.17469376611213)
# (('calculator', 'multiview'), 50.53929867863276)
# (('solar', 'calculator'), 46.77224044888144)
# (('calculator', 'h'), 36.94735793641187)
# (('instrument', 'calculator'), 32.872409033429584)
# (('desktop', 'calculator'), 31.388825348646275)
# (('pocket', 'calculator'), 28.004472333442887)
# (('good', 'calculator'), 21.27867989444827)
# (('powered', 'calculator'), 20.0914408467306)
# (('calculator', 'which'), 19.95925791072565)
# (('classic', 'calculator'), 19.40022039967923)
# (('you', 'calculator'), 17.47955119305376)
# (('little', 'calculator'), 17.287867447052136)
# (('simple', 'calculator'), 17.030693218269377)
# (('advanced', 'calculator'), 16.874246193211828)
# (('calculator', 'arrived'), 15.635325122061769)
# (('new', 'calculator'), 15.54378898505766)
# (('h', 'calculator'), 15.522471691232433)
# (('handheld', 'calculator'), 15.522471691232433)
# (('calculator', 'doe'), 15.237091038990648)
# (('pen', 'calculator'), 14.84171223036586)
# (('lined', 'calculator'), 14.565636917851188)
# (('abasic', 'calculator'), 14.540775036441232)
# (('amazonasics', 'calculator'), 14.540775036441232)
# (('amazonbasics', 'calculator'), 14.540775036441232)
# (('calculator', 'david'), 14.540775036441232)
# (('calculator', 'keyset'), 14.540775036441232)
# (('calculator', 'scientifics'), 14.540775036441232)
# (('casiothis', 'calculator'), 14.540775036441232)
# (('forany', 'calculator'), 14.540775036441232)
# (('potent', 'calculator'), 14.540775036441232)
# (('protractor', 'calculator'), 14.540775036441232)
# (('scienfic', 'calculator'), 14.540775036441232)
# (('scienfitic', 'calculator'), 14.540775036441232)
# (('therethe', 'calculator'), 14.540775036441232)
# (('calculator', 'today'), 14.266623776107979)
# (('great', 'calculator'), 14.081921592034137)
# (('calculator', 'production'), 13.91513730170201)
# (('l', 'calculator'), 13.91513730170201)
# (('other', 'calculator'), 13.73106231285628)
# (('old', 'calculator'), 13.730404379729253)
# (('larger', 'calculator'), 13.587817171152084)

# %% [markdown]
# Мне показались более качественными последние биграммы

# %% [markdown]
# #### Теперь посмотрим на триграммы

# %%
finder_3 = TrigramCollocationFinder.from_words(' '.join(new_df['new_review']).split())

# %% [markdown]
# ### PMI

# %%
pmi_trigrams = {'printer':[], 'binder':[], 'dispenser':[], 'folder':[], 'stapler':[], 'calculator':[]}

for trigram in finder_3.score_ngrams(trigram_measures.pmi):
    for product in product_names:
        if (product in trigram[0] and trigram[0][0] != trigram[0][1] and trigram[0][1] != trigram[0][2]):
            pmi_trigrams[product].append(trigram)

# %%
for product in product_names:
    print(product) 
    for trigram in pmi_trigrams[product][0:50]:
        print(trigram)
    print('\n')
# Out:
# printer
# (('comparisonthe', 'printer', 'mfx'), 26.548201547049615)
# (('diablo', 'daisywheel', 'printer'), 26.548201547049615)
# (('emptyplus', 'morethe', 'printer'), 26.548201547049615)
# (('feederwireless', 'printingtouchscreen', 'printer'), 26.548201547049615)
# (('printer', 'eddy', 'kleinnewton'), 26.548201547049615)
# (('upusb', 'portcolor', 'printer'), 26.548201547049615)
# (('alexmark', 'pinnacle', 'printer'), 25.548201547049615)
# (('sampler', 'printer', 'controlas'), 25.548201547049615)
# (('thissamsung', 'printer', 'fwis'), 25.548201547049615)
# (('upgradeable', 'printer', 'firmwarethe'), 25.548201547049615)
# (('printer', 'roger', 'meyerlife'), 24.96323904632846)
# (('inket', 'printer', 'jean'), 24.548201547049615)
# (('printer', 'kindly', 'remembered'), 24.548201547049615)
# (('printer', 'chug', 'gallon'), 24.226273452162253)
# (('pcl', 'fontsthis', 'printer'), 23.96323904632846)
# (('printer', 'screeched', 'horribly'), 23.96323904632846)
# (('snazzier', 'printer', 'featuring'), 23.96323904632846)
# (('thissamsung', 'printer', 'fw'), 23.96323904632846)
# (('humble', 'printer', 'devoid'), 23.740846624992013)
# (('unplugging', 'printer', 'replugging'), 23.226273452162253)
# (('funky', 'java', 'printer'), 22.96323904632846)
# (('contemporary', 'inket', 'printer'), 22.548201547049615)
# (('vengeful', 'printer', 'god'), 22.548201547049615)
# (('printer', 'inspires', 'confidence'), 22.460738705799276)
# (('multipack', 'cmyblack', 'printer'), 22.378276545607303)
# (('daisy', 'wheel', 'printer'), 22.226273452162253)
# (('printer', 'thereby', 'soaking'), 22.226273452162253)
# (('anaemic', 'printer', 'bundle'), 22.155884124270855)
# (('producting', 'lesser', 'printer'), 22.024639590992603)
# (('startling', 'transition', 'printer'), 21.96323904632846)
# (('printer', 'debbie', 'lee'), 21.933491702934408)
# (('printer', 'galaxy', 'captivate'), 21.740846624992013)
# (('wicked', 'former', 'printer'), 21.6413109514411)
# (('envy', 'printer', 'andsamsung'), 21.548201547049615)
# (('unlikehp', 'envy', 'printer'), 21.548201547049615)
# (('akodak', 'esp', 'printer'), 21.503807427691164)
# (('printer', 'developed', 'radiance'), 21.503807427691164)
# (('printer', 'ugly', 'stepsister'), 21.30027403360603)
# (('printer', 'cmyk', 'deter'), 21.226273452162253)
# (('printer', 'reveals', 'defined'), 21.08876992841232)
# (('printer', 'began', 'clattering'), 21.024639590992603)
# (('printer', 'hostage', 'till'), 21.024639590992603)
# (('printer', 'animated', 'tutorial'), 20.90434535727489)
# (('printer', 'helpfully', 'beep'), 20.79331404488615)
# (('printer', 'causing', 'lockup'), 20.740846624992013)
# (('printer', 'konica', 'minolta'), 20.5709216235497)
# (('printer', 'sends', 'anonymous'), 20.503807427691164)
# (('attention', 'printer', 'usersthis'), 20.41891853010465)
# (('capacityblack', 'printer', 'durabrite'), 20.398454427544934)
# (('cmyblack', 'printer', 'durabrite'), 20.398454427544934)
#
#
# binder
# (('duratech', 'binder', 'violet'), 28.490001019314718)
# (('onestorex', 'duratech', 'binder'), 28.490001019314718)
# (('thesestorex', 'duratech', 'binder'), 28.490001019314718)
# (('fivestar', 'zipped', 'binder'), 25.682646097257113)
# (('ballet', 'horse', 'binder'), 24.5831104237062)
# (('adult', 'binder', 'standout'), 24.40253817806438)
# (('simplify', 'binder', 'titling'), 24.20459880045247)
# (('troublesome', 'protruding', 'binder'), 23.90503851859356)
# (('seuss', 'binder', 'classroom'), 23.40253817806438)
# (('binder', 'round', 'ringswilson'), 22.413185422263886)
# (('mead', 'zipper', 'binder'), 22.21387661404048)
# (('binder', 'violet', 'spine'), 21.32509409263903)
# (('fanatastic', 'binder', 'wish'), 21.285429875065514)
# (('simplify', 'binder', 'labeling'), 21.250402490065593)
# (('binder', 'apparatus', 'sits'), 21.232613176622067)
# (('theavery', 'economy', 'binder'), 21.20459880045247)
# (('binder', 'super', 'bummed'), 21.1457051113989)
# (('sewn', 'binder', 'round'), 20.95375380362659)
# (('comb', 'binder', 'starlet'), 20.882670705565108)
# (('professional', 'binder', 'velo'), 20.803500492131498)
# (('avery', 'binder', 'shrunk'), 20.619636299731315)
# (('binder', 'olympics', 'close'), 20.47041029095684)
# (('binder', 'endure', 'frequent'), 20.381476562536548)
# (('silhouette', 'view', 'binder'), 20.29770820484395)
# (('recycled', 'bliss', 'binder'), 20.19079300092744)
# (('spine', 'simplify', 'binder'), 19.9465824693853)
# (('wilson', 'jones', 'binder'), 19.851037239480014)
# (('fellowes', 'binder', 'video'), 19.849756083092373)
# (('priced', 'binder', 'looseleaf'), 19.75529139908888)
# (('binder', 'felt', 'floppy'), 19.633575490689186)
# (('medal', 'ring', 'binder'), 19.54602110497098)
# (('visible', 'binder', 'host'), 19.49564758245586)
# (('each', 'timeflexible', 'binder'), 19.48859282492191)
# (('wj', 'binder', 'ultra'), 19.406521691982878)
# (('vinyl', 'binder', 'extensively'), 19.381476562536548)
# (('binder', 'clip', 'operated'), 19.358144058705925)
# (('their', 'binder', 'closeing'), 19.311336168308245)
# (('their', 'seuss', 'binder'), 19.311336168308245)
# (('bliss', 'binder', 'round'), 19.091257327376525)
# (('overflowing', 'school', 'binder'), 19.07214850442882)
# (('recipe', 'food', 'binder'), 19.053289477177504)
# (('corrugated', 'cardboard', 'binder'), 19.031594406078185)
# (('cost', 'fanatastic', 'binder'), 18.868864906040077)
# (('sturdily', 'built', 'binder'), 18.864292176250252)
# (('binder', 'arrived', 'warped'), 18.85882396361074)
# (('ledger', 'binder', 'inch'), 18.769329232489163)
# (('especially', 'destroys', 'binder'), 18.74769158323072)
# (('cheapest', 'economy', 'binder'), 18.712745704122796)
# (('school', 'aged', 'binder'), 18.657111005149975)
# (('binder', 'contain', 'pvc'), 18.632797547806554)
#
#
# dispenser
# (('dispenser', 'silvertech', 'shoe'), 26.71235250674542)
# (('silvertech', 'shoe', 'dispenser'), 26.71235250674542)
# (('jetson', 'cubicle', 'dispenser'), 26.44931810091163)
# (('dispenser', 'tartan', 'pistol'), 25.71235250674542)
# (('dispenser', 'um', 'indispensable'), 25.641963178854024)
# (('dispenser', 'devidoir', 'designer'), 24.946817760382444)
# (('collection', 'dispenser', 'devidoir'), 24.608015846930687)
# (('pepto', 'pink', 'dispenser'), 23.22692567957518)
# (('dispenser', 'infor', 'sealing'), 22.968191411175013)
# (('refilable', 'weighted', 'dispenser'), 22.968191411175013)
# (('fancier', 'handled', 'dispenser'), 22.90499758468782)
# (('refillable', 'deskgrip', 'dispenser'), 22.404923981553175)
# (('scotch', 'dispenser', 'alleviates'), 21.730499853455683)
# (('basicbandit', 'dispenser', 'due'), 21.707851114510483)
# (('pebble', 'collection', 'dispenser'), 21.608015846930687)
# (('dispenser', 'cut', 'extrememly'), 21.35480050212734)
# (('dispenser', 'incategory', 'power'), 21.217296978377405)
# (('implement', 'equally', 'dispenser'), 21.191930258218978)
# (('dispenser', 'attache', 'firmly'), 21.08883676525487)
# (('dispenser', 'bottomthe', 'bottom'), 20.976288878873607)
# (('dispenser', 'especially', 'whenwrapping'), 20.87693366626994)
# (('plus', 'anote', 'dispenser'), 20.837063908522733)
# (('dispenser', 'us', 'tapeinstead'), 20.641963178854024)
# (('giftwrap', 'dispenser', 'along'), 20.512680161909056)
# (('tried', 'mannnny', 'dispenser'), 20.358323568691034)
# (('lime', 'green', 'dispenser'), 20.333840883491693)
# (('pistol', 'style', 'dispenser'), 20.220499410415748)
# (('sealing', 'dispenser', 'food'), 20.160836489117408)
# (('encircled', 'each', 'dispenser'), 20.032872407239974)
# (('carton', 'sealing', 'dispenser'), 19.880728569924674)
# (('dispenser', 'delivers', 'precut'), 19.62807559621393)
# (('dispenser', 'such', 'asscotch'), 19.556522335188898)
# (('contour', 'dispenser', 'refill'), 19.54543625517545)
# (('roll', 'dispenser', 'ymmv'), 19.466324526217317)
# (('handband', 'dispenser', 'eliminates'), 19.419570757517576)
# (('headband', 'dispenser', 'might'), 19.41589509937418)
# (('traditional', 'dispenser', 'ending'), 19.414977646217096)
# (('dispenser', 'loses', 'suction'), 19.36185525966129)
# (('handband', 'dispenser', 'dispenses'), 19.29028774057261)
# (('deskgrip', 'dispenser', 'wow'), 19.199809551648563)
# (('dispenser', 'dispenses', 'equal'), 19.17707713012462)
# (('dispenser', 'once', 'dialed'), 19.096171275413546)
# (('anote', 'dispenser', 'because'), 18.951466263960512)
# (('vertical', 'dispenser', 'split'), 18.941523460712933)
# (('round', 'dispenser', 'attache'), 18.870002163331613)
# (('hefty', 'weighted', 'dispenser'), 18.838908394230046)
# (('handy', 'dandy', 'dispenser'), 18.61326774585356)
# (('popup', 'handband', 'dispenser'), 18.61221583545997)
# (('dispenser', 'by', 'karim'), 18.55796835619888)
# (('dispensingthis', 'dispenser', 'tape'), 18.51218953274572)
#
#
# folder
# (('notorious', 'nesting', 'folder'), 27.152925098131405)
# (('brights', 'partition', 'folder'), 25.567962597410247)
# (('folder', 'webdav', 'evernote'), 24.294944103003832)
# (('coloful', 'folder', 'labeled'), 23.567962597410247)
# (('folder', 'thereby', 'exposing'), 23.246034502522885)
# (('classification', 'partition', 'folder'), 22.983000096689093)
# (('erasablesupertab', 'folder', 'assorted'), 22.983000096689093)
# (('ix', 'vertical', 'folder'), 22.867522879269156)
# (('sizeeach', 'folder', 'measure'), 22.867522879269156)
# (('subertab', 'heavyweight', 'folder'), 22.693493479494105)
# (('misplace', 'folder', 'struck'), 22.661072001801728)
# (('supertab', 'superheavyweight', 'folder'), 22.509068908356678)
# (('invention', 'handing', 'folder'), 22.480499756159908)
# (('manilla', 'folder', 'resting'), 22.210410592792165)
# (('dcim', 'folder', 'common'), 22.152925098131405)
# (('brighter', 'folder', 'rail'), 21.983000096689093)
# (('cutless', 'folder', 'hmmm'), 21.983000096689093)
# (('folder', 'con', 'nonetotally'), 21.963100539251386)
# (('sunrise', 'colored', 'folder'), 21.963100539251386)
# (('reuse', 'folder', 'handwrite'), 21.76060767535264)
# (('semicircular', 'folder', 'flap'), 21.677191667165005)
# (('ordinary', 'pocketed', 'folder'), 21.637225259847362)
# (('thia', 'manila', 'folder'), 21.49471361537961)
# (('jones', 'snapper', 'folder'), 21.404732248541944)
# (('web', 'folder', 'webdav'), 20.97301600811647)
# (('andsmead', 'supertab', 'folder'), 20.924106407635524)
# (('nesting', 'folder', 'within'), 20.876800692857167)
# (('subtopic', 'folder', 'within'), 20.876800692857167)
# (('final', 'annual', 'folder'), 20.701713986299076)
# (('snapper', 'folder', 'wilson'), 20.677191667165005)
# (('supertab', 'lockit', 'folder'), 20.583069489800454)
# (('separating', 'folder', 'visually'), 20.567962597410247)
# (('course', 'lolthese', 'folder'), 20.44211866443205)
# (('erasablefastab', 'hanging', 'folder'), 20.391373865686923)
# (('thatsmead', 'hanging', 'folder'), 20.391373865686923)
# (('folder', 'appeared', 'functionally'), 20.371565384606743)
# (('supertab', 'heavyweight', 'folder'), 20.04963728971938)
# (('valuable', 'enhanced', 'folder'), 19.9981069890793)
# (('folder', 'encourage', 'organization'), 19.90499758468782)
# (('practical', 'folder', 'represent'), 19.867522879269156)
# (('tuff', 'hanging', 'folder'), 19.80641136496577)
# (('folder', 'three', 'tabbled'), 19.782237691324188)
# (('three', 'subtopic', 'folder'), 19.782237691324188)
# (('excellently', 'constructed', 'folder'), 19.739297169107232)
# (('traditional', 'handing', 'folder'), 19.649099360135654)
# (('folder', 'strong', 'tyvek'), 19.643150093804465)
# (('brightly', 'colored', 'folder'), 19.641172444364024)
# (('ampad', 'comparison', 'folder'), 19.631324658407678)
# (('folder', 'shall', 'become'), 19.57360916055139)
# (('manila', 'folder', 'reveals'), 19.49471361537961)
#
#
# stapler
# (('viet', 'nam', 'stapler'), 29.584912666340188)
# (('nonelectric', 'stapler', 'balk'), 28.584912666340188)
# (('oakland', 'athletics', 'stapler'), 27.262984571452822)
# (('ergonomicsthe', 'stapler', 'earns'), 26.777557744282582)
# (('stapler', 'boasting', 'ruler'), 26.414987664897872)
# (('rotating', 'stapler', 'crimp'), 25.192595243561424)
# (('excessively', 'sparkly', 'stapler'), 24.777557744282582)
# (('mistaking', 'whose', 'stapler'), 24.72693167121261)
# (('boring', 'unicolored', 'stapler'), 24.584912666340184)
# (('simplee', 'stapler', 'remains'), 24.299510447477935)
# (('thanswingline', 'optimum', 'stapler'), 24.09305957001051)
# (('lived', 'stapler', 'imaginable'), 23.99995016561903)
# (('stapler', 'stealing', 'freak'), 23.777557744282582)
# (('paperpro', 'prodigy', 'stapler'), 23.642398161000944)
# (('stapler', 'crimp', 'plate'), 23.60763274284027)
# (('oldswingline', 'classic', 'stapler'), 23.56254485331173)
# (('smoothgrip', 'handheld', 'stapler'), 23.476388209562018)
# (('stapler', 'smoothgrip', 'handheld'), 23.476388209562018)
# (('stapler', 'reduced', 'effortwith'), 23.09305957001051)
# (('stapler', 'partially', 'depressed'), 22.91248732436869)
# (('stapler', 'picky', 'spouse'), 22.91248732436869)
# (('search', 'forswingline', 'stapler'), 22.830025164176718)
# (('polished', 'chrome', 'stapler'), 22.318126125645282)
# (('stapler', 'circa', 'late'), 22.262984571452822)
# (('stapler', 'particularly', 'theirclassic'), 22.201208373866134)
# (('stapler', 'leaning', 'towards'), 22.158647911638088)
# (('bulge', 'max', 'stapler'), 21.884472948199093)
# (('coveted', 'red', 'stapler'), 21.636545434755508)
# (('standby', 'stapler', 'rio'), 21.584912666340184)
# (('customizable', 'fashion', 'stapler'), 21.436181887166995)
# (('bling', 'fashion', 'stapler'), 21.411235530036766)
# (('figure', 'ergonomicsthe', 'stapler'), 21.390155811917936)
# (('theswingline', 'smarttouch', 'stapler'), 21.218590452094368)
# (('stapler', 'theswingline', 'lighttouch'), 21.133701554507855)
# (('doggone', 'desktop', 'stapler'), 20.89142570884086)
# (('stanley', 'bostitch', 'stapler'), 20.85359363531512)
# (('customizeable', 'stapler', 'handle'), 20.846820406719694)
# (('stapler', 'ez', 'squeeze'), 20.84007882884064)
# (('consider', 'thepaperpro', 'stapler'), 20.60763274284027)
# (('stapler', 'capacity', 'ecofriendly'), 20.318126125645282)
# (('stapler', 'perhaps', 'lugging'), 20.306463208119702)
# (('theswingline', 'classic', 'stapler'), 20.24061675842437)
# (('mass', 'producing', 'stapler'), 20.139897820471763)
# (('sleek', 'stapler', 'airplane'), 20.105132402311085)
# (('pink', 'ribbon', 'stapler'), 20.077118026141488)
# (('stapler', 'absolutely', 'crush'), 20.030323814662548)
# (('pathetic', 'lightweight', 'stapler'), 19.977582352590574)
# (('conventional', 'stapler', 'anytime'), 19.851897344654223)
# (('classic', 'stapler', 'introduced'), 19.755189931254126)
# (('electric', 'stapler', 'sounded'), 19.74728473316878)
#
#
# calculator
# (('protractor', 'calculator', 'swatch'), 29.993320281953014)
# (('calculator', 'amortization', 'depreciation'), 29.408357781231857)
# (('rpn', 'scienfitic', 'calculator'), 25.86403726500805)
# (('calculator', 'mv', 'lacked'), 25.671392187065653)
# (('handheld', 'surviving', 'calculator'), 25.469758325896002)
# (('calculator', 'swatch', 'paint'), 25.185965359895413)
# (('nicest', 'coolest', 'calculator'), 25.185965359895413)
# (('solver', 'financial', 'calculator'), 24.884795825174848)
# (('ban', 'graphing', 'calculator'), 24.726533741258113)
# (('singapore', 'produced', 'calculator'), 24.469758325896002)
# (('pencil', 'protractor', 'calculator'), 24.03912397156614)
# (('solarand', 'battery', 'calculator'), 23.916504684902183)
# (('deepest', 'financial', 'calculator'), 23.884795825174848)
# (('calculator', 'david', 'wilson'), 23.517586850986618)
# (('calculator', 's', 'cps'), 23.356695661409365)
# (('calculator', 'multiview', 'fails'), 23.19890441560291)
# (('texas', 'instrument', 'calculator'), 22.97651199426646)
# (('aurora', 'solar', 'calculator'), 22.905857440702675)
# (('multiview', 'scientific', 'calculator'), 22.431077857731943)
# (('superior', 'calculator', 'mv'), 22.238432779789548)
# (('calculator', 'manufacturer', 'replacable'), 22.104577033054756)
# (('aa', 'powered', 'calculator'), 21.96541428538313)
# (('whole', 'calculator', 'premise'), 21.879578115903826)
# (('ti', 'calculator', 'aos'), 21.864037265008047)
# (('programmable', 'scientific', 'calculator'), 21.846115357010788)
# (('calculator', 'thank', 'goodness'), 21.823395280510702)
# (('calculator', 'gum', 'stuff'), 21.754915542627938)
# (('manual', 'calculator', 'david'), 21.717195876678776)
# (('calculator', 'gold', 'anniversary'), 21.700998649150975)
# (('scientific', 'calculator', 'cousin'), 21.694112263565735)
# (('calculator', 'thus', 'supremely'), 21.53184083466686)
# (('calculator', 'sits', 'snugly'), 21.513540017923916)
# (('handheld', 'calculator', 'production'), 21.382295484645663)
# (('casio', 'scientific', 'calculator'), 21.3476618495443)
# (('keyed', 'calculator', 'under'), 21.211960568428356)
# (('enough', 'therethe', 'calculator'), 20.940752231148863)
# (('calculator', 'ruler', 'pencil'), 20.86919897012383)
# (('old', 'calculator', 'scientifics'), 20.81341119193808)
# (('confirms', 'plus', 'calculator'), 20.796103588842964)
# (('aa', 'battery', 'calculator'), 20.74657968345987)
# (('calculator', 'measuring', 'roughly'), 20.717195876678776)
# (('exam', 'scientific', 'calculator'), 20.694112263565735)
# (('phone', 'calculator', 'gum'), 20.577578513662925)
# (('calculator', 'arrived', 'promptly'), 20.47762044366897)
# (('graphing', 'calculator', 'measuring'), 20.40460564637075)
# (('calculator', 'premise', 'feel'), 20.363963661873406)
# (('calculator', 'differs', 'slightly'), 20.30944841333041)
# (('ti', 'graphing', 'calculator'), 20.182213225034303)
# (('calculator', 'include', 'arithmetic'), 20.1667717946621)
# (('calculator', 'function', 'ln'), 20.158849231968794)

# %% [markdown]
# ### raw_freq

# %%
rf_trigrams = {'printer':[], 'binder':[], 'dispenser':[], 'folder':[], 'stapler':[], 'calculator':[]}

for trigram in finder_3.score_ngrams(trigram_measures.pmi):
    for product in product_names:
        if (product in trigram[0] and trigram[0][0] != trigram[0][1] and trigram[0][1] != trigram[0][2]):
            rf_trigrams[product].append(trigram)

# %%
for product in product_names:
    print(product) 
    for trigram in rf_trigrams[product][0:50]:
        print(trigram)
    print('\n')
# Out:
# printer
# (('comparisonthe', 'printer', 'mfx'), 26.548201547049615)
# (('diablo', 'daisywheel', 'printer'), 26.548201547049615)
# (('emptyplus', 'morethe', 'printer'), 26.548201547049615)
# (('feederwireless', 'printingtouchscreen', 'printer'), 26.548201547049615)
# (('printer', 'eddy', 'kleinnewton'), 26.548201547049615)
# (('upusb', 'portcolor', 'printer'), 26.548201547049615)
# (('alexmark', 'pinnacle', 'printer'), 25.548201547049615)
# (('sampler', 'printer', 'controlas'), 25.548201547049615)
# (('thissamsung', 'printer', 'fwis'), 25.548201547049615)
# (('upgradeable', 'printer', 'firmwarethe'), 25.548201547049615)
# (('printer', 'roger', 'meyerlife'), 24.96323904632846)
# (('inket', 'printer', 'jean'), 24.548201547049615)
# (('printer', 'kindly', 'remembered'), 24.548201547049615)
# (('printer', 'chug', 'gallon'), 24.226273452162253)
# (('pcl', 'fontsthis', 'printer'), 23.96323904632846)
# (('printer', 'screeched', 'horribly'), 23.96323904632846)
# (('snazzier', 'printer', 'featuring'), 23.96323904632846)
# (('thissamsung', 'printer', 'fw'), 23.96323904632846)
# (('humble', 'printer', 'devoid'), 23.740846624992013)
# (('unplugging', 'printer', 'replugging'), 23.226273452162253)
# (('funky', 'java', 'printer'), 22.96323904632846)
# (('contemporary', 'inket', 'printer'), 22.548201547049615)
# (('vengeful', 'printer', 'god'), 22.548201547049615)
# (('printer', 'inspires', 'confidence'), 22.460738705799276)
# (('multipack', 'cmyblack', 'printer'), 22.378276545607303)
# (('daisy', 'wheel', 'printer'), 22.226273452162253)
# (('printer', 'thereby', 'soaking'), 22.226273452162253)
# (('anaemic', 'printer', 'bundle'), 22.155884124270855)
# (('producting', 'lesser', 'printer'), 22.024639590992603)
# (('startling', 'transition', 'printer'), 21.96323904632846)
# (('printer', 'debbie', 'lee'), 21.933491702934408)
# (('printer', 'galaxy', 'captivate'), 21.740846624992013)
# (('wicked', 'former', 'printer'), 21.6413109514411)
# (('envy', 'printer', 'andsamsung'), 21.548201547049615)
# (('unlikehp', 'envy', 'printer'), 21.548201547049615)
# (('akodak', 'esp', 'printer'), 21.503807427691164)
# (('printer', 'developed', 'radiance'), 21.503807427691164)
# (('printer', 'ugly', 'stepsister'), 21.30027403360603)
# (('printer', 'cmyk', 'deter'), 21.226273452162253)
# (('printer', 'reveals', 'defined'), 21.08876992841232)
# (('printer', 'began', 'clattering'), 21.024639590992603)
# (('printer', 'hostage', 'till'), 21.024639590992603)
# (('printer', 'animated', 'tutorial'), 20.90434535727489)
# (('printer', 'helpfully', 'beep'), 20.79331404488615)
# (('printer', 'causing', 'lockup'), 20.740846624992013)
# (('printer', 'konica', 'minolta'), 20.5709216235497)
# (('printer', 'sends', 'anonymous'), 20.503807427691164)
# (('attention', 'printer', 'usersthis'), 20.41891853010465)
# (('capacityblack', 'printer', 'durabrite'), 20.398454427544934)
# (('cmyblack', 'printer', 'durabrite'), 20.398454427544934)
#
#
# binder
# (('duratech', 'binder', 'violet'), 28.490001019314718)
# (('onestorex', 'duratech', 'binder'), 28.490001019314718)
# (('thesestorex', 'duratech', 'binder'), 28.490001019314718)
# (('fivestar', 'zipped', 'binder'), 25.682646097257113)
# (('ballet', 'horse', 'binder'), 24.5831104237062)
# (('adult', 'binder', 'standout'), 24.40253817806438)
# (('simplify', 'binder', 'titling'), 24.20459880045247)
# (('troublesome', 'protruding', 'binder'), 23.90503851859356)
# (('seuss', 'binder', 'classroom'), 23.40253817806438)
# (('binder', 'round', 'ringswilson'), 22.413185422263886)
# (('mead', 'zipper', 'binder'), 22.21387661404048)
# (('binder', 'violet', 'spine'), 21.32509409263903)
# (('fanatastic', 'binder', 'wish'), 21.285429875065514)
# (('simplify', 'binder', 'labeling'), 21.250402490065593)
# (('binder', 'apparatus', 'sits'), 21.232613176622067)
# (('theavery', 'economy', 'binder'), 21.20459880045247)
# (('binder', 'super', 'bummed'), 21.1457051113989)
# (('sewn', 'binder', 'round'), 20.95375380362659)
# (('comb', 'binder', 'starlet'), 20.882670705565108)
# (('professional', 'binder', 'velo'), 20.803500492131498)
# (('avery', 'binder', 'shrunk'), 20.619636299731315)
# (('binder', 'olympics', 'close'), 20.47041029095684)
# (('binder', 'endure', 'frequent'), 20.381476562536548)
# (('silhouette', 'view', 'binder'), 20.29770820484395)
# (('recycled', 'bliss', 'binder'), 20.19079300092744)
# (('spine', 'simplify', 'binder'), 19.9465824693853)
# (('wilson', 'jones', 'binder'), 19.851037239480014)
# (('fellowes', 'binder', 'video'), 19.849756083092373)
# (('priced', 'binder', 'looseleaf'), 19.75529139908888)
# (('binder', 'felt', 'floppy'), 19.633575490689186)
# (('medal', 'ring', 'binder'), 19.54602110497098)
# (('visible', 'binder', 'host'), 19.49564758245586)
# (('each', 'timeflexible', 'binder'), 19.48859282492191)
# (('wj', 'binder', 'ultra'), 19.406521691982878)
# (('vinyl', 'binder', 'extensively'), 19.381476562536548)
# (('binder', 'clip', 'operated'), 19.358144058705925)
# (('their', 'binder', 'closeing'), 19.311336168308245)
# (('their', 'seuss', 'binder'), 19.311336168308245)
# (('bliss', 'binder', 'round'), 19.091257327376525)
# (('overflowing', 'school', 'binder'), 19.07214850442882)
# (('recipe', 'food', 'binder'), 19.053289477177504)
# (('corrugated', 'cardboard', 'binder'), 19.031594406078185)
# (('cost', 'fanatastic', 'binder'), 18.868864906040077)
# (('sturdily', 'built', 'binder'), 18.864292176250252)
# (('binder', 'arrived', 'warped'), 18.85882396361074)
# (('ledger', 'binder', 'inch'), 18.769329232489163)
# (('especially', 'destroys', 'binder'), 18.74769158323072)
# (('cheapest', 'economy', 'binder'), 18.712745704122796)
# (('school', 'aged', 'binder'), 18.657111005149975)
# (('binder', 'contain', 'pvc'), 18.632797547806554)
#
#
# dispenser
# (('dispenser', 'silvertech', 'shoe'), 26.71235250674542)
# (('silvertech', 'shoe', 'dispenser'), 26.71235250674542)
# (('jetson', 'cubicle', 'dispenser'), 26.44931810091163)
# (('dispenser', 'tartan', 'pistol'), 25.71235250674542)
# (('dispenser', 'um', 'indispensable'), 25.641963178854024)
# (('dispenser', 'devidoir', 'designer'), 24.946817760382444)
# (('collection', 'dispenser', 'devidoir'), 24.608015846930687)
# (('pepto', 'pink', 'dispenser'), 23.22692567957518)
# (('dispenser', 'infor', 'sealing'), 22.968191411175013)
# (('refilable', 'weighted', 'dispenser'), 22.968191411175013)
# (('fancier', 'handled', 'dispenser'), 22.90499758468782)
# (('refillable', 'deskgrip', 'dispenser'), 22.404923981553175)
# (('scotch', 'dispenser', 'alleviates'), 21.730499853455683)
# (('basicbandit', 'dispenser', 'due'), 21.707851114510483)
# (('pebble', 'collection', 'dispenser'), 21.608015846930687)
# (('dispenser', 'cut', 'extrememly'), 21.35480050212734)
# (('dispenser', 'incategory', 'power'), 21.217296978377405)
# (('implement', 'equally', 'dispenser'), 21.191930258218978)
# (('dispenser', 'attache', 'firmly'), 21.08883676525487)
# (('dispenser', 'bottomthe', 'bottom'), 20.976288878873607)
# (('dispenser', 'especially', 'whenwrapping'), 20.87693366626994)
# (('plus', 'anote', 'dispenser'), 20.837063908522733)
# (('dispenser', 'us', 'tapeinstead'), 20.641963178854024)
# (('giftwrap', 'dispenser', 'along'), 20.512680161909056)
# (('tried', 'mannnny', 'dispenser'), 20.358323568691034)
# (('lime', 'green', 'dispenser'), 20.333840883491693)
# (('pistol', 'style', 'dispenser'), 20.220499410415748)
# (('sealing', 'dispenser', 'food'), 20.160836489117408)
# (('encircled', 'each', 'dispenser'), 20.032872407239974)
# (('carton', 'sealing', 'dispenser'), 19.880728569924674)
# (('dispenser', 'delivers', 'precut'), 19.62807559621393)
# (('dispenser', 'such', 'asscotch'), 19.556522335188898)
# (('contour', 'dispenser', 'refill'), 19.54543625517545)
# (('roll', 'dispenser', 'ymmv'), 19.466324526217317)
# (('handband', 'dispenser', 'eliminates'), 19.419570757517576)
# (('headband', 'dispenser', 'might'), 19.41589509937418)
# (('traditional', 'dispenser', 'ending'), 19.414977646217096)
# (('dispenser', 'loses', 'suction'), 19.36185525966129)
# (('handband', 'dispenser', 'dispenses'), 19.29028774057261)
# (('deskgrip', 'dispenser', 'wow'), 19.199809551648563)
# (('dispenser', 'dispenses', 'equal'), 19.17707713012462)
# (('dispenser', 'once', 'dialed'), 19.096171275413546)
# (('anote', 'dispenser', 'because'), 18.951466263960512)
# (('vertical', 'dispenser', 'split'), 18.941523460712933)
# (('round', 'dispenser', 'attache'), 18.870002163331613)
# (('hefty', 'weighted', 'dispenser'), 18.838908394230046)
# (('handy', 'dandy', 'dispenser'), 18.61326774585356)
# (('popup', 'handband', 'dispenser'), 18.61221583545997)
# (('dispenser', 'by', 'karim'), 18.55796835619888)
# (('dispensingthis', 'dispenser', 'tape'), 18.51218953274572)
#
#
# folder
# (('notorious', 'nesting', 'folder'), 27.152925098131405)
# (('brights', 'partition', 'folder'), 25.567962597410247)
# (('folder', 'webdav', 'evernote'), 24.294944103003832)
# (('coloful', 'folder', 'labeled'), 23.567962597410247)
# (('folder', 'thereby', 'exposing'), 23.246034502522885)
# (('classification', 'partition', 'folder'), 22.983000096689093)
# (('erasablesupertab', 'folder', 'assorted'), 22.983000096689093)
# (('ix', 'vertical', 'folder'), 22.867522879269156)
# (('sizeeach', 'folder', 'measure'), 22.867522879269156)
# (('subertab', 'heavyweight', 'folder'), 22.693493479494105)
# (('misplace', 'folder', 'struck'), 22.661072001801728)
# (('supertab', 'superheavyweight', 'folder'), 22.509068908356678)
# (('invention', 'handing', 'folder'), 22.480499756159908)
# (('manilla', 'folder', 'resting'), 22.210410592792165)
# (('dcim', 'folder', 'common'), 22.152925098131405)
# (('brighter', 'folder', 'rail'), 21.983000096689093)
# (('cutless', 'folder', 'hmmm'), 21.983000096689093)
# (('folder', 'con', 'nonetotally'), 21.963100539251386)
# (('sunrise', 'colored', 'folder'), 21.963100539251386)
# (('reuse', 'folder', 'handwrite'), 21.76060767535264)
# (('semicircular', 'folder', 'flap'), 21.677191667165005)
# (('ordinary', 'pocketed', 'folder'), 21.637225259847362)
# (('thia', 'manila', 'folder'), 21.49471361537961)
# (('jones', 'snapper', 'folder'), 21.404732248541944)
# (('web', 'folder', 'webdav'), 20.97301600811647)
# (('andsmead', 'supertab', 'folder'), 20.924106407635524)
# (('nesting', 'folder', 'within'), 20.876800692857167)
# (('subtopic', 'folder', 'within'), 20.876800692857167)
# (('final', 'annual', 'folder'), 20.701713986299076)
# (('snapper', 'folder', 'wilson'), 20.677191667165005)
# (('supertab', 'lockit', 'folder'), 20.583069489800454)
# (('separating', 'folder', 'visually'), 20.567962597410247)
# (('course', 'lolthese', 'folder'), 20.44211866443205)
# (('erasablefastab', 'hanging', 'folder'), 20.391373865686923)
# (('thatsmead', 'hanging', 'folder'), 20.391373865686923)
# (('folder', 'appeared', 'functionally'), 20.371565384606743)
# (('supertab', 'heavyweight', 'folder'), 20.04963728971938)
# (('valuable', 'enhanced', 'folder'), 19.9981069890793)
# (('folder', 'encourage', 'organization'), 19.90499758468782)
# (('practical', 'folder', 'represent'), 19.867522879269156)
# (('tuff', 'hanging', 'folder'), 19.80641136496577)
# (('folder', 'three', 'tabbled'), 19.782237691324188)
# (('three', 'subtopic', 'folder'), 19.782237691324188)
# (('excellently', 'constructed', 'folder'), 19.739297169107232)
# (('traditional', 'handing', 'folder'), 19.649099360135654)
# (('folder', 'strong', 'tyvek'), 19.643150093804465)
# (('brightly', 'colored', 'folder'), 19.641172444364024)
# (('ampad', 'comparison', 'folder'), 19.631324658407678)
# (('folder', 'shall', 'become'), 19.57360916055139)
# (('manila', 'folder', 'reveals'), 19.49471361537961)
#
#
# stapler
# (('viet', 'nam', 'stapler'), 29.584912666340188)
# (('nonelectric', 'stapler', 'balk'), 28.584912666340188)
# (('oakland', 'athletics', 'stapler'), 27.262984571452822)
# (('ergonomicsthe', 'stapler', 'earns'), 26.777557744282582)
# (('stapler', 'boasting', 'ruler'), 26.414987664897872)
# (('rotating', 'stapler', 'crimp'), 25.192595243561424)
# (('excessively', 'sparkly', 'stapler'), 24.777557744282582)
# (('mistaking', 'whose', 'stapler'), 24.72693167121261)
# (('boring', 'unicolored', 'stapler'), 24.584912666340184)
# (('simplee', 'stapler', 'remains'), 24.299510447477935)
# (('thanswingline', 'optimum', 'stapler'), 24.09305957001051)
# (('lived', 'stapler', 'imaginable'), 23.99995016561903)
# (('stapler', 'stealing', 'freak'), 23.777557744282582)
# (('paperpro', 'prodigy', 'stapler'), 23.642398161000944)
# (('stapler', 'crimp', 'plate'), 23.60763274284027)
# (('oldswingline', 'classic', 'stapler'), 23.56254485331173)
# (('smoothgrip', 'handheld', 'stapler'), 23.476388209562018)
# (('stapler', 'smoothgrip', 'handheld'), 23.476388209562018)
# (('stapler', 'reduced', 'effortwith'), 23.09305957001051)
# (('stapler', 'partially', 'depressed'), 22.91248732436869)
# (('stapler', 'picky', 'spouse'), 22.91248732436869)
# (('search', 'forswingline', 'stapler'), 22.830025164176718)
# (('polished', 'chrome', 'stapler'), 22.318126125645282)
# (('stapler', 'circa', 'late'), 22.262984571452822)
# (('stapler', 'particularly', 'theirclassic'), 22.201208373866134)
# (('stapler', 'leaning', 'towards'), 22.158647911638088)
# (('bulge', 'max', 'stapler'), 21.884472948199093)
# (('coveted', 'red', 'stapler'), 21.636545434755508)
# (('standby', 'stapler', 'rio'), 21.584912666340184)
# (('customizable', 'fashion', 'stapler'), 21.436181887166995)
# (('bling', 'fashion', 'stapler'), 21.411235530036766)
# (('figure', 'ergonomicsthe', 'stapler'), 21.390155811917936)
# (('theswingline', 'smarttouch', 'stapler'), 21.218590452094368)
# (('stapler', 'theswingline', 'lighttouch'), 21.133701554507855)
# (('doggone', 'desktop', 'stapler'), 20.89142570884086)
# (('stanley', 'bostitch', 'stapler'), 20.85359363531512)
# (('customizeable', 'stapler', 'handle'), 20.846820406719694)
# (('stapler', 'ez', 'squeeze'), 20.84007882884064)
# (('consider', 'thepaperpro', 'stapler'), 20.60763274284027)
# (('stapler', 'capacity', 'ecofriendly'), 20.318126125645282)
# (('stapler', 'perhaps', 'lugging'), 20.306463208119702)
# (('theswingline', 'classic', 'stapler'), 20.24061675842437)
# (('mass', 'producing', 'stapler'), 20.139897820471763)
# (('sleek', 'stapler', 'airplane'), 20.105132402311085)
# (('pink', 'ribbon', 'stapler'), 20.077118026141488)
# (('stapler', 'absolutely', 'crush'), 20.030323814662548)
# (('pathetic', 'lightweight', 'stapler'), 19.977582352590574)
# (('conventional', 'stapler', 'anytime'), 19.851897344654223)
# (('classic', 'stapler', 'introduced'), 19.755189931254126)
# (('electric', 'stapler', 'sounded'), 19.74728473316878)
#
#
# calculator
# (('protractor', 'calculator', 'swatch'), 29.993320281953014)
# (('calculator', 'amortization', 'depreciation'), 29.408357781231857)
# (('rpn', 'scienfitic', 'calculator'), 25.86403726500805)
# (('calculator', 'mv', 'lacked'), 25.671392187065653)
# (('handheld', 'surviving', 'calculator'), 25.469758325896002)
# (('calculator', 'swatch', 'paint'), 25.185965359895413)
# (('nicest', 'coolest', 'calculator'), 25.185965359895413)
# (('solver', 'financial', 'calculator'), 24.884795825174848)
# (('ban', 'graphing', 'calculator'), 24.726533741258113)
# (('singapore', 'produced', 'calculator'), 24.469758325896002)
# (('pencil', 'protractor', 'calculator'), 24.03912397156614)
# (('solarand', 'battery', 'calculator'), 23.916504684902183)
# (('deepest', 'financial', 'calculator'), 23.884795825174848)
# (('calculator', 'david', 'wilson'), 23.517586850986618)
# (('calculator', 's', 'cps'), 23.356695661409365)
# (('calculator', 'multiview', 'fails'), 23.19890441560291)
# (('texas', 'instrument', 'calculator'), 22.97651199426646)
# (('aurora', 'solar', 'calculator'), 22.905857440702675)
# (('multiview', 'scientific', 'calculator'), 22.431077857731943)
# (('superior', 'calculator', 'mv'), 22.238432779789548)
# (('calculator', 'manufacturer', 'replacable'), 22.104577033054756)
# (('aa', 'powered', 'calculator'), 21.96541428538313)
# (('whole', 'calculator', 'premise'), 21.879578115903826)
# (('ti', 'calculator', 'aos'), 21.864037265008047)
# (('programmable', 'scientific', 'calculator'), 21.846115357010788)
# (('calculator', 'thank', 'goodness'), 21.823395280510702)
# (('calculator', 'gum', 'stuff'), 21.754915542627938)
# (('manual', 'calculator', 'david'), 21.717195876678776)
# (('calculator', 'gold', 'anniversary'), 21.700998649150975)
# (('scientific', 'calculator', 'cousin'), 21.694112263565735)
# (('calculator', 'thus', 'supremely'), 21.53184083466686)
# (('calculator', 'sits', 'snugly'), 21.513540017923916)
# (('handheld', 'calculator', 'production'), 21.382295484645663)
# (('casio', 'scientific', 'calculator'), 21.3476618495443)
# (('keyed', 'calculator', 'under'), 21.211960568428356)
# (('enough', 'therethe', 'calculator'), 20.940752231148863)
# (('calculator', 'ruler', 'pencil'), 20.86919897012383)
# (('old', 'calculator', 'scientifics'), 20.81341119193808)
# (('confirms', 'plus', 'calculator'), 20.796103588842964)
# (('aa', 'battery', 'calculator'), 20.74657968345987)
# (('calculator', 'measuring', 'roughly'), 20.717195876678776)
# (('exam', 'scientific', 'calculator'), 20.694112263565735)
# (('phone', 'calculator', 'gum'), 20.577578513662925)
# (('calculator', 'arrived', 'promptly'), 20.47762044366897)
# (('graphing', 'calculator', 'measuring'), 20.40460564637075)
# (('calculator', 'premise', 'feel'), 20.363963661873406)
# (('calculator', 'differs', 'slightly'), 20.30944841333041)
# (('ti', 'graphing', 'calculator'), 20.182213225034303)
# (('calculator', 'include', 'arithmetic'), 20.1667717946621)
# (('calculator', 'function', 'ln'), 20.158849231968794)

# %% [markdown]
# ### likelihood_ratio

# %%
lr_trigrams = {'printer':[], 'binder':[], 'dispenser':[], 'folder':[], 'stapler':[], 'calculator':[]}

for trigram in finder_3.score_ngrams(trigram_measures.likelihood_ratio):
    for product in product_names:
        if (product in trigram[0] and trigram[0][0] != trigram[0][1] and trigram[0][1] != trigram[0][2]):
            lr_trigrams[product].append(trigram)

# %%
for product in product_names:
    print(product) 
    for trigram in lr_trigrams[product][0:50]:
        print(trigram)
    print('\n')
# Out:
# printer
# (('printer', 'if', 'you'), 24299.351551983418)
# (('of', 'the', 'printer'), 23365.06701390706)
# (('on', 'the', 'printer'), 23111.311427881377)
# (('the', 'printer', 'of'), 19440.504218693706)
# (('in', 'the', 'printer'), 19008.486693660565)
# (('this', 'printer', 'is'), 18489.028854459677)
# (('i', 'the', 'printer'), 17676.339986297968)
# (('the', 'printer', 'is'), 17348.18532206544)
# (('with', 'the', 'printer'), 17238.227041105678)
# (('with', 'this', 'printer'), 16713.136398989598)
# (('this', 'printer', 'a'), 16250.915896174745)
# (('a', 'the', 'printer'), 15836.9119371161)
# (('the', 'this', 'printer'), 15765.720420314672)
# (('i', 'this', 'printer'), 15683.060721120986)
# (('recommend', 'this', 'printer'), 15661.682405165733)
# (('a', 'this', 'printer'), 15641.65251967662)
# (('the', 'printer', 'the'), 15637.795350594499)
# (('i', 'have', 'printer'), 15577.318982224402)
# (('from', 'the', 'printer'), 15556.714169621282)
# (('of', 'this', 'printer'), 15236.17325879713)
# (('printer', 'i', 'have'), 15221.807530271828)
# (('this', 'printer', 'ha'), 15131.060014385068)
# (('it', 'the', 'printer'), 15073.93857590984)
# (('it', 'this', 'printer'), 14858.637550310665)
# (('this', 'printer', 'for'), 14807.13032670673)
# (('the', 'printer', 'a'), 14804.652736860568)
# (('bought', 'this', 'printer'), 14774.375257457305)
# (('using', 'this', 'printer'), 14678.871443645257)
# (('this', 'printer', 'doe'), 14652.102496978672)
# (('on', 'this', 'printer'), 14633.545836969)
# (('love', 'this', 'printer'), 14589.215176242)
# (('use', 'this', 'printer'), 14574.117867165922)
# (('this', 'printer', 'i'), 14553.948753223714)
# (('like', 'this', 'printer'), 14548.049733996766)
# (('about', 'this', 'printer'), 14545.873273182357)
# (('this', 'printer', 'and'), 14536.020548599101)
# (('is', 'this', 'printer'), 14520.644054171917)
# (('you', 'this', 'printer'), 14505.470597027763)
# (('this', 'printer', 'itself'), 14454.94401759138)
# (('this', 'printer', 'that'), 14443.28829566127)
# (('this', 'printer', 'be'), 14395.768107670814)
# (('this', 'the', 'printer'), 14357.136682232393)
# (('this', 'printer', 'the'), 14356.243956122751)
# (('got', 'this', 'printer'), 14349.806826314812)
# (('my', 'the', 'printer'), 14338.2372017415)
# (('this', 'printer', 'wa'), 14324.64141775135)
# (('for', 'this', 'printer'), 14313.79658214793)
# (('for', 'the', 'printer'), 14310.425223742906)
# (('this', 'printer', 'of'), 14299.325629158455)
# (('this', 'printer', 'not'), 14268.659629203012)
#
#
# binder
# (('binder', 'if', 'you'), 24247.028292316194)
# (('binder', 'i', 'have'), 14551.246051304739)
# (('binder', 'you', 'can'), 13947.355219388359)
# (('easy', 'to', 'binder'), 11376.443740593375)
# (('of', 'the', 'binder'), 11359.231144969566)
# (('on', 'the', 'binder'), 11128.086492541788)
# (('binder', 'of', 'the'), 10465.596639925465)
# (('binder', 'on', 'the'), 10379.942153445423)
# (('binder', 'a', 'lot'), 9981.361098494872)
# (('binder', 'this', 'is'), 9886.803661922566)
# (('lot', 'of', 'binder'), 9746.918430901898)
# (('binder', 'i', 'am'), 8603.044644928686)
# (('binder', 'is', 'a'), 8324.444935978185)
# (('binder', 'to', 'be'), 8282.097214392712)
# (('is', 'a', 'binder'), 7876.872482616914)
# (('binder', 'i', 'had'), 7542.580953435501)
# (('i', 'had', 'binder'), 7510.2957497652305)
# (('binder', 'it', 'is'), 7368.695982896903)
# (('to', 'use', 'binder'), 7099.413413019345)
# (('binder', 'to', 'use'), 7089.818762466234)
# (('in', 'the', 'binder'), 6971.039138963773)
# (('the', 'binder', 'of'), 6652.08104743775)
# (('a', 'few', 'binder'), 6466.276273512873)
# (('binder', 'in', 'the'), 6267.369267911699)
# (('the', 'same', 'binder'), 5946.043012364165)
# (('binder', 'i', 'wa'), 5718.631469797748)
# (('binder', 'they', 'are'), 5606.475891950784)
# (('binder', 'i', 'do'), 5563.311842151939)
# (('a', 'binder', 'of'), 5516.891250742578)
# (('there', 'are', 'binder'), 5308.461609641732)
# (('binder', 'there', 'are'), 5290.527631996921)
# (('binder', 'it', 'doe'), 5099.003028286981)
# (('binder', 'a', 'little'), 5067.27523054724)
# (('binder', 'can', 'be'), 4753.236219938128)
# (('this', 'binder', 'is'), 4714.182439476101)
# (('binder', 'have', 'been'), 4546.767420177321)
# (('binder', 'i', 'did'), 4534.459596026869)
# (('binder', 'there', 'is'), 4518.176098282795)
# (('more', 'than', 'binder'), 4472.707437026542)
# (('binder', 'would', 'be'), 4469.102603051804)
# (('with', 'the', 'binder'), 4416.188216200492)
# (('heavy', 'duty', 'binder'), 4353.66920211152)
# (('binder', 'i', 'would'), 4324.927020560689)
# (('binder', 'to', 'get'), 4265.840768878797)
# (('come', 'with', 'binder'), 4219.681128625892)
# (('binder', 'come', 'with'), 4209.99724433332)
# (('binder', 'heavy', 'duty'), 4009.3877611554517)
# (('binder', 'you', 'want'), 4002.8009261525167)
# (('a', 'good', 'binder'), 3987.5454010801122)
# (('out', 'of', 'binder'), 3874.153315265896)
#
#
# dispenser
# (('dispenser', 'if', 'you'), 24241.4464383519)
# (('dispenser', 'i', 'have'), 14475.580184865094)
# (('dispenser', 'you', 'can'), 13925.005083420692)
# (('of', 'the', 'dispenser'), 11427.737431608915)
# (('on', 'the', 'dispenser'), 11346.164379163489)
# (('dispenser', 'easy', 'to'), 11217.571402408572)
# (('dispenser', 'of', 'the'), 10483.095611179242)
# (('dispenser', 'on', 'the'), 10382.03088269165)
# (('this', 'is', 'dispenser'), 10073.310003611561)
# (('dispenser', 'a', 'lot'), 9958.465179006058)
# (('dispenser', 'this', 'is'), 9860.826022747804)
# (('lot', 'of', 'dispenser'), 9719.94376694075)
# (('dispenser', 'i', 'am'), 8534.359649590715)
# (('dispenser', 'is', 'a'), 8451.088538585087)
# (('dispenser', 'to', 'be'), 8276.152943812283)
# (('is', 'a', 'dispenser'), 7783.065948579093)
# (('dispenser', 'i', 'had'), 7473.755479889072)
# (('it', 'is', 'dispenser'), 7410.286175248381)
# (('dispenser', 'it', 'is'), 7368.428557459374)
# (('in', 'the', 'dispenser'), 7192.287623308124)
# (('to', 'use', 'dispenser'), 7117.845412921508)
# (('dispenser', 'to', 'use'), 7071.820831110892)
# (('dispenser', 'in', 'the'), 6260.732790660482)
# (('of', 'tape', 'dispenser'), 5764.159375037841)
# (('dispenser', 'i', 'wa'), 5646.532060939093)
# (('dispenser', 'they', 'are'), 5602.566673526199)
# (('dispenser', 'i', 'do'), 5494.045162950282)
# (('dispenser', 'need', 'to'), 5442.112883101172)
# (('a', 'dispenser', 'of'), 5428.360088979428)
# (('i', 'the', 'dispenser'), 5409.161450591795)
# (('dispenser', 'there', 'are'), 5275.069339933541)
# (('the', 'tape', 'dispenser'), 5237.011265538593)
# (('scotch', 'tape', 'dispenser'), 5188.561210733)
# (('a', 'little', 'dispenser'), 5164.994813373353)
# (('dispenser', 'a', 'little'), 5043.471602101619)
# (('packing', 'tape', 'dispenser'), 4886.160428556312)
# (('dispenser', 'can', 'be'), 4758.573626012362)
# (('tape', 'dispenser', 'is'), 4688.806423927442)
# (('with', 'the', 'dispenser'), 4665.460151153755)
# (('packaging', 'tape', 'dispenser'), 4565.639399255164)
# (('i', 'did', 'dispenser'), 4515.417517649546)
# (('dispenser', 'i', 'did'), 4467.395364136835)
# (('dispenser', 'would', 'be'), 4464.299112965097)
# (('dispenser', 'more', 'than'), 4462.008218609582)
# (('popup', 'tape', 'dispenser'), 4446.6022563779225)
# (('sealing', 'tape', 'dispenser'), 4439.583622053566)
# (('dispenser', 'to', 'get'), 4262.0669159260215)
# (('dispenser', 'i', 'would'), 4245.592478501073)
# (('dispenser', 'come', 'with'), 4232.890161924393)
# (('this', 'tape', 'dispenser'), 4192.520042341448)
#
#
# folder
# (('folder', 'if', 'you'), 24244.069578719376)
# (('folder', 'i', 'have'), 14540.994534996611)
# (('folder', 'you', 'can'), 13938.090699256401)
# (('the', 'printer', 'folder'), 12707.042405955684)
# (('of', 'the', 'folder'), 11738.520471252286)
# (('on', 'the', 'folder'), 11280.68033824527)
# (('folder', 'easy', 'to'), 11245.387541221586)
# (('folder', 'of', 'the'), 10501.586281311373)
# (('folder', 'on', 'the'), 10380.353143479037)
# (('folder', 'a', 'lot'), 10003.160374520323)
# (('folder', 'this', 'is'), 9840.972880700054)
# (('lot', 'of', 'folder'), 9720.365250152561)
# (('folder', 'i', 'am'), 8573.149932036396)
# (('folder', 'to', 'be'), 8306.264665765526)
# (('is', 'a', 'folder'), 7842.472640014757)
# (('folder', 'is', 'a'), 7819.850548227807)
# (('folder', 'i', 'had'), 7523.4318238029555)
# (('folder', 'it', 'is'), 7361.20168675414)
# (('in', 'the', 'folder'), 7149.192412719782)
# (('to', 'use', 'folder'), 7124.901390290779)
# (('folder', 'to', 'use'), 7072.918074795111)
# (('folder', 'a', 'bit'), 7072.659327991247)
# (('the', 'folder', 'of'), 6875.892847001048)
# (('file', 'folder', 'are'), 6434.790856893812)
# (('folder', 'in', 'the'), 6333.743930577329)
# (('folder', 'they', 'are'), 5948.004826321472)
# (('the', 'same', 'folder'), 5939.977136586699)
# (('hanging', 'file', 'folder'), 5843.396505931017)
# (('folder', 'i', 'wa'), 5703.852545731913)
# (('they', 'are', 'folder'), 5615.2193519626835)
# (('these', 'file', 'folder'), 5546.32603320173)
# (('folder', 'i', 'do'), 5536.986090995151)
# (('folder', 'there', 'are'), 5507.134050497003)
# (('folder', 'need', 'to'), 5468.460001823532)
# (('of', 'file', 'folder'), 5433.370314778922)
# (('there', 'are', 'folder'), 5294.763718679399)
# (('smead', 'file', 'folder'), 5229.046650061157)
# (('folder', 'it', 'doe'), 5125.315759003401)
# (('folder', 'a', 'little'), 5091.359245840394)
# (('supertab', 'file', 'folder'), 5075.705496755287)
# (('standard', 'file', 'folder'), 5063.539876823331)
# (('manila', 'file', 'folder'), 5044.575976110262)
# (('file', 'folder', 'they'), 5033.949999633848)
# (('regular', 'file', 'folder'), 5005.636218378982)
# (('file', 'folder', 'these'), 4981.929054533135)
# (('i', 'file', 'folder'), 4968.644914828366)
# (('it', 'file', 'folder'), 4966.594934403797)
# (('my', 'file', 'folder'), 4960.378271976837)
# (('fastab', 'file', 'folder'), 4951.015654367814)
# (('heavyweight', 'file', 'folder'), 4948.670122976762)
#
#
# stapler
# (('stapler', 'if', 'you'), 24241.41591276879)
# (('stapler', 'i', 'have'), 14573.792606716386)
# (('stapler', 'you', 'can'), 13939.639014470187)
# (('stapler', 'easy', 'to'), 11255.462765134984)
# (('of', 'the', 'stapler'), 11176.0045984994)
# (('on', 'the', 'stapler'), 11047.333392984088)
# (('stapler', 'of', 'the'), 10485.569299056202)
# (('stapler', 'on', 'the'), 10377.30044026743)
# (('stapler', 'a', 'lot'), 9977.95858435833)
# (('this', 'is', 'stapler'), 9908.990778213763)
# (('stapler', 'this', 'is'), 9875.443840903632)
# (('stapler', 'lot', 'of'), 9743.093878824875)
# (('lot', 'of', 'stapler'), 9721.332699297218)
# (('stapler', 'i', 'am'), 8620.593813608193)
# (('stapler', 'to', 'be'), 8269.626987144533)
# (('stapler', 'is', 'a'), 8192.69431627688)
# (('is', 'a', 'stapler'), 7882.839680012262)
# (('i', 'had', 'stapler'), 7565.234637459483)
# (('stapler', 'i', 'had'), 7564.426427793435)
# (('stapler', 'it', 'is'), 7398.39920520224)
# (('to', 'use', 'stapler'), 7095.807613098625)
# (('stapler', 'to', 'use'), 7072.24486197151)
# (('stapler', 'a', 'bit'), 7043.246561711018)
# (('in', 'the', 'stapler'), 6918.873053095127)
# (('the', 'stapler', 'of'), 6613.2244511544395)
# (('a', 'few', 'stapler'), 6529.253757828106)
# (('stapler', 'in', 'the'), 6259.178094921965)
# (('the', 'same', 'stapler'), 5951.388040815177)
# (('stapler', 'i', 'wa'), 5736.201860556321)
# (('stapler', 'i', 'do'), 5585.256639776257)
# (('a', 'stapler', 'of'), 5538.964896565681)
# (('stapler', 'need', 'to'), 5482.513788662436)
# (('stapler', 'there', 'are'), 5277.299938463562)
# (('a', 'little', 'stapler'), 5206.080776716202)
# (('stapler', 'it', 'doe'), 5121.569487771774)
# (('stapler', 'can', 'be'), 4754.615741782924)
# (('this', 'stapler', 'is'), 4728.743313056932)
# (('stapler', 'have', 'been'), 4569.952396600582)
# (('stapler', 'i', 'did'), 4563.198012331366)
# (('stapler', 'at', 'least'), 4531.329864057539)
# (('stapler', 'there', 'is'), 4518.100687864335)
# (('at', 'least', 'stapler'), 4514.468787485992)
# (('stapler', 'more', 'than'), 4469.147081989377)
# (('stapler', 'would', 'be'), 4458.2924523650945)
# (('with', 'the', 'stapler'), 4424.279941514731)
# (('stapler', 'i', 'would'), 4333.943849456016)
# (('stapler', 'you', 'need'), 4333.35385930741)
# (('to', 'get', 'stapler'), 4292.922875546998)
# (('stapler', 'to', 'get'), 4267.001904393169)
# (('stapler', 'come', 'with'), 4243.613912158224)
#
#
# calculator
# (('calculator', 'if', 'you'), 24234.183339180876)
# (('calculator', 'i', 'have'), 14468.92999069646)
# (('calculator', 'you', 'can'), 13927.34912743724)
# (('of', 'the', 'calculator'), 10651.443748179825)
# (('on', 'the', 'calculator'), 10549.991824610825)
# (('calculator', 'of', 'the'), 10463.810707213144)
# (('calculator', 'on', 'the'), 10376.182845415082)
# (('calculator', 'this', 'is'), 9854.836176278413)
# (('lot', 'of', 'calculator'), 9720.646315907545)
# (('calculator', 'i', 'am'), 8524.117168401892)
# (('calculator', 'to', 'be'), 8266.80559407345)
# (('calculator', 'is', 'a'), 7875.685685680473)
# (('is', 'a', 'calculator'), 7787.599066208651)
# (('calculator', 'i', 'had'), 7465.032765091943)
# (('calculator', 'it', 'is'), 7327.7498030182)
# (('to', 'use', 'calculator'), 7087.701094050129)
# (('calculator', 'to', 'use'), 7077.728439913099)
# (('a', 'few', 'calculator'), 6442.207361729314)
# (('in', 'the', 'calculator'), 6399.8199966957345)
# (('calculator', 'in', 'the'), 6259.98663137595)
# (('the', 'calculator', 'of'), 6076.412068000945)
# (('calculator', 'the', 'same'), 5951.248785521335)
# (('the', 'same', 'calculator'), 5945.153754882914)
# (('calculator', 'i', 'wa'), 5641.037919228058)
# (('they', 'are', 'calculator'), 5616.666217975444)
# (('calculator', 'they', 'are'), 5606.04630221148)
# (('calculator', 'i', 'do'), 5492.156514697235)
# (('a', 'calculator', 'of'), 5437.489093046831)
# (('calculator', 'it', 'doe'), 5079.63278586554)
# (('calculator', 'can', 'be'), 4752.972173735399)
# (('calculator', 'there', 'is'), 4478.215949621443)
# (('calculator', 'would', 'be'), 4453.188839645953)
# (('calculator', 'the', 'to'), 4282.797429471643)
# (('calculator', 'come', 'with'), 4211.007992261883)
# (('a', 'good', 'calculator'), 3963.143080156764)
# (('with', 'the', 'calculator'), 3859.407121858417)
# (('calculator', 'doe', 'not'), 3743.99905920336)
# (('calculator', 'with', 'the'), 3701.2018302232786)
# (('calculator', 'i', 'think'), 3554.0671814921875)
# (('calculator', 'which', 'is'), 3548.245936255948)
# (('calculator', 'the', 'and'), 3483.837164339586)
# (('calculator', 'it', 'wa'), 3408.6041058941278)
# (('calculator', 'so', 'i'), 3389.5569497264914)
# (('calculator', 'will', 'be'), 3341.8975759199707)
# (('this', 'calculator', 'is'), 3299.6038086269887)
# (('calculator', 'i', 'can'), 3288.788794247058)
# (('calculator', 'highly', 'recommend'), 3267.5700395543904)
# (('a', 'great', 'calculator'), 3246.979880270986)
# (('calculator', 'for', 'me'), 3216.608498180209)
# (('calculator', 'i', 'love'), 3112.0407735412646)

# %% [markdown]
# Триграммы мне не особо понравились, поэтому выведем только биграммы по каждому товару

# %%
for product in product_names:
    print(product)
    print('---')
    for bi in lr_bigrams[product][:50]:   
        print(' '.join(bi[0]))
    print('\n')
# Out:
# printer
# ---
# laser printer
# inkjet printer
# epson printer
# photo printer
# canon printer
# hp printer
# other printer
# new printer
# wireless printer
# printer itself
# workforce printer
# printer doe
# you printer
# printer wa
# multifunction printer
# jet printer
# brother printer
# great printer
# format printer
# old printer
# have printer
# pixma printer
# not printer
# monochrome printer
# wa printer
# printer driver
# printer copier
# previous printer
# print printer
# paper printer
# be printer
# printer which
# printer us
# your printer
# printer be
# do printer
# printer come
# printer scanner
# home printer
# samsung printer
# they printer
# kodak printer
# out printer
# when printer
# printing printer
# printer folder
# doe printer
# just printer
# printer cable
# very printer
#
#
# binder
# ---
# view binder
# jones binder
# ring binder
# duty binder
# avery binder
# other binder
# zipper binder
# inch binder
# basic binder
# durable binder
# particular binder
# binder clip
# sturdy binder
# binder ring
# white binder
# binder unusable
# quality binder
# you binder
# average binder
# binder itself
# ordinary binder
# binder cover
# nice binder
# vinyl binder
# standard binder
# flexible binder
# strongest binder
# simplify binder
# comb binder
# binder arrived
# polypro binder
# bliss binder
# ledger binder
# great binder
# sewn binder
# have binder
# cheaper binder
# sturdiest binder
# binder seems
# sized binder
# regular binder
# binder instead
# binder feel
# wj binder
# typical binder
# binder hold
# decent binder
# hard binder
# binder should
# binder connoisseur
#
#
# dispenser
# ---
# tape dispenser
# handband dispenser
# note dispenser
# heart dispenser
# deskgrip dispenser
# dispenser tape
# little dispenser
# scotch dispenser
# dispenser itself
# weighted dispenser
# dispenser work
# new dispenser
# plastic dispenser
# you dispenser
# desktop dispenser
# disposable dispenser
# old dispenser
# apple dispenser
# dispenser attache
# dispenser doe
# traditional dispenser
# cute dispenser
# dispenser loses
# dispenser x
# dispenser solves
# reusable dispenser
# dispenser provides
# dispenser which
# purse dispenser
# dispenser come
# industrial dispenser
# refillable dispenser
# handy dispenser
# shoe dispenser
# grip dispenser
# dispenser stick
# dispenser refill
# regular dispenser
# sealing dispenser
# style dispenser
# gun dispenser
# dispenser be
# dispenser have
# paper dispenser
# particular dispenser
# dispenser make
# dispenser packaging
# anote dispenser
# basicbandit dispenser
# bescotch dispenser
#
#
# folder
# ---
# file folder
# hanging folder
# manila folder
# manilla folder
# supertab folder
# each folder
# heavyweight folder
# folder they
# organizer folder
# colored folder
# folder themselves
# smead folder
# tabbed folder
# pocket folder
# printer folder
# regular folder
# folder letter
# fastab folder
# classification folder
# erasable folder
# other folder
# pendaflex folder
# folder tuff
# vertical folder
# standard folder
# folder which
# tab folder
# folder itself
# presentation folder
# red folder
# folder label
# lockit folder
# folder tab
# not folder
# folder without
# green folder
# folder print
# have folder
# repocket folder
# pocketed folder
# cutless folder
# fastener folder
# folder have
# folder come
# ordinary folder
# expansion folder
# sturdy folder
# folder be
# per folder
# folder paper
#
#
# stapler
# ---
# swingline stapler
# electric stapler
# duty stapler
# regular stapler
# standard stapler
# effort stapler
# smarttouch stapler
# classic stapler
# stapler itself
# stapler doe
# old stapler
# red stapler
# fashion stapler
# traditional stapler
# new stapler
# prodigy stapler
# desk stapler
# desktop stapler
# other stapler
# metal stapler
# basic stapler
# great stapler
# handheld stapler
# personalized stapler
# normal stapler
# stapler work
# compact stapler
# optimum stapler
# stapler reduced
# lightweight stapler
# my stapler
# conventional stapler
# not stapler
# best stapler
# bostitch stapler
# stapler arrived
# stapler come
# capacity stapler
# lighttouch stapler
# stapler slapper
# stapler came
# paperpro stapler
# customizable stapler
# stapler which
# ribbon stapler
# mini stapler
# your stapler
# stapler be
# average stapler
# manual stapler
#
#
# calculator
# ---
# graphing calculator
# scientific calculator
# financial calculator
# hp calculator
# casio calculator
# ti calculator
# basic calculator
# calculator gold
# calculator mv
# calculator multiview
# solar calculator
# calculator h
# instrument calculator
# desktop calculator
# pocket calculator
# good calculator
# powered calculator
# calculator which
# classic calculator
# you calculator
# little calculator
# simple calculator
# advanced calculator
# calculator arrived
# new calculator
# h calculator
# handheld calculator
# calculator doe
# pen calculator
# lined calculator
# abasic calculator
# amazonasics calculator
# amazonbasics calculator
# calculator david
# calculator keyset
# calculator scientifics
# casiothis calculator
# forany calculator
# potent calculator
# protractor calculator
# scienfic calculator
# scienfitic calculator
# therethe calculator
# calculator today
# great calculator
# calculator production
# l calculator
# other calculator
# old calculator
# larger calculator
